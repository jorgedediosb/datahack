# %% [markdown]
# # Ejercicio: Query Documents
#
# El objetivo de este notebook es afianzar todos los conocimientos que hemos visto hasta ahora tanto en clase como en los ejercicios sobre búsquedas con find sobre MongoDB.
#
# Antes de empezar con los ejercicios, vamos a familiarizarnos con los datos que queremos consultar.
#
# Vamos a crear la colección 'restaurants' donde insertaremos datos sobre restaurantes. Los documentos almacenan la siguiente información:
#
# `
# {
#   "address": {
#      "building": "1007",
#      "coord": [ -73.856077, 40.848447 ],
#      "street": "Morris Park Ave",
#      "zipcode": "10462"
#   },
#   "borough": "Bronx",
#   "cuisine": "Bakery",
#   "grades": [
#      { "date": { "$date": 1393804800000 }, "grade": "A", "score": 2 },
#      { "date": { "$date": 1378857600000 }, "grade": "A", "score": 6 },
#      { "date": { "$date": 1358985600000 }, "grade": "A", "score": 10 },
#      { "date": { "$date": 1322006400000 }, "grade": "A", "score": 9 },
#      { "date": { "$date": 1299715200000 }, "grade": "B", "score": 14 }
#   ],
#   "name": "Morris Park Bake Shop",
#   "restaurant_id": "30075445"
# }
# `

# %% [markdown]
# Antes de nada vamos a importar las librerías que necesitamos para acceder a MongoDB.
#
# ¡¡¡HE CREADO UN CÓDIGO PARA IMPORTAR DOCUMENTOS EVITANDO LOS REPETIDOS!!!
#
# * Ejecutar únicamente el código: "IMPORTACIÓN PARA EVITAR DOCUMENTOS REPETIDOS"

# %%
import pymongo
from pymongo import MongoClient

# %% [markdown]
# Creamos la conexión a MongoDB y borramos la base de datos que utilizaremos en este notebook para limpiar el entorno de posibles ejecuciones anteriores.

# %%
client = MongoClient('mongodb://nosql:nosql@mongo:27017/')

client.drop_database("notebook_dos")

# %% [markdown]
# Creamos la base de datos para el notebook.

# %%
db = client["ejercicio_dos"]

# %% [markdown]
# Ahora vamos a insertar los datos en la colección que acabas de crear para realizar los ejercicios.
#
# Los datos los encontrarás en la carpeta work/data/mongoDB en el fichero restaurants.json. Cada línea del fichero representa un documento con la información de un restaurante.
#
# Vamos ha crear unos métodos para recorrer el fichero, parsearlo en formato JSON e insertarlo en la colección.

# %%
from bson.json_util import loads

# Recibe una colección y un documento en formato JSON.
# Inserta el documento en la colección.
def insert_document(collection, document):
    try:
        collection.insert_one(document)
    except:
        pass

# %%
import sys
from bson.json_util import loads

# Recibe la url de un fichero que contiene los documentos a insertar y la colección donde tiene que insertarlos.
# Recorre el fichero indicado, parsea cada línea en formato JSON y llama al método insert_document para que inserte
# el documento parseado en la colección.
def import_file(file_path, collection):
    document_file = open(file_path, "r")

    for line in document_file:
        document = loads(line)
        insert_document(collection, document)

# %%
restaurants_path = '../data/mongoDB/restaurants.json'

# Realizamos la importación utilizando los métodos definidos en las celdas superiores
import_file(restaurants_path, db.restaurants)

# %%
# IMPORTACIÓN PARA EVITAR DOCUMENTOS REPETIDOS:

import pymongo
from pymongo import MongoClient
from bson.json_util import loads

# Conéctate a la base de datos
client = MongoClient('mongodb://nosql:nosql@mongo:27017/')
client.drop_database("notebook_dos")
db = client["ejercicio_dos"]

# Elimina la colección 'restaurants' si ya existe
if 'restaurants' in db.list_collection_names():
    db.drop_collection('restaurants')

# Recibe una colección y un documento en formato JSON.
# Inserta el documento en la colección solo si no existe previamente.
def insert_document(collection, document):
    try:
        # Verifica si existe un documento con los mismos valores en todos los campos
        existing_document = collection.find_one({field: document[field] for field in document})
        
        # Si no existe, inserta el nuevo documento
        if not existing_document:
            collection.insert_one(document)
    except:
        pass

# Recibe la url de un fichero que contiene los documentos a insertar y la colección donde tiene que insertarlos.
# Recorre el fichero indicado, parsea cada línea en formato JSON y llama al método insert_document para que inserte
# el documento parseado en la colección.
def import_file(file_path, collection):
    document_file = open(file_path, "r")

    for line in document_file:
        document = loads(line)
        insert_document(collection, document)

restaurants_path = '../data/mongoDB/restaurants.json'

# Realizamos la importación utilizando los métodos definidos en las celdas superiores
import_file(restaurants_path, db.restaurants)

# %% [markdown]
# Comprobamos que la insercción se ha realizado correctamente.

# %%
all_restaurants = db.restaurants.find({}).limit(5)

for restaurant in all_restaurants:
    print(restaurant)
# Out:
# {'_id': ObjectId('65df17a47377fb2e6cd15572'), 'address': {'building': '1007', 'coord': [-73.856077, 40.848447], 'street': 'Morris Park Ave', 'zipcode': '10462'}, 'borough': 'Bronx', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 9, 11, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2013, 1, 24, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 3, 10, 0, 0), 'grade': 'B', 'score': 14}], 'name': 'Morris Park Bake Shop', 'restaurant_id': '30075445'}
# {'_id': ObjectId('65df17a47377fb2e6cd15573'), 'address': {'building': '469', 'coord': [-73.961704, 40.662942], 'street': 'Flatbush Avenue', 'zipcode': '11225'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 12, 30, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2014, 7, 1, 0, 0), 'grade': 'B', 'score': 23}, {'date': datetime.datetime(2013, 4, 30, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 12}], 'name': "Wendy'S", 'restaurant_id': '30112340'}
# {'_id': ObjectId('65df17a47377fb2e6cd15574'), 'address': {'building': '351', 'coord': [-73.98513559999999, 40.7676919], 'street': 'West   57 Street', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'Irish', 'grades': [{'date': datetime.datetime(2014, 9, 6, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 7, 22, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 7, 31, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 12, 29, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Dj Reynolds Pub And Restaurant', 'restaurant_id': '30191841'}
# {'_id': ObjectId('65df17a47377fb2e6cd15575'), 'address': {'building': '2780', 'coord': [-73.98241999999999, 40.579505], 'street': 'Stillwell Avenue', 'zipcode': '11224'}, 'borough': 'Brooklyn', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 6, 10, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 6, 5, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 4, 13, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 10, 12, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Riviera Caterer', 'restaurant_id': '40356018'}
# {'_id': ObjectId('65df17a47377fb2e6cd15576'), 'address': {'building': '97-22', 'coord': [-73.8601152, 40.7311739], 'street': '63 Road', 'zipcode': '11374'}, 'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0), 'grade': 'Z', 'score': 20}, {'date': datetime.datetime(2013, 1, 17, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 8, 2, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 12, 15, 0, 0), 'grade': 'B', 'score': 25}], 'name': 'Tov Kosher Kitchen', 'restaurant_id': '40356068'}

# %% [markdown]
# ## Ejercicios:
#
# Realiza los siguientes ejercicios sobre la colección que hemos creado.

# %% [markdown]
# 1. Escribe una consulta que muestre todos los documentos en la colección de restaurantes.

# %%
# Mostrar colecciones existentes
collections = db.list_collection_names()

for collection in collections:
    print(collection)
# Out:
# restaurants

# %%
# Mostrar nº de restaurantes en la colección
num_restaurants = db.restaurants.count_documents({})
print(f"Número de restaurantes en la colección: {num_restaurants}")
# Out:
# Número de restaurantes en la colección: 3772

# %%
# Mostrar todos los documentos de 'restaurants'
restaurants = db.restaurants.find()
for restaurant in restaurants:
    print(restaurant)

# %%
# Mostrar todos los restaurantes repetidos basándose en el 'name':
duplicates = db.restaurants.aggregate([
    {"$group": {"_id": "$name", "count": {"$sum": 1}}},
    {"$match": {"count": {"$gt": 1}}}
])

for duplicate in duplicates:
    print("Duplicate Name:", duplicate["_id"], "- Count:", duplicate["count"])
# Out:
# Duplicate Name: Pronto Pizza - Count: 2
# Duplicate Name: Lenny'S Pizza - Count: 2
# Duplicate Name: Souen Restaurant - Count: 2
# Duplicate Name: Da Vinci Pizza - Count: 2
# Duplicate Name: Health King - Count: 2
# Duplicate Name: Bella Napoli - Count: 2
# Duplicate Name: Happy Garden - Count: 2
# Duplicate Name: Coffee Shop - Count: 2
# Duplicate Name: John'S Pizzeria - Count: 2
# Duplicate Name: Bravo Pizza - Count: 2
# Duplicate Name: Joe'S Shanghai Restaurant - Count: 2
# Duplicate Name: Jackson Hole - Count: 5
# Duplicate Name: Minar Indian Restaurant - Count: 2
# Duplicate Name: Caridad Restaurant - Count: 2
# Duplicate Name: Napoli Pizza - Count: 2
# Duplicate Name: Cafe Metro - Count: 3
# Duplicate Name: Gino'S Pizza - Count: 4
# Duplicate Name: Famous Famiglia Pizza - Count: 2
# Duplicate Name: Hornado Ecuatoriano - Count: 2
# Duplicate Name: Phoebe'S - Count: 2
# Duplicate Name: Juniors - Count: 2
# Duplicate Name: Patsy'S Pizzeria - Count: 3
# Duplicate Name: Juice Generation - Count: 2
# Duplicate Name: Tim Hortons - Count: 2
# Duplicate Name: Zaro'S Bakery - Count: 2
# Duplicate Name: Mike'S Coffee Shop - Count: 2
# Duplicate Name: Barnes & Noble Cafe - Count: 3
# Duplicate Name: Tai Pan Bakery - Count: 2
# Duplicate Name: Bally Total Fitness - Count: 2
# Duplicate Name: Pret A Manger - Count: 2
# Duplicate Name: The Country Cafe - Count: 2
# Duplicate Name: Mariella Pizza - Count: 2
# Duplicate Name: Omonia Cafe - Count: 2
# Duplicate Name: Starbucks Coffee - Count: 104
# Duplicate Name: Duke'S - Count: 2
# Duplicate Name: Pizza Hut - Count: 9
# Duplicate Name: French Roast - Count: 2
# Duplicate Name: White Castle - Count: 26
# Duplicate Name: Carvel Ice Cream - Count: 9
# Duplicate Name: Devon & Blakely - Count: 4
# Duplicate Name: Heartland Brewery - Count: 2
# Duplicate Name: Boston Market - Count: 13
# Duplicate Name: The Bread Factory Cafe - Count: 2
# Duplicate Name: Arturo'S Pizza - Count: 2
# Duplicate Name: Mercury Bar - Count: 2
# Duplicate Name: Emerald Pub - Count: 2
# Duplicate Name: Rocco'S Pizzeria - Count: 3
# Duplicate Name: Alfonso'S Pastry Shoppe - Count: 2
# Duplicate Name: Delmonico Gourmet - Count: 2
# Duplicate Name: Haagen-Dazs - Count: 4
# Duplicate Name: Connecticut Muffin - Count: 3
# Duplicate Name: Palm Restaurant - Count: 2
# Duplicate Name: Cilantro - Count: 2
# Duplicate Name: Bourbon Street - Count: 2
# Duplicate Name: Murray'S Bagels - Count: 2
# Duplicate Name: Chuck E Cheese'S - Count: 2
# Duplicate Name: Popeyes Chicken & Biscuits - Count: 11
# Duplicate Name: Ali'S Roti Shop - Count: 2
# Duplicate Name: John'S Pizza - Count: 2
# Duplicate Name: Dallas Bbq - Count: 4
# Duplicate Name: Baskin Robbins - Count: 3
# Duplicate Name: Perkins Family Restaurant & Bakery - Count: 3
# Duplicate Name: Dunkin' Donuts, Baskin Robbins - Count: 6
# Duplicate Name: Subway - Count: 7
# Duplicate Name: Pomodoro Ristorante - Count: 2
# Duplicate Name: Carmine'S - Count: 2
# Duplicate Name: Ihop - Count: 7
# Duplicate Name: Great Wall Restaurant - Count: 2
# Duplicate Name: Le Pain Quotidien - Count: 3
# Duplicate Name: Nathan'S Famous - Count: 2
# Duplicate Name: Sushiden - Count: 2
# Duplicate Name: Haru - Count: 3
# Duplicate Name: Zaro'S Bread Basket - Count: 5
# Duplicate Name: White Horse Tavern - Count: 2
# Duplicate Name: Burger King - Count: 37
# Duplicate Name: Playwright Celtic Pub - Count: 2
# Duplicate Name: T.G.I. Friday'S - Count: 6
# Duplicate Name: Papa John'S - Count: 2
# Duplicate Name: Mcdonald'S - Count: 83
# Duplicate Name: Glen Patrick'S Pub - Count: 2
# Duplicate Name: Richmond County Country Club - Count: 2
# Duplicate Name: T.G.I. Fridays - Count: 2
# Duplicate Name: The University Club - Count: 3
# Duplicate Name: Peking Duck House - Count: 2
# Duplicate Name: Country Donuts - Count: 2
# Duplicate Name: Four Seasons Hotel - Count: 2
# Duplicate Name: Wendy'S - Count: 11
# Duplicate Name: Master Wok - Count: 2
# Duplicate Name: Domino'S Pizza - Count: 40
# Duplicate Name: El Mariachi Restaurant - Count: 2
# Duplicate Name: Amy'S Bread - Count: 2
# Duplicate Name: Boulevard Tavern - Count: 2
# Duplicate Name: San Loco - Count: 2
# Duplicate Name: Hale & Hearty Soups - Count: 8
# Duplicate Name: Tony'S Pizzeria & Restaurant - Count: 2
# Duplicate Name: Flute - Count: 2
# Duplicate Name: Toast - Count: 2
# Duplicate Name: Applebee'S Neighborhood Grill & Bar - Count: 6
# Duplicate Name: Brother Jimmy'S Bbq - Count: 2
# Duplicate Name: Le Petit Cafe - Count: 2
# Duplicate Name: Fay Da Bakery - Count: 2
# Duplicate Name: Dunkin' Donuts - Count: 22
# Duplicate Name: Golden Krust Caribbean Bakery & Grill - Count: 6
# Duplicate Name: Pax Wholesome Foods - Count: 2
# Duplicate Name: Michael'S Restaurant - Count: 2
# Duplicate Name: Au Bon Pain - Count: 12
# Duplicate Name: Tony'S Pizza - Count: 3
# Duplicate Name: Ray'S Pizza - Count: 2
# Duplicate Name: Mikes Pizza - Count: 2
# Duplicate Name: Blimpie - Count: 2
# Duplicate Name: Tony'S Pizzeria - Count: 2
# Duplicate Name: Uno Chicago Grill - Count: 5
# Duplicate Name: Tous Les Jours - Count: 3
# Duplicate Name: Bella Luna - Count: 2
# Duplicate Name: Gino'S Pizzeria - Count: 2
# Duplicate Name: Europa Cafe - Count: 4
# Duplicate Name: Arturo'S - Count: 2
# Duplicate Name: Costco Wholesale - Count: 2

# %%
# Mostrar nº de restaurantes con un nombre concreto:
duplicates = db.restaurants.aggregate([
    {"$group": {"_id": "$name", "count": {"$sum": 1}}},
    {"$match": {"count": {"$gt": 1}}}
])

# Mostrar los restaurantes con un nombre concreto
nombre_restaurante = "Amy'S Bread"

num_restaurantes_con_nombre = db.restaurants.count_documents({"name": nombre_restaurante})
print(f"Número de restaurantes con el nombre '{nombre_restaurante}': {num_restaurantes_con_nombre}")
# Out:
# Número de restaurantes con el nombre 'Amy'S Bread': 2

# %%
# Mostrar los restaurantes con un nombre concreto
consulta = db.restaurants.find({"name": "Amy'S Bread"})
for item in consulta:
    print(item)
# Out:
# {'_id': ObjectId('65df17a77377fb2e6cd15af9'), 'address': {'building': '672', 'coord': [-73.990218, 40.7612], 'street': '9 Avenue', 'zipcode': '10036'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 11, 28, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 12, 13, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 7, 18, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 3, 4, 0, 0), 'grade': 'C', 'score': 10}, {'date': datetime.datetime(2012, 1, 27, 0, 0), 'grade': 'A', 'score': 9}], 'name': "Amy'S Bread", 'restaurant_id': '40424894'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b9a'), 'address': {'building': '75', 'coord': [-74.00489689999999, 40.7419343], 'street': 'Ninth Avenue', 'zipcode': '10011'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 2, 14, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 9, 17, 0, 0), 'grade': 'A', 'score': 0}, {'date': datetime.datetime(2012, 9, 18, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2011, 9, 20, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2011, 3, 23, 0, 0), 'grade': 'A', 'score': 11}], 'name': "Amy'S Bread", 'restaurant_id': '40526104'}

# %% [markdown]
# 2. Escribe una sentencia que muestre todos los campos restaurant_id, name, borough y cuisine de todos los documentos de la colección de restaurantes.

# %%
consulta = db.restaurants.find({},{"_id":0, "restaurant_id":1, "name":1, "borough":1, "cuisine":1})
for restaurantes in consulta:
    print(restaurantes)
# Out:
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'name': 'Morris Park Bake Shop', 'restaurant_id': '30075445'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Wendy'S", 'restaurant_id': '30112340'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Dj Reynolds Pub And Restaurant', 'restaurant_id': '30191841'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Riviera Caterer', 'restaurant_id': '40356018'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'name': 'Tov Kosher Kitchen', 'restaurant_id': '40356068'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Brunos On The Boulevard', 'restaurant_id': '40356151'}
# {'borough': 'Staten Island', 'cuisine': 'Jewish/Kosher', 'name': 'Kosher Island', 'restaurant_id': '40356442'}
# {'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': "Wilken'S Fine Food", 'restaurant_id': '40356483'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Regina Caterers', 'restaurant_id': '40356649'}
# {'borough': 'Brooklyn', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Taste The Tropics Ice Cream', 'restaurant_id': '40356731'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Wild Asia', 'restaurant_id': '40357217'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'C & C Catering Service', 'restaurant_id': '40357437'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'May May Kitchen', 'restaurant_id': '40358429'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '1 East 66Th Street Kitchen', 'restaurant_id': '40359480'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Seuda Foods', 'restaurant_id': '40360045'}
# {'borough': 'Brooklyn', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Carvel Ice Cream', 'restaurant_id': '40360076'}
# {'borough': 'Queens', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Carvel Ice Cream', 'restaurant_id': '40361322'}
# {'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': 'Nordic Delicacies', 'restaurant_id': '40361390'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Glorious Food', 'restaurant_id': '40361521'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'The Movable Feast', 'restaurant_id': '40361606'}
# {'borough': 'Queens', 'cuisine': 'Delicatessen', 'name': "Sal'S Deli", 'restaurant_id': '40361618'}
# {'borough': 'Manhattan', 'cuisine': 'Delicatessen', 'name': "Bully'S Deli", 'restaurant_id': '40361708'}
# {'borough': 'Queens', 'cuisine': 'Delicatessen', 'name': "Steve Chu'S Deli & Grocery", 'restaurant_id': '40361998'}
# {'borough': 'Manhattan', 'cuisine': 'Chicken', 'name': "Harriet'S Kitchen", 'restaurant_id': '40362098'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'P & S Deli Grocery', 'restaurant_id': '40362264'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Angelika Film Center', 'restaurant_id': '40362274'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': 'White Castle', 'restaurant_id': '40362344'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': 'Ho Mei Restaurant', 'restaurant_id': '40362432'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'The Country Cafe', 'restaurant_id': '40362715'}
# {'borough': 'Brooklyn', 'cuisine': 'Caribbean', 'name': "Shashemene Int'L Restaura", 'restaurant_id': '40362869'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Downtown Deli', 'restaurant_id': '40363021'}
# {'borough': 'Bronx', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Carvel Ice Cream', 'restaurant_id': '40363093'}
# {'borough': 'Brooklyn', 'cuisine': 'Donuts', 'name': "Dunkin' Donuts", 'restaurant_id': '40363098'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Mejlander & Mulgannon', 'restaurant_id': '40363117'}
# {'borough': 'Manhattan', 'cuisine': 'Bakery', 'name': "Olive'S", 'restaurant_id': '40363151'}
# {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden', 'restaurant_id': '40363289'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Metro', 'restaurant_id': '40363298'}
# {'borough': 'Queens', 'cuisine': 'Delicatessen', 'name': "Tony'S Deli", 'restaurant_id': '40363333'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Lexler Deli', 'restaurant_id': '40363426'}
# {'borough': 'Staten Island', 'cuisine': 'Delicatessen', 'name': 'Bagels N Buns', 'restaurant_id': '40363427'}
# {'borough': 'Queens', 'cuisine': 'Bagels/Pretzels', 'name': 'Hot Bagels', 'restaurant_id': '40363565'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Snack Time Grill', 'restaurant_id': '40363590'}
# {'borough': 'Manhattan', 'cuisine': 'Continental', 'name': "Lorenzo & Maria'S", 'restaurant_id': '40363630'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': "Domino'S Pizza", 'restaurant_id': '40363644'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Berkely', 'restaurant_id': '40363685'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Sonny'S Heros", 'restaurant_id': '40363744'}
# {'borough': 'Staten Island', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Carvel Ice Cream', 'restaurant_id': '40363834'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'Golden Pavillion', 'restaurant_id': '40363920'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': "Domino'S Pizza", 'restaurant_id': '40363945'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Spoon Bread Catering', 'restaurant_id': '40364179'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Kosher Bagel Hole', 'restaurant_id': '40364220'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Terminal Cafe/Yankee Clipper', 'restaurant_id': '40364262'}
# {'borough': 'Staten Island', 'cuisine': 'Delicatessen', 'name': 'Plaza Bagels & Deli', 'restaurant_id': '40364286'}
# {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden', 'restaurant_id': '40364296'}
# {'borough': 'Staten Island', 'cuisine': 'Delicatessen', 'name': 'B & M Hot Bagel & Grocery', 'restaurant_id': '40364299'}
# {'borough': 'Manhattan', 'cuisine': 'Chicken', 'name': 'Texas Rotisserie', 'restaurant_id': '40364304'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Philadelhia Grille Express', 'restaurant_id': '40364305'}
# {'borough': 'Brooklyn', 'cuisine': 'Steak', 'name': 'Peter Luger Steakhouse', 'restaurant_id': '40364335'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Metropolitan Club', 'restaurant_id': '40364347'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Palm Restaurant', 'restaurant_id': '40364355'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '21 Club', 'restaurant_id': '40364362'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Manhem Club', 'restaurant_id': '40364363'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Isle Of Capri Resturant', 'restaurant_id': '40364373'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Old Town Bar & Restaurant', 'restaurant_id': '40364389'}
# {'borough': 'Brooklyn', 'cuisine': 'Polish', 'name': 'Polish National Home', 'restaurant_id': '40364404'}
# {'borough': 'Manhattan', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': 'Seville Restaurant', 'restaurant_id': '40364439'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Criminal Court Bldg Cafeteria', 'restaurant_id': '40364443'}
# {'borough': 'Queens', 'cuisine': 'German', 'name': 'Gottscheer Hall', 'restaurant_id': '40364449'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nyac Main Dining Room', 'restaurant_id': '40364467'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '7B Bar', 'restaurant_id': '40364518'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'name': 'Ben-Best Deli & Restaurant', 'restaurant_id': '40364529'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Atelier (Art Students League)', 'restaurant_id': '40364531'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Donohue'S Steak House", 'restaurant_id': '40364572'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Tout Va Bien', 'restaurant_id': '40364576'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Junior'S", 'restaurant_id': '40364581'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Great Kills Yacht Club', 'restaurant_id': '40364610'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Marchis Restaurant', 'restaurant_id': '40364668'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Towne Cafe', 'restaurant_id': '40364681'}
# {'borough': 'Manhattan', 'cuisine': 'Continental', 'name': 'Dining Room', 'restaurant_id': '40364691'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Old Homestead', 'restaurant_id': '40364715'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': 'New Park Pizzeria & Restaurant', 'restaurant_id': '40364744'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Douglaston Club', 'restaurant_id': '40364858'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Serendipity 3', 'restaurant_id': '40364863'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Melody Lanes', 'restaurant_id': '40364889'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': "Rizzo'S Fine Pizza", 'restaurant_id': '40364920'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'The New Starling Athletic Club Of The Bronx', 'restaurant_id': '40364956'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'White Horse Tavern', 'restaurant_id': '40364958'}
# {'borough': 'Staten Island', 'cuisine': 'Italian', 'name': 'Crystal Room', 'restaurant_id': '40365013'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Labetti'S Post # 2159", 'restaurant_id': '40365022'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Shell Lanes', 'restaurant_id': '40365043'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Mcsorley'S Old Ale House", 'restaurant_id': '40365075'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Forlinis Restaurant', 'restaurant_id': '40365098'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'South Shore Swimming Club', 'restaurant_id': '40365120'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Corner Bistro', 'restaurant_id': '40365166'}
# {'borough': 'Brooklyn', 'cuisine': 'Donuts', 'name': 'Nostrand Donut Shop', 'restaurant_id': '40365226'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Dorrian'S Red Hand Restaurant", 'restaurant_id': '40365239'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'La Grenouille', 'restaurant_id': '40365264'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': 'Como Pizza', 'restaurant_id': '40365280'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Keats Restaurant', 'restaurant_id': '40365288'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Angelo Of Mulberry St.', 'restaurant_id': '40365293'}
# {'borough': 'Manhattan', 'cuisine': 'Mexican', 'name': "Panchito'S", 'restaurant_id': '40365348'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'New Corner', 'restaurant_id': '40365355'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Princeton Club', 'restaurant_id': '40365361'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Arturo'S", 'restaurant_id': '40365387'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Le Perigord', 'restaurant_id': '40365414'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Reynold'S Bar", 'restaurant_id': '40365423'}
# {'borough': 'Staten Island', 'cuisine': 'Pizza/Italian', 'name': "Joe & Pat'S Pizzeria", 'restaurant_id': '40365454'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Spain Restaurant & Bar', 'restaurant_id': '40365472'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Palace Cafe', 'restaurant_id': '40365473'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Yankee Tavern', 'restaurant_id': '40365499'}
# {'borough': 'Manhattan', 'cuisine': 'Donuts', 'name': 'Donut Pub', 'restaurant_id': '40365525'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Moran'S Chelsea", 'restaurant_id': '40365526'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Reben Luncheonette', 'restaurant_id': '40365546'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'V & T Restaurant', 'restaurant_id': '40365577'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': 'King Yum Restaurant', 'restaurant_id': '40365592'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Jahn'S Restaurant", 'restaurant_id': '40365627'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': 'J&V Famous Pizza', 'restaurant_id': '40365632'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'La Parisienne Diner', 'restaurant_id': '40365633'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Joe Allen Restaurant', 'restaurant_id': '40365644'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Joyce'S Tavern", 'restaurant_id': '40365692'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Il Vagabondo Restaurant', 'restaurant_id': '40365709'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Barbetta Restaurant', 'restaurant_id': '40365726'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': "Gargiulo'S Restaurant", 'restaurant_id': '40365784'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Patsy'S Italian Restaurant", 'restaurant_id': '40365789'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Parkside Restaurant', 'restaurant_id': '40365841'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Lavelle'S Admiral'S Club", 'restaurant_id': '40365844'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Neary'S Pub", 'restaurant_id': '40365871'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': 'New York Pizza Suprema', 'restaurant_id': '40365882'}
# {'borough': 'Bronx', 'cuisine': 'Irish', 'name': 'Mcdwyers Pub', 'restaurant_id': '40365893'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Mee Sum Coffee Shop', 'restaurant_id': '40365904'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Nancy'S Fire Side", 'restaurant_id': '40365938'}
# {'borough': 'Manhattan', 'cuisine': 'Chinese', 'name': 'Hop Kee Restaurant', 'restaurant_id': '40365942'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nancy Whiskey Pub', 'restaurant_id': '40365968'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Blarney Bar', 'restaurant_id': '40365972'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': 'Margherita Pizza', 'restaurant_id': '40366002'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Healy'S Pub", 'restaurant_id': '40366054'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Fifth Avenue Bingo', 'restaurant_id': '40366109'}
# {'borough': 'Staten Island', 'cuisine': 'Pizza/Italian', 'name': "Denino'S Pizzeria Tavern", 'restaurant_id': '40366132'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': "Michael'S Restaurant", 'restaurant_id': '40366154'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Nanni Restaurant', 'restaurant_id': '40366157'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Lenihan'S Saloon", 'restaurant_id': '40366162'}
# {'borough': 'Queens', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': 'Emilio Iii Bar', 'restaurant_id': '40366214'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Killarney Rose', 'restaurant_id': '40366222'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Don Peppe', 'restaurant_id': '40366230'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Blarney Castle', 'restaurant_id': '40366356'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Three Star Restaurant', 'restaurant_id': '40366361'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Blarney Rock', 'restaurant_id': '40366379'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Dangerfield'S Night Club", 'restaurant_id': '40366381'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Desmond'S Tavern", 'restaurant_id': '40366396'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'name': 'Naomi Kosher Pizza', 'restaurant_id': '40366425'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Roll-N-Roaster', 'restaurant_id': '40366471'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Tio Pepe', 'restaurant_id': '40366473'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Brennan & Carr', 'restaurant_id': '40366487'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'The Punch Bowl', 'restaurant_id': '40366497'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': 'Jardin De China Rest', 'restaurant_id': '40366543'}
# {'borough': 'Queens', 'cuisine': 'Irish', 'name': 'Irish Cottage', 'restaurant_id': '40366549'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Blarney Stone', 'restaurant_id': '40366574'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'name': 'Shimons Kosher Pizza', 'restaurant_id': '40366586'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Riviera Cafe', 'restaurant_id': '40366643'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': "Fascati'S Pizzeria", 'restaurant_id': '40366652'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': "Baby Bo'S Burritos", 'restaurant_id': '40366661'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Li Greci'S Staaten Restaurant", 'restaurant_id': '40366711'}
# {'borough': 'Manhattan', 'cuisine': 'Chinese', 'name': 'Shun Lee Palace Restaurant', 'restaurant_id': '40366716'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Tamaqua', 'restaurant_id': '40366742'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Munchtime', 'restaurant_id': '40366748'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Cara Mia', 'restaurant_id': '40366812'}
# {'borough': 'Bronx', 'cuisine': 'Pancakes/Waffles', 'name': 'Ihop', 'restaurant_id': '40366833'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Maloney'S Bar", 'restaurant_id': '40366857'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'La Fusta Restaurant', 'restaurant_id': '40366879'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Richmond County Country Club', 'restaurant_id': '40366928'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Little Brown Jug', 'restaurant_id': '40366929'}
# {'borough': 'Bronx', 'cuisine': 'Café/Coffee/Tea', 'name': "Lulu'S Coffee Shop", 'restaurant_id': '40366938'}
# {'borough': 'Brooklyn', 'cuisine': 'Soul Food', 'name': "Mitchell'S Restaurant", 'restaurant_id': '40366961'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'El Charro Espanol', 'restaurant_id': '40366987'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Finnegan'S Wake", 'restaurant_id': '40366993'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'Da Vinci Pizza', 'restaurant_id': '40367005'}
# {'borough': 'Manhattan', 'cuisine': 'Mexican', 'name': 'Mexico Lindo Restaurant', 'restaurant_id': '40367038'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Marina Delray', 'restaurant_id': '40367161'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'New Floridian Diner', 'restaurant_id': '40367164'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Twins Pub', 'restaurant_id': '40367179'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Narrows Coffee Shop', 'restaurant_id': '40367183'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broome Street Bar', 'restaurant_id': '40367189'}
# {'borough': 'Queens', 'cuisine': 'Irish', 'name': "O'Hanlon'S Pub", 'restaurant_id': '40367232'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Charlies Sports Bar', 'restaurant_id': '40367240'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jg Melon Restaurant', 'restaurant_id': '40367241'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': "Jack'S Pizza & Pasta", 'restaurant_id': '40367278'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Emerald Pub', 'restaurant_id': '40367329'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tap Room', 'restaurant_id': '40367338'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cocktail Room (Nyac)', 'restaurant_id': '40367339'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Flame Restaurant Coffee House', 'restaurant_id': '40367365'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jackson Hole', 'restaurant_id': '40367373'}
# {'borough': 'Queens', 'cuisine': 'German', 'name': 'Zum Stammtisch', 'restaurant_id': '40367377'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "John'S Restaurant", 'restaurant_id': '40367407'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Grassroot Tavern', 'restaurant_id': '40367420'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Buddy'S Wonder Bar", 'restaurant_id': '40367442'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Assembly Bar', 'restaurant_id': '40367481'}
# {'borough': 'Manhattan', 'cuisine': 'Jewish/Kosher', 'name': 'Mr Broadway Kosher Restaurant', 'restaurant_id': '40367534'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Piccola Venezia', 'restaurant_id': '40367540'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Malaga Restaurant', 'restaurant_id': '40367544'}
# {'borough': 'Staten Island', 'cuisine': 'Italian', 'name': "Ni-Ni'S Cafe", 'restaurant_id': '40367570'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Capitol Restaurant', 'restaurant_id': '40367677'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'La Bonne Soupe Bistro', 'restaurant_id': '40367715'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Mimis Restaurant & Bar', 'restaurant_id': '40367728'}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': "Lenny'S Clam Bar", 'restaurant_id': '40367749'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Griffis Faculty Club', 'restaurant_id': '40367752'}
# {'borough': 'Manhattan', 'cuisine': 'Hotdogs', 'name': "Gray'S Papaya", 'restaurant_id': '40367766'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': 'Dani Pizza And Restaurant', 'restaurant_id': '40367789'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40367790'}
# {'borough': 'Brooklyn', 'cuisine': 'Greek', 'name': 'El Greco Diner', 'restaurant_id': '40367795'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'One If By Land Two If By Sea', 'restaurant_id': '40367797'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40367829'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Fiorellos', 'restaurant_id': '40367841'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'Lb Spumoni Gardens', 'restaurant_id': '40367860'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': 'Amore Pizzeria & Restaurant', 'restaurant_id': '40367870'}
# {'borough': 'Bronx', 'cuisine': 'Not Listed/Not Applicable', 'name': "The Lark'S Nest", 'restaurant_id': '40367946'}
# {'borough': 'Bronx', 'cuisine': 'Café/Coffee/Tea', 'name': 'Terrace Cafe', 'restaurant_id': '40368018'}
# {'borough': 'Bronx', 'cuisine': 'African', 'name': 'African Terrace', 'restaurant_id': '40368021'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Cool Zone', 'restaurant_id': '40368022'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Beaver Pond', 'restaurant_id': '40368025'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'African Market (Baboon Cafe)', 'restaurant_id': '40368026'}
# {'borough': 'Staten Island', 'cuisine': 'Italian', 'name': 'Roadhouse Restaurant', 'restaurant_id': '40368034'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ford Foundation Cafeteria', 'restaurant_id': '40368065'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Elephant & Castle', 'restaurant_id': '40368157'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Mill Basin Kosher Deli', 'restaurant_id': '40368207'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Oyster Bar', 'restaurant_id': '40368223'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cherry Tavern', 'restaurant_id': '40368271'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Colonnade Diner', 'restaurant_id': '40368291'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Red Flame Diner', 'restaurant_id': '40368313'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Maggies Place', 'restaurant_id': '40368318'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Brady'S Bar", 'restaurant_id': '40368338'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Da Silvano Restaurant', 'restaurant_id': '40368346'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Benjamin', 'restaurant_id': '40368370'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Jimmy'S Corner", 'restaurant_id': '40368374'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Frost Restaurant', 'restaurant_id': '40368526'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Sammy'S Steakhouse", 'restaurant_id': '40368552'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Il Cortile Restaurant', 'restaurant_id': '40368555'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Denny'S Pub", 'restaurant_id': '40368577'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Maries Crisis Cafe', 'restaurant_id': '40368581'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Boots & Saddle Bar', 'restaurant_id': '40368617'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'New Parkway Restaurant', 'restaurant_id': '40368632'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Cafe Riazor', 'restaurant_id': '40368725'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Raouls', 'restaurant_id': '40368752'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Brook', 'restaurant_id': '40368763'}
# {'borough': 'Queens', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': 'Marbella Restaurant', 'restaurant_id': '40368801'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "P.J.' S", 'restaurant_id': '40368809'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Hatsuhana Restaurant', 'restaurant_id': '40368897'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'La Mangeoire', 'restaurant_id': '40368971'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': "Valentino'S Pizza", 'restaurant_id': '40369012'}
# {'borough': 'Manhattan', 'cuisine': 'Greek', 'name': 'Viand Coffee Shop', 'restaurant_id': '40369016'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Palm Too', 'restaurant_id': '40369017'}
# {'borough': 'Queens', 'cuisine': 'Café/Coffee/Tea', 'name': "Steve'S Coffee Shop", 'restaurant_id': '40369051'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Blue Bay Restaurant', 'restaurant_id': '40369087'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Nada-Sushi', 'restaurant_id': '40369097'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'The Hytes Bar', 'restaurant_id': '40369111'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Pergola Des Artistes', 'restaurant_id': '40369139'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Jody'S Club", 'restaurant_id': '40369158'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Reif'S Tavern", 'restaurant_id': '40369165'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Whitestone Lanes', 'restaurant_id': '40369213'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': "John'S Pizzeria", 'restaurant_id': '40369262'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Seashore Restaurant', 'restaurant_id': '40369299'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'White Horse Tavern', 'restaurant_id': '40369400'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Caffe Reggio', 'restaurant_id': '40369418'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Cafe Un Deux Trois', 'restaurant_id': '40369461'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': "Armando'S Pizza", 'restaurant_id': '40369482'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Dan Tempura', 'restaurant_id': '40369495'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Knickerbocker Bar & Grill', 'restaurant_id': '40369521'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40369535'}
# {'borough': 'Manhattan', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': 'El Pote Espanol', 'restaurant_id': '40369580'}
# {'borough': 'Brooklyn', 'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Capri', 'restaurant_id': '40369597'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Bronx Grill', 'restaurant_id': '40369601'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'The River Cafe', 'restaurant_id': '40369608'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mudville Saloon', 'restaurant_id': '40369619'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Johnny'S Reef Restaurant", 'restaurant_id': '40369641'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': 'White Castle', 'restaurant_id': '40369667'}
# {'borough': 'Bronx', 'cuisine': 'Hamburgers', 'name': 'White Castle', 'restaurant_id': '40369669'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'White Castle', 'restaurant_id': '40369675'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': 'White Castle', 'restaurant_id': '40369676'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': "Ferdinando'S Restaurant", 'restaurant_id': '40369716'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40369724'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Viand Cafe', 'restaurant_id': '40369753'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nectar Coffee Shop', 'restaurant_id': '40369759'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Cupping Room', 'restaurant_id': '40369775'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40369782'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Pete'S Tavern", 'restaurant_id': '40369810'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': "Gino'S Pizzeria", 'restaurant_id': '40369849'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Jim Brady'S Restaurant", 'restaurant_id': '40369869'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Villa Mosconi Restaurant', 'restaurant_id': '40369878'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': "P & K'S Grill", 'restaurant_id': '40369895'}
# {'borough': 'Bronx', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40369915'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Reme Restaurant', 'restaurant_id': '40369928'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The New Amity Restaurant', 'restaurant_id': '40369940'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Volare Restaurant', 'restaurant_id': '40369954'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Sparks Steak House', 'restaurant_id': '40369958'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Dart Inn', 'restaurant_id': '40369983'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': "Bamonte'S Restaurant", 'restaurant_id': '40370015'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': 'Pizza Town', 'restaurant_id': '40370091'}
# {'borough': 'Manhattan', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40370146'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': "John Mulligan'S Fireside Pub", 'restaurant_id': '40370150'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40370167'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ear Inn', 'restaurant_id': '40370168'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40370238'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40370239'}
# {'borough': 'Manhattan', 'cuisine': 'Indian', 'name': 'Mughlai Restaurant', 'restaurant_id': '40370243'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Greenpoint Tavern', 'restaurant_id': '40370342'}
# {'borough': 'Staten Island', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40370356'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': "Tony'S Pizzeria", 'restaurant_id': '40370425'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Rossini'S", 'restaurant_id': '40370436'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Pat'S Stationary", 'restaurant_id': '40370449'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Three Guy'S Restaurant", 'restaurant_id': '40370463'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Cucina Vivolo', 'restaurant_id': '40370497'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Players Club', 'restaurant_id': '40370507'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Divers Cove', 'restaurant_id': '40370519'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Tjk Cafe & Restaurant', 'restaurant_id': '40370638'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Cafe Espanol', 'restaurant_id': '40370759'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Smith & Wollensky', 'restaurant_id': '40370766'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40370781'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Olive Tree Cafe & Comedy Cellar', 'restaurant_id': '40370856'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Perkins Family Restaurant & Bakery', 'restaurant_id': '40370910'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40370916'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40370917'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Tokubei 86', 'restaurant_id': '40370935'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Manducatis', 'restaurant_id': '40370939'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sizzler', 'restaurant_id': '40370946'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Mama Lucia', 'restaurant_id': '40370994'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Coliseum Bar Restaurant', 'restaurant_id': '40371281'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': 'Mariella Pizza', 'restaurant_id': '40371313'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': "Vinny'S Pizza", 'restaurant_id': '40371323'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Kosher Delight', 'restaurant_id': '40371419'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'West Bank Cafe', 'restaurant_id': '40371454'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Four Seasons', 'restaurant_id': '40371588'}
# {'borough': 'Queens', 'cuisine': 'French', 'name': 'La Baraka Restaurant', 'restaurant_id': '40371614'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Dairy Luncheonette', 'restaurant_id': '40371684'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Zafi'S Luncheonette", 'restaurant_id': '40371718'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'La Palina Restaurant', 'restaurant_id': '40371727'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Schaffer'S Tavern", 'restaurant_id': '40371771'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Ty'S", 'restaurant_id': '40371805'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': "Aunt Bella'S Rest Of Little Neck", 'restaurant_id': '40371807'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Mariner Inn', 'restaurant_id': '40371906'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'North Shore Diner', 'restaurant_id': '40371988'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Exclusive Catering', 'restaurant_id': '40372016'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Green House Cafe', 'restaurant_id': '40372112'}
# {'borough': 'Bronx', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40372196'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Water Front Crab House', 'restaurant_id': '40372258'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'La Ripaille Restaurant', 'restaurant_id': '40372262'}
# {'borough': 'Staten Island', 'cuisine': 'Italian', 'name': 'Marina Cafe', 'restaurant_id': '40372357'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Don Filippo Restaurant', 'restaurant_id': '40372417'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40372422'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Dazies Restaurant', 'restaurant_id': '40372426'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Triestes Restaurant', 'restaurant_id': '40372433'}
# {'borough': 'Queens', 'cuisine': 'Greek', 'name': 'Omonia Cafe', 'restaurant_id': '40372445'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Murals On 54/Randolphs'S", 'restaurant_id': '40372466'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Veterans Of Foreign Wars Post #107 Canteen', 'restaurant_id': '40372485'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': 'Caruso Pizza #2', 'restaurant_id': '40372523'}
# {'borough': 'Brooklyn', 'cuisine': 'Bakery', 'name': 'Tropical House Baking Co.', 'restaurant_id': '40372596'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': 'Burger King', 'restaurant_id': '40372618'}
# {'borough': 'Bronx', 'cuisine': 'Pizza', 'name': 'Yankee Jz Pizza', 'restaurant_id': '40372631'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Clinton Restaurant', 'restaurant_id': '40372694'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Shabu-Shabu 70 Restaurant', 'restaurant_id': '40372787'}
# {'borough': 'Staten Island', 'cuisine': 'Chinese', 'name': "Chen'S Chinese", 'restaurant_id': '40372831'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Greek Corner', 'restaurant_id': '40372944'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Racquet & Tennis Club', 'restaurant_id': '40372971'}
# {'borough': 'Brooklyn', 'cuisine': 'Mexican', 'name': 'Casa Pepe', 'restaurant_id': '40372999'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Astro Restaurant', 'restaurant_id': '40373113'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Golden Dove Diner', 'restaurant_id': '40373118'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Caffe Dante', 'restaurant_id': '40373149'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'Korner Pizzeria', 'restaurant_id': '40373160'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Henry'S End", 'restaurant_id': '40373272'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Souen Restaurant', 'restaurant_id': '40373318'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Villa Berulia', 'restaurant_id': '40373462'}
# {'borough': 'Manhattan', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': "Victor'S Cafe", 'restaurant_id': '40373500'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'Petes Pizzeria & Restaurant', 'restaurant_id': '40373597'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Keens Steakhouse', 'restaurant_id': '40373656'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bar 515', 'restaurant_id': '40373669'}
# {'borough': 'Queens', 'cuisine': 'Irish', 'name': 'Ready Penny Inn', 'restaurant_id': '40373794'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Il Mulino', 'restaurant_id': '40373888'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Felidia Restaurant', 'restaurant_id': '40373889'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40373909'}
# {'borough': 'Manhattan', 'cuisine': 'Armenian', 'name': 'The Malt House', 'restaurant_id': '40373912'}
# {'borough': 'Manhattan', 'cuisine': 'Chinese', 'name': 'Shun Lee', 'restaurant_id': '40373937'}
# {'borough': 'Bronx', 'cuisine': 'Pancakes/Waffles', 'name': 'Ihop', 'restaurant_id': '40373938'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Bridgeview Diner', 'restaurant_id': '40373948'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Burke'S Pub", 'restaurant_id': '40373984'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Hill Tap Tavern', 'restaurant_id': '40374015'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Pongsri Thai Restaurant', 'restaurant_id': '40374088'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza/Italian', 'name': 'Primavera Pizza & Pasta', 'restaurant_id': '40374131'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Tony'S Pier Restaurant", 'restaurant_id': '40374136'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Elio'S", 'restaurant_id': '40374192'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Quality Cafe & Restaurant', 'restaurant_id': '40374259'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Kasteli Ii', 'restaurant_id': '40374266'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': 'Victoria Pizza', 'restaurant_id': '40374268'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': 'Molly Wee Pub', 'restaurant_id': '40374277'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'La Mediterranee Restaurant', 'restaurant_id': '40374325'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'El Caribe', 'restaurant_id': '40374395'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Omen Japanese Cuisine', 'restaurant_id': '40374415'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40374460'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40374507'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Bar Vetro', 'restaurant_id': '40374559'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Rosie O'Grady Restaurant", 'restaurant_id': '40374711'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Europa Go-Go Dancing', 'restaurant_id': '40374814'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Casa Bella', 'restaurant_id': '40374834'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Raccoon Lodge', 'restaurant_id': '40374968'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Chez Napolean', 'restaurant_id': '40374974'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Turkey'S Nest Tavern", 'restaurant_id': '40375108'}
# {'borough': 'Bronx', 'cuisine': 'Chinese/Cuban', 'name': 'Sabrosura Restaurant', 'restaurant_id': '40375136'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': 'La Villa De Pizza & Restaurant', 'restaurant_id': '40375286'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': 'Ozone Pizzeria', 'restaurant_id': '40375369'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Ponticello Restaurant', 'restaurant_id': '40375371'}
# {'borough': 'Manhattan', 'cuisine': 'Indian', 'name': 'Agra Restaurant', 'restaurant_id': '40375376'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Lindy'S", 'restaurant_id': '40375521'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Arturo'S", 'restaurant_id': '40375616'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Paris Blues', 'restaurant_id': '40375634'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Gene'S Resturant", 'restaurant_id': '40375699'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Maria Ristorante', 'restaurant_id': '40375819'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cozy Soup & Burger', 'restaurant_id': '40375839'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': "Neron'S Pizza", 'restaurant_id': '40375899'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Villa Fiorita', 'restaurant_id': '40375929'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Vegas Diner', 'restaurant_id': '40375972'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Moms Luncheonette', 'restaurant_id': '40376029'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Candle Bar', 'restaurant_id': '40376031'}
# {'borough': 'Manhattan', 'cuisine': 'Jewish/Kosher', 'name': 'Tevere 84', 'restaurant_id': '40376039'}
# {'borough': 'Manhattan', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Haagen-Dazs', 'restaurant_id': '40376067'}
# {'borough': 'Queens', 'cuisine': 'Greek', 'name': 'Fontana Famous Pizza & Gyro', 'restaurant_id': '40376077'}
# {'borough': 'Manhattan', 'cuisine': 'Chinese', 'name': "Charlie'S Mom Chinese Restaurant", 'restaurant_id': '40376121'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Lusardi'S Restaurant", 'restaurant_id': '40376142'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Portofino', 'restaurant_id': '40376204'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "King'S Arms Restaurant", 'restaurant_id': '40376290'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Blue Note Jazz', 'restaurant_id': '40376352'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'The Water Club', 'restaurant_id': '40376493'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Marco Polo Ristorante', 'restaurant_id': '40376495'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Manhattan Monster', 'restaurant_id': '40376496'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'American Museum Of Natural History Food Court', 'restaurant_id': '40376515'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'War Memorial Ice Skating Rink', 'restaurant_id': '40376583'}
# {'borough': 'Brooklyn', 'cuisine': 'Mediterranean', 'name': 'Tripoli Restaurant', 'restaurant_id': '40376635'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Chez Jaqueline', 'restaurant_id': '40376687'}
# {'borough': 'Manhattan', 'cuisine': 'Delicatessen', 'name': 'Pj Bernstein Deli & Restaurant', 'restaurant_id': '40376718'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'name': "Pj Carney'S", 'restaurant_id': '40376735'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Water'S Edge Club", 'restaurant_id': '40376933'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Tomoe Sushi', 'restaurant_id': '40376944'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Amsterdam Restaurant & Tapas Lounge', 'restaurant_id': '40377111'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Jp'S Waterside Restaurant", 'restaurant_id': '40377124'}
# {'borough': 'Queens', 'cuisine': 'Irish', 'name': 'Rogers Irish Tavern', 'restaurant_id': '40377164'}
# {'borough': 'Bronx', 'cuisine': 'Pizza/Italian', 'name': 'John & Joe Pizzeria & Restaurant', 'restaurant_id': '40377243'}
# {'borough': 'Staten Island', 'cuisine': 'Pizza/Italian', 'name': 'Sunset Pizzeria', 'restaurant_id': '40377262'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40377294'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Utopia Restaurant', 'restaurant_id': '40377299'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jackson Hole', 'restaurant_id': '40377325'}
# {'borough': 'Queens', 'cuisine': 'Italian', 'name': 'Napoli Pizza', 'restaurant_id': '40377385'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'Vesuvio Restaurant & Pizza', 'restaurant_id': '40377506'}
# {'borough': 'Queens', 'cuisine': 'Caribbean', 'name': 'Western Bakery', 'restaurant_id': '40377560'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Johns Cafe & Resturant', 'restaurant_id': '40377630'}
# {'borough': 'Manhattan', 'cuisine': 'Greek', 'name': 'Karavas Place', 'restaurant_id': '40377698'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Cafe Luxembourg', 'restaurant_id': '40377789'}
# ...
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Angelique', 'restaurant_id': '40875888'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Chase Edr', 'restaurant_id': '40875955'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Re: Sources', 'restaurant_id': '40876068'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Cipriani Dolci', 'restaurant_id': '40876078'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Jerry'S 637 Diner", 'restaurant_id': '40876297'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': 'San Remo Pizzeria', 'restaurant_id': '40876361'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': 'Corato I Pizza & Restaurant', 'restaurant_id': '40876472'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Bijan'S", 'restaurant_id': '40876618'}
# {'borough': 'Queens', 'cuisine': 'Caribbean', 'name': 'Crystal Curry House', 'restaurant_id': '40876695'}
# {'borough': 'Bronx', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Carvel', 'restaurant_id': '40876932'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Daddy'S", 'restaurant_id': '40877242'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Fordham University - Millenium Grill', 'restaurant_id': '40877246'}
# {'borough': 'Queens', 'cuisine': 'Greek', 'name': "Zorba'S", 'restaurant_id': '40877247'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': "Tony'S Pizzeria & Restaurant", 'restaurant_id': '40877264'}
# {'borough': 'Bronx', 'cuisine': 'Delicatessen', 'name': 'Fordham University - Student Deli', 'restaurant_id': '40877285'}
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'name': 'La Nueva Giralda Bakery', 'restaurant_id': '40877421'}
# {'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': 'Point View Deli', 'restaurant_id': '40877738'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': "J 'S Pizza", 'restaurant_id': '40877741'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Sports Center Cafe', 'restaurant_id': '40877855'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': "Papa John'S", 'restaurant_id': '40877857'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': "Moti'S", 'restaurant_id': '40878231'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Soy', 'restaurant_id': '40878403'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Don Pedro Restaurant', 'restaurant_id': '40878507'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Sapporo Restaurant', 'restaurant_id': '40878590'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': 'Taco Bell Pizza Hut Express', 'restaurant_id': '40878675'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Barclay'S Capital", 'restaurant_id': '40878687'}
# {'borough': 'Queens', 'cuisine': 'Bakery', 'name': 'Girasol Bakery', 'restaurant_id': '40878775'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Kitchenette Uptown', 'restaurant_id': '40879015'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Hyatt, Ny Central/Room Service', 'restaurant_id': '40879243'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Grand Hyatt New York Hotel', 'restaurant_id': '40879245'}
# {'borough': 'Queens', 'cuisine': 'Pizza', 'name': "Domino'S Pizza", 'restaurant_id': '40879347'}
# {'borough': 'Manhattan', 'cuisine': 'Caribbean', 'name': 'Negril', 'restaurant_id': '40879743'}
# {'borough': 'Manhattan', 'cuisine': 'German', 'name': 'Heidelberg Restaurant', 'restaurant_id': '40880188'}
# {'borough': 'Queens', 'cuisine': 'French', 'name': 'Tournesol', 'restaurant_id': '40880194'}
# {'borough': 'Queens', 'cuisine': 'Irish', 'name': 'Tavern Lounge', 'restaurant_id': '40880365'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Starbucks Coffee', 'restaurant_id': '40880619'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Starbucks Coffee', 'restaurant_id': '40880634'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Blue Smoke', 'restaurant_id': '40880715'}
# {'borough': 'Brooklyn', 'cuisine': 'Caribbean', 'name': "Q'S Tavern", 'restaurant_id': '40880741'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'The Trash Bar', 'restaurant_id': '40880866'}
# {'borough': 'Brooklyn', 'cuisine': 'Thai', 'name': 'Ott Thai Cuisine', 'restaurant_id': '40880867'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Digby'S", 'restaurant_id': '40880990'}
# {'borough': 'Queens', 'cuisine': 'Hamburgers', 'name': "Mcdonald'S", 'restaurant_id': '40881083'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Soda Bar', 'restaurant_id': '40881088'}
# {'borough': 'Manhattan', 'cuisine': 'Chinese', 'name': 'Ling Kee Beef Jerky', 'restaurant_id': '40881416'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Big Daddy'S Diner", 'restaurant_id': '40881492'}
# {'borough': 'Manhattan', 'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Juice Generation', 'restaurant_id': '40881627'}
# {'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': 'Bari Sandwich Shop', 'restaurant_id': '40881703'}
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': 'Subway', 'restaurant_id': '40881793'}
# {'borough': 'Brooklyn', 'cuisine': 'Mediterranean', 'name': 'Moto', 'restaurant_id': '40882044'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Sports Center At Chelsea Piers (Sushi Bar)', 'restaurant_id': '40882356'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Whaler Bar, Cafe Buon Giorno', 'restaurant_id': '40882359'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'New York University - Palladium Food Court', 'restaurant_id': '40882360'}
# {'borough': 'Queens', 'cuisine': 'Bakery', 'name': 'El Hornero Bakery', 'restaurant_id': '40882663'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jones Reavis & Pague Llp', 'restaurant_id': '40882732'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': 'Verona Pizza', 'restaurant_id': '40882825'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Brendan'S", 'restaurant_id': '40882849'}
# {'borough': 'Staten Island', 'cuisine': 'Donuts', 'name': "Dunkin' Donuts", 'restaurant_id': '40883049'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Toast', 'restaurant_id': '40883548'}
# {'borough': 'Bronx', 'cuisine': 'Irish', 'name': 'Sheas Emerald', 'restaurant_id': '40883581'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Eurest Dining Service (American Express)', 'restaurant_id': '40883586'}
# {'borough': 'Brooklyn', 'cuisine': 'Caribbean', 'name': "Joyce'S West Indies Restaurant", 'restaurant_id': '40883740'}
# {'borough': 'Bronx', 'cuisine': 'Caribbean', 'name': 'Memories Lounge', 'restaurant_id': '40883866'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'American Express', 'restaurant_id': '40884041'}
# {'borough': 'Manhattan', 'cuisine': 'Barbecue', 'name': 'Dallas Bbq', 'restaurant_id': '40884320'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': '111 Restaurant', 'restaurant_id': '40884354'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Carlow East', 'restaurant_id': '40884395'}
# {'borough': 'Queens', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': 'El Cuencanito', 'restaurant_id': '40884503'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Java Girl', 'restaurant_id': '40884510'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': 'Yao Wah Kitchen', 'restaurant_id': '40884708'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': "Domino'S Pizza", 'restaurant_id': '40884718'}
# {'borough': 'Manhattan', 'cuisine': 'Delicatessen', 'name': 'Ny Hot Jumbo Bagels', 'restaurant_id': '40884743'}
# {'borough': 'Brooklyn', 'cuisine': 'Italian', 'name': 'Doc Wine Bar', 'restaurant_id': '40884999'}
# {'borough': 'Queens', 'cuisine': 'Donuts', 'name': "Dunkin' Donuts", 'restaurant_id': '40885010'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': "Patsy'S Pizzeria Restaurant", 'restaurant_id': '40885315'}
# {'borough': 'Manhattan', 'cuisine': 'Hamburgers', 'name': 'Jimbos Hamburger Palace', 'restaurant_id': '40885326'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Swiss International Airlines Lounge', 'restaurant_id': '40885333'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Dolcino Trattoria Toscana', 'restaurant_id': '40885415'}
# {'borough': 'Bronx', 'cuisine': 'Caribbean', 'name': 'Roca Tone Seafood Restaurant', 'restaurant_id': '40885478'}
# {'borough': 'Queens', 'cuisine': 'Bakery', 'name': 'Rico Pan Bakery', 'restaurant_id': '40885485'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Applebee'S Neighborhood Grill & Bar", 'restaurant_id': '40885643'}
# {'borough': 'Manhattan', 'cuisine': 'Indian', 'name': 'Amma', 'restaurant_id': '40885805'}
# {'borough': 'Manhattan', 'cuisine': 'Delicatessen', 'name': "Danny'S Deli", 'restaurant_id': '40885816'}
# {'borough': 'Manhattan', 'cuisine': 'Korean', 'name': 'Kunjip Restaurant', 'restaurant_id': '40885968'}
# {'borough': 'Bronx', 'cuisine': 'Pizza', 'name': 'The Best Italian Pizza', 'restaurant_id': '40886422'}
# {'borough': 'Queens', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': "Jennifer'S Restaurant", 'restaurant_id': '40886435'}
# {'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'name': "D'Angelo'S Pizzeria And Restaurant", 'restaurant_id': '40886613'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Canard Inc', 'restaurant_id': '40886675'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': "Harry'O", 'restaurant_id': '40886786'}
# {'borough': 'Manhattan', 'cuisine': 'French', 'name': 'Marquet Fine Pastry', 'restaurant_id': '40887092'}
# {'borough': 'Brooklyn', 'cuisine': 'Mexican', 'name': 'Alma', 'restaurant_id': '40887208'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Johnny Pumps', 'restaurant_id': '40887371'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Barbes', 'restaurant_id': '40887518'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Pencil Factory', 'restaurant_id': '40887622'}
# {'borough': 'Manhattan', 'cuisine': 'Italian', 'name': 'Lamarca Pasta Restaurant', 'restaurant_id': '40887926'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sullivan & Cromwell', 'restaurant_id': '40887930'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza/Italian', 'name': "Danny'S Pizzeria & Cafe", 'restaurant_id': '40887949'}
# {'borough': 'Brooklyn', 'cuisine': 'Middle Eastern', 'name': 'Yemen Cuisine', 'restaurant_id': '40888097'}
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': 'Subway', 'restaurant_id': '40888264'}
# {'borough': 'Manhattan', 'cuisine': 'Mexican', 'name': 'San Loco', 'restaurant_id': '40888633'}
# {'borough': 'Manhattan', 'cuisine': 'Chicken', 'name': 'Popeyes Chicken & Biscuits', 'restaurant_id': '40888787'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': 'New China Kitchen', 'restaurant_id': '40889213'}
# {'borough': 'Brooklyn', 'cuisine': 'Jewish/Kosher', 'name': 'Amazon Cafe', 'restaurant_id': '40889582'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Uno Cafe & Billiards', 'restaurant_id': '40889676'}
# {'borough': 'Manhattan', 'cuisine': 'Greek', 'name': 'Ethos Greek Cuisine', 'restaurant_id': '40889792'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Casa Java', 'restaurant_id': '40889838'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'White & Case', 'restaurant_id': '40889924'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Snafu', 'restaurant_id': '40890184'}
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'name': 'J.E. Bakery', 'restaurant_id': '40890186'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'Happy Restaurant', 'restaurant_id': '40890246'}
# {'borough': 'Bronx', 'cuisine': 'Soul Food', 'name': 'Cea Lo Cafe', 'restaurant_id': '40890407'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'China New Star', 'restaurant_id': '40890510'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': "Mug-Z'S Sports Bar", 'restaurant_id': '40891377'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Hotel Carlyle', 'restaurant_id': '40891446'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Regal Entertainment Group', 'restaurant_id': '40891782'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'A & B Deli & Catering', 'restaurant_id': '40891881'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Euzkadi', 'restaurant_id': '40891976'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ernst & Young Cafe', 'restaurant_id': '40892252'}
# {'borough': 'Queens', 'cuisine': 'Korean', 'name': "Park'S Snack", 'restaurant_id': '40892367'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'New No 1 Chinese Restaurant', 'restaurant_id': '40892468'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'The Usual Restaurant', 'restaurant_id': '40892777'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Yakiniku West Restaurant', 'restaurant_id': '40892845'}
# {'borough': 'Bronx', 'cuisine': 'Pizza/Italian', 'name': "Frank'S Pizzeria", 'restaurant_id': '40892887'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Mirage Diner Restauraunt', 'restaurant_id': '40892893'}
# {'borough': 'Brooklyn', 'cuisine': 'Pizza', 'name': "Jojo'S Pizza", 'restaurant_id': '40892913'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Coffee Shop', 'restaurant_id': '40893443'}
# {'borough': 'Manhattan', 'cuisine': 'Pizza', 'name': "Domino'S Pizza", 'restaurant_id': '40893866'}
# {'borough': 'Queens', 'cuisine': 'Chinese', 'name': "Annie'S Kitchen", 'restaurant_id': '40894025'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nublu', 'restaurant_id': '40894333'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Ruth'S Chris Steak House", 'restaurant_id': '40894838'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Blimpie', 'restaurant_id': '40895206'}
# {'borough': 'Manhattan', 'cuisine': 'Bagels/Pretzels', 'name': 'The Liberty Cafe (S.I. Newhouse)', 'restaurant_id': '40895766'}
# {'borough': 'Manhattan', 'cuisine': 'Bagels/Pretzels', 'name': 'Eat-A-Bagel (Andrew J. Barbery Ferry Boat)', 'restaurant_id': '40895769'}
# {'borough': 'Brooklyn', 'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)', 'name': "Ramonita'S Restaurant", 'restaurant_id': '40895911'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Court Order', 'restaurant_id': '40896929'}
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'name': 'Nb. National Bakery', 'restaurant_id': '40897418'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Beauty Bar', 'restaurant_id': '40897437'}
# {'borough': 'Queens', 'cuisine': 'Caribbean', 'name': 'Golden Krust Caribbean Bakery & Grill', 'restaurant_id': '40897493'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tsq Brasserie', 'restaurant_id': '40897685'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Renaissance Hotel', 'restaurant_id': '40897778'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups', 'restaurant_id': '40898273'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Ashby'S Specialty", 'restaurant_id': '40898366'}
# {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Rainbow Restaurant', 'restaurant_id': '40899178'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'La Villita Restaurant', 'restaurant_id': '40899209'}
# {'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'name': 'Starbucks Coffee', 'restaurant_id': '40899767'}
# {'borough': 'Brooklyn', 'cuisine': 'Café/Coffee/Tea', 'name': "Andy'S Cafeteria", 'restaurant_id': '40899816'}
# {'borough': 'Manhattan', 'cuisine': 'Japanese', 'name': 'Sushi Zen', 'restaurant_id': '40899971'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe', 'restaurant_id': '40900039'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'Chopstix Restaurant', 'restaurant_id': '40900694'}

# %% [markdown]
# 3. Escribe ina sentencia que muestre los campos restaurant_id, name, borough y cuisine y que excluya del resultado el campo _id para todos los documentos de la colección de restaurantes.

# %%
consulta = db.restaurants.find({},{"restaurant_id":1, "name":1, "borough":1, "cuisine":1, "_id":0})
for restaurantes in consulta:
    print(restaurantes)

# %% [markdown]
# 4. Escribe una sentencia que muestre los campos restaurant_id, name, borough y zip code y que excluya del resultado el campo _id para todos los documentos de la colección de restaurantes.

# %%
consulta = db.restaurants.find({}, {"restaurant_id":1, "name":1, "borough":1, "address.zipcode":1, "_id":0})
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 5. Escribe una sentencia que muestre todos los restaurantes que se encuentren en el Bronx.

# %%
consulta = db.restaurants.find({'borough':'Bronx'}, {"name":1, "_id":0})
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 6. Escribe una sentencia que muestre los 5 primeros restaurantes que se encuentran en el Bronx.

# %%
consulta = db.restaurants.find({'borough':'Bronx'}, {"name":1, "_id":0}).limit(5)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 7. Escribe una sentencia que muestre los siguientes 5 restaurantes del Bronx despues de obviar los 5 primeros.

# %%
consulta = db.restaurants.find({'borough':'Bronx'}, {"name":1, "_id":0}).skip(5).limit(5)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 8. Escribe una sentencia que encuentre los restaurantes que han recibido una puntuación mayor de 90.

# %%
consulta = db.restaurants.find({'grades.score':{"$gt":90}}, {"name": 1, "_id":0})
for restaurants in consulta:
    print(restaurants)
# Out:
# {'name': "Murals On 54/Randolphs'S"}
# {'name': 'Gandhi'}
# {'name': 'Bella Napoli'}

# %% [markdown]
# 9. Escribe una sentencia que encuentre los restaurantes que han recibido una puntuación mayor de 80 pero menor de 100.

# %%
consulta = db.restaurants.find({'grades.score':{"$gt":80, "$lt": 100}}, {"name":1, "_id":0})
for restaurants in consulta:
    print(restaurants)
# Out:
# {'name': "Murals On 54/Randolphs'S"}
# {'name': 'Gandhi'}
# {'name': 'Bella Napoli'}
# {'name': 'West 79Th Street Boat Basin Cafe'}

# %% [markdown]
# 10. Escribe una sentencia que busque los restaurantes que se encuentran a menos de -95.754168 de latitud.

# %%
consulta = db.restaurants.find({'address.coord':{"$lt": -95.754168}}, {"name":1, "_id":0})
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 11. Escribe una sentencia que busque los restaurantes que no preparen cocina americana ('American') y su puntuación sea mayor de 70 y se encuentren a una altitud menor de -65.754168.
#
# **Nota**: Realizala utilizándo el operador $and.

# %%
consulta = db.restaurants.find(
    {
        "$and": [
            {"cuisine": {"$ne": "American"}},
            {"grades.score": {"$gt": 70}},
            {"address.coord": {"$lt": -65.754168}}
        ]
    }, {'name':1, '_id':0}
)
for restaurants in consulta:
    print(restaurants)
# Out:
# {'name': "Murals On 54/Randolphs'S"}
# {'name': 'Gandhi'}
# {'name': 'Live Bait Bar & Restaurant'}
# {'name': 'Bella Napoli'}
# {'name': 'El Molino Rojo Restaurant'}
# {'name': 'Fortunato Bros Cafe & Bakery'}
# {'name': 'B.B. Kings'}
# {'name': 'Two Boots Grand Central'}
# {'name': 'West 79Th Street Boat Basin Cafe'}

# %% [markdown]
# 12. Escribe una sentencia que busque los restaurantes que no preparen cocina americana ('American') y su puntuación sea mayor de 70 y se encuentren a una altitud menor de -65.754168.
#
# **Nota**: Realizala sin utilizar el operador $and.

# %%
consulta = db.restaurants.find(
    {
    "cuisine": {"$ne": "American"},
    "grades.score": {"$gt": 70},
    "address.coord": {"$lt": -65.754168}
    },
    {"name":1, "_id":0}
)
for restaurants in consulta:
    print(restaurants)
# Out:
# {'name': "Murals On 54/Randolphs'S"}
# {'name': 'Gandhi'}
# {'name': 'Live Bait Bar & Restaurant'}
# {'name': 'Bella Napoli'}
# {'name': 'El Molino Rojo Restaurant'}
# {'name': 'Fortunato Bros Cafe & Bakery'}
# {'name': 'B.B. Kings'}
# {'name': 'Two Boots Grand Central'}
# {'name': 'West 79Th Street Boat Basin Cafe'}

# %% [markdown]
# 13. Escribe una sentencia que busque restaurantes que no preparen cocina americana ('American') y hayan recibido una nota 'A' que no pertenezcan a Brooklyn.
#
# El resultado se debe mostrar por orden descendente del campo cuisine.

# %%
consulta = db.restaurants.find(
    {
        "cuisine": {"$ne": "American"},
        "grades.grade": "A",
        "borough": {"$ne": "Brooklyn"}
    }, {"name":1, "_id":0}
).sort("cuisine", -1)

for restaurants in consulta:
    print(restaurants)
# Out:
# {'name': 'Thai Son'}
# {'name': 'Pho Bac Vietnamese Seafood Cuisine'}
# {'name': 'Nha-Trang Centre Vietnam Restaurant'}
# {'name': 'Angelica Kitchen'}
# {'name': 'Candle Cafe'}
# {'name': 'Village Yogurt'}
# {'name': 'Village Natural'}
# {'name': 'Caravan Of Dreams'}
# {'name': 'Mana'}
# {'name': 'Red Bamboo'}
# {'name': 'The Country Cafe'}
# {'name': 'Turkish Kitchen'}
# {'name': 'Uskudar Restaurant'}
# {'name': 'Pasha Turkish Restaurant'}
# {'name': 'Kebab House'}
# {'name': 'Turkish Cuisine'}
# {'name': 'Turkuaz Turkish Cuisine'}
# {'name': 'Saharas Turkish Cuisine'}
# {'name': 'Pongsri Thai Restaurant'}
# {'name': 'Jaiya Thai Oriental Restaurant'}
# {'name': 'Topaz Thai Restaurant'}
# {'name': 'Arharn Thai Cuisine'}
# {'name': 'Bangkok Grand Palace'}
# {'name': 'Rohm Thai'}
# {'name': 'Cafe Asean'}
# {'name': "Bennie'S Thai Cafe"}
# {'name': 'Republic Restaurant'}
# {'name': 'Erawan Thai Cuisine'}
# {'name': 'Wondee Siam Ii'}
# {'name': "Baby Bo'S Burritos"}
# {'name': 'Burrito Loco'}
# {'name': 'Tortilla Flats'}
# {'name': 'Cowgirl Hall Of Fame'}
# {'name': 'Bennys Burritos'}
# {'name': "Benny'S Burritos"}
# {'name': "Harry'S Burrito Junction"}
# {'name': 'The Heights Bar & Grill'}
# {'name': 'Taco Bell'}
# {'name': 'Blockheads Burritos'}
# {'name': 'Burrito Box'}
# {'name': 'Kana Tapas Bar & Restaurant'}
# {'name': 'Cafe Ronda'}
# {'name': 'El Boqueron Tapas Bar & Restaurant'}
# {'name': 'Verlaine'}
# {'name': "Donohue'S Steak House"}
# {'name': "Sammy'S Steakhouse"}
# {'name': 'Sparks Steak House'}
# {'name': 'Keens Steakhouse'}
# {'name': 'Frankie & Johnnies Steakhouse'}
# {'name': 'Bliss Street Station Restaurant'}
# {'name': 'T-Bar Steak & Lounge'}
# {'name': "Bobby Van'S"}
# {'name': 'Quality Meats'}
# {'name': "Michael Jordan'S Steak House - In Grand Central"}
# {'name': 'Riverdale Steak House'}
# {'name': "My Uncle'S Steak Restaurant"}
# {'name': 'Wolf And Lamb'}
# {'name': "Del Frisco'S"}
# {'name': 'Palm Restaurant'}
# {'name': 'Hillstone Manhattan'}
# {'name': "Jake'S Steakhouse"}
# {'name': "Ruth'S Chris Steak House"}
# {'name': 'Spain Restaurant & Bar'}
# {'name': 'Tio Pepe'}
# {'name': 'La Fusta Restaurant'}
# {'name': 'El Charro Espanol'}
# {'name': 'Malaga Restaurant'}
# {'name': 'Cafe Riazor'}
# {'name': 'Cafe Espanol'}
# {'name': 'Cuchifritos'}
# {'name': 'Real Madrid Restaurant'}
# {'name': 'Ipanema Bar'}
# {'name': 'Caridad Restaurant'}
# {'name': 'Pollos A La Brasa'}
# {'name': 'Toledo'}
# {'name': 'Scorpio Bar'}
# {'name': 'El Olivo'}
# {'name': 'El Rinconcito Restaurant'}
# {'name': 'Los Arrieros Restaurant'}
# {'name': "Nelly'S Cafe"}
# {'name': 'Tierras Columbianas'}
# {'name': 'Riazor Blue Tapas Bar'}
# {'name': 'Cosmos Restaurant'}
# {'name': 'Don Coqui'}
# {'name': "El Chivito D'Oro Iii"}
# {'name': "Francisco'S Centro Vasco"}
# {'name': 'Bicheiros Bar'}
# {'name': "K'S Cafeteria"}
# {'name': 'Hornado Ecuatoriano'}
# {'name': 'Bravo Cafe Concert'}
# {'name': "Goody'S Spanish Food"}
# {'name': 'Euzkadi'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': 'Hale & Hearty Soups'}
# {'name': "Sam'S Restaurant"}
# {'name': 'Manna Restaurant Ii'}
# {'name': "Sylvia'S Restaurant"}
# {'name': 'Cea Lo Cafe'}
# {'name': "Lenny'S Clam Bar"}
# {'name': 'One If By Land Two If By Sea'}
# {'name': 'Oyster Bar'}
# {'name': 'Seashore Restaurant'}
# {'name': "Johnny'S Reef Restaurant"}
# {'name': "Tony'S Pier Restaurant"}
# {'name': 'The Water Club'}
# {'name': "Jp'S Waterside Restaurant"}
# {'name': 'London Lennies'}
# {'name': 'Pier 25A Restaurant'}
# {'name': 'Island'}
# {'name': 'Loui Seafood'}
# {'name': 'City Crab'}
# {'name': 'Elias Corner For Fish'}
# {'name': 'Aqua Grill'}
# {'name': 'Blue Water Grill'}
# {'name': 'Crab Shanty'}
# {'name': 'Estiatorio Milos'}
# {'name': 'Pearl'}
# {'name': 'Atlantic Grill'}
# {'name': 'El Tina Fish Market & Seafood Restaurant'}
# {'name': 'Black Whale'}
# {'name': 'Famous Fish Market'}
# {'name': 'Fish'}
# {'name': "Sammy'S Fishbox"}
# {'name': 'City Lobster & Steak'}
# {'name': 'Esca'}
# {'name': 'J & C Seafood'}
# {'name': 'A Salt & Battery'}
# {'name': "Mary'S Fish Camp"}
# {'name': 'Blue Fin'}
# {'name': 'Seafood  City'}
# {'name': 'Lexler Deli'}
# {'name': 'Devon & Blakely'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Bits Bite & Baguettes'}
# {'name': "Moe'S Southwestern Grill/Charley'S"}
# {'name': 'Au Bon Pain'}
# {'name': 'Le Pain Quotidien'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Le Bon Cafe'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Au Bon Pain'}
# {'name': 'Europa Cafe'}
# {'name': 'Subway'}
# {'name': 'Roy Rogers'}
# {'name': 'Le Pain Quotidien'}
# {'name': 'Food Fair Deli & Pizza'}
# {'name': 'Blimpie'}
# {'name': 'Le Pain Quotidien'}
# {'name': 'Pret A Manger'}
# {'name': 'Subway'}
# {'name': 'Subway'}
# {'name': 'Subway'}
# {'name': "Rocco'S Italian Sausages & Philly Cheesesteaks"}
# {'name': 'Pret A Manger'}
# {'name': "American Hero & Sub'S"}
# {'name': 'Subway'}
# {'name': 'Subway'}
# {'name': 'Subway'}
# {'name': 'Blimpie'}
# {'name': "Chop'T"}
# {'name': 'Russian Turkish Baths'}
# {'name': 'Russian Samovar'}
# {'name': 'Uncle Vanya'}
# {'name': 'Anyway Cafe'}
# {'name': 'Russia Vodka Room'}
# {'name': 'Mateus Restaurant'}
# {'name': 'Pao'}
# {'name': 'Little Poland Restaurant'}
# {'name': 'I.O. Cafe'}
# {'name': 'Neptune Polish Restaurant'}
# {'name': 'New Park Pizzeria & Restaurant'}
# {'name': "Joe & Pat'S Pizzeria"}
# {'name': "Denino'S Pizzeria Tavern"}
# {'name': "Jack'S Pizza & Pasta"}
# {'name': 'Amore Pizzeria & Restaurant'}
# {'name': "Valentino'S Pizza"}
# {'name': "Gino'S Pizzeria"}
# {'name': 'Primavera Pizza & Pasta'}
# {'name': 'Ozone Pizzeria'}
# {'name': 'John & Joe Pizzeria & Restaurant'}
# {'name': 'Sunset Pizzeria'}
# {'name': 'Pisa Pizzeria'}
# {'name': 'Phil & Sons Restaurant & Pizzeria'}
# {'name': "Ljubo'S Pizzeria"}
# {'name': 'Uno Chicago Grill'}
# {'name': 'Pomodoro Ristorante'}
# {'name': 'A & S Pizzeria'}
# {'name': "Vaccaro'S Pizzeria & Trattoria"}
# {'name': 'Bella Napoli'}
# {'name': 'Rosa #2 Pizzeria'}
# {'name': "Gennaro'S Rest & Pizzeria"}
# {'name': "Angelo'S Pizzeria/Mimmo'S Restaurant"}
# {'name': 'Mikes Pizza'}
# {'name': 'John & Tonys Pizza'}
# {'name': "Lombardi'S"}
# {'name': 'Plum Tomatoes Pizzeria & Restaurant'}
# {'name': "Daniello'S Pizzeria"}
# {'name': 'Tribeca Pizzeria'}
# {'name': 'Minitalia Pizzeria'}
# {'name': "Romeo'S Pizzeria"}
# {'name': 'Corato Pizza Ii'}
# {'name': "Lopez'S Pizzeria And Coffee Shop"}
# {'name': "Gino'S Pizzeria"}
# {'name': 'Picasso Pizzeria'}
# {'name': 'S S Calabro Pizzeria'}
# {'name': 'Xtra Cheese Pizzeria'}
# {'name': 'L. A. Pizzeria'}
# {'name': 'Yolanda Pizzeria Restaurant'}
# {'name': "Tony'S Brick Oven"}
# {'name': 'Perfecto Pizzeria'}
# {'name': 'Rossville Pizzeria'}
# {'name': "Patsy'S Pizzeria"}
# {'name': 'Barios Pizza & Restaurant'}
# {'name': "Francesco'S Pizzeria Restaurant"}
# {'name': "Peppino'S Pizzeria"}
# {'name': 'Pepe Joes Pizzeria'}
# {'name': "John'S Pizzeria"}
# {'name': "Donato'S Pizzeria Restaurant"}
# {'name': 'Ambrosinos Pizzeria'}
# {'name': "Dino'S Pizza & Pasta"}
# {'name': "Captain'S Pizzeria And Restaurant"}
# {'name': "Patsy'S Pizzeria"}
# {'name': "Patsy'S Pizzeria"}
# {'name': "Gaudio'S Pizzeria"}
# {'name': 'Phillies Pizzeria Ii'}
# {'name': 'Cafe Rustico Ii'}
# {'name': 'Casabianca Pizzeria'}
# {'name': 'Italian Village Restaurant Pizzeria'}
# {'name': "The Original Sal'S Pizzeria"}
# {'name': 'Broadway Pizza & Pasta'}
# {'name': "Cavallo'S Pizzeria"}
# {'name': "D'Angelo'S Pizzeria And Restaurant"}
# {'name': "Frank'S Pizzeria"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Rizzo'S Fine Pizza"}
# {'name': 'Como Pizza'}
# {'name': 'New York Pizza Suprema'}
# {'name': 'Margherita Pizza'}
# {'name': 'Dani Pizza And Restaurant'}
# {'name': "John'S Pizzeria"}
# {'name': 'Pizza Town'}
# {'name': 'Mariella Pizza'}
# {'name': "Vinny'S Pizza"}
# {'name': 'Caruso Pizza #2'}
# {'name': 'Yankee Jz Pizza'}
# {'name': 'La Villa De Pizza & Restaurant'}
# {'name': "Neron'S Pizza"}
# {'name': "Tony'S Pizza"}
# {'name': "Caesar'S Palace"}
# {'name': 'Carlos Pizza'}
# {'name': "Tommy'S Pizza"}
# {'name': "Gaby'S Pizza"}
# {'name': 'The Grotto'}
# {'name': 'Barone Pizza'}
# {'name': "Pizza D'Oro"}
# {'name': 'Dream Pizza'}
# {'name': 'Dairy Palace'}
# {'name': 'Pizza Garden'}
# {'name': "Ray'S Pizza"}
# {'name': 'Venice Pizza'}
# {'name': 'Karavas Pizza N Pita'}
# {'name': 'Sal And Carmine Pizza'}
# {'name': 'Sanremo Pizza'}
# {'name': "Arturo'S Pizza"}
# {'name': 'Lucky Pizza'}
# {'name': 'The Pizza Place'}
# {'name': 'Famous Famiglia Pizza'}
# {'name': 'Glendale Pizza'}
# {'name': 'Sacco Pizza'}
# {'name': 'Rivoli Pizza Restaurant'}
# {'name': "Vinny'S Famous Pizza"}
# {'name': 'Uno Chicago Grill'}
# {'name': "Rosa'S Pizza"}
# {'name': "Caterina'S Pizza"}
# {'name': 'Lazzaras Pizza Cafe'}
# {'name': 'Pronto Pizza'}
# {'name': "Salvatore And Lloyd'S Pizza"}
# {'name': 'Pizza Boy Ii'}
# {'name': 'San Remo Pizza'}
# {'name': "Abitino'S Pizza"}
# {'name': "Gino'S Pizzeria Restaurant"}
# {'name': 'Uno Chicago Grill'}
# {'name': 'Elmhurst Famous Pizza'}
# {'name': 'Golden Pizza'}
# {'name': 'Two Boots To Go-Go'}
# {'name': 'Pugsley Pizza'}
# {'name': 'Bravo Pizza'}
# {'name': 'Lucia Pizza'}
# {'name': "Nick'S Pizza"}
# {'name': 'Famous Pizza'}
# {'name': "Joe'S Pizza"}
# {'name': 'Singas Famous Pizza'}
# {'name': 'Pizza Chef'}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': 'Avellino Restaurant'}
# {'name': 'Village Maria Pizza Ii'}
# {'name': 'Two Boots To Go West'}
# {'name': 'City Pie'}
# {'name': 'Village Pizza'}
# {'name': 'Grand Avenue Pizza'}
# {'name': 'Pizza Park'}
# {'name': "Domino'S Pizza"}
# {'name': "Freddie & Pepper'S Pizza"}
# {'name': "Catania'S Pizza Cafe"}
# {'name': 'Full Moon Pizza'}
# {'name': 'Capri Ii Pizza'}
# {'name': "Arturo'S Pizza"}
# {'name': "Cascarino'S Pizza"}
# {'name': "Luigi'S Pizza & Restaurant"}
# {'name': 'Towne Deli & Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': "Alba'S Pizza"}
# {'name': 'Don Pepi Pizza'}
# {'name': "Ray'S Pizza Restuarant"}
# {'name': 'Mikes Pizza'}
# {'name': "Gigi'S Pizzeria"}
# {'name': "Ciro'S Pizza Restaurant"}
# {'name': 'Costco Wholesale'}
# {'name': "Rose'S Pizza"}
# {'name': "Marino'S Pizza & Restaurant"}
# {'name': "Domino'S Pizza"}
# {'name': 'Pizza Hut'}
# {'name': "Famous Joe'S Pizza"}
# {'name': 'Mariella Pizza'}
# {'name': "Mama Carmela'S"}
# {'name': "John'S Pizza"}
# {'name': 'Boston Pizza'}
# {'name': 'Ciro Pizza'}
# {'name': "John'S Pizza"}
# {'name': 'Majestic Pizza'}
# {'name': 'Stromboli Pizza'}
# {'name': 'Roccos Pizza'}
# {'name': 'Big Als Chicago Pizza'}
# {'name': 'Che Bella Pizza'}
# {'name': 'Famous Famiglia Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': "Polito'S Pizza"}
# {'name': "Fresh Meadow'S Pizza & Restaurant"}
# {'name': 'Capri Pizza Restaurant'}
# {'name': "Little Vincent'S Pizza Restaurant"}
# {'name': "Tony'S Pizza"}
# {'name': 'A-1 Pizza Shop'}
# {'name': 'Pizza Express'}
# {'name': 'Pizza Italia 1'}
# {'name': 'Belmora Pizza & Restaurant'}
# {'name': 'J And D Pizza'}
# {'name': "Ray'S Pizza"}
# {'name': 'J & S Pizza'}
# {'name': '10Th Avenue Pizza & Cafe'}
# {'name': 'Big Jons Pizza & Restaurant'}
# {'name': "Burek'S Pizza"}
# {'name': 'Bartow Pizza'}
# {'name': 'New Roma Pizza'}
# {'name': "Gary And Gino'S"}
# {'name': "Big Al'S Chicago Pizza"}
# {'name': 'Da Vinci Pizza'}
# {'name': "Ben'S Pizza"}
# {'name': 'Harbor Pizza'}
# {'name': 'Pepolino'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut/Wing Street'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': 'Pizza Hut'}
# {'name': "Rosario'S Pizza"}
# {'name': "Chuck E Cheese'S"}
# {'name': 'Gustosa Pizza'}
# {'name': 'Bravo Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': "Chuck E Cheese'S"}
# {'name': 'Market Place Pizza'}
# {'name': 'Pizza Jarden'}
# {'name': "Tom'S Delicious Pizza"}
# {'name': "Susie'S Pies"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Junior'S Cafe"}
# {'name': 'Samaria Pizza'}
# {'name': 'Little Italy Pizza'}
# {'name': "Cafe Amore'S Restaurant"}
# {'name': 'Morris Park Pizza'}
# {'name': 'Circle Pizzeria'}
# {'name': 'Bella Napoli'}
# {'name': 'Roma Pizza'}
# {'name': 'Pizza Palace'}
# {'name': 'Ponticello Baybridge Pizzeria & Restaurant'}
# {'name': 'Pizza Pub'}
# {'name': 'La Piazza Pizzeria & Restaurant'}
# {'name': 'Pizza Port'}
# {'name': 'Muzzarella Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': 'Sutton Pizza & Gyro'}
# {'name': 'Regina Pizza'}
# {'name': "Papa John'S"}
# {'name': "Gino'S Pizza"}
# {'name': 'Pizza 33'}
# {'name': "Domino'S Pizza"}
# {'name': "Famous Ben'S Pizza Of Soho"}
# {'name': 'La Bella Pizza'}
# {'name': "Mario'S Pizza"}
# {'name': 'Pizza Hut (Store #825)'}
# {'name': 'Fratelli Pizza'}
# {'name': 'Euro Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Domino'S Pizza"}
# {'name': "Gina'S Pizza"}
# {'name': 'Wilbel Pizza'}
# {'name': 'Alba Pizza'}
# {'name': 'Corato I Pizza & Restaurant'}
# {'name': "J 'S Pizza"}
# {'name': "Papa John'S"}
# {'name': 'Taco Bell Pizza Hut Express'}
# {'name': "Domino'S Pizza"}
# {'name': 'The Best Italian Pizza'}
# {'name': "Domino'S Pizza"}
# {'name': 'El Anzuelo Fino Restaurant'}
# {'name': 'Don Alex Restaurant'}
# {'name': 'Ihop'}
# {'name': 'Ihop'}
# {'name': 'Ihop'}
# {'name': 'Ihop'}
# {'name': 'Ihop'}
# {'name': 'Ihop'}
# {'name': 'Roti Boti Restaurant'}
# {'name': "Walter'S Bar"}
# {'name': 'Novecento'}
# {'name': "Johnny'S O'S"}
# {'name': 'Sing Sing Karaoke'}
# {'name': "The Lark'S Nest"}
# {'name': 'Cafe Mogador'}
# {'name': "Cleopatra'S Needle"}
# {'name': 'Salam Cafe & Rest'}
# {'name': 'Rainbow Falafel'}
# {'name': 'Pita City Falafel'}
# {'name': 'Moustache'}
# {'name': 'Mamoun Falafel'}
# {'name': 'Sahara East Restaurant'}
# {'name': 'Kabul Kabab House'}
# {'name': 'Pita Pan Cafe'}
# {'name': "Panchito'S"}
# {'name': 'Mexico Lindo Restaurant'}
# {'name': 'Cuchifrito'}
# {'name': "Mary Ann'S"}
# {'name': 'Arriba Arriba'}
# {'name': 'Rosa Mexicano'}
# {'name': "Lupe'S East L.A. Kitchen"}
# {'name': 'Rocking Horse Cafe'}
# {'name': 'Campeon'}
# {'name': 'Ah! Chihuahua'}
# {'name': '5 Burro Cafe'}
# {'name': 'El Cantinero'}
# {'name': 'Tequilla Sunrise'}
# {'name': "Blockhead'S Burritos"}
# {'name': 'El Rey Mexican Restaurant'}
# {'name': 'Iguanas'}
# {'name': 'Downtown Bakery Ii Mexican Food'}
# {'name': 'Tajin Restaurant'}
# {'name': 'Los Amigos Mexican Restaurant'}
# {'name': 'The Great Burrito Mexican Kitchen'}
# {'name': 'Caliente Cab Co'}
# {'name': 'The Burrito Bar Restaurant'}
# {'name': 'Montezuma Restaurant'}
# {'name': "Blockhead'S Mexican Diner"}
# {'name': 'La Perla Mexicana'}
# {'name': 'Rodeo Grill'}
# {'name': 'El Rio Grande'}
# {'name': 'Diamante Poblano Restaurant'}
# {'name': 'Canyon Road Grill'}
# {'name': 'Maya'}
# {'name': 'Maz Mezcal'}
# {'name': 'Blockheads'}
# {'name': 'Los Girasoles Restaurant'}
# {'name': 'Cilantro'}
# {'name': 'San Loco'}
# {'name': 'Tacos Mexico'}
# {'name': 'Iguana Restaurant'}
# {'name': 'El Mariachi Restaurant'}
# {'name': 'Tequila Sunrise'}
# {'name': 'El Centro'}
# {'name': 'Mi Pueblito Bakery/Comida Tipica Mexicana'}
# {'name': 'El Mariachi Restaurant'}
# {'name': 'Mexican Radio'}
# {'name': "Hell'S Kitchen"}
# {'name': 'Cafe Frida'}
# {'name': 'Jalapeno Deli'}
# {'name': 'Rosa Mexicano At Lincoln Center'}
# {'name': 'La Nortena Express Restaurant'}
# {'name': 'La Flor Bakery Cafe'}
# {'name': 'Pasiones Sports-Bar'}
# {'name': 'La Palapa'}
# {'name': 'Sabor A Mexico'}
# {'name': 'Sombrero Mexican Restaurant'}
# {'name': 'Cilantro'}
# {'name': 'Vista Hermosa Deli Restaurant'}
# {'name': 'Agave'}
# {'name': 'San Loco'}
# {'name': 'Pangea Restaurant'}
# {'name': 'Solera Restaurant'}
# {'name': 'Beyoglu'}
# {'name': 'Uncle Nicks'}
# {'name': 'Moustache Restaurant'}
# {'name': 'United Cyprians Of America'}
# {'name': 'Cafe Bar'}
# {'name': 'Virage'}
# {'name': 'Cafe Rakka'}
# {'name': 'Wine Bar'}
# {'name': 'The Place'}
# {'name': 'Sido Falalel & More'}
# {'name': 'Brasserie Athenee'}
# {'name': 'Seville Restaurant'}
# {'name': 'Emilio Iii Bar'}
# {'name': 'Marbella Restaurant'}
# {'name': 'El Pote Espanol'}
# {'name': "Victor'S Cafe"}
# {'name': 'Flamingo'}
# {'name': 'El Azteca Mexican Restaurant'}
# {'name': 'Galicia Restaurant'}
# {'name': "Sob'S"}
# {'name': 'Isla Restauraunt'}
# {'name': 'El Castillo De Jagua Rest'}
# {'name': 'Guayoyo'}
# {'name': "Lucho'S Place"}
# {'name': 'El Lina Restaurant'}
# {'name': 'Rincon Salvadoreno Restaurant'}
# {'name': 'Los Toldos Restaurant'}
# {'name': 'El Molino Rojo Restaurant'}
# {'name': 'Queens Coffee Shop'}
# {'name': 'La Lechonera Criolla'}
# {'name': 'Cafe 75 Bar'}
# {'name': "Lolita'S Restaurant"}
# {'name': 'La Barca Restaurant'}
# {'name': 'Pio Pio'}
# {'name': 'La Caridad Restaurant'}
# {'name': 'Cabana'}
# {'name': 'La Cabana Salvadorena Restaurant'}
# {'name': 'El Rey De La Caridad'}
# {'name': 'Estancia 460'}
# {'name': 'Izalco Restaurant'}
# {'name': 'El Vaquero Barras'}
# {'name': 'La Isla Restaurant'}
# {'name': 'El Castillo De Madison'}
# {'name': 'El Nuevo Ambiente Restaurant'}
# {'name': 'Desseo Night Club'}
# {'name': 'Dyckman Express Restaurant'}
# {'name': 'Ipanema Restaurant'}
# {'name': 'Post Billiards Cafe'}
# {'name': 'El Gauchito Restaurant'}
# {'name': 'La Isla Cuchifritos'}
# {'name': 'El Malecon Restaurant'}
# {'name': 'Caridad Restaurant'}
# {'name': 'Lena Restaurant'}
# {'name': 'La Taza De Oro Restaurant'}
# {'name': 'La Cabana Argentina'}
# {'name': 'El Nuevo Conquistador'}
# {'name': 'Hornado Ecuatoriano'}
# {'name': 'El Dorado Cafe'}
# {'name': 'La Picada Azuaya Restaurant'}
# {'name': 'La Nueva Playitas'}
# {'name': 'Pollos A La Barasa Mario'}
# {'name': 'El Nuevo Cafe Latino'}
# {'name': 'Latin Bakery'}
# {'name': 'La Sabrosura'}
# {'name': 'La Boina Roja Steak House'}
# {'name': 'El Caramelo Coffee Shop'}
# {'name': 'Hairos Night Club'}
# {'name': "Ifh El Buffet Restaurant  Alberto'S Mofongo House"}
# {'name': "Joe'S Place"}
# {'name': 'Garden Cafe Restaurant'}
# {'name': 'Studio 46'}
# {'name': 'Havana Alma De Cuba'}
# {'name': 'Parrilla Latina Steakhouse'}
# {'name': 'Galicia Bar'}
# {'name': 'Latino Restaurant'}
# {'name': "Braulio'S & Family Restaurant"}
# {'name': 'El Sitio Restaurant'}
# {'name': 'Cositas Ricas'}
# {'name': 'El Paraiso Bar & Restaurant'}
# {'name': 'La Cabana'}
# {'name': 'Latin American Restaurant'}
# {'name': 'El Rumbero Bar Restaurant'}
# {'name': 'Picanteria El Botecito'}
# {'name': "Sophie'S Restaurant"}
# {'name': 'El Pollo Peruano'}
# {'name': 'Parrilla Restaurant'}
# {'name': 'El Nuevo Amanecer Restaurant'}
# {'name': 'Caridad'}
# {'name': 'El Ranchito De Daisy'}
# {'name': 'La Cabana Jarabacoa Restaurant'}
# {'name': 'Picanteria El Austro'}
# {'name': "Grini'S Grill & Restaurant"}
# {'name': 'Arka Lounge'}
# {'name': 'San German Cuchifrito'}
# {'name': 'J & J Restaurant & Cuchifritos'}
# {'name': 'Charo Restaurant'}
# {'name': 'Bum Bum Bar'}
# {'name': 'Milanes Spanish Restaurant'}
# {'name': 'Polanco Restaurant Bbq'}
# {'name': 'Malecon Restaurant'}
# {'name': "Polanco'S"}
# {'name': 'El Familar Restaurant'}
# {'name': 'Barranquilla Bakery & Restaurant'}
# {'name': 'Rice & Beans Lechonera'}
# {'name': 'Shalon Restaurant'}
# {'name': 'Mi Sueno Restaurant'}
# {'name': 'El Buen Ambiente'}
# {'name': 'Liberato Restaurant'}
# {'name': 'El Cuencanito'}
# {'name': "Jennifer'S Restaurant"}
# {'name': 'Kang Suh Korean Restaurant'}
# {'name': 'Han Bat Restaurant'}
# {'name': 'Han Gawi'}
# {'name': 'Mill Korean Restaurant'}
# {'name': 'E-Dah Korean Bbq Lounge'}
# {'name': 'Kum Gang San'}
# {'name': 'Cho Dang Gol'}
# {'name': 'Woo Chon Restaurant'}
# {'name': 'Korean Lounge'}
# {'name': 'Kum Gang San Korean Restaurant'}
# {'name': 'Seoul Garden'}
# {'name': 'Book Chang Dong Sodndubu'}
# {'name': 'Do Hwa'}
# {'name': 'Fountain Of Youth Health Spa Juice Bar & Dinner'}
# {'name': 'San Soo Kap San'}
# {'name': 'Carom Cafe Billiards'}
# {'name': 'Hyo Dong Gak'}
# {'name': 'Namudol'}
# {'name': 'Kunjip Restaurant'}
# {'name': "Park'S Snack"}
# {'name': "Gold'S Gym"}
# {'name': 'Health King'}
# {'name': 'Health King'}
# {'name': 'Juice Generation'}
# {'name': 'Juicy Lucy'}
# {'name': 'Bally Total Fitness'}
# {'name': "Juicy Lucy'S"}
# {'name': 'Astral Fitness & Wellness'}
# {'name': 'Blanches @ Dkny'}
# {'name': 'Juice Generation'}
# {'name': 'Tov Kosher Kitchen'}
# {'name': 'Kosher Island'}
# {'name': 'Ben-Best Deli & Restaurant'}
# {'name': 'Naomi Kosher Pizza'}
# {'name': 'Shimons Kosher Pizza'}
# {'name': 'Mr Broadway Kosher Restaurant'}
# {'name': 'Tevere 84'}
# {'name': 'Va Bene'}
# {'name': 'Cho-Sen Garden'}
# {'name': 'Azuri Cafe'}
# {'name': 'Fine & Shapiro'}
# {'name': "Mendy'S"}
# {'name': 'Sharmel Caterers'}
# {'name': 'Hapisgah Restaurant'}
# {'name': "Ben'S Kosher Deli & Restaurant"}
# {'name': 'Beth Torah Kosher Caterers'}
# {'name': 'Le Marais'}
# {'name': "Mother'S Bake Shop"}
# {'name': "Ben'S Deli"}
# {'name': 'Jewish Theological Seminary'}
# {'name': 'Tandoori Food & Bakery'}
# {'name': 'Pahal Zan Restaurant'}
# {'name': 'Nyu Kosher Eatery'}
# {'name': 'Da Mikelle Ii'}
# {'name': 'Crystal Palace'}
# {'name': "Abigael'S On Broadway"}
# {'name': 'Kosher Deluxe'}
# {'name': 'Alibaba'}
# {'name': 'Arzu Restaurant'}
# {'name': 'Hatsuhana Restaurant'}
# {'name': 'Nada-Sushi'}
# {'name': 'Dan Tempura'}
# {'name': 'Tokubei 86'}
# {'name': 'Shabu-Shabu 70 Restaurant'}
# {'name': 'Souen Restaurant'}
# {'name': 'Omen Japanese Cuisine'}
# {'name': 'Narita Japanese Restaurant'}
# {'name': 'Hasaki Restaurant'}
# {'name': 'Restuarant Nippon'}
# {'name': 'Village Yokocho'}
# {'name': 'Mishima Restaurant'}
# {'name': 'Sushiden'}
# {'name': 'Arirang Hibachi Steak House'}
# {'name': "Yama Japanese Restaurant'"}
# {'name': 'Sakebar Decibel'}
# {'name': 'Taka Hashi Restaurant'}
# {'name': 'The Nippon Club'}
# {'name': 'Dojo Restaurant'}
# {'name': 'Shabu Tatsu'}
# {'name': 'Marumi'}
# {'name': 'Souen Restaurant'}
# {'name': 'Sharaku Japanese Restaurant'}
# {'name': 'Usagi'}
# {'name': 'Panya/The Barrel'}
# {'name': 'Nobu'}
# {'name': 'Sushiden'}
# {'name': 'Blue Ribbon Sushi'}
# {'name': 'Azusa Of Japan'}
# {'name': 'Sushi Family'}
# {'name': 'Sakagura'}
# {'name': 'Ariyoshi Japanese Restaurant'}
# {'name': 'Kurumazushi Restaurant'}
# {'name': 'Akiyama Japanese Restaurant'}
# {'name': 'Yakitori Taisho'}
# {'name': 'Miyagi Japanese Home Cooking'}
# {'name': 'Noodle Cafe Zen'}
# {'name': 'Iroha Japanese Restaurant'}
# {'name': 'Sushi Of Gari'}
# {'name': 'Udon West'}
# {'name': 'Sushiya Japanese Restaurant'}
# {'name': 'Restaurant Riki'}
# {'name': 'Monster Sushi'}
# {'name': 'Soba-Ya'}
# {'name': 'Ise Japanese Restaurant'}
# {'name': 'Planet Sushi'}
# {'name': 'Bond St'}
# {'name': 'Japan Airlines Lounge'}
# {'name': 'Nobu Next Door'}
# {'name': 'Sugiyama Restaurant'}
# {'name': 'Hana Sushi'}
# {'name': '15 East Restaurant'}
# {'name': 'Ramen-Ya'}
# {'name': 'Soba Nippon Japanese Restaurant'}
# {'name': 'Oki Japanese Restaruant'}
# {'name': "Saji'S Japanese Food"}
# {'name': 'Sato Japanese Restaurant'}
# {'name': 'Haru'}
# {'name': 'Haru'}
# {'name': 'Sushi Samba #7'}
# {'name': 'Sushi Damo'}
# {'name': 'Tsukushi Restaurant'}
# {'name': 'Jewel Bako'}
# {'name': 'Haru'}
# {'name': 'Seo Japanese Restaurant'}
# {'name': 'Ko-Sushi Japanese Restaurant'}
# {'name': 'East Japanese Restaurant/ Bar'}
# {'name': 'Wakamatsu Japanese Restaurant'}
# {'name': 'Haru Sake Bar'}
# {'name': 'Ennju'}
# {'name': 'Ginger'}
# {'name': 'Cafe Zaiya'}
# {'name': 'Soy'}
# {'name': 'Sapporo Restaurant'}
# {'name': 'Sports Center At Chelsea Piers (Sushi Bar)'}
# {'name': 'Yakiniku West Restaurant'}
# {'name': 'Sushi Zen'}
# {'name': 'Isle Of Capri Resturant'}
# {'name': 'Marchis Restaurant'}
# {'name': 'Crystal Room'}
# {'name': 'Forlinis Restaurant'}
# {'name': 'Angelo Of Mulberry St.'}
# {'name': "Arturo'S"}
# {'name': 'V & T Restaurant'}
# {'name': 'Il Vagabondo Restaurant'}
# {'name': 'Barbetta Restaurant'}
# {'name': "Patsy'S Italian Restaurant"}
# {'name': 'Parkside Restaurant'}
# {'name': 'Nanni Restaurant'}
# {'name': 'Don Peppe'}
# {'name': 'Cara Mia'}
# {'name': "John'S Restaurant"}
# {'name': 'Piccola Venezia'}
# {'name': "Ni-Ni'S Cafe"}
# {'name': 'Mimis Restaurant & Bar'}
# {'name': 'Fiorellos'}
# {'name': 'Roadhouse Restaurant'}
# {'name': 'Da Silvano Restaurant'}
# {'name': 'Il Cortile Restaurant'}
# {'name': 'Villa Mosconi Restaurant'}
# {'name': 'Volare Restaurant'}
# {'name': "Rossini'S"}
# {'name': 'Cucina Vivolo'}
# {'name': 'Manducatis'}
# {'name': "Aunt Bella'S Rest Of Little Neck"}
# {'name': 'Marina Cafe'}
# {'name': 'Don Filippo Restaurant'}
# {'name': 'Dazies Restaurant'}
# {'name': 'Triestes Restaurant'}
# {'name': 'Clinton Restaurant'}
# {'name': 'Caffe Dante'}
# {'name': 'Villa Berulia'}
# {'name': 'Il Mulino'}
# {'name': 'Felidia Restaurant'}
# {'name': "Elio'S"}
# {'name': 'Bar Vetro'}
# {'name': 'Casa Bella'}
# {'name': 'Ponticello Restaurant'}
# {'name': "Arturo'S"}
# {'name': "Gene'S Resturant"}
# {'name': "Lusardi'S Restaurant"}
# {'name': 'Portofino'}
# {'name': 'Napoli Pizza'}
# {'name': 'Il Cantinori Restauraunt'}
# {'name': "Monte'S"}
# {'name': 'Mezzaluna'}
# {'name': 'Porto Bello Restaurant'}
# {'name': 'Pietros'}
# {'name': 'Uno Chicago Grill'}
# {'name': "Cha Cha'S Backyard Garden Bar & Cafe"}
# {'name': 'Il Toscano Ristorante'}
# {'name': 'Sistina Restaurant'}
# {'name': 'Verdi Restaurant'}
# {'name': "Canlon'S Restaurant"}
# {'name': 'La Mela Restaurant'}
# {'name': "Carol'S Cafe"}
# {'name': 'Lattanzi'}
# {'name': 'Salumeria Beillese/ Biricchino Rest'}
# {'name': 'Trattoria Alba'}
# {'name': "Sam'S Place"}
# {'name': 'Primola Restaurant'}
# {'name': "Erin'S Isle"}
# {'name': 'Arno Ristorante'}
# {'name': 'Due'}
# {'name': "Pellegrino'S"}
# {'name': 'Da Umberto Restaurant'}
# {'name': 'Venice Restaurant'}
# {'name': 'Trattoria Della Arte'}
# {'name': 'Tre Giovani Pizza & Pasta'}
# {'name': 'Scaletta Ristorante'}
# {'name': "Spoto'S Restaurant"}
# {'name': 'Bella Luna'}
# {'name': 'Sette Mezzo'}
# {'name': 'La Rivista Restaurant'}
# {'name': "Sac'S Pizza Place"}
# {'name': 'Da Tommasso'}
# {'name': "Rino'S"}
# {'name': 'Papazzio Restaurant'}
# {'name': "Joey'S Place"}
# {'name': 'Cafe Luna'}
# {'name': 'Bello Restaurant'}
# {'name': 'Vico Ristorante'}
# {'name': 'Orso'}
# {'name': 'La Strada Restaurant'}
# {'name': 'Cafe Bella Vita'}
# {'name': "Gabriel'S Bar & Grill"}
# {'name': 'Scalinatella Ristaurant'}
# {'name': 'Pasta Lovers Trattoria'}
# {'name': 'Don Giovanni Restaurant'}
# {'name': 'San Pietro'}
# {'name': "Manetta'S Ristorante"}
# {'name': 'Da Rosina Restaurant'}
# {'name': 'Piccolo Angolo'}
# {'name': 'Baraonda'}
# {'name': "Luigi'S Restaurant"}
# {'name': 'Campagnola Restaurant'}
# {'name': 'Becco'}
# {'name': 'Prima Pasta & Cafe'}
# {'name': 'Cafe Cardini'}
# {'name': 'Il Violino'}
# {'name': "Carmine'S"}
# {'name': 'Da Nico Restaurant'}
# {'name': 'Montebello Restaurant'}
# {'name': 'Mediterraneo'}
# {'name': 'Caffe Grazie'}
# {'name': "Dominick'S Bar & Restaurant"}
# {'name': 'La Gioconda'}
# {'name': 'Trattoria Romana'}
# {'name': 'San Martin'}
# {'name': "Joseph'S Ristorante"}
# {'name': 'Enzo Cafe'}
# {'name': 'Fresco'}
# {'name': 'Gigino Trattoria'}
# {'name': 'Pomodoro Ristorante'}
# {'name': 'Arte Restaurant'}
# {'name': 'Acappella Restaurant'}
# {'name': 'Olive Garden Italian Restaurant'}
# {'name': 'Novita'}
# {'name': 'Villa Monte Pizzeria'}
# {'name': 'Giardino Ristorante'}
# {'name': 'Il Buco Restaurant'}
# {'name': 'Three Of Cups'}
# {'name': 'Savore'}
# {'name': 'Hudson Place'}
# {'name': 'Cibo'}
# {'name': 'Villa Barone'}
# {'name': 'Piadina Restaurant'}
# {'name': 'New York Rifle Club'}
# {'name': 'Columbus Citizens Foundation'}
# {'name': 'Artuso Pastry Shop'}
# {'name': "Little Sal'S Italiano"}
# {'name': 'Restivo Ristorante'}
# {'name': 'I Trulli Restaurant'}
# {'name': 'Notaro Restaurant'}
# {'name': 'Bella Blu'}
# {'name': 'Chelsea Trattoria'}
# {'name': 'Arte Cafe'}
# {'name': "Nick And Toni'S Cafe"}
# {'name': "Artie'S"}
# {'name': 'Il Palazzo'}
# {'name': 'Tiramisu Restaurant'}
# {'name': 'Al-Dente'}
# {'name': 'Via Italia Ristorante'}
# {'name': 'Circo Restaurant'}
# {'name': 'Giovanni 25'}
# {'name': "Aldo'S Ii Pizza And Restaurant"}
# {'name': 'Portobello Cafe'}
# {'name': 'Basta Pasta Restaurant'}
# {'name': 'Appetito Restaurant'}
# {'name': 'Pasta Pasta Restaurant'}
# {'name': "The Old Time Vincent'S"}
# {'name': 'Da Marino Restaurant'}
# {'name': 'La Pizza Fresca'}
# {'name': 'Vespa Cibobuono'}
# {'name': 'Mezzogiorno'}
# {'name': 'Buona Notte Ristorante'}
# {'name': "Spolini'S"}
# {'name': 'Serafina Fabulous Pizza'}
# {'name': 'Erminia Restaurant'}
# {'name': 'Bricco Restaurant'}
# {'name': "Lanza'S"}
# {'name': 'Caffe Napoli'}
# {'name': 'P.J. Charlton'}
# {'name': 'Bocca Di Bacco'}
# {'name': 'The Stairs Bar And Lounge'}
# {'name': 'La Giara'}
# {'name': 'Pepe Rosso To Go'}
# {'name': "Nicola'S Restaurant"}
# {'name': 'Cipriani Downtown Restaurant'}
# {'name': 'Felice 64 Wine Bar'}
# {'name': 'Il Postino'}
# {'name': 'Osteria Laguna'}
# {'name': 'Villa Russo'}
# {'name': "Paul & Jimmy'S Restaurant"}
# {'name': "Ballato'S Restaurant"}
# {'name': 'Grano Trattoria'}
# {'name': 'Campanile'}
# {'name': "Mario'S Restaurant"}
# {'name': 'Cafe Borgia Ii'}
# {'name': 'Caffe Palermo'}
# {'name': 'Nocello'}
# {'name': 'Park Italian Gourment'}
# {'name': 'Brioso Ristorante'}
# {'name': "Rao'S Bar & Grill"}
# {'name': 'Bottino'}
# {'name': 'Pasquale Rigoletto Restaurant'}
# {'name': "Nino'S Restaurant"}
# {'name': 'Primo Amore'}
# {'name': 'Frank'}
# {'name': 'Cavatappo Grill'}
# {'name': 'Babbo Ristorante E Enoteca'}
# {'name': 'Trattoria I Malatesta'}
# {'name': "Giovanni'S Restaurant & Cafe"}
# {'name': 'Maruzzella'}
# {'name': 'Parma Restaurant'}
# {'name': 'Po Restaurant'}
# {'name': 'Canaletto Ristorante'}
# {'name': 'Bocelli'}
# {'name': 'Cafe Al Mercato'}
# {'name': "Coppola'S"}
# {'name': "Cascarino'S"}
# {'name': 'Osteria Serafina'}
# {'name': 'Teodora'}
# {'name': 'Le Zie Trattoria'}
# {'name': 'Pepe Giallo'}
# {'name': "Trattoria L'Incontro"}
# {'name': 'Via Quadronno'}
# {'name': 'Il Riccio Restaurant'}
# {'name': 'Trattoria Pesce Pasta'}
# {'name': 'Vice Versa'}
# {'name': 'Bello Giardino'}
# {'name': '44 Sw Ristorante & Bar'}
# {'name': 'Gigino At Wagner Park'}
# {'name': 'Scalini Fedeli'}
# {'name': "Emilia'S Restaurant"}
# {'name': 'Il Posto Accanto'}
# {'name': 'Lupa'}
# {'name': 'Pine Bar & Grill'}
# {'name': 'Delmonicos'}
# {'name': "Nucci'S Restaurant"}
# {'name': 'Cinema The Brasserie'}
# {'name': 'Gente'}
# {'name': 'Two Boots Grand Central'}
# {'name': 'Cucina Di Pesce'}
# {'name': 'Roc Restaurant'}
# {'name': 'Villa Rustica Ristorante'}
# {'name': 'Antica Trattoria'}
# {'name': 'Bar Veloce'}
# {'name': "Giorgio'S Of Gramercy"}
# {'name': "Nino'S Positano"}
# {'name': 'Pinocchio Ristorante'}
# {'name': 'Milan Sports Bar'}
# {'name': 'Sanpanino'}
# {'name': 'La Grotta Ristorante'}
# {'name': 'Barbaresco'}
# {'name': 'Cafe Buon Gusto'}
# {'name': 'Gnocco'}
# {'name': 'Gradisca Restaurant'}
# {'name': 'Albella Ristorante & Bar'}
# {'name': 'Studio Cafe 59'}
# {'name': 'Risotteria'}
# {'name': 'Palma'}
# {'name': 'Manor House Restaurant'}
# {'name': "Carmine'S"}
# {'name': 'Lunella Restaurant'}
# {'name': 'Acquista Trattoria'}
# {'name': 'Max Soha'}
# {'name': 'Trufa Restaurant'}
# {'name': 'Tiberio Dimare'}
# {'name': 'Caffe Linda'}
# {'name': "Madison'S"}
# {'name': 'Firenze'}
# {'name': 'Bread'}
# {'name': 'Pazza Notte'}
# {'name': 'Azalea'}
# {'name': 'Aquamarina'}
# {'name': 'Mozzarella & Vino'}
# {'name': 'Al Forno'}
# {'name': 'Ristorante Settepani'}
# {'name': "Fred'S At Barney'S"}
# {'name': 'Tarallucci E Vino'}
# {'name': "Conti'S"}
# {'name': 'Supper'}
# {'name': 'Maria Pia'}
# {'name': 'Finestra'}
# {'name': 'Acqua'}
# {'name': "Luigi'S Catering"}
# {'name': 'Numero 28 Pizzeria'}
# {'name': 'Cipriani Dolci'}
# {'name': "Patsy'S Pizzeria Restaurant"}
# {'name': 'Dolcino Trattoria Toscana'}
# {'name': 'Lamarca Pasta Restaurant'}
# {'name': 'Dj Reynolds Pub And Restaurant'}
# {'name': "Mcsorley'S Old Ale House"}
# {'name': "Dorrian'S Red Hand Restaurant"}
# {'name': "Moran'S Chelsea"}
# {'name': 'Mcdwyers Pub'}
# {'name': 'Killarney Rose'}
# {'name': 'Blarney Rock'}
# {'name': 'Irish Cottage'}
# {'name': 'Blarney Stone'}
# {'name': 'Twins Pub'}
# {'name': "O'Hanlon'S Pub"}
# {'name': "Jim Brady'S Restaurant"}
# {'name': 'Ready Penny Inn'}
# {'name': 'Molly Wee Pub'}
# {'name': "Rosie O'Grady Restaurant"}
# {'name': "Pj Carney'S"}
# {'name': 'Rogers Irish Tavern'}
# {'name': "Mcaleer'S Pub"}
# {'name': 'Aqueduct North'}
# {'name': 'Pj Morans'}
# {'name': 'Pipers Kilt'}
# {'name': 'Irish Brigade'}
# {'name': "Malachy'S"}
# {'name': 'The Beekman'}
# {'name': "Molly'S"}
# {'name': 'Muldoons Bar'}
# {'name': 'Grandstand Tavern'}
# {'name': 'Cronin & Phelan Pub & Restaurant'}
# {'name': 'The Abbey Pub'}
# {'name': "Dempsey'S Pub"}
# {'name': 'Langans Bar & Restaurant'}
# {'name': "Tee Dee'S Tavern"}
# {'name': 'Irish Eye Bar'}
# {'name': "Mccoy'S Pub"}
# {'name': "Foley'S N.Y. Pub And Restaurant"}
# {'name': "Mulligan'S Pub"}
# {'name': 'The Scratcher Cafe'}
# {'name': 'Irish Punt'}
# {'name': "Annie Moore'S Restaurant"}
# {'name': "Mccabe'S Bar Car"}
# {'name': 'The Triple Crown'}
# {'name': "Connolly'S Pub"}
# {'name': "St. Dymphna'S"}
# {'name': 'Bull Mccabes'}
# {'name': "Barrow'S Pub"}
# {'name': "Murphy'S Law"}
# {'name': 'Shamrock Inn'}
# {'name': "Mc Guinness'S"}
# {'name': 'Mcloughlins Bar'}
# {'name': "O'Reilly'S Pub"}
# {'name': 'Playwright Celtic Pub'}
# {'name': 'Failte'}
# {'name': "Behan'S Pub"}
# {'name': 'The Black Sheep'}
# {'name': 'Liffy Ii Bar'}
# {'name': 'Kerry Hills Pub'}
# {'name': "Sissy Mcginty'S"}
# {'name': 'The Full Shilling'}
# {'name': 'Playwright Tavern'}
# {'name': "Hurley'S Saloon"}
# {'name': "Maguire'S Public House"}
# {'name': 'Peter Mcmanus'}
# {'name': "Marty O'Brien'S"}
# {'name': 'The Dead Poet'}
# {'name': 'Playwright Celtic Pub'}
# {'name': 'Boulevard Tavern'}
# {'name': 'Banshee Pub'}
# {'name': "Murphy'S Pub & Restaurant"}
# {'name': "Deacon Brodie'S"}
# {'name': "Connolly'S"}
# {'name': "Peter Dillon'S Bar"}
# {'name': 'The Irish Pub'}
# {'name': "Mccann'S Pub"}
# {'name': 'Tavern Lounge'}
# {'name': 'Sheas Emerald'}
# {'name': 'Bali Nusa Indonesian Restaurant'}
# {'name': 'Mughlai Restaurant'}
# {'name': 'Agra Restaurant'}
# {'name': 'Annam Braham Restaurant'}
# {'name': 'Gandhi'}
# {'name': 'Haveli'}
# {'name': 'Taste Of India Ii Restaurant'}
# {'name': 'Bombay Masala'}
# {'name': 'Indigo Indian Cuisine'}
# {'name': 'Curry In A Hurry'}
# {'name': 'Bangal Curry'}
# {'name': 'Air India Lounge'}
# {'name': 'Vatan'}
# {'name': 'Madras Mahal'}
# {'name': 'Diwan-E-Khaas'}
# {'name': 'Khyber Restaurant'}
# {'name': 'Ajanta India'}
# {'name': 'Raj Mahal Indian Restaurant'}
# {'name': 'Pongal Indian Cuisine'}
# {'name': 'Kismat Indian Cuisine'}
# {'name': 'Santoor Indian Restaurant'}
# {'name': 'Diwan-E- Khaas'}
# {'name': 'Aladdin'}
# {'name': 'Mehak'}
# {'name': 'Ayurveda Cafe'}
# {'name': 'Minar Indian Restaurant'}
# {'name': 'Ghandi Cafe'}
# {'name': 'Dosa Hutt'}
# {'name': 'Sapphire Indian Cuisine'}
# {'name': 'Utsav Festive India Restaurant'}
# {'name': 'Maurya Restaurant'}
# {'name': 'Taj Cafe'}
# {'name': 'Cafe Spice'}
# {'name': 'Hampton Chutney Company'}
# {'name': 'Al-Mehran Restaurant'}
# {'name': 'Indian Taj'}
# {'name': 'Gandhi Indian Cuisine'}
# {'name': 'Devasthanam Canteen'}
# {'name': 'Maharaja Quality Sweets'}
# {'name': 'Minar Indian Restaurant'}
# {'name': 'Amma'}
# {'name': 'Carvel Ice Cream'}
# {'name': 'Carvel Ice Cream'}
# {'name': 'Carvel Ice Cream'}
# {'name': 'Haagen-Dazs'}
# {'name': 'Baskin Robbins'}
# {'name': "Egger'S Ice Cream Parlor"}
# {'name': 'Carvel Ice Cream'}
# {'name': 'Ciao Bella'}
# {'name': 'Carvel Ice Cream'}
# {'name': "The Ice Box-Ralph'S Famous Italian Ices"}
# {'name': "My Mother'S Place"}
# {'name': 'Carvel Ice Cream'}
# {'name': 'The Little Sweet Shoppe'}
# {'name': 'Carvel Ice Cream'}
# {'name': "Dylan'S Candybar"}
# {'name': 'Carvel'}
# {'name': "Gray'S Papaya"}
# {'name': "Nathan'S Famous"}
# {'name': "Madame Tussaud'S"}
# {'name': "Nathan'S Famous"}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Wendy'S"}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': "Wendy'S"}
# {'name': 'White Castle'}
# {'name': "The Famous Jimbo'S Hamburger Palace"}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'White Castle'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Island Burgers And Shakes'}
# {'name': "Wendy'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Wendy'S"}
# {'name': "Wendy'S"}
# {'name': "Wendy'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Checkers'}
# {'name': 'White Castle'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King/Metro Mall'}
# {'name': "Wendy'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S (Macy'S 7Th Fl)"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Jimbo'S Hamburgers"}
# {'name': "Mcdonald'S"}
# {'name': 'Burger King'}
# {'name': 'Burger Heaven'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': 'Burger King'}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': "Mcdonald'S"}
# {'name': 'Jimbos Hamburger Palace'}
# {'name': 'Viand Coffee Shop'}
# {'name': 'Omonia Cafe'}
# {'name': 'Fontana Famous Pizza & Gyro'}
# {'name': 'Karavas Place'}
# {'name': 'Symposium Greek Restaurant'}
# {'name': 'Periyali'}
# {'name': 'Jackson House Restaurant'}
# {'name': 'Oasis Cafe'}
# {'name': 'Molyvos'}
# {'name': 'Gyro King'}
# {'name': 'Laterna Taverna'}
# {'name': 'Fresco Bar Cafe Restaurant'}
# {'name': 'Cavo'}
# {'name': 'Bahari Estiatorio'}
# {'name': 'Snack'}
# {'name': 'Plaza Lounge'}
# {'name': 'Avra Estiatorio'}
# {'name': 'The Greek Kitchen  Clinton Bakery Cafe'}
# {'name': 'Mythos Restaurant'}
# {'name': 'Igloo Ice Cream Cafe'}
# {'name': "Zorba'S"}
# {'name': 'Ethos Greek Cuisine'}
# {'name': 'Gottscheer Hall'}
# {'name': 'Zum Stammtisch'}
# {'name': "Killmeyer'S Old Bavaria Inn."}
# {'name': "Rolf'S German Restaurant"}
# {'name': 'Hallo Berlin'}
# {'name': 'Wallse Restaruant'}
# {'name': 'Zum Schneider'}
# {'name': 'Cafe Sabarsky'}
# {'name': 'Heidelberg Restaurant'}
# {'name': 'Tout Va Bien'}
# {'name': 'La Grenouille'}
# {'name': 'Le Perigord'}
# {'name': 'La Bonne Soupe Bistro'}
# {'name': 'Raouls'}
# {'name': 'La Mangeoire'}
# {'name': 'Pergola Des Artistes'}
# {'name': 'Cafe Un Deux Trois'}
# {'name': 'La Baraka Restaurant'}
# {'name': 'La Ripaille Restaurant'}
# {'name': 'La Mediterranee Restaurant'}
# {'name': 'Chez Napolean'}
# {'name': 'Chez Jaqueline'}
# {'name': 'Cafe Luxembourg'}
# {'name': 'Petrossian Restauraunt'}
# {'name': 'Le Bernardin'}
# {'name': 'Chez Josephine'}
# {'name': 'Quatorze Bistro'}
# {'name': 'Air France Lounge'}
# {'name': 'Demarchelier Restaurant'}
# {'name': 'Pascalou'}
# {'name': 'Bar Six'}
# {'name': 'Felix'}
# {'name': 'Les Halles'}
# {'name': 'Jules Bistro'}
# {'name': 'French Roast'}
# {'name': 'Cafe Loup'}
# {'name': 'La Luncheonette'}
# {'name': 'Credit Agricole-Cbi Executive Room'}
# {'name': 'Cafe Gitane'}
# {'name': 'Vin Et Fleurs'}
# {'name': 'French Roast'}
# {'name': "Jacque'S Cafe"}
# {'name': "L'Express"}
# {'name': 'Le Gigot'}
# {'name': 'Jean Georges'}
# {'name': 'Balthazar Restaurant'}
# {'name': 'Le Singe Vert'}
# {'name': 'Le Paris Bistrot Francais'}
# {'name': 'Le Rivage'}
# {'name': 'Picholine'}
# {'name': 'Cassis Bistro/Brasserie'}
# {'name': 'Bistro Les Amis'}
# {'name': 'La Mirabelle Restaurant'}
# {'name': 'The Crooked Tree'}
# {'name': 'Madison Bistro'}
# {'name': 'Lucien Restauraunt'}
# {'name': 'Le Bateau Ivre'}
# {'name': 'Daniel'}
# {'name': 'Le Monde'}
# {'name': 'Amaranth'}
# {'name': 'Bistro Citron'}
# {'name': 'Orsay'}
# {'name': 'Le Charlot'}
# {'name': 'Rue 57'}
# {'name': 'Vol De Nuit'}
# {'name': 'Deux Amis'}
# {'name': 'Cafe Joul'}
# {'name': 'Flute'}
# {'name': 'Artisanal'}
# {'name': 'Db Bistro Moderne'}
# {'name': 'Le Train Bleu & B Cafe'}
# {'name': 'Opia Restaurant'}
# {'name': 'Marseille'}
# {'name': 'Pigalle'}
# {'name': 'Jo Jo'}
# {'name': 'Paradou'}
# {'name': 'Cafe Angus'}
# {'name': 'Brasserie Les Halles'}
# {'name': 'Tournesol'}
# {'name': 'Marquet Fine Pastry'}
# {'name': "Renee'S Kitchenette"}
# {'name': 'Krystal Pastry Shop'}
# {'name': 'Ihawan'}
# {'name': 'Masawa'}
# {'name': 'Meskerem'}
# {'name': 'Queen Of Sheba Ethiopian Restaurant'}
# {'name': 'Tea And Sympathy'}
# {'name': 'Tartine'}
# {'name': 'Kabab Cafe'}
# {'name': 'Veselka Restaurant'}
# {'name': 'Hungarian Pastry Shop'}
# {'name': 'Yonah Shimmels Knishes'}
# {'name': 'Scorpio'}
# {'name': 'Sarajevo Fast Food'}
# {'name': 'Donut Pub'}
# {'name': "Dunkin' Donuts/Baskin' Robbins"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts/Baskin Robbins"}
# {'name': 'Country Donuts'}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': 'Country Donuts'}
# {'name': "Dunkin' Donuts, Baskin Robbins"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts, Baskin Robbins"}
# {'name': "Dunkin' Donuts, Baskin Robbins"}
# {'name': "Dunkin' Donuts, Baskin Robbins"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts, Baskin Robbins"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': 'Hillside Gourmet'}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': 'Dunkin Donuts'}
# {'name': "Dunkin' Donuts"}
# {'name': 'Tim Hortons'}
# {'name': "Dunkin' Donuts"}
# {'name': 'Taj Donut Shop'}
# {'name': "Dunkin' Donuts"}
# {'name': "Dunkin' Donuts"}
# {'name': "Sal'S Deli"}
# {'name': "Bully'S Deli"}
# {'name': "Steve Chu'S Deli & Grocery"}
# {'name': "Tony'S Deli"}
# {'name': 'Bagels N Buns'}
# {'name': 'Plaza Bagels & Deli'}
# {'name': 'B & M Hot Bagel & Grocery'}
# {'name': 'Pj Bernstein Deli & Restaurant'}
# {'name': 'Tal Bagels Deli'}
# {'name': "Champ'S Deli"}
# {'name': 'Bagel Cafe'}
# {'name': 'Stage Door Deli'}
# {'name': 'Bel Paese Italian Deli'}
# {'name': 'Delmonico Gourmet'}
# {'name': "Smiler'S Deli"}
# {'name': 'Ben Ash Delicatessen'}
# {'name': 'Glory Deli'}
# {'name': 'Deli Plus ( Inside Port Authority Station)'}
# {'name': 'Blake & Todd'}
# {'name': 'Bagels Deli'}
# {'name': 'Don Pepis Delicatessen'}
# {'name': 'Hamilton Deli'}
# {'name': 'Trevi Deli'}
# {'name': 'Bellrose Deli'}
# {'name': 'Food Mart Deli'}
# {'name': 'Olive Tree'}
# {'name': 'Bagel Club'}
# {'name': 'Hello Deli'}
# {'name': 'Parisi Bakery'}
# {'name': 'Whitestone Bagel Factory'}
# {'name': 'Airport Deli'}
# {'name': "Bono'S Cafe"}
# {'name': 'Roosevelt Gourmet Deli'}
# {'name': 'Million Deli'}
# {'name': 'Tottenville Bagels'}
# {'name': '101 Deli'}
# {'name': 'West 53Rd Gourmet Deli'}
# {'name': 'Vincents Bagel'}
# {'name': 'Bagelman Of Woodside'}
# {'name': "Millie'S Deli"}
# {'name': 'Friends Deli'}
# {'name': 'Grand Street Deli & Mini Market'}
# {'name': 'Highway Deli And Coffee Shop'}
# {'name': "Loeser'S Hebrew National"}
# {'name': 'L & M Italian Deli & Catering'}
# {'name': 'Seguine Bagel Bakery'}
# {'name': 'Central Cafe'}
# {'name': 'Strokos Gourmet Deli'}
# {'name': 'Tribeca Park Cafe'}
# {'name': 'Continental Luncheonette & Deli'}
# {'name': 'United Grocery & Deli'}
# {'name': "Katz'S Delicatessen"}
# {'name': "Munchy'S"}
# {'name': 'Marathon Food Shop'}
# {'name': "Ralph'S Ii Deli"}
# {'name': 'Hanover Gourmet Deli'}
# {'name': "New Andy'S Deli"}
# {'name': 'Hallmark Deli'}
# {'name': 'Devon & Blakely'}
# {'name': 'Constantines Deli'}
# {'name': "Mrs Friggins' Kitchen"}
# {'name': 'Rosario Deli'}
# {'name': 'City Island Deli'}
# {'name': 'All American Deli'}
# {'name': 'Cheito Duran Deli Grocery'}
# {'name': 'Star Lite Deli'}
# {'name': 'Times Deli & Cafe'}
# {'name': 'Fordham University - Student Deli'}
# {'name': 'Ny Hot Jumbo Bagels'}
# {'name': "Danny'S Deli"}
# {'name': 'Koliba Restaurant'}
# {'name': "Lorenzo & Maria'S"}
# {'name': 'Dining Room'}
# {'name': "Austin'S Steak & Ale House"}
# {'name': 'Cafe Champignon'}
# {'name': "Michael'S Restaurant"}
# {'name': 'Petite Abeille'}
# {'name': "Uncle Peter'S"}
# {'name': 'Sabrosura Restaurant'}
# {'name': 'La Nueva Victoria Restaurant'}
# {'name': 'La Dinastia'}
# {'name': 'Americas Restorante'}
# {'name': 'New Pabellon De Oro Restaurant'}
# {'name': 'Ho Mei Restaurant'}
# {'name': 'Happy Garden'}
# {'name': 'Happy Garden'}
# {'name': 'King Yum Restaurant'}
# {'name': 'Hop Kee Restaurant'}
# {'name': 'Jardin De China Rest'}
# {'name': 'Shun Lee Palace Restaurant'}
# {'name': "Chen'S Chinese"}
# {'name': 'Shun Lee'}
# {'name': "Charlie'S Mom Chinese Restaurant"}
# {'name': 'Ocean Dragon Restaurant'}
# {'name': "Yip'S"}
# {'name': 'Baybridge Szechuan Restaurant'}
# {'name': 'Peking Restaurant'}
# {'name': 'Nueva Villa China Restaurant'}
# {'name': 'Empire Szechuan Noodle House'}
# {'name': 'Island Taste'}
# {'name': 'Master Wok'}
# {'name': 'Jing Fong Restaurant'}
# {'name': 'Kelley & Ping'}
# {'name': 'Phoenix Garden'}
# {'name': 'Dinastia China'}
# {'name': 'Peking Duck House'}
# {'name': 'Happy Fortune Ii'}
# {'name': 'S Dynasty'}
# {'name': 'Oriental Palace Kitchen'}
# {'name': 'Oriental Express'}
# {'name': 'Manna One Bakery'}
# {'name': 'Manna House Bakery'}
# {'name': 'China Wok Ii'}
# {'name': 'China Chalet'}
# {'name': 'Dragon City'}
# {'name': 'Jade Island Restaurant'}
# {'name': 'No.1 Kitchen Chinese Restaurant'}
# {'name': "Joe'S Shanghai Restaurant"}
# {'name': 'Jj Garden Restaurant'}
# {'name': 'Hunan Balcony'}
# {'name': 'Great Wall Restaurant'}
# {'name': 'Happy Fortune'}
# {'name': 'Oriental Star Restaurant'}
# {'name': "New Feng'S Garden"}
# {'name': 'La Caridad 78'}
# {'name': 'Empire Wok Kitchen'}
# {'name': 'Lucky House Restaurant'}
# {'name': 'New Wah Kitchen'}
# {'name': 'Hop Won Express'}
# {'name': 'Fuji Bakery'}
# {'name': 'Red Bowl Noodle Shop'}
# {'name': 'Lok Sing Chinese Restaurant'}
# {'name': "Mr K'S Restaurant"}
# {'name': "Hunan ''K'' Chinese Restaurant"}
# {'name': 'Ten-Tan Chinese Restaurant'}
# {'name': 'Empire Szechuan Village'}
# {'name': 'Szechuan Kitchen'}
# {'name': "Joe'S Shanghai Restaurant"}
# {'name': 'New Hing Restaurant'}
# {'name': 'Nuevo Jardin De China Restaurant'}
# {'name': 'Peking Duck House'}
# {'name': "New Kim'S Restaurant"}
# {'name': 'Dragon Land Bakery'}
# {'name': 'Mr. Chow Restaurant'}
# {'name': "Sammy'S Noodle Shop & Grill"}
# {'name': 'Peking House'}
# {'name': 'Double Dragon'}
# {'name': 'New Sunny Garden Restaurant'}
# {'name': 'Peking Express'}
# {'name': 'Great N.Y. Noodletown'}
# {'name': 'Yummy Kitchen'}
# {'name': 'Hong Kong Restaurant'}
# {'name': 'Jade Seneca Oriental Restaurant'}
# {'name': 'China Fun'}
# {'name': "Kristy'S Restaurant"}
# {'name': 'Wu Liang Ye Restaurant'}
# {'name': 'East Dynasty'}
# {'name': 'Dim Sum Go Go'}
# {'name': 'Lin Home Chinese Restaura'}
# {'name': 'Peacock Restaurant'}
# {'name': "Lin'S Garden"}
# {'name': 'Hong Cheong'}
# {'name': "Chan'S Kitchen"}
# {'name': 'New Kam Sheng Restaurant'}
# {'name': 'Red Star Chinese Restaurant'}
# {'name': 'Jian On Chinese Restaurant'}
# {'name': 'Ling Kee Beef Jerky'}
# {'name': 'Yao Wah Kitchen'}
# {'name': 'New China Kitchen'}
# {'name': "Annie'S Kitchen"}
# {'name': 'New Rainbow Restaurant'}
# {'name': "Harriet'S Kitchen"}
# {'name': 'Texas Rotisserie'}
# {'name': "Mom'S Fried Chicken"}
# {'name': 'La Casa Del Pollo Restaurant'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Chick-N-Ribs'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Fordham Fried Chicken & Sea Food'}
# {'name': 'Big New York Fried Chicken'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Boston Market'}
# {'name': 'Kennedy Fried Chicken'}
# {'name': 'Caravan Chicken'}
# {'name': 'Chicken Holiday Express'}
# {'name': "Mama'S Fried Chicken"}
# {'name': "Alex'S Kitchen"}
# {'name': 'Chicken Festival'}
# {'name': 'Pizza Hut, Kentucky Fried Chicken'}
# {'name': 'Boston Market'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Chirping Chicken'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Kfc/Taco Bell'}
# {'name': 'Kentucky Fried Chicken/ Island Cuisine'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Popeyes Chicken & Biscuits'}
# {'name': 'Western Bakery'}
# {'name': "Miss Lily'S 7A"}
# {'name': "Frank'S Soup Bowl"}
# ...
# {'name': 'Fireside'}
# {'name': 'Tastee Corner'}
# {'name': 'G'}
# {'name': 'Glenlo Tavern'}
# {'name': 'Death & Co'}
# {'name': 'Roma View Catering'}
# {'name': 'Blue & Gray Inn'}
# {'name': "Louie'Sdale Diner"}
# {'name': 'Mug Shots'}
# {'name': 'Lite Delights'}
# {'name': "Aretsky'S Patroon"}
# {'name': 'The Gin Mill'}
# {'name': 'Ground Level Beer Pub'}
# {'name': 'Distilled'}
# {'name': 'Birdland'}
# {'name': 'Bank Of New York'}
# {'name': "Sunberry'S"}
# {'name': 'Last Stop Restaurant'}
# {'name': 'Keenans'}
# {'name': 'Flik International'}
# {'name': 'Quad Cinema'}
# {'name': "Duke'S"}
# {'name': 'Mansions Cater'}
# {'name': 'Gotham Cafe (Inside Holiday Inn)'}
# {'name': 'Tick Tock Diner'}
# {'name': 'Coopers Tavern'}
# {'name': 'Jays Restaurant'}
# {'name': 'M & M Bar & Grill'}
# {'name': 'Devon & Blakely'}
# {'name': 'Rose Pizza'}
# {'name': "Iggy'S"}
# {'name': 'Ethel Barrymore Theater'}
# {'name': 'Town Hall Theatre'}
# {'name': 'Music Box Theater'}
# {'name': 'Lyceum Theatre'}
# {'name': 'Ambassador Theatre'}
# {'name': 'Cort Theatre'}
# {'name': 'Golden Theatre'}
# {'name': "Arthur'S Tavern"}
# {'name': 'Douglaston Golf Snacks'}
# {'name': 'Sugar Bar'}
# {'name': 'Trellis'}
# {'name': "Mcdonald'S"}
# {'name': "Ray'S Candy Store"}
# {'name': "Gussy'S Bar"}
# {'name': 'Carleton Lounge - Mudd Building'}
# {'name': 'Ocean Grill'}
# {'name': 'Wakamba'}
# {'name': 'East Of Eighth'}
# {'name': 'Carry On Tea & Sympathy'}
# {'name': 'Kentucky Fried Chicken, Tim Hortons'}
# {'name': "Tad'S Steaks"}
# {'name': 'The Thirsty Scholar'}
# {'name': 'Faces & Names'}
# {'name': 'Bleecker Street Bar'}
# {'name': 'Pier 72 Restaurant'}
# {'name': 'Bull Head Tavern'}
# {'name': 'Glen Roy Bar And Grill'}
# {'name': 'The Green Table(Chelsea Market)'}
# {'name': 'An Beal Bocht Cafe'}
# {'name': 'Archer Sports Bar'}
# {'name': 'National Arts Club'}
# {'name': 'Carnegie Delicatessen & Restaurant'}
# {'name': 'Turtle Bay Grill And Lounge'}
# {'name': 'El Dorado Sports Lounge'}
# {'name': 'The Spring Lounge'}
# {'name': 'Westside Theatre'}
# {'name': 'Tavern On Jane'}
# {'name': 'The Triad'}
# {'name': 'Whitsons And Forbes'}
# {'name': 'Hudson Bar And Books'}
# {'name': 'Arabelle'}
# {'name': 'Bread Market Cafe'}
# {'name': 'Throgs Neck Clipper'}
# {'name': 'La Bonbonniere'}
# {'name': "Cafe Lou'S"}
# {'name': 'Ruthys Bakery & Cafe'}
# {'name': 'Paris Cafe'}
# {'name': "Hector'S Cafe & Diner"}
# {'name': 'New York University - Snow Dining'}
# {'name': 'Bel-Aire Diner'}
# {'name': 'Acme Bar & Grill'}
# {'name': "Sarabeth'S Kitchen"}
# {'name': 'Plug Uglies'}
# {'name': 'Lucky Deli'}
# {'name': "Hillstone'S"}
# {'name': 'Coral Diner'}
# {'name': "Applebaum'S"}
# {'name': 'The Village Lantern'}
# {'name': 'Citibank Employee Cafeteria'}
# {'name': 'New Capital Restaurant'}
# {'name': 'N.Y. Life Executive Dining Room .'}
# {'name': 'Guy & Gallard'}
# {'name': 'Perfecto Pizza & Coffee Shop'}
# {'name': 'Metro Grill'}
# {'name': 'Bocca'}
# {'name': "South'S"}
# {'name': 'Underground Lounge'}
# {'name': 'The Parlour'}
# {'name': "Lovell'S Guiding Light"}
# {'name': 'The Otheroom'}
# {'name': 'Bowlmor Chelsea Piers'}
# {'name': '3 Deli & Grill'}
# {'name': "Fred'S"}
# {'name': 'Forest Park Golf Course'}
# {'name': 'Flute'}
# {'name': 'Reade Street Pub & Kitchen'}
# {'name': 'La Gourmet'}
# {'name': 'Maggie Mays'}
# {'name': "Kabooz'S Bar & Grille"}
# {'name': 'Tribeca Tavern'}
# {'name': "Rick'S Cafe"}
# {'name': 'New Yorker Hotel Kitchen'}
# {'name': 'Great Jones Cafe'}
# {'name': 'Botanica Bar'}
# {'name': 'Lunch Box'}
# {'name': 'Le Glacier'}
# {'name': 'Ten Degrees Bistro'}
# {'name': 'Blue Ribbon'}
# {'name': 'Simone Bar Cafe'}
# {'name': 'Lane Deli & Catering'}
# {'name': "Norma'S, Burger Joint"}
# {'name': 'Joshua Tree'}
# {'name': 'Wrap N Run Grill'}
# {'name': 'City Island Diner /Snug Bar'}
# {'name': "T.G.I. Friday'S"}
# {'name': 'Delta Grill'}
# {'name': '42Nd Street Pizza Diner'}
# {'name': 'Gemini Diner'}
# {'name': 'The Rail Line Diner'}
# {'name': 'Box Car Lounge'}
# {'name': "P.J. Brady'S Tavern"}
# {'name': 'Steinway Billiard'}
# {'name': 'Bedford Cafe & Restaurant'}
# {'name': 'Dive 75'}
# {'name': 'Morningstar Restaurant'}
# {'name': 'Van Dam Diner'}
# {'name': 'Citibank Executive Conference Center'}
# {'name': 'The Summit'}
# {'name': 'Madame X'}
# {'name': 'Caprice'}
# {'name': 'City Hall Restaurant'}
# {'name': "Gene'S Coffee Shop"}
# {'name': 'The Bowery Ballroom'}
# {'name': 'The Carnegie Cigar Club And Lounge'}
# {'name': 'Lexington Bar And Books'}
# {'name': "Sarabeth'S"}
# {'name': 'Webster Cafe'}
# {'name': 'Chickpea'}
# {'name': 'Cafeteria'}
# {'name': "Afternoone'S Restaurant"}
# {'name': "Applebee'S Neighborhood Grill & Bar"}
# {'name': 'Point Break'}
# {'name': 'Good Enough To Eat (A.G. Bistro)'}
# {'name': "Billy'S Sport Bar Restaurant & Lounge"}
# {'name': 'Swing 46 Jazz And Supper Club'}
# {'name': 'The Fitz'}
# {'name': 'The Esplanade'}
# {'name': "Chic-Fil-A, Quiznos Subs, Jw'S, Tossed"}
# {'name': 'New York University - Courtyard Cafe'}
# {'name': 'The Bread Factory Cafe'}
# {'name': "Arlene'S Grocery"}
# {'name': 'The Lowell'}
# {'name': 'Gaslight'}
# {'name': 'Rose Restaurant'}
# {'name': 'Legends Bar & Grill'}
# {'name': 'Mercer Kitchen'}
# {'name': 'Tasty Fast Food'}
# {'name': 'Spirit Of New York'}
# {'name': '3 Guys Resturant'}
# {'name': 'Spirit Of New Jersey'}
# {'name': 'Whiskey Park'}
# {'name': "Jack'S Restaurant & Bar"}
# {'name': 'The Dish Restaurant'}
# {'name': 'Shade'}
# {'name': "Mcdonald'S"}
# {'name': 'Wcou Radio / Tile Bar'}
# {'name': 'Solas'}
# {'name': 'Townhouse Diner'}
# {'name': 'Ibm Executive Dining Room'}
# {'name': "Old John'S Luncheonette"}
# {'name': 'Bar None'}
# {'name': 'Yura & Company On Madison'}
# {'name': 'Jackson Hole'}
# {'name': 'Terrace On The Park'}
# {'name': 'Thomas Preti Caterers'}
# {'name': 'Westside Tavern'}
# {'name': 'Pier 60'}
# {'name': 'New York University- Hall Cafe/ Burger Studio'}
# {'name': 'V-Bar And Cafe'}
# {'name': 'Bateaux New York'}
# {'name': 'Greenhouse Cafe (557 Broaday) Scholastic Building'}
# {'name': 'Blondies'}
# {'name': "Showman'S Cafe"}
# {'name': 'Snacks-N-Wheels'}
# {'name': 'Tribeca Rooftop'}
# {'name': 'Good Restaurant'}
# {'name': 'Evolution'}
# {'name': 'Off The Wagon'}
# {'name': 'Nosh! - Courtyard By Marriott'}
# {'name': 'New Amsterdam Theater'}
# {'name': "Cookie'S Lounge"}
# {'name': 'Alta'}
# {'name': 'Session 73'}
# {'name': 'Sanfords Restaurant'}
# {'name': "Joe'S Pub"}
# {'name': 'Food For Thought Catered Events'}
# {'name': 'Circa Tabac'}
# {'name': 'Phillip Marie'}
# {'name': 'Starbucks Coffee'}
# {'name': 'Lexicon'}
# {'name': "Vic'S"}
# {'name': 'Manhattan Courtyard'}
# {'name': 'Deluxe'}
# {'name': 'Grand Havana Room'}
# {'name': 'Midway Cinemas'}
# {'name': 'Queen Vic'}
# {'name': 'Mcgraw Hill Executive Dining'}
# {'name': 'Tir Na Nog'}
# {'name': 'Emerald Pub'}
# {'name': 'Track Kitchen'}
# {'name': 'The Mansion Grand'}
# {'name': "Duke'S"}
# {'name': 'Pig & Whistle On 3Rd'}
# {'name': 'Sean Og'}
# {'name': 'Lace'}
# {'name': 'Kenyon & Kenyon Cafeteria'}
# {'name': 'Market Restaurant (C-D Block)'}
# {'name': 'Cafe Express'}
# {'name': 'Hi Life Bar & Grill'}
# {'name': 'Astra'}
# {'name': 'Mercury Bar'}
# {'name': 'Bourbon Street'}
# {'name': 'Cinema Cafe & Bar'}
# {'name': 'House Of Brews'}
# {'name': 'Taste Restaurant'}
# {'name': 'The Red Cat'}
# {'name': 'Toast'}
# {'name': 'Perkins Family Restaurant & Bakery'}
# {'name': "Christie'S"}
# {'name': 'Le Trapeze'}
# {'name': "Fella'S Bar"}
# {'name': 'Smoke'}
# {'name': 'Fresco On The Go'}
# {'name': "Thomasina'S"}
# {'name': 'Pershing Square Cafe'}
# {'name': 'Delight Donut'}
# {'name': 'Snack Bar (Located Between A-B Between Fancy Food And Masters)'}
# {'name': 'Belasco Theatre'}
# {'name': 'Longacre Theatre'}
# {'name': "J.R'S Cabaret"}
# {'name': 'Trackside'}
# {'name': 'New York Luncheonette'}
# {'name': 'Kew Gardens Cinemas'}
# {'name': 'The Tick Tavern'}
# {'name': 'Europa Cafe'}
# {'name': 'The Country Cafe'}
# {'name': 'Kinsale Tavern'}
# {'name': 'Skadden Arps, Slate'}
# {'name': 'The Bread Factory Cafe'}
# {'name': "Josie Wood'S Pub"}
# {'name': "Swifty'S"}
# {'name': 'B.B. Kings'}
# {'name': 'G.P. Diner'}
# {'name': 'Blue Hill Restaurant'}
# {'name': 'Black And White'}
# {'name': 'No Partners'}
# {'name': 'Thalia'}
# {'name': 'C.U.N.Y Cafe'}
# {'name': 'Amerada Hess Express Cafe'}
# {'name': "Henry'S"}
# {'name': 'Prune'}
# {'name': 'Morrell Wine Bar & Cafe'}
# {'name': 'Gold Bar B'}
# {'name': 'Billiard Company'}
# {'name': 'Stage Restaurant'}
# {'name': 'Torch Club'}
# {'name': 'Windfall'}
# {'name': 'Triomphe'}
# {'name': 'Park Bar'}
# {'name': 'Lexington Candy Shop'}
# {'name': 'Family Corner'}
# {'name': 'Prospect Coffee Shop'}
# {'name': 'Juniors'}
# {'name': 'Juniors'}
# {'name': 'The Historic Old Bermuda Inn'}
# {'name': "Andrew'S Diner"}
# {'name': 'Karma'}
# {'name': 'Leonidas'}
# {'name': 'Pier Sixty One-The Lighthouse'}
# {'name': 'Anotheroom'}
# {'name': 'Cucina Gourmet'}
# {'name': 'Blue & Gold Bar'}
# {'name': 'Village Den'}
# {'name': 'Bourbon Street'}
# {'name': 'The Whiskey Ward'}
# {'name': 'Peasant'}
# {'name': "Adrian & Rocky'S Caterers"}
# {'name': 'Ten Degrees'}
# {'name': 'Black Fat Pussy Cat'}
# {'name': 'The Wheeltapper'}
# {'name': 'Reliable Food'}
# {'name': 'Housing Works Food'}
# {'name': 'Unique Lounge'}
# {'name': 'Julius'}
# {'name': 'Juice For Life'}
# {'name': "Guastavino'S"}
# {'name': 'Scandals'}
# {'name': 'Jolly Tinker'}
# {'name': 'Stir Cafe'}
# {'name': 'Mccaffrey And Burke'}
# {'name': 'Fish Bar'}
# {'name': "Brother Jimmy'S Bbq"}
# {'name': 'Giacomo Fine Foods'}
# {'name': 'The Campbell Apartment - In Grand Central'}
# {'name': 'Cup & Saucer'}
# {'name': 'Silver Star Restaurant'}
# {'name': 'George Keeley'}
# {'name': "Applebee'S Neighborhood Grill & Bar"}
# {'name': 'Cafe Cello Deli'}
# {'name': 'Nations Cafe'}
# {'name': 'Puck Fair'}
# {'name': 'Cafe Orlin'}
# {'name': 'Hooters'}
# {'name': "Mike'S Place"}
# {'name': 'Amf 34 Avenue Lanes'}
# {'name': 'Bar Coastal'}
# {'name': 'Island Shores'}
# {'name': 'Nonis Coffee Shop'}
# {'name': 'Blue Diner'}
# {'name': 'Restaurant Annisa'}
# {'name': 'Sugar Factory'}
# {'name': 'Springfield Diner'}
# {'name': 'Flushing Meadows Pitch And Putt'}
# {'name': 'Seven Bar & Grill'}
# {'name': 'Marriott Marquis - Main Kitchen'}
# {'name': 'Room Service Kitchen'}
# {'name': 'Intermisson Cafe'}
# {'name': 'Broadway Lounge'}
# {'name': 'View Restaurant'}
# {'name': 'Crossroads (Marriott Marquis)'}
# {'name': 'Mariott Marquis/Crossroads Bar'}
# {'name': 'View Lounge'}
# {'name': 'The Courtyard Ale House'}
# {'name': 'Strokos Pizza Deli'}
# {'name': 'Opal'}
# {'name': 'Tribeca Grand Hotel'}
# {'name': "Applebee'S Neighborhood Grill & Bar"}
# {'name': "Dave'S Tavern"}
# {'name': 'Tres Coronas Bar'}
# {'name': 'West 79Th Street Boat Basin Cafe'}
# {'name': 'Ballfields Cafe'}
# {'name': 'Laguardia Courtyard Hotel By Marriott'}
# {'name': 'Cafe Luka'}
# {'name': 'Time Cafeteria'}
# {'name': 'B. Smith Restaurant'}
# {'name': 'Circle In The Square Theatre'}
# {'name': 'Eatery Restaurant'}
# {'name': 'Cafe Metro'}
# {'name': 'The Half King'}
# {'name': 'Cafe Duke'}
# {'name': 'Macelleria Restaurant'}
# {'name': 'Essex'}
# {'name': 'Georgios Country Grill'}
# {'name': 'Cinnabon World Famous Cinnamon Rolls'}
# {'name': 'Billymarks West'}
# {'name': 'The Slaughtered Lamb'}
# {'name': 'Private Eyes'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': 'Boston Market'}
# {'name': "Kelly'S Restaurant & Pizza"}
# {'name': 'The Hallmark Of Battery Park City- Dining Room'}
# {'name': 'Ferris Booth Commons - Alfred Lerner Hall'}
# {'name': 'Forest Hills Coffe Shop'}
# {'name': 'Dancing Crane Cafe (Bx Zoo)'}
# {'name': 'Terminal1 Employee Cafeteria'}
# {'name': 'Nbc-Ge'}
# {'name': 'Americas Burger And Wraps'}
# {'name': 'Triple Crown Diner'}
# {'name': 'Dublin 6'}
# {'name': 'Ritz Diner'}
# {'name': 'Posh'}
# {'name': 'Section 5 Pizza Restaurant'}
# {'name': 'The Park'}
# {'name': "Curves Gentleman'S Club"}
# {'name': 'Mayer, Brown & Platt'}
# {'name': 'Step In Restaurant & Lounge'}
# {'name': 'New Leaf Cafe'}
# {'name': 'Tasty Cafe Catering'}
# {'name': 'Baker Street Pub'}
# {'name': 'Paul Weiss Rifkin Wharton'}
# {'name': '525 Lex Restaurant & Bar'}
# {'name': 'Richmond County Country Club - Pool Snack Bar'}
# {'name': 'Richmond County Country Club(10Th Hole)'}
# {'name': 'Richmond County Country Club'}
# {'name': 'Bermay Luncheonette'}
# {'name': "44 & X Hell'S Kitchen"}
# {'name': "T.J.'S Sports Bar"}
# {'name': 'Funtopia Usa'}
# {'name': 'Barrage'}
# {'name': 'Central Park Boathouse'}
# {'name': 'Everest Diner'}
# {'name': "Applebee'S Neighborhood Grill & Bar"}
# {'name': "Applebee'S Neighborhood Grill & Bar"}
# {'name': 'Shore Haven Diner'}
# {'name': 'Dock Street Bar & Grill'}
# {'name': "Dunkin' Donuts/Baskin Robins"}
# {'name': 'Hsbc Bank'}
# {'name': 'Rathbones Pub'}
# {'name': 'Jane'}
# {'name': '7 Stars'}
# {'name': 'Bistro Ten-18'}
# {'name': 'Columbus House'}
# {'name': 'Comic Strip'}
# {'name': 'Community Food And Juice'}
# {'name': 'Courtyard By Marriott'}
# {'name': 'Mercury Bar'}
# {'name': 'The Patio Grill'}
# {'name': 'Society Of Illustrators'}
# {'name': 'Bungalow Bar & Restaurant'}
# {'name': 'Clinton Street Baking Company'}
# {'name': 'Heartland Brewery'}
# {'name': 'Koyzina Kafe'}
# {'name': 'The Harrison'}
# {'name': "Dante'S Gourmet Food"}
# {'name': '71 Irving Place'}
# {'name': 'Lucky Star Cafe'}
# {'name': 'Old Castle Pub & Restaurant'}
# {'name': "Nelly'S Corner Pizzeria Restaurant"}
# {'name': "Bubby'S"}
# {'name': 'Reuters Executive Dining Room'}
# {'name': 'Reuters Cafeteria'}
# {'name': "Connolly'S Corner"}
# {'name': 'To Go Express'}
# {'name': 'The Great American Health Bar'}
# {'name': 'Crossbay Diner'}
# {'name': 'Nba Employer Cafeteria'}
# {'name': 'Boulevard Tavern'}
# {'name': 'Debevoise & Plimpton'}
# {'name': 'Uno Chicago Grill'}
# {'name': 'The Magician'}
# {'name': 'Chelsea Square Restaurant'}
# {'name': 'The Williamsbridge Tavern'}
# {'name': 'La Verite Restaurant Bar'}
# {'name': 'The New Thompson Diner'}
# {'name': 'Lorenzos Bar & Grill (Hilton Garden)'}
# {'name': 'New York Dolls'}
# {'name': 'Famous Bagel Buffet'}
# {'name': "Vivienne'S"}
# {'name': "Crif Dogs / Please Don'T Tell"}
# {'name': 'The Eagle'}
# {'name': 'Mad River Bar & Grille'}
# {'name': 'Belvedere Cafe'}
# {'name': "Carmine'S Restaurant"}
# {'name': 'The Black Duck Restaurant'}
# {'name': 'Casa Promesa'}
# {'name': 'Sweet & Vicious'}
# {'name': "Lil Frankie'S Pizza"}
# {'name': 'Ua Kaufman Astoria #14'}
# {'name': 'Washington Square Diner'}
# {'name': 'The Village Tavern'}
# {'name': "Gallagher'S 2000"}
# {'name': 'T.G.I. Fridays'}
# {'name': 'Cafe Mae Mae'}
# {'name': 'Columbo Yogurt/ Taco Bell/ Nathans/ Tim Horton/Pizza Hut'}
# {'name': 'Tim Hortons'}
# {'name': 'Burgers & Cupcakes'}
# {'name': "Bill'S Restaurant"}
# {'name': "Alice'S Tea Cup"}
# {'name': 'W Times Square'}
# {'name': "Mr Mcgoo'S"}
# {'name': 'The Black Dog Grill'}
# {'name': 'Sodexo'}
# {'name': 'Elmo'}
# {'name': 'Cafe Bonjour'}
# {'name': "Wimpy'S Restaurant"}
# {'name': 'Craft'}
# {'name': 'Bowery Eletric'}
# {'name': 'Fordham University - Mcginley Center'}
# {'name': 'Fordham University/Mcginley Center/Ramskeller Kitchen'}
# {'name': 'Fordham University - Ram Cafeteria'}
# {'name': 'Chase Edr'}
# {'name': 'Re: Sources'}
# {'name': "Jerry'S 637 Diner"}
# {'name': 'Fordham University - Millenium Grill'}
# {'name': "Barclay'S Capital"}
# {'name': 'Kitchenette Uptown'}
# {'name': 'Hyatt, Ny Central/Room Service'}
# {'name': 'Grand Hyatt New York Hotel'}
# {'name': 'Blue Smoke'}
# {'name': "Digby'S"}
# {'name': "Big Daddy'S Diner"}
# {'name': 'Whaler Bar, Cafe Buon Giorno'}
# {'name': 'New York University - Palladium Food Court'}
# {'name': 'Jones Reavis & Pague Llp'}
# {'name': "Brendan'S"}
# {'name': 'Toast'}
# {'name': 'Eurest Dining Service (American Express)'}
# {'name': 'American Express'}
# {'name': '111 Restaurant'}
# {'name': 'Carlow East'}
# {'name': 'Swiss International Airlines Lounge'}
# {'name': 'Canard Inc'}
# {'name': 'Sullivan & Cromwell'}
# {'name': 'Uno Cafe & Billiards'}
# {'name': 'White & Case'}
# {'name': 'Snafu'}
# {'name': "Mug-Z'S Sports Bar"}
# {'name': 'Hotel Carlyle'}
# {'name': 'Regal Entertainment Group'}
# {'name': 'A & B Deli & Catering'}
# {'name': 'Ernst & Young Cafe'}
# {'name': 'Coffee Shop'}
# {'name': 'Nublu'}
# {'name': 'Beauty Bar'}
# {'name': 'Tsq Brasserie'}
# {'name': 'Renaissance Hotel'}
# {'name': "Ashby'S Specialty"}
# {'name': 'African Terrace'}
# {'name': 'Africana Restaurant'}
# {'name': 'Ebe Ye Yie African Restaurant'}
# {'name': 'Afghan Kebab House'}
# {'name': 'Khyber Pass'}
# {'name': 'Afghan Kebab House #1'}
# {'name': 'Ariana Kebab House'}

# %% [markdown]
# 14. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que contengan 'Wil' como primera tres letras de su nombre.

# %%
consulta = db.restaurants.find(
    {"name": {"$regex": "^Wil"}},
    {"_id": 1, "name": 1, "borough": 1, "cuisine": 1}
)

for restaurants in consulta:
    print(restaurants)
# Out:
# {'_id': ObjectId('65df17a47377fb2e6cd15579'), 'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': "Wilken'S Fine Food"}
# {'_id': ObjectId('65df17a47377fb2e6cd1557c'), 'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Wild Asia'}
# {'_id': ObjectId('65df17ad7377fb2e6cd16381'), 'borough': 'Bronx', 'cuisine': 'Pizza', 'name': 'Wilbel Pizza'}

# %% [markdown]
# 15. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes cuyo nombre termine por 'ces'.

# %%
consulta = db.restaurants.find(
    {"name": {"$regex": "ces$"}},
    {"_id": 1, "name": 1, "borough": 1, "cuisine": 1}
)

for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 16. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que contengan 'Reg' en cualquier parte de su nombre.

# %%
consulta = db.restaurants.find(
    {"name": {"$regex": "Reg"}},
    {"_id": 1, "name": 1, "borough": 1, "cuisine": 1}
)

for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 17. Escribe una sentencia que encuentre los restaurantes que pertenezcan al Bronx y preparen platos de cocina americana ('American') o china ('Chinese').

# %%
consulta = db.restaurants.find(
    {"borough": "Bronx",
    "cuisine": "Chinese"},
    {"_id": 0, "name": 1}
)

for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 18. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que pertenezcan a Staten Island, Queens, Bronx o Brooklyn.

# %%
consulta =  db.restaurants.find(
    {"borough": {"$in": ["Staten Island", "Queens", "Bronx", "Brooklyn"]}},
    {"_id": 0, "name": 1, "borough":1, "cuisine":1}
)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 19. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que NO pertenezcan a Staten Island, Queens, Bronx o Brooklyn.

# %%
consulta =  db.restaurants.find(
    {"borough": {"$nin": ["Staten Island", "Queens", "Bronx", "Brooklyn"]}},
    {"_id": 0, "name": 1, "borough":1, "cuisine":1}
)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 20. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que han recibido una puntuación que no sea mayor a 10.

# %%
consulta =  db.restaurants.find(
    {"grades.score": {"$lte": 10}},
    {"_id": 0, "name": 1, "borough":1, "cuisine":1}
)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 21. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que preparan platos de comida americana ('American') y china ('Chinees') o de restaurantes cuyo nombre empieza pro 'Wil'.

# %%
consulta =  db.restaurants.find(
    {
        "$or": [
            {"cuisine": "American", "cuisine": "Chinese"},
            {"name": {"$regex": "^Wil"}}
        ]
    },
    {"_id": 1, "name": 1, "borough": 1, "cuisine": 1}
)
for restaurants in consulta:
    print(restaurants)

# %% [markdown]
# 22. Escribe una sentencia que busque el Id, name, borough y cuisine de los restaurantes que reciben una nota 'A' y una puntuación de 11 en una fecha ISODate "2014-08-11T00:00:00Z" entre sus fechas de encuestas.

# %%
from datetime import datetime

fecha_iso = datetime.strptime("2014-08-11T00:00:00+0000", "%Y-%m-%dT%H:%M:%S%z")

consulta = db.restaurants.find(
    {
        "grades": {
            "$elemMatch": {
                "date": fecha_iso,
                "grade": "A",
                "score": 11
            }
        }
    },
    {"_id": 1, "name": 1, "borough": 1, "cuisine": 1}
)

for restaurant in consulta:
    print(restaurant)

# %% [markdown]
# 23. Escribe una sentencia que encuentre el Id, name y grades de los restaurantes cuyo segundo elemento de notas ('grades') contenga la nota 'A' y la puntucaión ('score') 9 en la fecha ISODate "2014-08-11T00:00:00Z".

# %%
from datetime import datetime

fecha_iso = datetime.strptime("2014-08-11T00:00:00+0000", "%Y-%m-%dT%H:%M:%S%z")

consulta = db.restaurants.find(
    {
        "grades": {
            "$elemMatch": {
                "date": fecha_iso,
                "grade": "A",
                "score": 9
            }
        }
    },
    {"_id": 1, "name": 1, "grades": 1}
)

for restaurant in consulta:
    print(restaurant)

# %% [markdown]
# 24. Escribe una sentencia que encuentre el Id, name, address and geographical location para los restaurantes donde el segundo elemento del array de coordenadas ('coord') contiene un valor mayor de 42 y menor de 52.

# %%
consulta = db.restaurants.find(
    {
        "address.coord": {
            "$elemMatch": {
                "$gt": 42,
                "$lt": 52
            }
        }
    },
    {"_id": 1, "name": 1, "address": 1}
)

for restaurant in consulta:
    print(restaurant)

# %% [markdown]
# 25. Escribe una sentencia que ordene los restaurantes por nombre en orden ascendente junto con el resto de columnas.

# %%
consulta = db.restaurants.find().sort("name", 1)
for restaurant in consulta:
    print(restaurant)

# %% [markdown]
# 26. Escribe una sentencia que ordene los restaurantes por nombre en orden descendente junto con el resto de columnas.

# %%
consulta = db.restaurants.find().sort("name", -1)
for restaurant in consulta:
    print(restaurant)
# Out:
# {'_id': ObjectId('65df17a47377fb2e6cd15631'), 'address': {'building': '6946', 'coord': [-73.8811834, 40.7017759], 'street': 'Myrtle Avenue', 'zipcode': '11385'}, 'borough': 'Queens', 'cuisine': 'German', 'grades': [{'date': datetime.datetime(2014, 9, 24, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2014, 4, 17, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 3, 12, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 10, 2, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 5, 9, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 12, 28, 0, 0), 'grade': 'B', 'score': 24}], 'name': 'Zum Stammtisch', 'restaurant_id': '40367377'}
# {'_id': ObjectId('65df17ab7377fb2e6cd1616b'), 'address': {'building': '107109', 'coord': [-73.9744668, 40.731155], 'street': 'Avenue C', 'zipcode': '10009'}, 'borough': 'Manhattan', 'cuisine': 'German', 'grades': [{'date': datetime.datetime(2014, 3, 4, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 8, 21, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 2, 27, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 6, 5, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 12, 20, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 7, 15, 0, 0), 'grade': 'A', 'score': 6}], 'name': 'Zum Schneider', 'restaurant_id': '40763382'}
# {'_id': ObjectId('65df17ad7377fb2e6cd163a5'), 'address': {'building': '2905', 'coord': [-73.91337299999999, 40.775064], 'street': '23 Avenue', 'zipcode': '11105'}, 'borough': 'Queens', 'cuisine': 'Greek', 'grades': [{'date': datetime.datetime(2014, 9, 29, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2014, 4, 18, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 19, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 10, 3, 0, 0), 'grade': 'B', 'score': 20}, {'date': datetime.datetime(2012, 5, 7, 0, 0), 'grade': 'A', 'score': 12}], 'name': "Zorba'S", 'restaurant_id': '40877247'}
# {'_id': ObjectId('65df17ac7377fb2e6cd161ed'), 'address': {'building': '305', 'coord': [-73.94830499999999, 40.781662], 'street': 'East 92 Street', 'zipcode': '10128'}, 'borough': 'Manhattan', 'cuisine': 'Brazilian', 'grades': [{'date': datetime.datetime(2015, 1, 9, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2014, 7, 16, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 4, 26, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 4, 21, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Zebu Grill', 'restaurant_id': '40800325'}
# {'_id': ObjectId('65df17a67377fb2e6cd159a8'), 'address': {'building': '29', 'coord': [-73.86119219999999, 40.8338023], 'street': 'Hugh Grant Circle', 'zipcode': '10462'}, 'borough': 'Bronx', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 8, 27, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 9, 10, 0, 0), 'grade': 'A', 'score': 0}, {'date': datetime.datetime(2013, 5, 7, 0, 0), 'grade': 'C', 'score': 2}, {'date': datetime.datetime(2013, 3, 23, 0, 0), 'grade': 'P', 'score': 13}, {'date': datetime.datetime(2012, 10, 24, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 11, 1, 0, 0), 'grade': 'A', 'score': 13}], 'name': "Zaro'S Bread Basket", 'restaurant_id': '40397863'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b23'), 'address': {'building': '1', 'coord': [-76.878256, 40.26205], 'street': 'Pennsylvania Station (Amtrack)', 'zipcode': '10001'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 2, 7, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 2, 11, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 9, 18, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 4, 5, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2011, 11, 17, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2011, 7, 5, 0, 0), 'grade': 'A', 'score': 4}], 'name': "Zaro'S Bread Basket", 'restaurant_id': '40510389'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b4d'), 'address': {'building': '89', 'coord': [-73.97729919999999, 40.7524958], 'street': 'East   42 Street', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 12, 23, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 1, 13, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2013, 1, 23, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 8, 20, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 3, 30, 0, 0), 'grade': 'A', 'score': 9}], 'name': "Zaro'S Bread Basket", 'restaurant_id': '40512617'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d6d'), 'address': {'building': '89', 'coord': [-73.97729919999999, 40.7524958], 'street': 'East   42 Street', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2014, 7, 17, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 6, 26, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 1, 29, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 7, 16, 0, 0), 'grade': 'A', 'score': 13}], 'name': "Zaro'S Bread Basket", 'restaurant_id': '40586000'}
# {'_id': ObjectId('65df17ab7377fb2e6cd1611e'), 'address': {'building': '2', 'coord': [-73.992255, 40.749712], 'street': 'Penn Plaza', 'zipcode': '10121'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 2, 18, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 1, 22, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 3, 21, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 11, 9, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 7, 25, 0, 0), 'grade': 'B', 'score': 18}], 'name': "Zaro'S Bread Basket", 'restaurant_id': '40750766'}
# {'_id': ObjectId('65df17a77377fb2e6cd15ae4'), 'address': {'building': '89', 'coord': [-73.97729919999999, 40.7524958], 'street': 'East   42 Street', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 9, 29, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 9, 11, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 9, 14, 0, 0), 'grade': 'A', 'score': 10}], 'name': "Zaro'S Bakery", 'restaurant_id': '40423705'}
# {'_id': ObjectId('65df17aa7377fb2e6cd15f6e'), 'address': {'building': '370', 'coord': [-73.9768121, 40.7507385], 'street': 'Lexington Avenue', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 9, 18, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 9, 9, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 4, 8, 0, 0), 'grade': 'B', 'score': 14}, {'date': datetime.datetime(2012, 10, 15, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 5, 24, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2011, 10, 31, 0, 0), 'grade': 'B', 'score': 25}], 'name': "Zaro'S Bakery", 'restaurant_id': '40686674'}
# {'_id': ObjectId('65df17a47377fb2e6cd156be'), 'address': {'building': '500', 'coord': [-73.9828058, 40.7150766], 'street': 'Grand Street', 'zipcode': '10002'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 3, 20, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 3, 13, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 10, 19, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 5, 25, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 6, 8, 0, 0), 'grade': 'A', 'score': 8}], 'name': "Zafi'S Luncheonette", 'restaurant_id': '40371718'}
# {'_id': ObjectId('65df17ad7377fb2e6cd16398'), 'address': {'building': '301', 'coord': [-73.9465592, 40.8165415], 'street': 'West  135 Street', 'zipcode': '10030'}, 'borough': 'Manhattan', 'cuisine': 'Caribbean', 'grades': [{'date': datetime.datetime(2014, 1, 8, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 7, 12, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 1, 30, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 12, 6, 0, 0), 'grade': 'C', 'score': 11}, {'date': datetime.datetime(2012, 2, 28, 0, 0), 'grade': 'B', 'score': 16}], 'name': 'Yvonne Yvonne Restaurant', 'restaurant_id': '40875849'}
# {'_id': ObjectId('65df17a97377fb2e6cd15eb4'), 'address': {'building': '1292', 'coord': [-73.9563202, 40.7846507], 'street': 'Madison Avenue', 'zipcode': '10128'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2015, 1, 5, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2014, 8, 8, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 12, 17, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 7, 10, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2013, 1, 8, 0, 0), 'grade': 'C', 'score': 41}], 'name': 'Yura & Company On Madison', 'restaurant_id': '40646987'}
# {'_id': ObjectId('65df17ab7377fb2e6cd16169'), 'address': {'building': '9021', 'coord': [-73.87785749999999, 40.760312], 'street': '31 Avenue', 'zipcode': '11369'}, 'borough': 'Queens', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2014, 12, 10, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 6, 12, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 11, 12, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 4, 10, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 10, 17, 0, 0), 'grade': 'B', 'score': 22}, {'date': datetime.datetime(2012, 5, 23, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2011, 12, 22, 0, 0), 'grade': 'P', 'score': 6}], 'name': 'Yummy Kitchen', 'restaurant_id': '40763160'}
# {'_id': ObjectId('65df17a77377fb2e6cd15bab'), 'address': {'building': '518', 'coord': [-74.02590599999999, 40.6209702], 'street': '86 Street', 'zipcode': '11209'}, 'borough': 'Brooklyn', 'cuisine': 'Bakery', 'grades': [{'date': datetime.datetime(2014, 5, 1, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2013, 4, 25, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 11, 19, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2011, 11, 4, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'Your Bakery', 'restaurant_id': '40529415'}
# {'_id': ObjectId('65df17a77377fb2e6cd15c0d'), 'address': {'building': '137', 'coord': [-73.9901259, 40.7231435], 'street': 'East Houston Street', 'zipcode': '10002'}, 'borough': 'Manhattan', 'cuisine': 'Eastern European', 'grades': [{'date': datetime.datetime(2014, 6, 23, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 6, 3, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 6, 25, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 1, 31, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 8, 30, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'Yonah Shimmels Knishes', 'restaurant_id': '40544576'}
# {'_id': ObjectId('65df17a97377fb2e6cd15db6'), 'address': {'building': '292', 'coord': [-73.9218923, 40.8169858], 'street': 'East  149 Street', 'zipcode': '10451'}, 'borough': 'Bronx', 'cuisine': 'Pizza/Italian', 'grades': [{'date': datetime.datetime(2014, 10, 6, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2014, 5, 20, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 25, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 9, 20, 0, 0), 'grade': 'A', 'score': 11}], 'name': 'Yolanda Pizzeria Restaurant', 'restaurant_id': '40594879'}
# {'_id': ObjectId('65df17a57377fb2e6cd15819'), 'address': {'building': '1290', 'coord': [-73.9788903, 40.7605367], 'street': 'Avenue Of Americas', 'zipcode': '10119'}, 'borough': 'Manhattan', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2014, 9, 23, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 12, 11, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 4, 9, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2012, 10, 4, 0, 0), 'grade': 'B', 'score': 23}, {'date': datetime.datetime(2012, 5, 7, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 12, 20, 0, 0), 'grade': 'B', 'score': 22}], 'name': "Yip'S", 'restaurant_id': '40388209'}
# {'_id': ObjectId('65df17a57377fb2e6cd158ca'), 'address': {'building': '404', 'coord': [-73.97635439999999, 40.6438997], 'street': 'Church Avenue', 'zipcode': '11218'}, 'borough': 'Brooklyn', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2014, 10, 29, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 3, 24, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 10, 25, 0, 0), 'grade': 'C', 'score': 3}, {'date': datetime.datetime(2012, 10, 1, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 5, 9, 0, 0), 'grade': 'C', 'score': 2}], 'name': 'Yen Yen Restaurant', 'restaurant_id': '40393181'}
# {'_id': ObjectId('65df17ae7377fb2e6cd163fa'), 'address': {'building': '145', 'coord': [-73.9922551, 40.6892272], 'street': 'Court Street', 'zipcode': '11201'}, 'borough': 'Brooklyn', 'cuisine': 'Middle Eastern', 'grades': [{'date': datetime.datetime(2014, 10, 8, 0, 0), 'grade': 'B', 'score': 15}, {'date': datetime.datetime(2014, 5, 6, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 9, 11, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 8, 22, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 2, 9, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 11, 18, 0, 0), 'grade': 'C', 'score': 11}], 'name': 'Yemen Cuisine', 'restaurant_id': '40888097'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16293'), 'address': {'building': '80', 'coord': [-73.97537299999999, 40.675044], 'street': '7 Avenue', 'zipcode': '11217'}, 'borough': 'Brooklyn', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 10, 11, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 5, 5, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2013, 11, 18, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 10, 26, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 11, 14, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Yb Food Market', 'restaurant_id': '40834127'}
# {'_id': ObjectId('65df17ad7377fb2e6cd163de'), 'address': {'building': '7312', 'coord': [-73.7582954, 40.7403191], 'street': 'Bell Boulevard', 'zipcode': '11364'}, 'borough': 'Queens', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2015, 1, 5, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 5, 22, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 4, 15, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 4, 23, 0, 0), 'grade': 'A', 'score': 11}], 'name': 'Yao Wah Kitchen', 'restaurant_id': '40884708'}
# {'_id': ObjectId('65df17a47377fb2e6cd155df'), 'address': {'building': '72', 'coord': [-73.92506, 40.8275556], 'street': 'East  161 Street', 'zipcode': '10451'}, 'borough': 'Bronx', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 4, 15, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 11, 14, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2013, 7, 29, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 12, 31, 0, 0), 'grade': 'B', 'score': 15}, {'date': datetime.datetime(2012, 5, 30, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 1, 9, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 8, 15, 0, 0), 'grade': 'C', 'score': 37}], 'name': 'Yankee Tavern', 'restaurant_id': '40365499'}
# {'_id': ObjectId('65df17a47377fb2e6cd156d5'), 'address': {'building': '1599', 'coord': [-73.87575, 40.8294396], 'street': 'Westchester Avenue', 'zipcode': '10472'}, 'borough': 'Bronx', 'cuisine': 'Pizza', 'grades': [{'date': datetime.datetime(2015, 1, 13, 0, 0), 'grade': 'Z', 'score': 17}, {'date': datetime.datetime(2014, 8, 4, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2014, 7, 21, 0, 0), 'grade': 'P', 'score': 12}, {'date': datetime.datetime(2014, 2, 20, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 8, 15, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 3, 13, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 1, 17, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'Yankee Jz Pizza', 'restaurant_id': '40372631'}
# {'_id': ObjectId('65df17a47377fb2e6cd1575b'), 'address': {'building': '0', 'coord': [-73.8865891, 40.7723001], 'street': 'Laguardia Airport Bldg', 'zipcode': '11371'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 10, 17, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2014, 2, 26, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 8, 30, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'B', 'score': 25}, {'date': datetime.datetime(2012, 8, 10, 0, 0), 'grade': 'B', 'score': 22}], 'name': 'Yankee Clipper', 'restaurant_id': '40379994'}
# {'_id': ObjectId('65df17a57377fb2e6cd15839'), 'address': {'building': '122', 'coord': [-73.9876443, 40.7358217], 'street': 'East   17 Street', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'Japanese', 'grades': [{'date': datetime.datetime(2014, 6, 26, 0, 0), 'grade': 'B', 'score': 19}, {'date': datetime.datetime(2013, 11, 18, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 27, 0, 0), 'grade': 'C', 'score': 36}, {'date': datetime.datetime(2012, 8, 21, 0, 0), 'grade': 'A', 'score': 13}], 'name': "Yama Japanese Restaurant'", 'restaurant_id': '40388818'}
# {'_id': ObjectId('65df17a67377fb2e6cd15aaf'), 'address': {'building': '50', 'coord': [-73.9774365, 40.7539873], 'street': 'Vanderbilt Avenue', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 11, 22, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 11, 1, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 4, 12, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 10, 19, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'Yale Club', 'restaurant_id': '40402610'}
# {'_id': ObjectId('65df17a87377fb2e6cd15c91'), 'address': {'building': '5', 'coord': [-73.989254, 40.729529], 'street': 'St Marks Place', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'Japanese', 'grades': [{'date': datetime.datetime(2014, 12, 12, 0, 0), 'grade': 'Z', 'score': 24}, {'date': datetime.datetime(2014, 5, 13, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 12, 17, 0, 0), 'grade': 'B', 'score': 17}, {'date': datetime.datetime(2013, 4, 16, 0, 0), 'grade': 'C', 'score': 17}, {'date': datetime.datetime(2012, 10, 19, 0, 0), 'grade': 'C', 'score': 4}, {'date': datetime.datetime(2012, 3, 16, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Yakitori Taisho', 'restaurant_id': '40560896'}
# {'_id': ObjectId('65df17ae7377fb2e6cd16412'), 'address': {'building': '218', 'coord': [-73.9885862, 40.7295327], 'street': 'East    9 Street', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'Japanese', 'grades': [{'date': datetime.datetime(2014, 7, 2, 0, 0), 'grade': 'B', 'score': 14}, {'date': datetime.datetime(2013, 10, 16, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 2, 7, 0, 0), 'grade': 'B', 'score': 18}, {'date': datetime.datetime(2012, 6, 12, 0, 0), 'grade': 'B', 'score': 17}, {'date': datetime.datetime(2012, 1, 10, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'Yakiniku West Restaurant', 'restaurant_id': '40892845'}
# {'_id': ObjectId('65df17a87377fb2e6cd15dab'), 'address': {'building': '14720', 'coord': [-73.8184241, 40.7650549], 'street': 'Northern Boulevard', 'zipcode': '11354'}, 'borough': 'Queens', 'cuisine': 'Pizza/Italian', 'grades': [{'date': datetime.datetime(2013, 12, 17, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 7, 6, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 1, 7, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 6, 11, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Xtra Cheese Pizzeria', 'restaurant_id': '40593817'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16275'), 'address': {'building': '36', 'coord': [-73.9799204, 40.7578379], 'street': 'West   48 Street', 'zipcode': '10036'}, 'borough': 'Manhattan', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2014, 12, 12, 0, 0), 'grade': 'Z', 'score': 36}, {'date': datetime.datetime(2014, 5, 21, 0, 0), 'grade': 'B', 'score': 27}, {'date': datetime.datetime(2013, 10, 23, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 4, 11, 0, 0), 'grade': 'B', 'score': 27}, {'date': datetime.datetime(2012, 9, 11, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 12, 19, 0, 0), 'grade': 'B', 'score': 24}], 'name': 'Wu Liang Ye Restaurant', 'restaurant_id': '40826684'}
# {'_id': ObjectId('65df17a97377fb2e6cd15df7'), 'address': {'building': '1125', 'coord': [-73.9590872, 40.7743729], 'street': 'Lexington Avenue', 'zipcode': '10075'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 11, 8, 0, 0), 'grade': 'Z', 'score': 36}, {'date': datetime.datetime(2014, 5, 13, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 8, 21, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 2, 19, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 8, 30, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 3, 26, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'Wrap N Run Grill', 'restaurant_id': '40604004'}
# {'_id': ObjectId('65df17a67377fb2e6cd159c3'), 'address': {'building': '956', 'coord': [-73.9634559, 40.768975], 'street': 'Lexington Avenue', 'zipcode': '10021'}, 'borough': 'Manhattan', 'cuisine': 'Café/Coffee/Tea', 'grades': [{'date': datetime.datetime(2014, 12, 15, 0, 0), 'grade': 'B', 'score': 16}, {'date': datetime.datetime(2014, 8, 7, 0, 0), 'grade': 'C', 'score': 56}, {'date': datetime.datetime(2014, 1, 28, 0, 0), 'grade': 'B', 'score': 27}, {'date': datetime.datetime(2013, 7, 17, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 7, 3, 0, 0), 'grade': 'P', 'score': 0}, {'date': datetime.datetime(2013, 1, 7, 0, 0), 'grade': 'B', 'score': 14}, {'date': datetime.datetime(2012, 8, 20, 0, 0), 'grade': 'C', 'score': 10}, {'date': datetime.datetime(2012, 2, 29, 0, 0), 'grade': 'A', 'score': 11}], 'name': 'World Cup Cafe', 'restaurant_id': '40398588'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b27'), 'address': {'building': '655', 'coord': [-74.20658449999999, 40.54289199999999], 'street': 'Rossville Avenue', 'zipcode': '10309'}, 'borough': 'Staten Island', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2015, 1, 12, 0, 0), 'grade': 'Z', 'score': 16}, {'date': datetime.datetime(2014, 6, 24, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 12, 5, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 4, 22, 0, 0), 'grade': 'B', 'score': 14}, {'date': datetime.datetime(2012, 9, 20, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 4, 11, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'Woodrow Diner', 'restaurant_id': '40510804'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b45'), 'address': {'building': '3700', 'coord': [-73.87808799999999, 40.8865392], 'street': 'Jerome Avenue', 'zipcode': '10467'}, 'borough': 'Bronx', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 2, 5, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 12, 19, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 7, 12, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 2, 6, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 8, 9, 0, 0), 'grade': 'B', 'score': 27}, {'date': datetime.datetime(2011, 6, 2, 0, 0), 'grade': 'P', 'score': 2}], 'name': 'Woodlawn Cafe', 'restaurant_id': '40512207'}
# {'_id': ObjectId('65df17a67377fb2e6cd15a97'), 'address': {'building': '2281', 'coord': [-73.95608, 40.650753], 'street': 'Church Avenue', 'zipcode': '11226'}, 'borough': 'Brooklyn', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 3, 15, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 6, 14, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 10, 7, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'Wood Bine Caterers', 'restaurant_id': '40402238'}
# {'_id': ObjectId('65df17a97377fb2e6cd15de1'), 'address': {'building': '41-19', 'coord': [-73.8289053, 40.7581581], 'street': 'Kissena Boulevard', 'zipcode': '11355'}, 'borough': 'Queens', 'cuisine': 'Korean', 'grades': [{'date': datetime.datetime(2014, 11, 13, 0, 0), 'grade': 'B', 'score': 27}, {'date': datetime.datetime(2014, 4, 16, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 9, 11, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2013, 8, 28, 0, 0), 'grade': 'P', 'score': 2}, {'date': datetime.datetime(2013, 5, 21, 0, 0), 'grade': 'B', 'score': 25}, {'date': datetime.datetime(2012, 11, 23, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2012, 8, 1, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 3, 7, 0, 0), 'grade': 'B', 'score': 23}], 'name': 'Woo Chon Restaurant', 'restaurant_id': '40601696'}
# {'_id': ObjectId('65df17ad7377fb2e6cd1637f'), 'address': {'building': '813', 'coord': [-73.9875078, 40.7659352], 'street': '9 Avenue', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'Thai', 'grades': [{'date': datetime.datetime(2015, 1, 9, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2014, 7, 10, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2014, 1, 16, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 5, 13, 0, 0), 'grade': 'B', 'score': 19}, {'date': datetime.datetime(2012, 4, 3, 0, 0), 'grade': 'A', 'score': 9}], 'name': 'Wondee Siam Ii', 'restaurant_id': '40871795'}
# {'_id': ObjectId('65df17a67377fb2e6cd15aa1'), 'address': {'building': '3', 'coord': [-73.97731999999999, 40.759653], 'street': 'West   51 Street', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 10, 3, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 10, 4, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 5, 21, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 11, 26, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 6, 4, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'Womens Natl. Republican Club', 'restaurant_id': '40402375'}
# {'_id': ObjectId('65df17aa7377fb2e6cd15f20'), 'address': {'building': '10', 'coord': [-73.9773755, 40.7568284], 'street': 'East   48 Street', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'Steak', 'grades': [{'date': datetime.datetime(2014, 12, 16, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 6, 16, 0, 0), 'grade': 'B', 'score': 18}, {'date': datetime.datetime(2013, 10, 8, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 2, 20, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 4, 30, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Wolf And Lamb', 'restaurant_id': '40668380'}
# {'_id': ObjectId('65df17a77377fb2e6cd15b0f'), 'address': {'building': '1634', 'coord': [-73.983583, 40.76174839999999], 'street': 'Broadway', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 7, 15, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2014, 2, 15, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 4, 25, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 6, 19, 0, 0), 'grade': 'A', 'score': 8}], 'name': 'Winter Garden Theater', 'restaurant_id': '40482600'}
# {'_id': ObjectId('65df17a57377fb2e6cd157de'), 'address': {'building': '104', 'coord': [-73.99976319999999, 40.7162194], 'street': 'Bayard Street', 'zipcode': '10013'}, 'borough': 'Manhattan', 'cuisine': 'Chinese', 'grades': [{'date': datetime.datetime(2014, 6, 17, 0, 0), 'grade': 'B', 'score': 16}, {'date': datetime.datetime(2013, 10, 16, 0, 0), 'grade': 'B', 'score': 21}, {'date': datetime.datetime(2013, 4, 9, 0, 0), 'grade': 'B', 'score': 17}, {'date': datetime.datetime(2012, 7, 13, 0, 0), 'grade': 'B', 'score': 23}], 'name': "Winnie'S Bar", 'restaurant_id': '40386287'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d6b'), 'address': {'building': '65', 'coord': [-73.9897793, 40.7260641], 'street': '2 Avenue', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'Mediterranean', 'grades': [{'date': datetime.datetime(2014, 12, 23, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 11, 30, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2013, 6, 11, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 11, 30, 0, 0), 'grade': 'B', 'score': 20}], 'name': 'Wine Bar', 'restaurant_id': '40585948'}
# {'_id': ObjectId('65df17a47377fb2e6cd15736'), 'address': {'building': '552', 'coord': [-73.9070012, 40.7090773], 'street': 'Grandview Avenue', 'zipcode': '11385'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 9, 9, 0, 0), 'grade': 'B', 'score': 14}, {'date': datetime.datetime(2014, 1, 7, 0, 0), 'grade': 'B', 'score': 18}, {'date': datetime.datetime(2012, 11, 29, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'Windjammers Bar', 'restaurant_id': '40377908'}
# {'_id': ObjectId('65df17aa7377fb2e6cd1601b'), 'address': {'building': '23', 'coord': [-73.9836989, 40.7522855], 'street': 'West   39 Street', 'zipcode': '10018'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 6, 30, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 12, 17, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 6, 20, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2012, 10, 2, 0, 0), 'grade': 'C', 'score': 43}, {'date': datetime.datetime(2012, 4, 9, 0, 0), 'grade': 'A', 'score': 9}], 'name': 'Windfall', 'restaurant_id': '40718574'}
# {'_id': ObjectId('65df17a67377fb2e6cd1592d'), 'address': {'building': '23312', 'coord': [-73.736463, 40.73316], 'street': 'Hillside Avenue', 'zipcode': '11427'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 9, 4, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2014, 3, 10, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 8, 21, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 5, 31, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 10, 18, 0, 0), 'grade': 'B', 'score': 14}], 'name': 'Winchesters Pub', 'restaurant_id': '40395218'}
# {'_id': ObjectId('65df17ad7377fb2e6cd16388'), 'address': {'building': '1822', 'coord': [-73.9453752, 40.828686], 'street': 'Amsterdam Avenue', 'zipcode': '10031'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 5, 8, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 11, 26, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 4, 1, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2012, 9, 17, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 9, 8, 0, 0), 'grade': 'A', 'score': 7}], 'name': "Wimpy'S Restaurant", 'restaurant_id': '40873138'}
# {'_id': ObjectId('65df17a47377fb2e6cd15579'), 'address': {'building': '7114', 'coord': [-73.9068506, 40.6199034], 'street': 'Avenue U', 'zipcode': '11234'}, 'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'grades': [{'date': datetime.datetime(2014, 5, 29, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2014, 1, 14, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 8, 3, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 7, 18, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 3, 9, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 10, 14, 0, 0), 'grade': 'A', 'score': 9}], 'name': "Wilken'S Fine Food", 'restaurant_id': '40356483'}
# {'_id': ObjectId('65df17a47377fb2e6cd1557c'), 'address': {'building': '2300', 'coord': [-73.8786113, 40.8502883], 'street': 'Southern Boulevard', 'zipcode': '10460'}, 'borough': 'Bronx', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 5, 28, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 6, 19, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2012, 6, 15, 0, 0), 'grade': 'A', 'score': 3}], 'name': 'Wild Asia', 'restaurant_id': '40357217'}
# {'_id': ObjectId('65df17ad7377fb2e6cd16381'), 'address': {'building': '605', 'coord': [-73.9020967, 40.81298], 'street': 'Southern Boulevard', 'zipcode': '10455'}, 'borough': 'Bronx', 'cuisine': 'Pizza', 'grades': [{'date': datetime.datetime(2014, 9, 18, 0, 0), 'grade': 'B', 'score': 21}, {'date': datetime.datetime(2014, 4, 15, 0, 0), 'grade': 'C', 'score': 32}, {'date': datetime.datetime(2013, 10, 8, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 9, 20, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 5, 7, 0, 0), 'grade': 'B', 'score': 19}, {'date': datetime.datetime(2011, 10, 13, 0, 0), 'grade': 'B', 'score': 19}], 'name': 'Wilbel Pizza', 'restaurant_id': '40871979'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d01'), 'address': {'building': '60', 'coord': [-73.99480199999999, 40.735016], 'street': 'Fifth Avenue', 'zipcode': '10011'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 2, 14, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 2, 5, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 2, 8, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 3, 1, 0, 0), 'grade': 'A', 'score': 11}], 'name': 'Whitsons And Forbes', 'restaurant_id': '40573432'}
# {'_id': ObjectId('65df17a47377fb2e6cd15673'), 'address': {'building': '3005', 'coord': [-73.8335566, 40.7703224], 'street': 'Whitestone Expressway', 'zipcode': '11354'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 9, 18, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 2, 18, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 6, 8, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 9, 15, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2011, 12, 7, 0, 0), 'grade': 'B', 'score': 16}], 'name': 'Whitestone Lanes', 'restaurant_id': '40369213'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d08'), 'address': {'building': '24-17', 'coord': [-73.817261, 40.7768177], 'street': '149 Street', 'zipcode': '11357'}, 'borough': 'Queens', 'cuisine': 'Delicatessen', 'grades': [{'date': datetime.datetime(2014, 4, 28, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 5, 13, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 5, 21, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 6, 13, 0, 0), 'grade': 'A', 'score': 11}], 'name': 'Whitestone Bagel Factory', 'restaurant_id': '40574150'}
# {'_id': ObjectId('65df17a47377fb2e6cd155c8'), 'address': {'building': '567', 'coord': [-74.00619499999999, 40.735663], 'street': 'Hudson Street', 'zipcode': '10014'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 7, 28, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 7, 25, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 2, 5, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 5, 29, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2011, 12, 23, 0, 0), 'grade': 'A', 'score': 5}], 'name': 'White Horse Tavern', 'restaurant_id': '40364958'}
# {'_id': ObjectId('65df17a47377fb2e6cd15676'), 'address': {'building': '25', 'coord': [-74.012376, 40.703721], 'street': 'Bridge Street', 'zipcode': '10004'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 8, 20, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 3, 21, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 9, 16, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'B', 'score': 15}, {'date': datetime.datetime(2012, 9, 13, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2011, 12, 30, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 9, 7, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'White Horse Tavern', 'restaurant_id': '40369400'}
# {'_id': ObjectId('65df17a47377fb2e6cd1558c'), 'address': {'building': '531', 'coord': [-73.9634876, 40.6940001], 'street': 'Myrtle Avenue', 'zipcode': '11205'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 3, 18, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2013, 3, 18, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 10, 10, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 9, 22, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40362344'}
# {'_id': ObjectId('65df17a47377fb2e6cd15683'), 'address': {'building': '846', 'coord': [-73.9321666, 40.6632351], 'street': 'Empire Boulevard', 'zipcode': '11213'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 3, 6, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 3, 1, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 3, 3, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2011, 3, 17, 0, 0), 'grade': 'A', 'score': 7}], 'name': 'White Castle', 'restaurant_id': '40369667'}
# {'_id': ObjectId('65df17a47377fb2e6cd15684'), 'address': {'building': '2701', 'coord': [-72.7329266, 41.3099228], 'street': 'Boston Post Road', 'zipcode': '10467'}, 'borough': 'Bronx', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 5, 28, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2014, 1, 16, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 1, 2, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 12, 27, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40369669'}
# {'_id': ObjectId('65df17a47377fb2e6cd15685'), 'address': {'building': '43-02', 'coord': [-73.92126499999999, 40.743009], 'street': 'Queens Boulevard', 'zipcode': '11104'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 3, 25, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2012, 3, 20, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 4, 14, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'White Castle', 'restaurant_id': '40369675'}
# {'_id': ObjectId('65df17a47377fb2e6cd15686'), 'address': {'building': '4202', 'coord': [-73.993031, 40.6417669], 'street': 'Ft Hamilton Parkway', 'zipcode': '11219'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 12, 9, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2013, 12, 31, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 12, 31, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 12, 30, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'White Castle', 'restaurant_id': '40369676'}
# {'_id': ObjectId('65df17a57377fb2e6cd157b4'), 'address': {'building': '900', 'coord': [-73.88898209999999, 40.65584459999999], 'street': 'Pennsylvania Avenue', 'zipcode': '11207'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 6, 9, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 6, 21, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 1, 29, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 1, 12, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'White Castle', 'restaurant_id': '40384575'}
# {'_id': ObjectId('65df17a57377fb2e6cd157eb'), 'address': {'building': '213-17', 'coord': [-73.76981409999999, 40.7605092], 'street': 'Northern Boulevard', 'zipcode': '11361'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 3, 5, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 2, 27, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2012, 2, 23, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2011, 3, 17, 0, 0), 'grade': 'A', 'score': 5}], 'name': 'White Castle', 'restaurant_id': '40386612'}
# {'_id': ObjectId('65df17a57377fb2e6cd157f4'), 'address': {'building': '3101', 'coord': [-73.8812773, 40.679218], 'street': 'Atlantic Avenue', 'zipcode': '11208'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 11, 14, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 10, 21, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 11, 14, 0, 0), 'grade': 'A', 'score': 0}], 'name': 'White Castle', 'restaurant_id': '40386837'}
# {'_id': ObjectId('65df17a57377fb2e6cd157fb'), 'address': {'building': '1677', 'coord': [-73.87113099999999, 40.825183], 'street': 'Bruckner Boulevard', 'zipcode': '10472'}, 'borough': 'Bronx', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2013, 12, 13, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 12, 6, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 12, 22, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 1, 12, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40387143'}
# {'_id': ObjectId('65df17a57377fb2e6cd157fd'), 'address': {'building': '550', 'coord': [-73.8864787, 40.8588703], 'street': 'East Fordham Road', 'zipcode': '10458'}, 'borough': 'Bronx', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 3, 27, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 3, 19, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 10, 23, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 11, 3, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'White Castle', 'restaurant_id': '40387178'}
# {'_id': ObjectId('65df17a57377fb2e6cd15820'), 'address': {'building': '3663', 'coord': [-73.8419254, 40.8803012], 'street': 'Boston Road', 'zipcode': '10466'}, 'borough': 'Bronx', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 12, 3, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 12, 24, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 12, 19, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40388269'}
# {'_id': ObjectId('65df17a57377fb2e6cd15832'), 'address': {'building': '781', 'coord': [-73.9431862, 40.7146566], 'street': 'Metropolitan Avenue', 'zipcode': '11211'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 8, 25, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 9, 9, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 3, 26, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 3, 5, 0, 0), 'grade': 'P', 'score': 2}, {'date': datetime.datetime(2012, 3, 6, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40388703'}
# {'_id': ObjectId('65df17a57377fb2e6cd15870'), 'address': {'building': '112-11', 'coord': [-73.739475, 40.705207], 'street': 'Springfield Boulevard', 'zipcode': '11429'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2015, 1, 5, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2013, 12, 12, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 12, 18, 0, 0), 'grade': 'A', 'score': 10}], 'name': 'White Castle', 'restaurant_id': '40390758'}
# {'_id': ObjectId('65df17a57377fb2e6cd1589c'), 'address': {'building': '8802', 'coord': [-73.8794087, 40.7559137], 'street': 'Northern Boulevard', 'zipcode': '11372'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 8, 6, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2014, 3, 21, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 7, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 3, 8, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2011, 10, 12, 0, 0), 'grade': 'A', 'score': 2}], 'name': 'White Castle', 'restaurant_id': '40391714'}
# {'_id': ObjectId('65df17a57377fb2e6cd158cd'), 'address': {'building': '959', 'coord': [-73.9605993, 40.6805698], 'street': 'Atlantic Avenue', 'zipcode': '11238'}, 'borough': 'Brooklyn', 'cuisine': 'Sandwiches', 'grades': [{'date': datetime.datetime(2014, 2, 26, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2013, 9, 19, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 8, 7, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2011, 8, 25, 0, 0), 'grade': 'A', 'score': 4}], 'name': 'White Castle', 'restaurant_id': '40393253'}
# {'_id': ObjectId('65df17a57377fb2e6cd158f2'), 'address': {'building': '175-28', 'coord': [-73.7977964, 40.7090806], 'street': 'Hillside Avenue', 'zipcode': '11432'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 2, 19, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 2, 13, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 9, 6, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 9, 14, 0, 0), 'grade': 'A', 'score': 5}], 'name': 'White Castle', 'restaurant_id': '40394037'}
# {'_id': ObjectId('65df17a67377fb2e6cd15939'), 'address': {'building': '2900', 'coord': [-73.8413936, 40.8402053], 'street': 'East Tremont Avenue', 'zipcode': '10461'}, 'borough': 'Bronx', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 2, 6, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 9, 11, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 3, 27, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2012, 2, 27, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 3, 24, 0, 0), 'grade': 'A', 'score': 5}], 'name': 'White Castle', 'restaurant_id': '40395511'}
# {'_id': ObjectId('65df17a67377fb2e6cd1594b'), 'address': {'building': '98-08', 'coord': [-73.84043869999999, 40.6797863], 'street': 'Rockaway Boulevard', 'zipcode': '11417'}, 'borough': 'Queens', 'cuisine': 'Hamburgers', 'grades': [{'date': datetime.datetime(2014, 4, 3, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 5, 8, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2012, 4, 23, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2011, 5, 16, 0, 0), 'grade': 'A', 'score': 13}], 'name': 'White Castle', 'restaurant_id': '40395882'}
# ...
# {'_id': ObjectId('65df17ac7377fb2e6cd162ce'), 'address': {'building': '324', 'coord': [-73.9815295, 40.667258], 'street': '7 Avenue', 'zipcode': '11215'}, 'borough': 'Brooklyn', 'cuisine': 'Donuts', 'grades': [{'date': datetime.datetime(2014, 10, 24, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2013, 11, 12, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 7, 15, 0, 0), 'grade': 'C', 'score': 63}, {'date': datetime.datetime(2013, 2, 5, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 1, 19, 0, 0), 'grade': 'A', 'score': 13}], 'name': '7Th Avenue Donut Shop', 'restaurant_id': '40846477'}
# {'_id': ObjectId('65df17a47377fb2e6cd155b7'), 'address': {'building': '108', 'coord': [-73.98146, 40.7250067], 'street': 'Avenue B', 'zipcode': '10009'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 7, 14, 0, 0), 'grade': 'B', 'score': 17}, {'date': datetime.datetime(2013, 12, 31, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 10, 22, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 5, 7, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 10, 14, 0, 0), 'grade': 'A', 'score': 12}], 'name': '7B Bar', 'restaurant_id': '40364518'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16298'), 'address': {'building': '71', 'coord': [-73.9870226, 40.7368137], 'street': 'Irving Place', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 9, 30, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2014, 4, 21, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 10, 10, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 5, 1, 0, 0), 'grade': 'C', 'score': 37}, {'date': datetime.datetime(2012, 5, 2, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 12, 23, 0, 0), 'grade': 'A', 'score': 7}], 'name': '71 Irving Place', 'restaurant_id': '40835721'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16258'), 'address': {'building': '13209', 'coord': [-73.83604179999999, 40.7867641], 'street': '14 Avenue', 'zipcode': '11356'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 8, 21, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2014, 4, 2, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 9, 25, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 4, 8, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 2, 6, 0, 0), 'grade': 'A', 'score': 12}], 'name': '7 Stars', 'restaurant_id': '40820080'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16208'), 'address': {'building': '525', 'coord': [-73.9728136, 40.75546629999999], 'street': 'Lexington Ave', 'zipcode': '10017'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 7, 22, 0, 0), 'grade': 'C', 'score': 41}, {'date': datetime.datetime(2014, 1, 24, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'B', 'score': 24}, {'date': datetime.datetime(2012, 9, 12, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 4, 12, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 10, 24, 0, 0), 'grade': 'C', 'score': 33}], 'name': '525 Lex Restaurant & Bar', 'restaurant_id': '40806489'}
# {'_id': ObjectId('65df17a57377fb2e6cd1585f'), 'address': {'building': '7205', 'coord': [-73.8424017, 40.7194513], 'street': 'Austin Street', 'zipcode': '11375'}, 'borough': 'Queens', 'cuisine': 'Mexican', 'grades': [{'date': datetime.datetime(2014, 3, 4, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 2, 25, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 12, 8, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 5, 23, 0, 0), 'grade': 'B', 'score': 18}], 'name': '5 Burro Cafe', 'restaurant_id': '40390163'}
# {'_id': ObjectId('65df17aa7377fb2e6cd15fa7'), 'address': {'building': '621', 'coord': [-73.992069, 40.759761], 'street': '9 Avenue', 'zipcode': '10036'}, 'borough': 'Manhattan', 'cuisine': 'Italian', 'grades': [{'date': datetime.datetime(2014, 4, 30, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 11, 19, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 3, 4, 0, 0), 'grade': 'B', 'score': 19}, {'date': datetime.datetime(2012, 7, 21, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 11, 14, 0, 0), 'grade': 'B', 'score': 16}], 'name': '44 Sw Ristorante & Bar', 'restaurant_id': '40698807'}
# {'_id': ObjectId('65df17ac7377fb2e6cd1621b'), 'address': {'building': '622', 'coord': [-73.9942049, 40.7610193], 'street': '10 Avenue', 'zipcode': '10036'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 12, 22, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 6, 19, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 11, 26, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 6, 8, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 10, 24, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 4, 18, 0, 0), 'grade': 'A', 'score': 13}], 'name': "44 & X Hell'S Kitchen", 'restaurant_id': '40809948'}
# {'_id': ObjectId('65df17a97377fb2e6cd15e03'), 'address': {'building': '647', 'coord': [-74.0001028, 40.7619413], 'street': 'West   42 Street', 'zipcode': '10036'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2014, 6, 4, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2013, 11, 20, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 3, 20, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 12, 22, 0, 0), 'grade': 'A', 'score': 10}], 'name': '42Nd Street Pizza Diner', 'restaurant_id': '40605319'}
# {'_id': ObjectId('65df17a97377fb2e6cd15e91'), 'address': {'building': '1232', 'coord': [-73.957787, 40.782685], 'street': 'Madison Avenue', 'zipcode': '10128'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 11, 18, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 11, 7, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 5, 29, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 12, 17, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 6, 21, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 2, 1, 0, 0), 'grade': 'A', 'score': 9}], 'name': '3 Guys Resturant', 'restaurant_id': '40640495'}
# {'_id': ObjectId('65df17a57377fb2e6cd1588b'), 'address': {'building': '1381', 'coord': [-73.9538783, 40.787312], 'street': 'Madison Avenue', 'zipcode': '10029'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 8, 21, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2014, 4, 18, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2013, 3, 12, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 10, 11, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 5, 10, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 12, 15, 0, 0), 'grade': 'A', 'score': 12}], 'name': '3 Guys', 'restaurant_id': '40391339'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d9e'), 'address': {'building': '133', 'coord': [-73.9702969, 40.75983919999999], 'street': 'East 55 Street', 'zipcode': '10022'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 4, 3, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2013, 3, 27, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2012, 10, 17, 0, 0), 'grade': 'A', 'score': 8}, {'date': datetime.datetime(2012, 4, 27, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2011, 12, 6, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2011, 7, 18, 0, 0), 'grade': 'A', 'score': 12}], 'name': '3 Deli & Grill', 'restaurant_id': '40592296'}
# {'_id': ObjectId('65df17a57377fb2e6cd15836'), 'address': {'building': '25', 'coord': [-73.9860427, 40.7229989], 'street': 'Avenue A', 'zipcode': '10009'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2013, 10, 29, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 10, 27, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2011, 10, 18, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 6, 23, 0, 0), 'grade': 'A', 'score': 7}], 'name': '2A', 'restaurant_id': '40388784'}
# {'_id': ObjectId('65df17a47377fb2e6cd155ae'), 'address': {'building': '21', 'coord': [-73.9774394, 40.7604522], 'street': 'West   52 Street', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 5, 14, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 8, 13, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 4, 4, 0, 0), 'grade': 'A', 'score': 12}], 'name': '21 Club', 'restaurant_id': '40364362'}
# {'_id': ObjectId('65df17a57377fb2e6cd157c5'), 'address': {'building': '200', 'coord': [-73.9804898, 40.6768216], 'street': '5 Avenue', 'zipcode': '11217'}, 'borough': 'Brooklyn', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 7, 3, 0, 0), 'grade': 'B', 'score': 26}, {'date': datetime.datetime(2013, 10, 30, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2013, 3, 21, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 8, 7, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2012, 3, 9, 0, 0), 'grade': 'C', 'score': 42}, {'date': datetime.datetime(2011, 10, 13, 0, 0), 'grade': 'A', 'score': 13}], 'name': '200 Fifth Avenue Restaurant & Sports Bar', 'restaurant_id': '40385555'}
# {'_id': ObjectId('65df17aa7377fb2e6cd15faa'), 'address': {'building': '15', 'coord': [-73.9921155, 40.7364657], 'street': 'East   15 Street', 'zipcode': '10003'}, 'borough': 'Manhattan', 'cuisine': 'Japanese', 'grades': [{'date': datetime.datetime(2014, 6, 28, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 10, 22, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'C', 'score': 64}, {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 2, 3, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2011, 6, 30, 0, 0), 'grade': 'A', 'score': 10}], 'name': '15 East Restaurant', 'restaurant_id': '40698892'}
# {'_id': ObjectId('65df17ad7377fb2e6cd163da'), 'address': {'building': '0', 'coord': [-73.7889689, 40.6433507], 'street': 'Central Taxi Hold', 'zipcode': '11430'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 3, 6, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 9, 18, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 8, 21, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2012, 2, 6, 0, 0), 'grade': 'B', 'score': 15}], 'name': '111 Restaurant', 'restaurant_id': '40884354'}
# {'_id': ObjectId('65df17aa7377fb2e6cd15f38'), 'address': {'building': '256', 'coord': [-73.998993, 40.74718060000001], 'street': '10Th Ave Bet 24 & 25 St )', 'zipcode': '10001'}, 'borough': 'Manhattan', 'cuisine': 'Pizza', 'grades': [{'date': datetime.datetime(2014, 11, 10, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 10, 21, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 5, 31, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 12, 14, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 7, 9, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 2, 3, 0, 0), 'grade': 'A', 'score': 9}], 'name': '10Th Avenue Pizza & Cafe', 'restaurant_id': '40673117'}
# {'_id': ObjectId('65df17a97377fb2e6cd15e8c'), 'address': {'building': '10401', 'coord': [-73.9004264, 40.6520939], 'street': 'Foster Avenue', 'zipcode': '11236'}, 'borough': 'Brooklyn', 'cuisine': 'Café/Coffee/Tea', 'grades': [{'date': datetime.datetime(2014, 12, 8, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2014, 4, 8, 0, 0), 'grade': 'B', 'score': 19}, {'date': datetime.datetime(2013, 3, 7, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2012, 10, 4, 0, 0), 'grade': 'A', 'score': 8}], 'name': '104-01 Foster Avenue Coffee Shop(Ups)', 'restaurant_id': '40639261'}
# {'_id': ObjectId('65df17a67377fb2e6cd15a52'), 'address': {'building': '1020', 'coord': [-73.96396419999999, 40.8032642], 'street': 'Amsterdam Avenue', 'zipcode': '10025'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 6, 26, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2013, 6, 19, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 12, 27, 0, 0), 'grade': 'C', 'score': 38}], 'name': '1020 Bar', 'restaurant_id': '40401104'}
# {'_id': ObjectId('65df17a87377fb2e6cd15c85'), 'address': {'building': '10018', 'coord': [-74.0343092, 40.6125569], 'street': '4 Avenue', 'zipcode': '11209'}, 'borough': 'Brooklyn', 'cuisine': 'Italian', 'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 11, 29, 0, 0), 'grade': 'A', 'score': 13}, {'date': datetime.datetime(2013, 6, 3, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 6, 5, 0, 0), 'grade': 'B', 'score': 15}, {'date': datetime.datetime(2012, 1, 10, 0, 0), 'grade': 'A', 'score': 10}], 'name': '101 Restaurant And Bar', 'restaurant_id': '40560108'}
# {'_id': ObjectId('65df17a87377fb2e6cd15d91'), 'address': {'building': '10016', 'coord': [-73.8216636, 40.5838155], 'street': 'Rockaway Beach Boulevard', 'zipcode': '11694'}, 'borough': 'Queens', 'cuisine': 'Delicatessen', 'grades': [{'date': datetime.datetime(2014, 1, 28, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2013, 8, 20, 0, 0), 'grade': 'A', 'score': 9}, {'date': datetime.datetime(2013, 3, 19, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2012, 3, 6, 0, 0), 'grade': 'A', 'score': 10}, {'date': datetime.datetime(2011, 3, 1, 0, 0), 'grade': 'A', 'score': 12}], 'name': '101 Deli', 'restaurant_id': '40591271'}
# {'_id': ObjectId('65df17a47377fb2e6cd1557f'), 'address': {'building': '1', 'coord': [-73.96926909999999, 40.7685235], 'street': 'East   66 Street', 'zipcode': '10065'}, 'borough': 'Manhattan', 'cuisine': 'American ', 'grades': [{'date': datetime.datetime(2014, 5, 7, 0, 0), 'grade': 'A', 'score': 3}, {'date': datetime.datetime(2013, 5, 3, 0, 0), 'grade': 'A', 'score': 4}, {'date': datetime.datetime(2012, 4, 30, 0, 0), 'grade': 'A', 'score': 6}, {'date': datetime.datetime(2011, 12, 27, 0, 0), 'grade': 'A', 'score': 0}], 'name': '1 East 66Th Street Kitchen', 'restaurant_id': '40359480'}
# {'_id': ObjectId('65df17ac7377fb2e6cd16202'), 'address': {'building': '129', 'coord': [-73.962943, 40.685007], 'street': 'Gates Avenue', 'zipcode': '11238'}, 'borough': 'Brooklyn', 'cuisine': 'Italian', 'grades': [{'date': datetime.datetime(2014, 3, 6, 0, 0), 'grade': 'A', 'score': 5}, {'date': datetime.datetime(2013, 8, 29, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 3, 8, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2012, 6, 27, 0, 0), 'grade': 'A', 'score': 7}, {'date': datetime.datetime(2011, 11, 17, 0, 0), 'grade': 'A', 'score': 12}], 'name': '(Lewis Drug Store) Locanda Vini E Olii', 'restaurant_id': '40804423'}

# %% [markdown]
# 27. Escribe una sentencia que ordene los restaurantes por el campo cuisine en orden ascendente y para esa misma cocina el campo borough en orden descendente.

# %%
consulta = db.restaurants.find({},{"name":1, "cuisine":1, "borough":1, "_id":0}).sort([("cuisine", 1), ("borough", -1)])
for restaurant in consulta:
    print(restaurant)
# Out:
# {'borough': 'Manhattan', 'cuisine': 'Afghan', 'name': 'Afghan Kebab House'}
# {'borough': 'Manhattan', 'cuisine': 'Afghan', 'name': 'Khyber Pass'}
# {'borough': 'Manhattan', 'cuisine': 'Afghan', 'name': 'Afghan Kebab House #1'}
# {'borough': 'Manhattan', 'cuisine': 'Afghan', 'name': 'Ariana Kebab House'}
# {'borough': 'Queens', 'cuisine': 'African', 'name': 'Africana Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'African', 'name': 'Madiba'}
# {'borough': 'Bronx', 'cuisine': 'African', 'name': 'African Terrace'}
# {'borough': 'Bronx', 'cuisine': 'African', 'name': 'Ebe Ye Yie African Restaurant'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Great Kills Yacht Club'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Labetti'S Post # 2159"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'South Shore Swimming Club'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Joyce'S Tavern"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Li Greci'S Staaten Restaurant"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Richmond County Country Club'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Buddy'S Wonder Bar"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Colonnade Diner'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Jody'S Club"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Perkins Family Restaurant & Bakery'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Schaffer'S Tavern"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Exclusive Catering'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Golden Dove Diner'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "King'S Arms Restaurant"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'War Memorial Ice Skating Rink'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Union Hall'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Duffy'S"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Latourette Golf Course'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Dakota Diner'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Jimmy Max Restaurant'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Rosebank Tavern'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Danny Blaine'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Hillside Swimming Club'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Excelsior Catering'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Henny'S Restaurant"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Legend'S Pub"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Rab'S Country Lane"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Island Chateau'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'The Cake Chef'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Hidden Cottage'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Woodrow Diner'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Campus Center Cafeteria'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Grand Plaza'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Perkins Family Restaurant & Bakery'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "W'S Bar & Restaurant"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'The Corner House'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Blue & Gray Inn'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Mug Shots'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Ground Level Beer Pub'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Afternoone'S Restaurant"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Applebee'S Neighborhood Grill & Bar"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'The Mansion Grand'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Perkins Family Restaurant & Bakery'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'The Historic Old Bermuda Inn'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Andrew'S Diner"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Unique Lounge'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Mike'S Place"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Island Shores'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Curves Gentleman'S Club"}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Richmond County Country Club - Pool Snack Bar'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Richmond County Country Club(10Th Hole)'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Richmond County Country Club'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Bermay Luncheonette'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Dock Street Bar & Grill'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Columbus House'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Boulevard Tavern'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'Lorenzos Bar & Grill (Hilton Garden)'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': 'The Black Dog Grill'}
# {'borough': 'Staten Island', 'cuisine': 'American ', 'name': "Jerry'S 637 Diner"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Brunos On The Boulevard'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Snack Time Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Terminal Cafe/Yankee Clipper'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Douglaston Club'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Jahn'S Restaurant"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Lavelle'S Admiral'S Club"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Nancy'S Fire Side"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Blarney Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Healy'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Lenihan'S Saloon"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Blarney Castle'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Maloney'S Bar"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Little Brown Jug'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Charlies Sports Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Assembly Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "P.J.' S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Whitestone Lanes'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Dart Inn'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Pat'S Stationary"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Divers Cove'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Tjk Cafe & Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sizzler'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'North Shore Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Water Front Crab House'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Burke'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Hill Tap Tavern'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Europa Go-Go Dancing'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Moms Luncheonette'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Water'S Edge Club"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Windjammers Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Port O' Calls"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Mike'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Clubhouse'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Fame Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Yankee Clipper'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Riverhead Gentlemen'S Club"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Cobblestone Pub'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Kanes Deli Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Doral Donuts'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Jacks Ale House'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Tasty'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Oakland Cafeteria/Queensborough Community College'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Q.B.Comm.College-Main Kitchen/Tiger Bites Pizza Section'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Copper Kettle'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Science Cafe (Queensborough  Community College)'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Kelly'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Ideal Donut'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Austin House'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Wharf Bar And Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'B.Q.E. Cafe Billiards'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Georgia Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Court Square Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Glen Patrick'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'C & B Luncheonette'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Glen Patrick'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Jackson Hole'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The End Zone Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Ambassador Dining Room  At Saratoga Family Inn'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Russo'S On The Bay"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Buccaneer Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'American Airlines Employee Cafeteria'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Winchesters Pub'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'T-Bone Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sunrise Coffee Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Ilda'S Place Ii"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Broadway Station'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Alpha Donuts'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Ritmo'S 60"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Rockaway Beach Inn'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Paradise Alley Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Olympia'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Paddy Quinns'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Cj Sullivan'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Home Deli & Catering'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Vixens'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "O'Hanlon'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Flagship Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Doyle'S Corner"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'All American Coffee Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Jj Peabody'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Pj Horgan'S Pub"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Starting Gate'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Paris Gourmet Deli'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Usa Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Mcdonald'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sports Mania Bar & Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Timmy'S Deli"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Unforgettable Lounge'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Di Luvio'S Deli"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Astoria Bagel Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Cafeteria- Lirr Employees'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Antun'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'S.M.R Restaurant Services'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Astoria World Manor'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Blue Bay Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Rego Park Cafe'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Shenanigan'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Burger King'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Adria Hotel'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Cassidy'S Ale House"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Towers Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Mini Star Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Forest Hills Spa'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Nix Mix Coffee Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Crescent Corner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Riccardo'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Neptune Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Tastee Corner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Glenlo Tavern'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Roma View Catering'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Last Stop Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Jays Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Douglaston Golf Snacks'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Gussy'S Bar"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'El Dorado Sports Lounge'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Bel-Aire Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Citibank Employee Cafeteria'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Perfecto Pizza & Coffee Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Lovell'S Guiding Light"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Forest Park Golf Course'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Maggie Mays'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "T.G.I. Friday'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Steinway Billiard'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Van Dam Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Caprice'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Legends Bar & Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Tasty Fast Food'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Mcdonald'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Jackson Hole'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Terrace On The Park'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Thomas Preti Caterers'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Evolution'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Cookie'S Lounge"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sanfords Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Midway Cinemas'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Emerald Pub'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Track Kitchen'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Sean Og'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Bourbon Street'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Thomasina'S"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Delight Donut'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Trackside'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Kew Gardens Cinemas'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Tick Tavern'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'G.P. Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'No Partners'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Billiard Company'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Family Corner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Adrian & Rocky'S Caterers"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Juice For Life'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Scandals'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Mccaffrey And Burke'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Amf 34 Avenue Lanes'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Springfield Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Flushing Meadows Pitch And Putt'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Courtyard Ale House'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Tres Coronas Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Laguardia Courtyard Hotel By Marriott'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Cinnabon World Famous Cinnamon Rolls'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Boston Market'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Kelly'S Restaurant & Pizza"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Forest Hills Coffe Shop'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Terminal1 Employee Cafeteria'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Triple Crown Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "T.J.'S Sports Bar"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Funtopia Usa'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Applebee'S Neighborhood Grill & Bar"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Applebee'S Neighborhood Grill & Bar"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Dunkin' Donuts/Baskin Robins"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': '7 Stars'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Courtyard By Marriott'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The Patio Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Bungalow Bar & Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Nelly'S Corner Pizzeria Restaurant"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Connolly'S Corner"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Crossbay Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Uno Chicago Grill'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'La Verite Restaurant Bar'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'The New Thompson Diner'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Carmine'S Restaurant"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Ua Kaufman Astoria #14'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Gallagher'S 2000"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': "Bill'S Restaurant"}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': '111 Restaurant'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Swiss International Airlines Lounge'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Uno Cafe & Billiards'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'A & B Deli & Catering'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '1 East 66Th Street Kitchen'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Glorious Food'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'P & S Deli Grocery'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Angelika Film Center'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Downtown Deli'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Metro'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Berkely'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Spoon Bread Catering'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Metropolitan Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Palm Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '21 Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Old Town Bar & Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Criminal Court Bldg Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nyac Main Dining Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '7B Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Atelier (Art Students League)'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Old Homestead'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Serendipity 3'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'White Horse Tavern'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Corner Bistro'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Keats Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Princeton Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Reynold'S Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'La Parisienne Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Joe Allen Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Neary'S Pub"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nancy Whiskey Pub'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Dangerfield'S Night Club"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Desmond'S Tavern"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Riviera Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Finnegan'S Wake"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broome Street Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jg Melon Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Emerald Pub'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tap Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cocktail Room (Nyac)'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Flame Restaurant Coffee House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jackson Hole'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Grassroot Tavern'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Capitol Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Griffis Faculty Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ford Foundation Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Elephant & Castle'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cherry Tavern'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Red Flame Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Maggies Place'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Brady'S Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Benjamin'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Jimmy'S Corner"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Maries Crisis Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Boots & Saddle Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Brook'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Palm Too'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Reif'S Tavern"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'White Horse Tavern'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Knickerbocker Bar & Grill'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mudville Saloon'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Viand Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nectar Coffee Shop'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Cupping Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Pete'S Tavern"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Reme Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The New Amity Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ear Inn'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Three Guy'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Players Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Smith & Wollensky'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Olive Tree Cafe & Comedy Cellar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Coliseum Bar Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'West Bank Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Four Seasons'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Zafi'S Luncheonette"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Ty'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Murals On 54/Randolphs'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Greek Corner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Racquet & Tennis Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Astro Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bar 515'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Kasteli Ii'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Raccoon Lodge'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Lindy'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Paris Blues'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cozy Soup & Burger'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Candle Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Blue Note Jazz'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Manhattan Monster'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'American Museum Of Natural History Food Court'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Amsterdam Restaurant & Tapas Lounge'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Utopia Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jackson Hole'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Johns Cafe & Resturant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broadway Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Andrews Coffee Shop'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Terra Blues'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Gotham Bar & Grill'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cooper Town Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Delmonico'S Kitchen"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Imperial Coffee House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "O'Hara'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'E.A.T. Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Club 101'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Bitter End'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Barney Greengrass'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Supernova-Novotel Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Fit Cafeteria (Building A)'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Noho Star Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sidewalk Bar & Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Coogan'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Regency Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Parnell'S Pub"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Spring St. Natural Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cornelia Street Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Brandy'S Piano Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Jackson Hole'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Flash Dancers'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Josie'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Friend Of A Farmer'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Edison'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Automatic Slims'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cloister Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Jimbo'S Hamburger Place"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Niles Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'New York University - Law School'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Westside Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Club Metropolitan'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "T & G Whitney'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Live Bait Bar & Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Peculiar Pub'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "T.G.I. Friday'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Westway Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lenox Hill Grill/Pizza'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "T.G.I. Friday'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Walker'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Holland Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "T.G.I. Friday'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Dive Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Cornell Center Of New York'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nectar Of 82Nd Street'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "T.G.I. Friday'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '2A'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Pax Wholesome Foods'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'T.G.I. Fridays'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lucky Strike'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Tom'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Townhouse Of Ny'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Champ Gourmet'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Barfly'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "O'Flanagan'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Edge Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Scotty'S Diner"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Luke'S Bar & Grill"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Belaire Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Palace Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bar Association Of The City Of Ny Kitchen'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '3 Guys'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tokya'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Lily'S Bar @ Roger Smith Hotel"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sutton Cafe Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cambridge Caterers'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Henrietta Hudson'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lucys'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Amelia'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Patrick Conways'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Amsterdam Billiards'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'E.J Luncheonette'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Davis Polk Dining Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Down The Hatch'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Fitzgerald'S Pub"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tribeca Grill'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Julliard & S.A.B. Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Niagara/ Lovers Of Today/ Cabin Down Below'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Flight 151'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Moonstruck East'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Members Dining Room @ The Met Museum'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Caroline'S On Broadway"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Upper Crust'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Rudy'S Bar & Grill"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Coyote Ugly'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Le Petit Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Camilles'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Olympic Flame Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Stumble Inn'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Europa Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Hi Fi'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Delmonico Gourmet'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Auction House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Corner Cafe And Bakery'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Metro Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Evergreen Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Market Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Flannery'S Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Motivo'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Salisbury Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Mustang Sally'S Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Manhattan Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Le Mirage Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Morton'S Steakhouse"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Mercury Lounge'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Pyramid'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Toad Hall'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Landmark Coffee Shop'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Pax Wholesome Foods'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Weiss Cafe Rockefeller University'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tom And Jerry Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Dyckman Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Doc Holidays'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Rick'S Cabaret"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mumbles'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '9Th Ave Saloon'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sale & Pepe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Rockefeller U/Abby Bldg'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sony Music Employee Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sardis Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Judge Roy Bean'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'La Linea Lounge'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Green Trees'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Hangar Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Pieces'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bus Stop Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Matt'S Grill Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Beyond'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Sweet Life Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Campus Eatery'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Eighty Two'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'D.B.A.'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Smiler'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Gramercy Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Touch Of Dee'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Ellen'S Stardust Diner"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Ryan Maguire'S Bar & Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '1020 Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Big Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Heartland Brewery'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broadway Dive'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Jake'S Dilemma"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Water Front Ale House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Highlands Cafe Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Three Decker Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Columbus Gourmet Food'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Johnny'S Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "O'Nieals"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Brooklyn Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Tj Byrne'S Bar"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Metro'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Michael'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Colony Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Womens Natl. Republican Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Century Association'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Regency Whist Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Harvard Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The River Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Friars National Assoc.'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Union Club Of City Of New York'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'New York Jr. League'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Knickerbocker Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Anglers Club Of New York'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Down Town Association'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Union League Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lotos Club Grill Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Madison Square'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Yale Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Metropolitan Museum Employee Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Webster Apartments'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The University Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The University Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Harmonie Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cbs Employee Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Tap Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The University Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Simpson Thacher And Bartlet Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cleary Gottlieb'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Black Rock Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bank Of New York Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe 101 16Th Floor Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'P.S. Gourmet (Cafe On 8)'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Credit Agricole'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Good Shepherd Services'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'City College Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ing Forman Selz'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cravath Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Patterson Employee Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Penn Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mutual Of America'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Morgan Stanley Cafeteria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lazard Freres'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Zaro'S Bakery"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Creative Cakes'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Booth Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Majestic Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Bernard B Jacobs Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Shubert Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broadhurst Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Broadway Theatre'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Imperial Theatre'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Schoenfield'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Winter Garden Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lincoln Plaza Cinemas'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Joyce Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Walter Reade Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Gershwin Theatre'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Richard Rogers Theatre'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Nederlander Theater Ba'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Minskoff Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Marquis Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Brooks Atkinson Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lunt Fontanne Theater'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Devon & Blakely'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Ginger Man'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Central Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Silver Spurs/Molcajate Taqueria'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Cibar - Lady Mendl'S Tea Salon"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Barracuda Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Doc Watsons'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Firehouse'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mcgees Pub'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Ace Bar'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Skylight Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Soho Grand Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Creative Edge Caterers'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'St. Marks Ale House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Bubble Lounge'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Kings Carriage House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Mcquaids Public House'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Club Macanudo (Cigar Bar)'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Deb'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Swift'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe Bravo'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Mona'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Corner Gourmet Ii'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Tap-A-Keg'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'The Room'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Odessa'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Crown Gourmet Deli'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Von'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Neil Simon Theatre'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Trinity Pub'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Anesis Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': '810 Deli & Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Edward'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Four Seasons Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Four Seasons Hotel'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Red Eye Grill'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Mustang Harry'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Food Merchants'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': "Neuman'S"}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Renaissance Restaurant Bar And Garden Diner'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Escuelita Club'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'City Market Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Speedy Deli'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Prohibition'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Cafe 31'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Internationalhouse'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Fireside'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'G'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Death & Co'}
# {'borough': 'Manhattan', 'cuisine': 'American ', 'name': 'Lite Delights'}
# ...
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': "Rocco'S Italian Sausages & Philly Cheesesteaks"}
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': "American Hero & Sub'S"}
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Queens', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Roy Rogers'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Le Pain Quotidien'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Food Fair Deli & Pizza'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Le Pain Quotidien'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Pret A Manger'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Pret A Manger'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches', 'name': 'Blimpie'}
# {'borough': 'Brooklyn', 'cuisine': 'Sandwiches', 'name': 'White Castle'}
# {'borough': 'Brooklyn', 'cuisine': 'Sandwiches', 'name': 'Subway / Twin Donut'}
# {'borough': 'Bronx', 'cuisine': 'Sandwiches', 'name': 'Blimpie'}
# {'borough': 'Bronx', 'cuisine': 'Sandwiches', 'name': 'Subway'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Lexler Deli'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Devon & Blakely'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Bits Bite & Baguettes'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': "Moe'S Southwestern Grill/Charley'S"}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Le Pain Quotidien'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Le Bon Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Manhattan', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'borough': 'Brooklyn', 'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Au Bon Pain'}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': "Lenny'S Clam Bar"}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': 'London Lennies'}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': 'Pier 25A Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': 'Elias Corner For Fish'}
# {'borough': 'Queens', 'cuisine': 'Seafood', 'name': 'J & C Seafood'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'One If By Land Two If By Sea'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Oyster Bar'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'The Water Club'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Island'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'City Crab'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Aqua Grill'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Blue Water Grill'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Estiatorio Milos'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Pearl'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Atlantic Grill'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'El Tina Fish Market & Seafood Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Famous Fish Market'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Fish'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'City Lobster & Steak'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Esca'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'A Salt & Battery'}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': "Mary'S Fish Camp"}
# {'borough': 'Manhattan', 'cuisine': 'Seafood', 'name': 'Blue Fin'}
# {'borough': 'Brooklyn', 'cuisine': 'Seafood', 'name': "Pete'S Clam Stop"}
# {'borough': 'Brooklyn', 'cuisine': 'Seafood', 'name': 'Surf Bar'}
# {'borough': 'Brooklyn', 'cuisine': 'Seafood', 'name': "Randazzo'S Clam Bar"}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Seashore Restaurant'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Johnny'S Reef Restaurant"}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Tony'S Pier Restaurant"}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Jp'S Waterside Restaurant"}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Loui Seafood'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Crab Shanty'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Black Whale'}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': "Sammy'S Fishbox"}
# {'borough': 'Bronx', 'cuisine': 'Seafood', 'name': 'Seafood  City'}
# {'borough': 'Manhattan', 'cuisine': 'Soul Food', 'name': 'Manna Restaurant Ii'}
# {'borough': 'Manhattan', 'cuisine': 'Soul Food', 'name': "Sylvia'S Restaurant"}
# {'borough': 'Brooklyn', 'cuisine': 'Soul Food', 'name': "Mitchell'S Restaurant"}
# {'borough': 'Brooklyn', 'cuisine': 'Soul Food', 'name': "Enid'S"}
# {'borough': 'Bronx', 'cuisine': 'Soul Food', 'name': "Sam'S Restaurant"}
# {'borough': 'Bronx', 'cuisine': 'Soul Food', 'name': 'Cea Lo Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Manhattan', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Brooklyn', 'cuisine': 'Soups & Sandwiches', 'name': 'Hale & Hearty Soups'}
# {'borough': 'Staten Island', 'cuisine': 'Spanish', 'name': 'Real Madrid Restaurant'}
# {'borough': 'Staten Island', 'cuisine': 'Spanish', 'name': 'La Candela Espanola'}
# {'borough': 'Staten Island', 'cuisine': 'Spanish', 'name': "Goody'S Spanish Food"}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'La Fusta Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Pollos A La Brasa'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Scorpio Bar'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'El Olivo'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Los Arrieros Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': "Nelly'S Cafe"}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Tierras Columbianas'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Riazor Blue Tapas Bar'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Don Coqui'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': "El Chivito D'Oro Iii"}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Bicheiros Bar'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': "K'S Cafeteria"}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Hornado Ecuatoriano'}
# {'borough': 'Queens', 'cuisine': 'Spanish', 'name': 'Bravo Cafe Concert'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Spain Restaurant & Bar'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Tio Pepe'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'El Charro Espanol'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Malaga Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Cafe Riazor'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Cafe Espanol'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Ipanema Bar'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Caridad Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Toledo'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'El Rinconcito Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': "Francisco'S Centro Vasco"}
# {'borough': 'Manhattan', 'cuisine': 'Spanish', 'name': 'Euzkadi'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': "Sancho'S Restaurant"}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': "Charle'S Corner Restaurant & Deli"}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'Don Paco  Lopez Panderia'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'La Cabana Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'La Lechonera Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'M. Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'El Salvador Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'American Coffee Shop'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'Cindy Restaurant Luncheonette'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'Cherokee Deli'}
# {'borough': 'Brooklyn', 'cuisine': 'Spanish', 'name': 'La Villita Restaurant'}
# {'borough': 'Bronx', 'cuisine': 'Spanish', 'name': 'Cuchifritos'}
# {'borough': 'Bronx', 'cuisine': 'Spanish', 'name': 'Cosmos Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Steak', 'name': 'Bliss Street Station Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Steak', 'name': "My Uncle'S Steak Restaurant"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Donohue'S Steak House"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Sammy'S Steakhouse"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Sparks Steak House'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Keens Steakhouse'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Frankie & Johnnies Steakhouse'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'T-Bar Steak & Lounge'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Bobby Van'S"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Quality Meats'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Michael Jordan'S Steak House - In Grand Central"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Wolf And Lamb'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Del Frisco'S"}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Palm Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': 'Hillstone Manhattan'}
# {'borough': 'Manhattan', 'cuisine': 'Steak', 'name': "Ruth'S Chris Steak House"}
# {'borough': 'Brooklyn', 'cuisine': 'Steak', 'name': 'Peter Luger Steakhouse'}
# {'borough': 'Brooklyn', 'cuisine': 'Steak', 'name': "Hunter'S Steak & Ale House"}
# {'borough': 'Brooklyn', 'cuisine': 'Steak', 'name': 'Arirang Hibachi Steakhouse'}
# {'borough': 'Bronx', 'cuisine': 'Steak', 'name': 'Riverdale Steak House'}
# {'borough': 'Bronx', 'cuisine': 'Steak', 'name': "Jake'S Steakhouse"}
# {'borough': 'Queens', 'cuisine': 'Tapas', 'name': 'El Boqueron Tapas Bar & Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Tapas', 'name': 'Kana Tapas Bar & Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Tapas', 'name': 'Cafe Ronda'}
# {'borough': 'Manhattan', 'cuisine': 'Tapas', 'name': 'Verlaine'}
# {'borough': 'Queens', 'cuisine': 'Tex-Mex', 'name': 'Taco Bell'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': "Baby Bo'S Burritos"}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Burrito Loco'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Tortilla Flats'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Cowgirl Hall Of Fame'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Bennys Burritos'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': "Benny'S Burritos"}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': "Harry'S Burrito Junction"}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'The Heights Bar & Grill'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Blockheads Burritos'}
# {'borough': 'Manhattan', 'cuisine': 'Tex-Mex', 'name': 'Burrito Box'}
# {'borough': 'Brooklyn', 'cuisine': 'Tex-Mex', 'name': 'Santa Fe Grill & Bar'}
# {'borough': 'Brooklyn', 'cuisine': 'Tex-Mex', 'name': "Buddy'S Burrito & Taco Bar"}
# {'borough': 'Queens', 'cuisine': 'Thai', 'name': 'Arharn Thai Cuisine'}
# {'borough': 'Queens', 'cuisine': 'Thai', 'name': 'Erawan Thai Cuisine'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Pongsri Thai Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Jaiya Thai Oriental Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Topaz Thai Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Bangkok Grand Palace'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Rohm Thai'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Cafe Asean'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': "Bennie'S Thai Cafe"}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Republic Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Thai', 'name': 'Wondee Siam Ii'}
# {'borough': 'Brooklyn', 'cuisine': 'Thai', 'name': 'Bangkok Thai House'}
# {'borough': 'Brooklyn', 'cuisine': 'Thai', 'name': 'Joya'}
# {'borough': 'Brooklyn', 'cuisine': 'Thai', 'name': 'Ott Thai Cuisine'}
# {'borough': 'Queens', 'cuisine': 'Turkish', 'name': 'Kebab House'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'The Country Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Turkish Kitchen'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Uskudar Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Pasha Turkish Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Turkish Cuisine'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Turkuaz Turkish Cuisine'}
# {'borough': 'Manhattan', 'cuisine': 'Turkish', 'name': 'Saharas Turkish Cuisine'}
# {'borough': 'Brooklyn', 'cuisine': 'Turkish', 'name': 'Sahara Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Turkish', 'name': 'Istanbul Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Turkish', 'name': 'Memo Shish Kebab'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Angelica Kitchen'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Candle Cafe'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Village Yogurt'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Village Natural'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Caravan Of Dreams'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Mana'}
# {'borough': 'Manhattan', 'cuisine': 'Vegetarian', 'name': 'Red Bamboo'}
# {'borough': 'Brooklyn', 'cuisine': 'Vegetarian', 'name': 'Strictly Vegetarian'}
# {'borough': 'Brooklyn', 'cuisine': 'Vegetarian', 'name': 'Original Vegetarian Restaurant'}
# {'borough': 'Brooklyn', 'cuisine': 'Vegetarian', 'name': 'Bliss Bakery & Cafe'}
# {'borough': 'Queens', 'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Pho Bac Vietnamese Seafood Cuisine'}
# {'borough': 'Manhattan', 'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Thai Son'}
# {'borough': 'Manhattan', 'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Pho Bang Restaurant'}
# {'borough': 'Manhattan', 'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Nha-Trang Centre Vietnam Restaurant'}

# %% [markdown]
# 28. Escribe una sentencia para saber si todas las direcciones tienen calle o no.

# %%
# Encontrar restaurantes CON calle en su dirección
consulta = db.restaurants.find({"address.street": {"$exists": True}})

# Verificar si el número de documentos con la calle especificada es igual al número total de documentos
todos_tienen_calle = consulta.count() == db.restaurants.count_documents({})

# Mostrar el resultado
print(todos_tienen_calle)
# Out:
# True
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """

# %%
# Verificar si existen restaurantes SIN calle en la dirección
restaurantes_sin_calle = db.restaurants.count_documents({
    "$or": [
        {"address.street": {"$exists": False}},
        {"address.street": {"$eq": ""}}
    ]
}) > 0

# Mostrar el resultado
print(restaurantes_sin_calle)
# Out:
# False

# %% [markdown]
# 29. Escribe una sentencia que obtenga todos los estaurantes cuyo valor del campo coord se de tipo Doble.

# %%
consulta = db.restaurants.find({"address.coord": {"$type": "double"}})
for restaurante in consulta:
    print(restaurante)

# %% [markdown]
# 30. Escribe una sentencia que obtenga el Id, name y grades de los restaurantes que obtengan de resto 0 al realizar la división entera por 7 de la puntuación.

# %%
consulta = db.restaurants.find({"grades.score": {"$mod": [7, 0]}},
                               {"_id": 1, "name": 1, "grades": 1})
for restaurante in consulta:
    print(restaurante)
