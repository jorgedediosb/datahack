# %% [markdown]
# # PRÁCTICA NOSQL (NEO4J) - SHAKESPEARE

# %% [markdown]
# #### CASO DE USO PARA EMPRESA DE VISITAS TEATRALIZADAS
#
# Una empresa afincada en Londres quiere hacer visitas teatralizadas por la ciudad basadas en la obra de Shakespeare.
#
# Para poder hacer el plan de trabajo de cada representación necesitan saber:
#
# * 1. Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare.
# * 2. Obras de Shakespeare ambientadas en Londres y sus localizaciones.
# * 3. De las obras en Londres, saber las escenas de cada obra.
# * 4. De las obras en Londres, saber los personajes que aparecen en cada obra.
# * 5. Cuantas veces aparece un personaje en un ambiente y en qué ambiente.
# * 6. TEXTO COMPLETO DE UNA ESCENA CONCRETA!!!
#
# A parte de estas consultas, facilito otras más genéricas que me han resultado muy interesantes.

# %% [markdown]
# He elegido Neo4j en vez de mongodb por:
#
# * Modelo de Datos Gráfico:
# Neo4j está basado en un modelo de datos gráfico, por lo que es muy sencillo para representar y consultar relaciones complejas entre entidades. Al necesitar bastantes relaciones y conexiones entre datos, consideré que ofrecería un rendimiento más eficiente a mongo.
#
# * Consultas de Relaciones:
# Neo4j proporciona el lenguaje Cypher que facilita la expresión y ejecución de consultas que involucran relaciones.
#
# * Transacciones ACID:
# Neo4j ofrece soporte para transacciones ACID (Atomicidad, Consistencia, Aislamiento, Durabilidad), lo que garantiza la integridad de los datos incluso en entornos de alta concurrencia. MongoDB también admite transacciones ACID desde su versión 4.0, pero la naturaleza de las transacciones puede variar según la configuración.
#
#
# En el modelado, al no necesitar todos los datos de cada uno de los documentos json, me  he centrado sólo en aquellos que me ofrecían la información que necesitaba y 'desechar' aquello que no necesitaba. En mi caso he hecho una selección sobre los que el type=scene. Gracias a esto he logrado que las consultas y carga de dataset sea MUCHO más rápida.

# %% [markdown]
# El diagrama del modelo de datos es:
#
# <img src="schema_shakespeare.jpg" alt="shakespeare" style="width: 800px; PADDING-LEFT: 5px"/>

# %% [markdown]
# #### Conclusiones:
# * ¿Qué te parece la base de datos seleccionada como data store?
# Me ha gustado muchísimo porque la he considerado la más creativa y la que permite aspectos más distintos a las otras usadas en el curso. Me gusta mucho las herramientas que ofrece Neo4j para la visualización y creación de proyectos con su base de datos. A parte del Browser, he 'trasteado' con sus otras herramientas (data importer, arrows, Aura/Workspace y Bloom) y me han parecido muy intuitivas y visualmente muy superiores al resto.
# * ¿Qué te ha parecido el ejercicio?
# Muy interesante al poder elegir entre distintas bases de datos y distintas bases de datos. Después de estudiar cada una de ellas, poder elegir la que más te motive creo que es esencial para disfrutar haciendo el ejercicio.
# * ¿Qué has aprendido?
# No sólo a manejar mongodb y sobretodo Neo4j sino a entender la importancia de estudiar el dataset y el caso de uso concreto antes de 'lanzarte' a modelar y hacer consultas como un loco.
# * ¿Qué has hechado de menos?
# En la práctica nada. Todo depende del tiempo de cada uno para hacerla todo lo completa que se quiera. En clase, ver en casos de uso reales de cada una de las bases de datos más importantes que hemos visto para entender mejor cuando elegir una u otra.
# * ¿Cómo mejorarías la prática?
# Creo que hay personas que les cuesta encontrar un caso de uso, se necesita algo de creatividad que no tenemos porque tenerla o que por falta de tiempo, no surja. Sería útil poner varios casos de uso genéricos para aquellas personas que lo puedan  necesitar.

# %% [markdown]
# ## Preparación del entorno

# %%
# Instalar librerías pprintpp y py2neo
# pprintpp -  (pretty-print) mejora la legibilidad al mostrar estructuras de datos complejas.
# py2neo - facilita la creación y ejecución de consultas en Neo4j usando Python

# !pip install pprintpp
# !pip install py2neo
# Out:
# Requirement already satisfied: pprintpp in /opt/conda/lib/python3.6/site-packages (0.4.0)
# Requirement already satisfied: py2neo in /opt/conda/lib/python3.6/site-packages (2021.2.3)
# Requirement already satisfied: monotonic in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from py2neo) (18.0)
# Requirement already satisfied: six>=1.15.0 in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: interchange~=2021.0.4 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: pansi>=2020.7.3 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.23)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.6/site-packages (from py2neo) (2018.8.24)
# Requirement already satisfied: pygments>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2.2.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from interchange~=2021.0.4->py2neo) (2018.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->py2neo) (2.2.2)

# %%
# Importación de clases de py2neo:
    # Graph, para representar la conexión con la base de datos.
    # Relationship, para modelar relaciones entre nodos en la base de datos.
    # Node, para representar nodos en la base de datos.

from py2neo import Graph, Relationship, Node

graph = Graph("http://neo4j:1234@neo4j:7474/db/data")

# %%
# Resetear notebook tras ejecuciones anteriores borrando los nodos y realaciones existentes en la base de datos.

graph.run("MATCH (n) DETACH DELETE n").evaluate()

# %% [markdown]
# ## CREACIÓN DE ÍNDICES Y CONSTRAINTS

# %% [markdown]
# #### cambiar city por LOCATION y location por AMBIENCE

# %%
# Comprobar ÍNDICES Y CONSTRAINTS creados:
graph.run("""
CALL db.indexes()
""").to_table()

# Eliminar constraint:
# graph.run("DROP CONSTRAINT const_name")
# Crear constraint:
# graph.run("""CREATE CONSTRAINT new_const_name ON (new_atrib:new_const_name) ASSERT new_atrib.new_prop IS UNIQUE""")
# Out:
#  id | name      | state  | populationPercent | uniqueness | type  | entityType | labelsOrTypes | properties | provider
# ----|-----------|--------|-------------------|------------|-------|------------|---------------|------------|------------------
#   4 | Ambience  | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Ambience']  | ['name']   | native-btree-1.0
#  16 | Character | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Character'] | ['name']   | native-btree-1.0
#   1 | Location  | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Location']  | ['name']   | native-btree-1.0
#  10 | Play      | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Play']      | ['name']   | native-btree-1.0
#   8 | Scene     | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Scene']     | ['number'] | native-btree-1.0

# %%
import json
import requests
from py2neo import Graph, Node, Relationship

# URL del conjunto de datos
url = "https://raw.githubusercontent.com/rafaelgarrote/datahack-nosql/nosql-especial/workespecial/practica/data/shakespeare.json"

# Ruta del archivo local
local_file = "dataset_shakespeare.json"

# Realizar la solicitud HTTP
response = requests.get(url)

# Verificar si la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Guardar los datos en un archivo local en modo "escritura"
    with open(local_file, "w") as file:
        file.write(response.text)  
    print("Datos descargados exitosamente.")

    # Dividir cada línea del dataset y cargarlas como un objeto JSON
    data_list = [json.loads(line) for line in response.text.split('\n') if line]

    # Verificar si los índices ya existen antes de intentar crearlos
    if not graph.schema.get_indexes("Location"):
        graph.run("CREATE INDEX ON :Location(name)")

    if not graph.schema.get_indexes("Ambience"):
        graph.run("CREATE INDEX ON :Ambience(name)")

    if not graph.schema.get_indexes("Play"):
        graph.run("CREATE INDEX ON :Play(name)")
        
    if not graph.schema.get_indexes("Character"):
        graph.run("CREATE INDEX ON :Character(name)")
    
    if not graph.schema.get_indexes("Scene"):
        graph.run("CREATE INDEX ON :Scene(number)")
        
    # Agregar restricciones de unicidad si no existen (las elimina y luego las vuelve a crear)
    if not graph.schema.get_uniqueness_constraints("Location"):
        graph.run("DROP INDEX ON :Location(name)")
        graph.run("CREATE CONSTRAINT Location ON (location:Location) ASSERT location.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Ambience"):
        graph.run("DROP INDEX ON :Ambience(name)")
        graph.run("CREATE CONSTRAINT Ambience ON (ambience:Ambience) ASSERT ambience.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Play"):
        graph.run("DROP INDEX ON :Play(name)")
        graph.run("CREATE CONSTRAINT Play ON (play:Play) ASSERT play.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Character"):
        graph.run("DROP INDEX ON :Character(name)")
        graph.run("CREATE CONSTRAINT Character ON (character:Character) ASSERT character.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Scene"):
        graph.run("DROP INDEX ON :Scene(number)")
        graph.run("CREATE CONSTRAINT Scene ON (scene:Scene) ASSERT scene.number IS UNIQUE")

    print("\nÍndices y restricciones de unicidad creados exitosamente.")
    
else:
    print(f"Error al obtener datos. Código de estado: {response.status_code}")
    
# Imprimir los primeros documentos JSON
print("\nPrimeros documentos JSON:")
for i, entry in enumerate(data_list[:3], 1):
    print(f"\nDocumento {i}:\n{json.dumps(entry, indent=2)}")
# Out:
# Datos descargados exitosamente.
#
# Índices y restricciones de unicidad creados exitosamente.
#
# Primeros documentos JSON:
#
# Documento 1:
# {
#   "type": "act",
#   "line_id": 1,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "ACT I"
# }
#
# Documento 2:
# {
#   "type": "scene",
#   "line_id": 2,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "SCENE I. London. The palace."
# }
#
# Documento 3:
# {
#   "type": "line",
#   "line_id": 3,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "Enter KING HENRY, LORD JOHN OF LANCASTER, the EARL of WESTMORELAND, SIR WALTER BLUNT, and others"
# }

# %% [markdown]
# ### MODELADO DE DATOS
#
# Tras varias pruebas en donde creaba un nodo por cada documento json y para mejorar los tiempos de carga, he importado sólo los documentos con 'type'='scene' ya  que con ellos se disponía de los datos necesarios para el caso de  uso. De esta forma se ha reducido el tiempo de carga de 30 min a 2 min.
#
# Según indica el dataset, hay secuencias de la obra que tienen una única localización: 'SCENE III. Warkworth castle' y hay otras que se especifica, dentro de esa localización, otro 'ambiente': 'SCENE IV. York. The ARCHBISHOPS palace.' (en 'York', 'The ARCHBISHOPS palace.'
#
# Por ello he creído necesario dividir en dos nodos distintos 'Location' y 'Ambience' para poder hacer las consultas más  precisas. Paro ello he tenido que importar los documentos dividiendo la frase en sus '.' para obtener cada parte y asignarla a su nodo correspondiente.
#
# Para el nodo 'Scene' he dejado el texto completo de la propiedad 'text_entry' ya que veía útil en ciertos casos que se indicase el nº de secuencia con su localización para facilitar las consultas.
#
# Para el resto de nodos se ha usado la propiedad que  indicaba el json del dataset:
# * Play --> 'play_name'
# * Character --> 'speaker'

# %%
# Crear grafo con nodos y relaciones

for entry in data_list:
    if entry["type"] == "scene":
        location_split = entry["text_entry"].split(". ", 1)
        if len(location_split) == 2:
            location_and_ambience = location_split[1].split(". ", 1)
            if len(location_and_ambience) == 2:
                location, ambience = location_and_ambience
            
            # Crear nodos con etiquetas y claves principales
            location_node = Node("Location", name=location)
            ambience_node = Node("Ambience", name=ambience)
            play_node = Node("Play", name=entry["play_name"])
            character_node = Node("Character", name=entry["speaker"])
            scene_node = Node("Scene", number=entry["text_entry"])

            graph.merge(location_node, "Location", "name")
            graph.merge(ambience_node, "Ambience", "name")
            graph.merge(play_node, "Play", "name")
            graph.merge(character_node, "Character", "name")
            graph.merge(scene_node, "Scene", "number")
            
            # Crear relaciones entre los nodos
            play_location_rel = Relationship(play_node, "REPRESENTED_IN", location_node)
            location_ambience_rel = Relationship(location_node, "HAS_LOCATION", ambience_node)
            ambience_play_rel = Relationship(ambience_node, "LOCATION_OF", play_node)
            character_play_rel = Relationship(character_node, "APPEARS_IN", play_node)
            character_ambience_rel =Relationship(character_node, "IS_IN", ambience_node)
            play_scene_rel = Relationship(play_node, "DIVIDED_BY", scene_node)
                
            graph.merge(play_location_rel)
            graph.merge(location_ambience_rel)
            graph.merge(ambience_play_rel)
            graph.merge(character_ambience_rel)
            graph.merge(character_play_rel)
            graph.merge(play_scene_rel)

print("Grafo creado exitosamente.")
# Out:
# Grafo creado exitosamente.

# %%
# Nodos y relaciones existentes
graph.run("""
MATCH (n)
RETURN DISTINCT labels(n) AS Labels, keys(n) AS Keys, n
""").to_table()
# Out:
#  Labels        | Keys       | n
# ---------------|------------|-------------------------------------------------------------------------------------------------
#  ['Location']  | ['name']   | (_0:Location {name: 'London'})
#  ['Ambience']  | ['name']   | (_1:Ambience {name: 'The palace.'})
#  ['Play']      | ['name']   | (_2:Play {name: 'Henry IV'})
#  ['Character'] | ['name']   | (_3:Character {name: ''})
#  ['Scene']     | ['number'] | (_4:Scene {number: 'SCENE I. London. The palace.'})
#  ['Ambience']  | ['name']   | (_5:Ambience {name: 'An apartment of the Princes.'})
#  ['Character'] | ['name']   | (_6:Character {name: 'WESTMORELAND'})
#  ['Scene']     | ['number'] | (_7:Scene {number: 'SCENE II. London. An apartment of the Princes.'})
#  ['Character'] | ['name']   | (_8:Character {name: 'PRINCE HENRY'})
#  ['Scene']     | ['number'] | (_9:Scene {number: 'SCENE III. London. The palace.'})
#  ['Location']  | ['name']   | (_10:Location {name: 'Rochester'})
#  ['Ambience']  | ['name']   | (_11:Ambience {name: 'An inn yard.'})
#  ['Character'] | ['name']   | (_12:Character {name: 'HOTSPUR'})
#  ['Scene']     | ['number'] | (_13:Scene {number: 'SCENE I. Rochester. An inn yard.'})
#  ['Character'] | ['name']   | (_14:Character {name: 'GADSHILL'})
#  ['Scene']     | ['number'] | (_15:Scene {number: 'SCENE II. The highway, near Gadshill.'})
#  ['Character'] | ['name']   | (_16:Character {name: 'POINS'})
#  ['Scene']     | ['number'] | (_17:Scene {number: 'SCENE III. Warkworth castle'})
#  ['Character'] | ['name']   | (_18:Character {name: 'LADY PERCY'})
#  ['Scene']     | ['number'] | (_19:Scene {number: 'SCENE IV. The Boars-Head Tavern, Eastcheap.'})
#  ['Location']  | ['name']   | (_20:Location {name: 'Bangor'})
#  ['Ambience']  | ['name']   | (_21:Ambience {name: 'The Archdeacons house.'})
#  ['Character'] | ['name']   | (_22:Character {name: 'PETO'})
#  ['Scene']     | ['number'] | (_23:Scene {number: 'SCENE I. Bangor. The Archdeacons house.'})
#  ['Character'] | ['name']   | (_24:Character {name: 'MORTIMER'})
#  ['Scene']     | ['number'] | (_25:Scene {number: 'SCENE II. London. The palace.'})
#  ['Character'] | ['name']   | (_26:Character {name: 'FALSTAFF'})
#  ['Scene']     | ['number'] | (_27:Scene {number: 'SCENE I. The rebel camp near Shrewsbury.'})
#  ['Character'] | ['name']   | (_28:Character {name: 'EARL OF DOUGLAS'})
#  ['Scene']     | ['number'] | (_29:Scene {number: 'SCENE II. A public road near Coventry.'})
#  ['Scene']     | ['number'] | (_30:Scene {number: 'SCENE III. The rebel camp near Shrewsbury.'})
#  ['Location']  | ['name']   | (_31:Location {name: 'York'})
#  ['Ambience']  | ['name']   | (_32:Ambience {name: 'The ARCHBISHOPS palace.'})
#  ['Character'] | ['name']   | (_33:Character {name: 'SIR WALTER BLUNT'})
#  ['Scene']     | ['number'] | (_34:Scene {number: 'SCENE IV. York. The ARCHBISHOPS palace.'})
#  ['Character'] | ['name']   | (_35:Character {name: 'ARCHBISHOP OF YORK'})
#  ['Scene']     | ['number'] | (_36:Scene {number: 'SCENE I. KING HENRY IVs camp near Shrewsbury.'})
#  ['Scene']     | ['number'] | (_37:Scene {number: 'SCENE II. The rebel camp.'})
#  ['Scene']     | ['number'] | (_38:Scene {number: 'SCENE III. Plain between the camps.'})
#  ['Scene']     | ['number'] | (_39:Scene {number: 'SCENE IV. Another part of the field.'})
#  ['Scene']     | ['number'] | (_40:Scene {number: 'SCENE V. Another part of the field.'})
#  ['Play']      | ['name']   | (_41:Play {name: 'Henry VI Part 1'})
#  ['Character'] | ['name']   | (_42:Character {name: 'KING HENRY IV'})
#  ['Scene']     | ['number'] | (_43:Scene {number: 'SCENE I. Westminster Abbey.'})
#  ['Location']  | ['name']   | (_44:Location {name: 'France'})
#  ['Ambience']  | ['name']   | (_45:Ambience {name: 'Before Orleans.'})
#  ['Character'] | ['name']   | (_46:Character {name: 'OF WINCHESTER'})
#  ['Scene']     | ['number'] | (_47:Scene {number: 'SCENE II. France. Before Orleans.'})
#  ['Ambience']  | ['name']   | (_48:Ambience {name: 'Before the Tower.'})
#  ['Character'] | ['name']   | (_49:Character {name: 'CHARLES'})
#  ['Scene']     | ['number'] | (_50:Scene {number: 'SCENE III. London. Before the Tower.'})
#  ['Character'] | ['name']   | (_51:Character {name: 'Mayor'})
#  ['Scene']     | ['number'] | (_52:Scene {number: 'SCENE IV. Orleans.'})
#  ['Character'] | ['name']   | (_53:Character {name: 'TALBOT'})
#  ['Scene']     | ['number'] | (_54:Scene {number: 'SCENE V. The same.'})
#  ['Scene']     | ['number'] | (_55:Scene {number: 'SCENE VI. The same.'})
#  ['Scene']     | ['number'] | (_56:Scene {number: 'SCENE I. Before Orleans.'})
#  ['Location']  | ['name']   | (_57:Location {name: 'Orleans'})
#  ['Ambience']  | ['name']   | (_58:Ambience {name: 'Within the town.'})
#  ['Character'] | ['name']   | (_59:Character {name: 'Soldier'})
#  ['Scene']     | ['number'] | (_60:Scene {number: 'SCENE II. Orleans. Within the town.'})
#  ['Location']  | ['name']   | (_61:Location {name: 'Auvergne'})
#  ['Ambience']  | ['name']   | (_62:Ambience {name: 'The COUNTESSs castle.'})
#  ['Character'] | ['name']   | (_63:Character {name: 'Captain'})
#  ['Scene']     | ['number'] | (_64:Scene {number: 'SCENE III. Auvergne. The COUNTESSs castle.'})
#  ['Ambience']  | ['name']   | (_65:Ambience {name: 'The Temple-garden.'})
#  ['Character'] | ['name']   | (_66:Character {name: 'OF AUVERGNE'})
#  ['Scene']     | ['number'] | (_67:Scene {number: 'SCENE IV. London. The Temple-garden.'})
#  ['Character'] | ['name']   | (_68:Character {name: 'PLANTAGENET'})
#  ['Scene']     | ['number'] | (_69:Scene {number: 'SCENE V. The Tower of London.'})
#  ['Ambience']  | ['name']   | (_70:Ambience {name: 'The Parliament-house.'})
#  ['Scene']     | ['number'] | (_71:Scene {number: 'SCENE I. London. The Parliament-house.'})
#  ['Ambience']  | ['name']   | (_72:Ambience {name: 'Before Rouen.'})
#  ['Character'] | ['name']   | (_73:Character {name: 'EXETER'})
#  ['Scene']     | ['number'] | (_74:Scene {number: 'SCENE II. France. Before Rouen.'})
#  ['Scene']     | ['number'] | (_75:Scene {number: 'SCENE III. The plains near Rouen.'})
#  ['Location']  | ['name']   | (_76:Location {name: 'Paris'})
#  ['Scene']     | ['number'] | (_77:Scene {number: 'SCENE IV. Paris. The palace.'})
#  ['Ambience']  | ['name']   | (_78:Ambience {name: 'A hall of state.'})
#  ['Character'] | ['name']   | (_79:Character {name: 'VERNON'})
#  ['Scene']     | ['number'] | (_80:Scene {number: 'SCENE I. Paris. A hall of state.'})
#  ['Scene']     | ['number'] | (_81:Scene {number: 'SCENE II. Before Bourdeaux.'})
#  ['Scene']     | ['number'] | (_82:Scene {number: 'SCENE III. Plains in Gascony.'})
#  ['Character'] | ['name']   | (_83:Character {name: 'LUCY'})
#  ['Scene']     | ['number'] | (_84:Scene {number: 'SCENE IV. Other plains in Gascony.'})
#  ['Scene']     | ['number'] | (_85:Scene {number: 'SCENE V. The English camp near Bourdeaux.'})
#  ['Scene']     | ['number'] | (_86:Scene {number: 'SCENE VI. A field of battle.'})
#  ['Scene']     | ['number'] | (_87:Scene {number: 'SCENE VII. Another part of the field.'})
#  ['Ambience']  | ['name']   | (_88:Ambience {name: 'Plains in Anjou.'})
#  ['Scene']     | ['number'] | (_89:Scene {number: 'SCENE II. France. Plains in Anjou.'})
#  ['Scene']     | ['number'] | (_90:Scene {number: 'SCENE III. Before Angiers.'})
#  ['Character'] | ['name']   | (_91:Character {name: 'SUFFOLK'})
#  ['Scene']     | ['number'] | (_92:Scene {number: 'SCENE IV. Camp of the YORK in Anjou.'})
#  ['Character'] | ['name']   | (_93:Character {name: 'YORK'})
#  ['Scene']     | ['number'] | (_94:Scene {number: 'SCENE V. London. The palace.'})
#  ['Play']      | ['name']   | (_95:Play {name: 'Henry VI Part 2'})
#  ['Scene']     | ['number'] | (_96:Scene {number: 'SCENE II. GLOUCESTERS house.'})
#  ['Character'] | ['name']   | (_97:Character {name: 'HUME'})
#  ['Scene']     | ['number'] | (_98:Scene {number: 'SCENE III. The palace.'})
#  ['Character'] | ['name']   | (_99:Character {name: 'KING HENRY VI'})
#  ['Scene']     | ['number'] | (_100:Scene {number: 'SCENE IV. GLOUCESTERs garden.'})
#  ['Scene']     | ['number'] | (_101:Scene {number: 'SCENE I. Saint Albans.'})
#  ['Ambience']  | ['name']   | (_102:Ambience {name: 'YORKS garden.'})
#  ['Scene']     | ['number'] | (_103:Scene {number: 'SCENE II. London. YORKS garden.'})
#  ['Scene']     | ['number'] | (_104:Scene {number: 'SCENE III. A hall of justice.'})
#  ['Scene']     | ['number'] | (_105:Scene {number: 'SCENE IV. A street.'})
#  ['Location']  | ['name']   | (_106:Location {name: 'The Abbey at Bury St'})
#  ['Ambience']  | ['name']   | (_107:Ambience {name: 'Edmunds.'})
#  ['Character'] | ['name']   | (_108:Character {name: 'DUCHESS'})
#  ['Scene']     | ['number'] | (_109:Scene {number: 'SCENE I. The Abbey at Bury St. Edmunds.'})
#  ['Location']  | ['name']   | (_110:Location {name: 'Bury St'})
#  ['Ambience']  | ['name']   | (_111:Ambience {name: 'Edmunds. A room of state.'})
#  ['Scene']     | ['number'] | (_112:Scene {number: 'SCENE II. Bury St. Edmunds. A room of state.'})
#  ['Character'] | ['name']   | (_113:Character {name: 'QUEEN MARGARET'})
#  ['Scene']     | ['number'] | (_114:Scene {number: 'SCENE III. A bedchamber.'})
#  ['Scene']     | ['number'] | (_115:Scene {number: 'SCENE I. The coast of Kent.'})
#  ['Character'] | ['name']   | (_116:Character {name: 'First Gentleman'})
#  ['Scene']     | ['number'] | (_117:Scene {number: 'SCENE II. Blackheath.'})
#  ['Character'] | ['name']   | (_118:Character {name: 'CADE'})
#  ['Scene']     | ['number'] | (_119:Scene {number: 'SCENE III. Another part of Blackheath.'})
#  ['Scene']     | ['number'] | (_120:Scene {number: 'SCENE IV. London. The palace.'})
#  ['Ambience']  | ['name']   | (_121:Ambience {name: 'The Tower.'})
#  ['Character'] | ['name']   | (_122:Character {name: 'SAY'})
#  ['Scene']     | ['number'] | (_123:Scene {number: 'SCENE V. London. The Tower.'})
#  ['Ambience']  | ['name']   | (_124:Ambience {name: 'Cannon Street.'})
#  ['Character'] | ['name']   | (_125:Character {name: 'SCALES'})
#  ['Scene']     | ['number'] | (_126:Scene {number: 'SCENE VI. London. Cannon Street.'})
#  ['Ambience']  | ['name']   | (_127:Ambience {name: 'Smithfield.'})
#  ['Scene']     | ['number'] | (_128:Scene {number: 'SCENE VII. London. Smithfield.'})
#  ['Scene']     | ['number'] | (_129:Scene {number: 'SCENE VIII. Southwark.'})
#  ['Character'] | ['name']   | (_130:Character {name: 'BUCKINGHAM'})
#  ['Scene']     | ['number'] | (_131:Scene {number: 'SCENE IX. Kenilworth Castle.'})
#  ['Location']  | ['name']   | (_132:Location {name: 'Kent'})
#  ['Ambience']  | ['name']   | (_133:Ambience {name: 'IDENs garden.'})
#  ['Scene']     | ['number'] | (_134:Scene {number: 'SCENE X. Kent. IDENs garden.'})
#  ['Character'] | ['name']   | (_135:Character {name: 'IDEN'})
#  ['Scene']     | ['number'] | (_136:Scene {number: 'SCENE I. Fields between Dartford and Blackheath.'})
#  ['Character'] | ['name']   | (_137:Character {name: 'RICHARD'})
#  ['Scene']     | ['number'] | (_138:Scene {number: 'SCENE II. Saint Albans.'})
#  ['Location']  | ['name']   | (_139:Location {name: 'Fields near St'})
#  ['Ambience']  | ['name']   | (_140:Ambience {name: 'Albans.'})
#  ['Character'] | ['name']   | (_141:Character {name: 'YOUNG CLIFFORD'})
#  ['Scene']     | ['number'] | (_142:Scene {number: 'SCENE III. Fields near St. Albans.'})
#  ['Play']      | ['name']   | (_143:Play {name: 'Henry VI Part 3'})
#  ['Character'] | ['name']   | (_144:Character {name: 'WARWICK'})
#  ['Scene']     | ['number'] | (_145:Scene {number: 'SCENE II. Sandal Castle.'})
#  ['Scene']     | ['number'] | (_146:Scene {number: 'SCENE III. Field of battle betwixt Sandal Castle and Wakefield.'})
#  ['Character'] | ['name']   | (_147:Character {name: 'CLIFFORD'})
#  ['Scene']     | ['number'] | (_148:Scene {number: 'SCENE I. A plain near Mortimers Cross in Herefordshire.'})
#  ['Scene']     | ['number'] | (_149:Scene {number: 'SCENE II. Before York.'})
#  ['Character'] | ['name']   | (_150:Character {name: 'EDWARD'})
#  ['Scene']     | ['number'] | (_151:Scene {number: 'SCENE III. A field of battle between Towton and Saxton, in'})
#  ['Character'] | ['name']   | (_152:Character {name: 'GEORGE'})
#  ['Scene']     | ['number'] | (_153:Scene {number: 'SCENE VI. Another part of the field.'})
#  ['Scene']     | ['number'] | (_154:Scene {number: 'SCENE I. A forest in the north of England.'})
#  ['Ambience']  | ['name']   | (_155:Ambience {name: 'KING LEWIS XIs palace.'})
#  ['Character'] | ['name']   | (_156:Character {name: 'GLOUCESTER'})
#  ['Scene']     | ['number'] | (_157:Scene {number: 'SCENE III. France. KING LEWIS XIs palace.'})
#  ['Character'] | ['name']   | (_158:Character {name: 'KING EDWARD IV'})
#  ['Scene']     | ['number'] | (_159:Scene {number: 'SCENE II. A plain in Warwickshire.'})
#  ['Scene']     | ['number'] | (_160:Scene {number: 'SCENE III. Edwards camp, near Warwick.'})
#  ['Character'] | ['name']   | (_161:Character {name: 'QUEEN ELIZABETH'})
#  ['Scene']     | ['number'] | (_162:Scene {number: 'SCENE V. A park near Middleham Castle In Yorkshire.'})
#  ['Scene']     | ['number'] | (_163:Scene {number: 'SCENE VI. London. The Tower.'})
#  ['Character'] | ['name']   | (_164:Character {name: 'SOMERSET'})
#  ['Scene']     | ['number'] | (_165:Scene {number: 'SCENE VII. Before York.'})
#  ['Scene']     | ['number'] | (_166:Scene {number: 'SCENE VIII. London. The palace.'})
#  ['Scene']     | ['number'] | (_167:Scene {number: 'SCENE I. Coventry.'})
#  ['Scene']     | ['number'] | (_168:Scene {number: 'SCENE II. A field of battle near Barnet.'})
#  ['Character'] | ['name']   | (_169:Character {name: 'OXFORD'})
#  ['Scene']     | ['number'] | (_170:Scene {number: 'SCENE III. Another part of the field.'})
#  ['Scene']     | ['number'] | (_171:Scene {number: 'SCENE IV. Plains near Tewksbury.'})
#  ['Scene']     | ['number'] | (_172:Scene {number: 'SCENE VII. London. The palace.'})
#  ['Location']  | ['name']   | (_173:Location {name: 'Rousillon'})
#  ['Ambience']  | ['name']   | (_174:Ambience {name: 'The COUNTs palace.'})
#  ['Play']      | ['name']   | (_175:Play {name: 'Alls well that ends well'})
#  ['Scene']     | ['number'] | (_176:Scene {number: 'SCENE I. Rousillon. The COUNTs palace.'})
#  ['Ambience']  | ['name']   | (_177:Ambience {name: 'The KINGs palace.'})
#  ['Character'] | ['name']   | (_178:Character {name: 'HELENA'})
#  ['Scene']     | ['number'] | (_179:Scene {number: 'SCENE II. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_180:Character {name: 'BERTRAM'})
#  ['Scene']     | ['number'] | (_181:Scene {number: 'SCENE III. Rousillon. The COUNTs palace.'})
#  ['Character'] | ['name']   | (_182:Character {name: 'COUNTESS'})
#  ['Scene']     | ['number'] | (_183:Scene {number: 'SCENE I. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_184:Character {name: 'KING'})
#  ['Scene']     | ['number'] | (_185:Scene {number: 'SCENE II. Rousillon. The COUNTs palace.'})
#  ['Scene']     | ['number'] | (_186:Scene {number: 'SCENE III. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_187:Character {name: 'PAROLLES'})
#  ['Scene']     | ['number'] | (_188:Scene {number: 'SCENE IV. Paris. The KINGs palace.'})
#  ['Scene']     | ['number'] | (_189:Scene {number: 'SCENE V. Paris. The KINGs palace.'})
#  ['Location']  | ['name']   | (_190:Location {name: 'Florence'})
#  ['Ambience']  | ['name']   | (_191:Ambience {name: 'The DUKEs palace.'})
#  ['Scene']     | ['number'] | (_192:Scene {number: 'SCENE I. Florence. The DUKEs palace.'})
#  ['Character'] | ['name']   | (_193:Character {name: 'DUKE'})
#  ['Ambience']  | ['name']   | (_194:Ambience {name: 'Before the DUKEs palace.'})
#  ['Scene']     | ['number'] | (_195:Scene {number: 'SCENE III. Florence. Before the DUKEs palace.'})
#  ['Scene']     | ['number'] | (_196:Scene {number: 'SCENE IV. Rousillon. The COUNTs palace.'})
#  ['Ambience']  | ['name']   | (_197:Ambience {name: 'Without the walls. A tucket afar off.'})
#  ['Scene']     | ['number'] | (_198:Scene {number: 'SCENE V. Florence. Without the walls. A tucket afar off.'})
#  ['Character'] | ['name']   | (_199:Character {name: 'BOTH'})
#  ['Scene']     | ['number'] | (_200:Scene {number: 'SCENE VI. Camp before Florence.'})
#  ['Ambience']  | ['name']   | (_201:Ambience {name: 'The Widows house.'})
#  ['Character'] | ['name']   | (_202:Character {name: 'First Lord'})
#  ['Scene']     | ['number'] | (_203:Scene {number: 'SCENE VII. Florence. The Widows house.'})
#  ['Scene']     | ['number'] | (_204:Scene {number: 'SCENE I. Without the Florentine camp.'})
#  ['Character'] | ['name']   | (_205:Character {name: 'Second Lord'})
#  ['Scene']     | ['number'] | (_206:Scene {number: 'SCENE II. Florence. The Widows house.'})
#  ['Character'] | ['name']   | (_207:Character {name: 'DIANA'})
#  ['Scene']     | ['number'] | (_208:Scene {number: 'SCENE III. The Florentine camp.'})
#  ['Scene']     | ['number'] | (_209:Scene {number: 'SCENE IV. Florence. The Widows house.'})
#  ['Scene']     | ['number'] | (_210:Scene {number: 'SCENE V. Rousillon. The COUNTs palace.'})
#  ['Location']  | ['name']   | (_211:Location {name: 'Marseilles'})
#  ['Ambience']  | ['name']   | (_212:Ambience {name: 'A street.'})
#  ['Character'] | ['name']   | (_213:Character {name: 'Clown'})
#  ['Scene']     | ['number'] | (_214:Scene {number: 'SCENE I. Marseilles. A street.'})
#  ['Ambience']  | ['name']   | (_215:Ambience {name: 'Before the COUNTs palace.'})
#  ['Scene']     | ['number'] | (_216:Scene {number: 'SCENE II. Rousillon. Before the COUNTs palace.'})
#  ['Play']      | ['name']   | (_217:Play {name: 'As you like it'})
#  ['Scene']     | ['number'] | (_218:Scene {number: 'SCENE I. Orchard of Olivers house.'})
#  ['Character'] | ['name']   | (_219:Character {name: 'OLIVER'})
#  ['Scene']     | ['number'] | (_220:Scene {number: 'SCENE II. Lawn before the Dukes palace.'})
#  ['Character'] | ['name']   | (_221:Character {name: 'ORLANDO'})
#  ['Scene']     | ['number'] | (_222:Scene {number: 'SCENE III. A room in the palace.'})
#  ['Character'] | ['name']   | (_223:Character {name: 'CELIA'})
#  ['Scene']     | ['number'] | (_224:Scene {number: 'SCENE I. The Forest of Arden.'})
#  ['Scene']     | ['number'] | (_225:Scene {number: 'SCENE II. A room in the palace.'})
#  ['Character'] | ['name']   | (_226:Character {name: 'DUKE FREDERICK'})
#  ['Scene']     | ['number'] | (_227:Scene {number: 'SCENE III. Before OLIVERS house.'})
#  ['Character'] | ['name']   | (_228:Character {name: 'ADAM'})
#  ['Scene']     | ['number'] | (_229:Scene {number: 'SCENE IV. The Forest of Arden.'})
#  ['Character'] | ['name']   | (_230:Character {name: 'CORIN'})
#  ['Scene']     | ['number'] | (_231:Scene {number: 'SCENE V. The Forest.'})
#  ['Character'] | ['name']   | (_232:Character {name: 'AMIENS'})
#  ['Scene']     | ['number'] | (_233:Scene {number: 'SCENE VI. The forest.'})
#  ['Scene']     | ['number'] | (_234:Scene {number: 'SCENE VII. The forest.'})
#  ['Character'] | ['name']   | (_235:Character {name: 'DUKE SENIOR'})
#  ['Scene']     | ['number'] | (_236:Scene {number: 'SCENE I. A room in the palace.'})
#  ['Scene']     | ['number'] | (_237:Scene {number: 'SCENE II. The forest.'})
#  ['Character'] | ['name']   | (_238:Character {name: 'ROSALIND'})
#  ['Scene']     | ['number'] | (_239:Scene {number: 'SCENE III. The forest.'})
#  ['Character'] | ['name']   | (_240:Character {name: 'SIR OLIVER MARTEXT'})
#  ['Scene']     | ['number'] | (_241:Scene {number: 'SCENE IV. The forest.'})
#  ['Scene']     | ['number'] | (_242:Scene {number: 'SCENE V. Another part of the forest.'})
#  ['Character'] | ['name']   | (_243:Character {name: 'PHEBE'})
#  ['Scene']     | ['number'] | (_244:Scene {number: 'SCENE I. The forest.'})
#  ['Character'] | ['name']   | (_245:Character {name: 'Forester'})
#  ['Character'] | ['name']   | (_246:Character {name: 'TOUCHSTONE'})
#  ['Location']  | ['name']   | (_247:Location {name: 'Alexandria'})
#  ['Ambience']  | ['name']   | (_248:Ambience {name: 'A room in CLEOPATRAs palace.'})
#  ['Play']      | ['name']   | (_249:Play {name: 'Antony and Cleopatra'})
#  ['Scene']     | ['number'] | (_250:Scene {number: 'SCENE I. Alexandria. A room in CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_251:Location {name: 'The same'})
#  ['Ambience']  | ['name']   | (_252:Ambience {name: 'Another room.'})
#  ['Character'] | ['name']   | (_253:Character {name: 'DEMETRIUS'})
#  ['Scene']     | ['number'] | (_254:Scene {number: 'SCENE II. The same. Another room.'})
#  ['Character'] | ['name']   | (_255:Character {name: 'DOMITIUS ENOBARBUS'})
#  ['Scene']     | ['number'] | (_256:Scene {number: 'SCENE III. The same. Another room.'})
#  ['Location']  | ['name']   | (_257:Location {name: 'Rome'})
#  ['Ambience']  | ['name']   | (_258:Ambience {name: 'OCTAVIUS CAESARs house.'})
#  ['Character'] | ['name']   | (_259:Character {name: 'MARK ANTONY'})
#  ['Scene']     | ['number'] | (_260:Scene {number: 'SCENE IV. Rome. OCTAVIUS CAESARs house.'})
#  ['Ambience']  | ['name']   | (_261:Ambience {name: 'CLEOPATRAs palace.'})
#  ['Character'] | ['name']   | (_262:Character {name: 'OCTAVIUS CAESAR'})
#  ['Scene']     | ['number'] | (_263:Scene {number: 'SCENE V. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_264:Location {name: 'Messina'})
#  ['Ambience']  | ['name']   | (_265:Ambience {name: 'POMPEYs house.'})
#  ['Character'] | ['name']   | (_266:Character {name: 'CLEOPATRA'})
#  ['Scene']     | ['number'] | (_267:Scene {number: 'SCENE I. Messina. POMPEYs house.'})
#  ['Ambience']  | ['name']   | (_268:Ambience {name: 'The house of LEPIDUS.'})
#  ['Character'] | ['name']   | (_269:Character {name: 'POMPEY'})
#  ['Scene']     | ['number'] | (_270:Scene {number: 'SCENE II. Rome. The house of LEPIDUS.'})
#  ['Scene']     | ['number'] | (_271:Scene {number: 'SCENE III. The same. OCTAVIUS CAESARs house.'})
#  ['Scene']     | ['number'] | (_272:Scene {number: 'SCENE IV. The same. A street.'})
#  ['Character'] | ['name']   | (_273:Character {name: 'LEPIDUS'})
#  ['Scene']     | ['number'] | (_274:Scene {number: 'SCENE VI. Near Misenum.'})
#  ['Character'] | ['name']   | (_275:Character {name: 'MENAS'})
#  ['Scene']     | ['number'] | (_276:Scene {number: 'SCENE VII. On board POMPEYs galley, off Misenum.'})
#  ['Scene']     | ['number'] | (_277:Scene {number: 'SCENE I. A plain in Syria.'})
#  ['Ambience']  | ['name']   | (_278:Ambience {name: 'An ante-chamber in OCTAVIUS CAESARs house.'})
#  ['Character'] | ['name']   | (_279:Character {name: 'VENTIDIUS'})
#  ['Scene']     | ['number'] | (_280:Scene {number: 'SCENE II. Rome. An ante-chamber in OCTAVIUS CAESARs house.'})
#  ['Scene']     | ['number'] | (_281:Scene {number: 'SCENE III. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_282:Location {name: 'Athens'})
#  ['Ambience']  | ['name']   | (_283:Ambience {name: 'A room in MARK ANTONYs house.'})
#  ['Character'] | ['name']   | (_284:Character {name: 'CHARMIAN'})
#  ['Scene']     | ['number'] | (_285:Scene {number: 'SCENE IV. Athens. A room in MARK ANTONYs house.'})
#  ['Scene']     | ['number'] | (_286:Scene {number: 'SCENE V. The same. Another room.'})
#  ['Character'] | ['name']   | (_287:Character {name: 'EROS'})
#  ['Scene']     | ['number'] | (_288:Scene {number: 'SCENE VI. Rome. OCTAVIUS CAESARs house.'})
#  ['Location']  | ['name']   | (_289:Location {name: 'Near Actium'})
#  ['Ambience']  | ['name']   | (_290:Ambience {name: 'MARK ANTONYs camp.'})
#  ['Scene']     | ['number'] | (_291:Scene {number: 'SCENE VII. Near Actium. MARK ANTONYs camp.'})
#  ['Character'] | ['name']   | (_292:Character {name: 'CANIDIUS'})
#  ['Scene']     | ['number'] | (_293:Scene {number: 'SCENE VIII. A plain near Actium.'})
#  ['Scene']     | ['number'] | (_294:Scene {number: 'SCENE IX. Another part of the plain.'})
#  ['Scene']     | ['number'] | (_295:Scene {number: 'SCENE X. Another part of the plain.'})
#  ['Scene']     | ['number'] | (_296:Scene {number: 'SCENE XI. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_297:Location {name: 'Egypt'})
#  ['Ambience']  | ['name']   | (_298:Ambience {name: 'OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_299:Scene {number: 'SCENE XII. Egypt. OCTAVIUS CAESARs camp.'})
#  ['Character'] | ['name']   | (_300:Character {name: 'THYREUS'})
#  ['Scene']     | ['number'] | (_301:Scene {number: 'SCENE XIII. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_302:Location {name: 'Before Alexandria'})
#  ['Scene']     | ['number'] | (_303:Scene {number: 'SCENE I. Before Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_304:Scene {number: 'SCENE II. Alexandria. CLEOPATRAs palace.'})
#  ['Ambience']  | ['name']   | (_305:Ambience {name: 'Before the palace.'})
#  ['Scene']     | ['number'] | (_306:Scene {number: 'SCENE III. The same. Before the palace.'})
#  ['Ambience']  | ['name']   | (_307:Ambience {name: 'A room in the palace.'})
#  ['Character'] | ['name']   | (_308:Character {name: 'All'})
#  ['Scene']     | ['number'] | (_309:Scene {number: 'SCENE IV. The same. A room in the palace.'})
#  ['Scene']     | ['number'] | (_310:Scene {number: 'SCENE V. Alexandria. MARK ANTONYs camp.'})
#  ['Scene']     | ['number'] | (_311:Scene {number: 'SCENE VI. Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_312:Scene {number: 'SCENE VII. Field of battle between the camps.'})
#  ['Character'] | ['name']   | (_313:Character {name: 'SCARUS'})
#  ['Scene']     | ['number'] | (_314:Scene {number: 'SCENE VIII. Under the walls of Alexandria.'})
#  ['Scene']     | ['number'] | (_315:Scene {number: 'SCENE IX. OCTAVIUS CAESARs camp.'})
#  ['Character'] | ['name']   | (_316:Character {name: 'Third Soldier'})
#  ['Scene']     | ['number'] | (_317:Scene {number: 'SCENE X. Between the two camps.'})
#  ['Scene']     | ['number'] | (_318:Scene {number: 'SCENE XI. Another part of the same.'})
#  ['Scene']     | ['number'] | (_319:Scene {number: 'SCENE XII. Another part of the same.'})
#  ['Ambience']  | ['name']   | (_320:Ambience {name: 'Cleopatras palace.'})
#  ['Scene']     | ['number'] | (_321:Scene {number: 'SCENE XIII. Alexandria. Cleopatras palace.'})
#  ['Scene']     | ['number'] | (_322:Scene {number: 'SCENE XIV. The same. Another room.'})
#  ['Ambience']  | ['name']   | (_323:Ambience {name: 'A monument.'})
#  ['Scene']     | ['number'] | (_324:Scene {number: 'SCENE XV. The same. A monument.'})
#  ['Scene']     | ['number'] | (_325:Scene {number: 'SCENE I. Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Ambience']  | ['name']   | (_326:Ambience {name: 'A room in the monument.'})
#  ['Scene']     | ['number'] | (_327:Scene {number: 'SCENE II. Alexandria. A room in the monument.'})
#  ['Play']      | ['name']   | (_328:Play {name: 'A Comedy of Errors'})
#  ['Scene']     | ['number'] | (_329:Scene {number: 'SCENE I. A hall in DUKE SOLINUSS palace.'})
#  ['Character'] | ['name']   | (_330:Character {name: 'AEGEON'})
#  ['Scene']     | ['number'] | (_331:Scene {number: 'SCENE II. The Mart.'})
#  ['Character'] | ['name']   | (_332:Character {name: 'OF SYRACUSE'})
#  ['Scene']     | ['number'] | (_333:Scene {number: 'SCENE I. The house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_334:Character {name: 'LUCIANA'})
#  ['Scene']     | ['number'] | (_335:Scene {number: 'SCENE II. A public place.'})
#  ['Scene']     | ['number'] | (_336:Scene {number: 'SCENE I. Before the house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_337:Character {name: 'OF EPHESUS'})
#  ['Scene']     | ['number'] | (_338:Scene {number: 'SCENE II. The same.'})
#  ['Scene']     | ['number'] | (_339:Scene {number: 'SCENE I. A public place.'})
#  ['Character'] | ['name']   | (_340:Character {name: 'DROMIO OF SYRACUSE'})
#  ['Scene']     | ['number'] | (_341:Scene {number: 'SCENE II. The house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_342:Character {name: 'ADRIANA'})
#  ['Scene']     | ['number'] | (_343:Scene {number: 'SCENE III. A public place.'})
#  ['Character'] | ['name']   | (_344:Character {name: 'Courtezan'})
#  ['Scene']     | ['number'] | (_345:Scene {number: 'SCENE I. A street before a Priory.'})
#  ['Play']      | ['name']   | (_346:Play {name: 'Coriolanus'})
#  ['Character'] | ['name']   | (_347:Character {name: 'DROMIO OF EPHESUS'})
#  ['Scene']     | ['number'] | (_348:Scene {number: 'SCENE I. Rome. A street.'})
#  ['Location']  | ['name']   | (_349:Location {name: 'Corioli'})
#  ['Ambience']  | ['name']   | (_350:Ambience {name: 'The Senate-house.'})
#  ['Character'] | ['name']   | (_351:Character {name: 'BRUTUS'})
#  ['Scene']     | ['number'] | (_352:Scene {number: 'SCENE II. Corioli. The Senate-house.'})
#  ['Ambience']  | ['name']   | (_353:Ambience {name: 'A room in Marcius house.'})
#  ['Scene']     | ['number'] | (_354:Scene {number: 'SCENE III. Rome. A room in Marcius house.'})
#  ['Character'] | ['name']   | (_355:Character {name: 'VALERIA'})
#  ['Scene']     | ['number'] | (_356:Scene {number: 'SCENE IV. Before Corioli.'})
#  ['Character'] | ['name']   | (_357:Character {name: 'LARTIUS'})
#  ['Scene']     | ['number'] | (_358:Scene {number: 'SCENE V. Corioli. A street.'})
#  ['Scene']     | ['number'] | (_359:Scene {number: 'SCENE VI. Near the camp of Cominius.'})
#  ['Character'] | ['name']   | (_360:Character {name: 'COMINIUS'})
#  ['Scene']     | ['number'] | (_361:Scene {number: 'SCENE VII. The gates of Corioli.'})
#  ['Scene']     | ['number'] | (_362:Scene {number: 'SCENE VIII. A field of battle.'})
#  ['Character'] | ['name']   | (_363:Character {name: 'AUFIDIUS'})
#  ['Scene']     | ['number'] | (_364:Scene {number: 'SCENE IX. The Roman camp.'})
#  ['Scene']     | ['number'] | (_365:Scene {number: 'SCENE X. The camp of the Volsces.'})
#  ['Ambience']  | ['name']   | (_366:Ambience {name: 'A public place.'})
#  ['Character'] | ['name']   | (_367:Character {name: 'First Soldier'})
#  ['Scene']     | ['number'] | (_368:Scene {number: 'SCENE I. Rome. A public place.'})
#  ['Ambience']  | ['name']   | (_369:Ambience {name: 'The Capitol.'})
#  ['Character'] | ['name']   | (_370:Character {name: 'SICINIUS'})
#  ['Scene']     | ['number'] | (_371:Scene {number: 'SCENE II. The same. The Capitol.'})
#  ['Ambience']  | ['name']   | (_372:Ambience {name: 'The Forum.'})
#  ['Scene']     | ['number'] | (_373:Scene {number: 'SCENE III. The same. The Forum.'})
#  ['Character'] | ['name']   | (_374:Character {name: 'First Senator'})
# ...
#  ['Play']      | ['name']   | (_1104:Play {name: 'Troilus and Cressida'})
#  ['Scene']     | ['number'] | (_1105:Scene {number: 'SCENE I. Troy. Before Priams palace.'})
#  ['Location']  | ['name']   | (_1106:Location {name: 'The Same'})
#  ['Character'] | ['name']   | (_1107:Character {name: 'TROILUS'})
#  ['Scene']     | ['number'] | (_1108:Scene {number: 'SCENE II. The Same. A street.'})
#  ['Location']  | ['name']   | (_1109:Location {name: 'The Grecian camp'})
#  ['Ambience']  | ['name']   | (_1110:Ambience {name: 'Before Agamemnons tent.'})
#  ['Character'] | ['name']   | (_1111:Character {name: 'CRESSIDA'})
#  ['Scene']     | ['number'] | (_1112:Scene {number: 'SCENE III. The Grecian camp. Before Agamemnons tent.'})
#  ['Character'] | ['name']   | (_1113:Character {name: 'NESTOR'})
#  ['Scene']     | ['number'] | (_1114:Scene {number: 'SCENE I. A part of the Grecian camp.'})
#  ['Ambience']  | ['name']   | (_1115:Ambience {name: 'A room in Priams palace.'})
#  ['Character'] | ['name']   | (_1116:Character {name: 'AJAX'})
#  ['Scene']     | ['number'] | (_1117:Scene {number: 'SCENE II. Troy. A room in Priams palace.'})
#  ['Ambience']  | ['name']   | (_1118:Ambience {name: 'Before Achilles tent.'})
#  ['Character'] | ['name']   | (_1119:Character {name: 'HECTOR'})
#  ['Scene']     | ['number'] | (_1120:Scene {number: 'SCENE III. The Grecian camp. Before Achilles tent.'})
#  ['Ambience']  | ['name']   | (_1121:Ambience {name: 'Priams palace.'})
#  ['Character'] | ['name']   | (_1122:Character {name: 'AGAMEMNON'})
#  ['Scene']     | ['number'] | (_1123:Scene {number: 'SCENE I. Troy. Priams palace.'})
#  ['Ambience']  | ['name']   | (_1124:Ambience {name: 'Pandarus orchard.'})
#  ['Character'] | ['name']   | (_1125:Character {name: 'PARIS'})
#  ['Scene']     | ['number'] | (_1126:Scene {number: 'SCENE II. The same. Pandarus orchard.'})
#  ['Character'] | ['name']   | (_1127:Character {name: 'PANDARUS'})
#  ['Character'] | ['name']   | (_1128:Character {name: 'THERSITES'})
#  ['Scene']     | ['number'] | (_1129:Scene {number: 'SCENE I. Troy. A street.'})
#  ['Ambience']  | ['name']   | (_1130:Ambience {name: 'Court of Pandarus house.'})
#  ['Scene']     | ['number'] | (_1131:Scene {number: 'SCENE II. The same. Court of Pandarus house.'})
#  ['Ambience']  | ['name']   | (_1132:Ambience {name: 'Street before Pandarus house.'})
#  ['Scene']     | ['number'] | (_1133:Scene {number: 'SCENE III. The same. Street before Pandarus house.'})
#  ['Ambience']  | ['name']   | (_1134:Ambience {name: 'Pandarus house.'})
#  ['Scene']     | ['number'] | (_1135:Scene {number: 'SCENE IV. The same. Pandarus house.'})
#  ['Ambience']  | ['name']   | (_1136:Ambience {name: 'Lists set out.'})
#  ['Character'] | ['name']   | (_1137:Character {name: 'AENEAS'})
#  ['Scene']     | ['number'] | (_1138:Scene {number: 'SCENE V. The Grecian camp. Lists set out.'})
#  ['Scene']     | ['number'] | (_1139:Scene {number: 'SCENE I. The Grecian camp. Before Achilles tent.'})
#  ['Ambience']  | ['name']   | (_1140:Ambience {name: 'Before Calchas tent.'})
#  ['Scene']     | ['number'] | (_1141:Scene {number: 'SCENE II. The same. Before Calchas tent.'})
#  ['Scene']     | ['number'] | (_1142:Scene {number: 'SCENE III. Troy. Before Priams palace.'})
#  ['Scene']     | ['number'] | (_1143:Scene {number: 'SCENE IV. Plains between Troy and the Grecian camp.'})
#  ['Scene']     | ['number'] | (_1144:Scene {number: 'SCENE V. Another part of the plains.'})
#  ['Character'] | ['name']   | (_1145:Character {name: 'ACHILLES'})
#  ['Scene']     | ['number'] | (_1146:Scene {number: 'SCENE VI. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_1147:Scene {number: 'SCENE VII. Another part of the plains.'})
#  ['Character'] | ['name']   | (_1148:Character {name: 'MARGARELON'})
#  ['Scene']     | ['number'] | (_1149:Scene {number: 'SCENE VIII. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_1150:Scene {number: 'SCENE IX. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_1151:Scene {number: 'SCENE X. Another part of the plains.'})
#  ['Play']      | ['name']   | (_1152:Play {name: 'Twelfth Night'})
#  ['Scene']     | ['number'] | (_1153:Scene {number: 'SCENE I. DUKE ORSINOs palace.'})
#  ['Character'] | ['name']   | (_1154:Character {name: 'DUKE ORSINO'})
#  ['Scene']     | ['number'] | (_1155:Scene {number: 'SCENE II. The sea-coast.'})
#  ['Character'] | ['name']   | (_1156:Character {name: 'VIOLA'})
#  ['Scene']     | ['number'] | (_1157:Scene {number: 'SCENE III. OLIVIAS house.'})
#  ['Character'] | ['name']   | (_1158:Character {name: 'SIR TOBY BELCH'})
#  ['Scene']     | ['number'] | (_1159:Scene {number: 'SCENE IV. DUKE ORSINOs palace.'})
#  ['Scene']     | ['number'] | (_1160:Scene {number: 'SCENE V. OLIVIAS house.'})
#  ['Character'] | ['name']   | (_1161:Character {name: 'OLIVIA'})
#  ['Scene']     | ['number'] | (_1162:Scene {number: 'SCENE I. The sea-coast.'})
#  ['Scene']     | ['number'] | (_1163:Scene {number: 'SCENE III. OLIVIAs house.'})
#  ['Scene']     | ['number'] | (_1164:Scene {number: 'SCENE V. OLIVIAs garden.'})
#  ['Character'] | ['name']   | (_1165:Character {name: 'SIR ANDREW'})
#  ['Scene']     | ['number'] | (_1166:Scene {number: 'SCENE I. OLIVIAs garden.'})
#  ['Scene']     | ['number'] | (_1167:Scene {number: 'SCENE II. OLIVIAs house.'})
#  ['Character'] | ['name']   | (_1168:Character {name: 'SEBASTIAN'})
#  ['Scene']     | ['number'] | (_1169:Scene {number: 'SCENE IV. OLIVIAs garden.'})
#  ['Scene']     | ['number'] | (_1170:Scene {number: 'SCENE I. Before OLIVIAs house.'})
#  ['Scene']     | ['number'] | (_1171:Scene {number: 'SCENE III. OLIVIAs garden.'})
#  ['Play']      | ['name']   | (_1172:Play {name: 'Two Gentlemen of Verona'})
#  ['Scene']     | ['number'] | (_1173:Scene {number: 'SCENE I. Verona. An open place.'})
#  ['Ambience']  | ['name']   | (_1174:Ambience {name: 'Garden of JULIAs house.'})
#  ['Character'] | ['name']   | (_1175:Character {name: 'PROTEUS'})
#  ['Scene']     | ['number'] | (_1176:Scene {number: 'SCENE II. The same. Garden of JULIAs house.'})
#  ['Ambience']  | ['name']   | (_1177:Ambience {name: 'ANTONIOs house.'})
#  ['Character'] | ['name']   | (_1178:Character {name: 'JULIA'})
#  ['Scene']     | ['number'] | (_1179:Scene {number: 'SCENE III. The same. ANTONIOs house.'})
#  ['Location']  | ['name']   | (_1180:Location {name: 'Milan'})
#  ['Scene']     | ['number'] | (_1181:Scene {number: 'SCENE I. Milan. The DUKEs palace.'})
#  ['Ambience']  | ['name']   | (_1182:Ambience {name: 'JULIAS house.'})
#  ['Character'] | ['name']   | (_1183:Character {name: 'SPEED'})
#  ['Scene']     | ['number'] | (_1184:Scene {number: 'SCENE II. Verona. JULIAS house.'})
#  ['Character'] | ['name']   | (_1185:Character {name: 'LAUNCE'})
#  ['Scene']     | ['number'] | (_1186:Scene {number: 'SCENE IV. Milan. The DUKEs palace.'})
#  ['Scene']     | ['number'] | (_1187:Scene {number: 'SCENE V. The same. A street.'})
#  ['Ambience']  | ['name']   | (_1188:Ambience {name: 'The DUKES palace.'})
#  ['Scene']     | ['number'] | (_1189:Scene {number: 'SCENE VI. The same. The DUKES palace.'})
#  ['Scene']     | ['number'] | (_1190:Scene {number: 'SCENE VII. Verona. JULIAS house.'})
#  ['Scene']     | ['number'] | (_1191:Scene {number: 'SCENE II. The same. The DUKEs palace.'})
#  ['Location']  | ['name']   | (_1192:Location {name: 'The frontiers of Mantua'})
#  ['Ambience']  | ['name']   | (_1193:Ambience {name: 'A forest.'})
#  ['Scene']     | ['number'] | (_1194:Scene {number: 'SCENE I. The frontiers of Mantua. A forest.'})
#  ['Ambience']  | ['name']   | (_1195:Ambience {name: 'Outside the DUKEs palace, under SILVIAs chamber.'})
#  ['Character'] | ['name']   | (_1196:Character {name: 'Third Outlaw'})
#  ['Scene']     | ['number'] | (_1197:Scene {number: 'SCENE II. Milan. Outside the DUKEs palace, under SILVIAs chamber.'})
#  ['Character'] | ['name']   | (_1198:Character {name: 'SILVIA'})
#  ['Ambience']  | ['name']   | (_1199:Ambience {name: 'An abbey.'})
#  ['Scene']     | ['number'] | (_1200:Scene {number: 'SCENE I. Milan. An abbey.'})
#  ['Character'] | ['name']   | (_1201:Character {name: 'EGLAMOUR'})
#  ['Ambience']  | ['name']   | (_1202:Ambience {name: 'The forest.'})
#  ['Scene']     | ['number'] | (_1203:Scene {number: 'SCENE III. The frontiers of Mantua. The forest.'})
#  ['Play']      | ['name']   | (_1204:Play {name: 'A Winters Tale'})
#  ['Character'] | ['name']   | (_1205:Character {name: 'VALENTINE'})
#  ['Scene']     | ['number'] | (_1206:Scene {number: 'SCENE I. Antechamber in LEONTES palace.'})
#  ['Character'] | ['name']   | (_1207:Character {name: 'ARCHIDAMUS'})
#  ['Scene']     | ['number'] | (_1208:Scene {number: 'SCENE II. A room of state in the same.'})
#  ['Character'] | ['name']   | (_1209:Character {name: 'CAMILLO'})
#  ['Scene']     | ['number'] | (_1210:Scene {number: 'SCENE I. A room in LEONTES palace.'})
#  ['Character'] | ['name']   | (_1211:Character {name: 'ANTIGONUS'})
#  ['Character'] | ['name']   | (_1212:Character {name: 'PAULINA'})
#  ['Scene']     | ['number'] | (_1213:Scene {number: 'SCENE III. A room in LEONTES palace.'})
#  ['Character'] | ['name']   | (_1214:Character {name: 'LEONTES'})
#  ['Scene']     | ['number'] | (_1215:Scene {number: 'SCENE I. A sea-port in Sicilia.'})
#  ['Character'] | ['name']   | (_1216:Character {name: 'DION'})
#  ['Scene']     | ['number'] | (_1217:Scene {number: 'SCENE II. A court of Justice.'})
#  ['Location']  | ['name']   | (_1218:Location {name: 'Bohemia'})
#  ['Ambience']  | ['name']   | (_1219:Ambience {name: 'A desert country near the sea.'})
#  ['Scene']     | ['number'] | (_1220:Scene {number: 'SCENE III. Bohemia. A desert country near the sea.'})
#  ['Ambience']  | ['name']   | (_1221:Ambience {name: 'The palace of POLIXENES.'})
#  ['Character'] | ['name']   | (_1222:Character {name: 'Time'})
#  ['Scene']     | ['number'] | (_1223:Scene {number: 'SCENE II. Bohemia. The palace of POLIXENES.'})
#  ['Character'] | ['name']   | (_1224:Character {name: 'POLIXENES'})
#  ['Scene']     | ['number'] | (_1225:Scene {number: 'SCENE III. A road near the Shepherds cottage.'})
#  ['Character'] | ['name']   | (_1226:Character {name: 'AUTOLYCUS'})
#  ['Scene']     | ['number'] | (_1227:Scene {number: 'SCENE IV. The Shepherds cottage.'})
#  ['Scene']     | ['number'] | (_1228:Scene {number: 'SCENE II. Before LEONTES palace.'})
#  ['Scene']     | ['number'] | (_1229:Scene {number: 'SCENE III. A chapel in PAULINAS house.'})

# %%
# Relaciones existentes entre los nodos:

graph.run("""
    MATCH (n)-[r]-(m)
    RETURN DISTINCT TYPE(r) AS RelationshipType
""").to_table()

# Eliminar relaciones:
# graph.run(""" MATCH (:City)-[r:BELONGS_TO]->(:Play) DELETE r """)
# Out:
#  RelationshipType
# ------------------
#  REPRESENTED_IN
#  HAS_LOCATION
#  IS_IN
#  LOCATION_OF
#  DIVIDED_BY
#  APPEARS_IN

# %% [markdown]
# ### CONSULTAS CASO DE USO

# %%
# Consulta 1: Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare

graph.run("""
    MATCH (location:Location {name: 'London'})-[:HAS_LOCATION]->(ambience:Ambience)
    RETURN location.name AS Location, COLLECT(ambience.name) AS Ambience
    ORDER BY location.name
""").to_table()
# Out:
#  Location | Ambience
# ----------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  London   | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']

# %%
# Consulta 2: Obras de Shakespeare ambientadas en Londres y sus localizaciones
graph.run("""
    MATCH (ambience:Ambience)<-[:HAS_LOCATION]-(locatioin:Location {name: 'London'})<-[:REPRESENTED_IN]-(play:Play)
    RETURN play.name AS Play, COLLECT(ambience.name) AS Ambience
""").to_table()
# Out:
#  Play            | Ambience
# -----------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Richard III     | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Richard II      | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry VIII      | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry V         | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry VI Part 3 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry VI Part 2 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry VI Part 1 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Henry IV        | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']

# %%
# Consulta 3: De las obras en Londres, saber las escenas de cada obra.
graph.run("""
    MATCH (location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)-[:DIVIDED_BY]->(scene:Scene)
    RETURN play.name AS Play, COLLECT(scene.number) AS Scene
    ORDER BY Scene
""").to_table()
# Out:
#  Play            | Scene
# -----------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Henry VI Part 2 | ['SCENE I. London. The palace.', 'SCENE III. Fields near St. Albans.', 'SCENE II. GLOUCESTERS house.', 'SCENE III. The palace.', 'SCENE IV. GLOUCESTERs garden.', 'SCENE I. Saint Albans.', 'SCENE II. London. YORKS garden.', 'SCENE III. A hall of justice.', 'SCENE IV. A street.', 'SCENE I. The Abbey at Bury St. Edmunds.', 'SCENE II. Bury St. Edmunds. A room of state.', 'SCENE III. A bedchamber.', 'SCENE I. The coast of Kent.', 'SCENE II. Blackheath.', 'SCENE III. Another part of Blackheath.', 'SCENE IV. London. The palace.', 'SCENE V. London. The Tower.', 'SCENE VI. London. Cannon Street.', 'SCENE VII. London. Smithfield.', 'SCENE VIII. Southwark.', 'SCENE IX. Kenilworth Castle.', 'SCENE X. Kent. IDENs garden.', 'SCENE I. Fields between Dartford and Blackheath.', 'SCENE II. Saint Albans.']
#  Henry VI Part 1 | ['SCENE I. London. The palace.', 'SCENE V. London. The palace.', 'SCENE IV. Camp of the YORK in Anjou.', 'SCENE III. Before Angiers.', 'SCENE II. France. Plains in Anjou.', 'SCENE I. Westminster Abbey.', 'SCENE II. France. Before Orleans.', 'SCENE III. London. Before the Tower.', 'SCENE IV. Orleans.', 'SCENE V. The same.', 'SCENE VI. The same.', 'SCENE I. Before Orleans.', 'SCENE II. Orleans. Within the town.', 'SCENE III. Auvergne. The COUNTESSs castle.', 'SCENE IV. London. The Temple-garden.', 'SCENE V. The Tower of London.', 'SCENE I. London. The Parliament-house.', 'SCENE II. France. Before Rouen.', 'SCENE III. The plains near Rouen.', 'SCENE IV. Paris. The palace.', 'SCENE I. Paris. A hall of state.', 'SCENE II. Before Bourdeaux.', 'SCENE III. Plains in Gascony.', 'SCENE IV. Other plains in Gascony.', 'SCENE V. The English camp near Bourdeaux.', 'SCENE VI. A field of battle.', 'SCENE VII. Another part of the field.']
#  Henry V         | ['SCENE II. France. A royal palace.', 'SCENE I. France. The English camp.', 'SCENE VIII. Before KING HENRYS pavilion.', 'SCENE VII. Another part of the field.', 'SCENE VI. Another part of the field.', 'SCENE V. Another part of the field.', 'SCENE IV. The field of battle.', 'SCENE III. The English camp.', 'SCENE II. The French camp.', 'SCENE I. The English camp at Agincourt.', 'SCENE VII. The French camp, near Agincourt:', 'SCENE VI. The English camp in Picardy.', 'SCENE V. The same.', 'SCENE IV. The FRENCH KINGs palace.', 'SCENE III. The same. Before the gates.', 'SCENE II. The same.', 'SCENE I. France. Before Harfleur.', 'SCENE IV. France. The KINGS palace.', 'SCENE III. London. Before a tavern.', 'SCENE II. Southampton. A council-chamber.', 'SCENE I. London. A street.', 'SCENE II. The same. The Presence chamber.', 'SCENE I. London. An ante-chamber in the KINGS palace.']
#  Richard III     | ['SCENE V. Another part of the field.', 'SCENE IV. Another part of the field.', 'SCENE III. Bosworth Field.', 'SCENE II. The camp near Tamworth.', 'SCENE I. Salisbury. An open place.', 'SCENE V. Lord Derbys house.', 'SCENE IV. Before the palace.', 'SCENE III. The same.', 'SCENE II. London. The palace.', 'SCENE I. Before the Tower.', 'SCENE VII. Baynards Castle.', 'SCENE VI. The same.', 'SCENE V. The Tower-walls.', 'SCENE IV. The Tower of London.', 'SCENE III. Pomfret Castle.', 'SCENE II. Before Lord Hastings house.', 'SCENE IV. London. The palace.', 'SCENE III. London. A street.', 'SCENE II. The palace.', 'SCENE I. London. The palace.', 'SCENE IV. London. The Tower.', 'SCENE III. The palace.', 'SCENE II. The same. Another street.', 'SCENE I. London. A street.']
#  Henry IV        | ['SCENE V. Another part of the field.', 'SCENE IV. Another part of the field.', 'SCENE III. Plain between the camps.', 'SCENE II. The rebel camp.', 'SCENE I. KING HENRY IVs camp near Shrewsbury.', 'SCENE IV. York. The ARCHBISHOPS palace.', 'SCENE III. The rebel camp near Shrewsbury.', 'SCENE II. A public road near Coventry.', 'SCENE I. The rebel camp near Shrewsbury.', 'SCENE II. London. The palace.', 'SCENE I. Bangor. The Archdeacons house.', 'SCENE IV. The Boars-Head Tavern, Eastcheap.', 'SCENE III. Warkworth castle', 'SCENE II. The highway, near Gadshill.', 'SCENE I. Rochester. An inn yard.', 'SCENE III. London. The palace.', 'SCENE II. London. An apartment of the Princes.', 'SCENE I. London. The palace.']
#  Henry VIII      | ['SCENE V. The palace.', 'SCENE IV. The palace yard.', 'SCENE III. The Council-Chamber.', 'SCENE II. Before the council-chamber. Pursuivants, Pages,  and c.', 'SCENE I. London. A gallery in the palace.', 'SCENE II. Kimbolton.', 'SCENE I. A street in Westminster.', 'SCENE II. Ante-chamber to KING HENRY VIIIs apartment.', 'SCENE I. London. QUEEN KATHARINEs apartments.', 'SCENE IV. A hall in Black-Friars.', 'SCENE III. An ante-chamber of the QUEENS apartments.', 'SCENE II. An ante-chamber in the palace.', 'SCENE I. Westminster. A street.', 'SCENE IV. A Hall in York Place.', 'SCENE III. An ante-chamber in the palace.', 'SCENE II. The same. The council-chamber.', 'SCENE I. London. An ante-chamber in the palace.']
#  Richard II      | ['SCENE VI. Windsor castle.', 'SCENE V. Pomfret castle.', 'SCENE IV. The same.', 'SCENE III. A royal palace.', 'SCENE II. The DUKE OF YORKs palace.', 'SCENE I. London. A street leading to the Tower.', 'SCENE I. Westminster Hall.', 'SCENE IV. LANGLEY. The DUKE OF YORKs garden.', 'SCENE III. Wales. Before Flint castle.', 'SCENE II. The coast of Wales. A castle in view.', 'SCENE I. Bristol. Before the castle.', 'SCENE IV. A camp in Wales.', 'SCENE III. Wilds in Gloucestershire.', 'SCENE II. The palace.', 'SCENE I. Ely House.', 'SCENE IV. The court.', 'SCENE III. The lists at Coventry.', 'SCENE II. The DUKE OF LANCASTERS palace.', 'SCENE I. London. KING RICHARD IIs palace.']
#  Henry VI Part 3 | ['SCENE VII. London. The palace.', 'SCENE IV. Plains near Tewksbury.', 'SCENE III. Another part of the field.', 'SCENE II. A field of battle near Barnet.', 'SCENE I. Coventry.', 'SCENE VIII. London. The palace.', 'SCENE VII. Before York.', 'SCENE VI. London. The Tower.', 'SCENE V. A park near Middleham Castle In Yorkshire.', 'SCENE IV. London. The palace.', 'SCENE III. Edwards camp, near Warwick.', 'SCENE II. A plain in Warwickshire.', 'SCENE I. London. The palace.', 'SCENE III. France. KING LEWIS XIs palace.', 'SCENE II. London. The palace.', 'SCENE I. A forest in the north of England.', 'SCENE VI. Another part of the field.', 'SCENE V. Another part of the field.', 'SCENE III. A field of battle between Towton and Saxton, in', 'SCENE II. Before York.', 'SCENE I. A plain near Mortimers Cross in Herefordshire.', 'SCENE IV. Another part of the field.', 'SCENE III. Field of battle betwixt Sandal Castle and Wakefield.', 'SCENE II. Sandal Castle.', 'SCENE I. London. The Parliament-house.']

# %%
# Consulta 4: De las obras en Londres, saber los personajes que aparecen en cada obra.
graph.run("""
    MATCH (location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COLLECT(character.name) AS Character
""").to_table()
# Out:
#  Play            | Character
# -----------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Richard III     | ['RICHMOND', 'DERBY', 'KING RICHARD III', 'QUEEN ELIZABETH', 'Scrivener', 'RIVERS', 'HASTINGS', 'ARCHBISHOP OF YORK', 'Third Citizen', 'BUCKINGHAM', 'First Murderer', 'GLOUCESTER', 'HENRY BOLINGBROKE']
#  Richard II      | ['EXTON', 'DUCHESS OF YORK', 'Abbot', 'GARDENER', 'EARL OF SALISBURY', 'DUKE OF YORK', 'BAGOT', 'LORD WILLOUGHBY', 'All', 'HENRY BOLINGBROKE', 'DUCHESS', 'KING RICHARD II', 'GOWER']
#  Henry VIII      | ['Porter', 'KATHARINE', 'Both', 'CARDINAL WOLSEY', 'QUEEN KATHARINE', 'Old Lady', 'First Gentleman', 'SANDS', 'KING HENRY VIII', 'BUCKINGHAM', 'Chorus']
#  Henry V         | ['BOURBON', 'Boy', 'Constable', 'KING OF FRANCE', 'KATHARINE', 'FLUELLEN', 'Hostess', 'KING HENRY V', 'PISTOL', 'ELY', 'Chorus']
#  Henry VI Part 3 | ['OXFORD', 'SOMERSET', 'QUEEN ELIZABETH', 'KING EDWARD IV', 'GLOUCESTER', 'KING HENRY VI', 'RICHARD', 'GEORGE', 'EDWARD', 'QUEEN MARGARET', 'CLIFFORD', 'YORK', 'EXETER', 'WARWICK']
#  Henry VI Part 2 | ['YOUNG CLIFFORD', 'SUFFOLK', 'YORK', 'HUME', 'KING HENRY VI', 'DUCHESS', 'QUEEN MARGARET', 'First Gentleman', 'CADE', 'SAY', 'SCALES', 'BUCKINGHAM', 'IDEN', 'RICHARD']
#  Henry VI Part 1 | ['KING HENRY IV', 'YORK', 'SUFFOLK', 'OF WINCHESTER', 'CHARLES', 'Mayor', 'TALBOT', 'Soldier', 'Captain', 'OF AUVERGNE', 'PLANTAGENET', 'EXETER', 'VERNON', 'LUCY']
#  Henry IV        | ['ARCHBISHOP OF YORK', 'SIR WALTER BLUNT', 'EARL OF DOUGLAS', 'FALSTAFF', 'MORTIMER', 'PETO', 'LADY PERCY', 'POINS', 'GADSHILL', 'HOTSPUR', 'PRINCE HENRY', 'WESTMORELAND', '']

# %%
# Consulta 5: Cuantas veces aparece un personaje en un ambiente y en qué ambiente.

graph.run("""
    MATCH (ambience:Ambience)<-[HAS_LOCATION]-(location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN character.name AS Character, COUNT(*) AS Appearances, COLLECT(ambience.name) As Ambience
    ORDER BY Appearances DESC
""").to_table()
# Out:
#  Character          | Appearances | Ambience
# --------------------|-------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  BUCKINGHAM         |          51 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  YORK               |          51 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  QUEEN ELIZABETH    |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  ARCHBISHOP OF YORK |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  GLOUCESTER         |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  HENRY BOLINGBROKE  |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  DUCHESS            |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  KATHARINE          |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  First Gentleman    |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Chorus             |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  KING HENRY VI      |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  RICHARD            |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  QUEEN MARGARET     |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  EXETER             |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  SUFFOLK            |          34 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.', 'A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  RICHMOND           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  DERBY              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  KING RICHARD III   |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Scrivener          |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  RIVERS             |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  HASTINGS           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Third Citizen      |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  First Murderer     |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  EXTON              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  DUCHESS OF YORK    |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Abbot              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  GARDENER           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  EARL OF SALISBURY  |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  DUKE OF YORK       |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  BAGOT              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  LORD WILLOUGHBY    |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  All                |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  KING RICHARD II    |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  GOWER              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Porter             |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Both               |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
# ...
#  LUCY               |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  SIR WALTER BLUNT   |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  EARL OF DOUGLAS    |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  FALSTAFF           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  MORTIMER           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  PETO               |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  LADY PERCY         |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  POINS              |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  GADSHILL           |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  HOTSPUR            |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  PRINCE HENRY       |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  WESTMORELAND       |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#                     |          17 | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']

# %%
# Consulta 6: Texto completo de una escena específica de una obra de Shakespeare 
graph.run("""
MATCH (play:Play {name: 'Richard III'})-[:DIVIDED_BY]->(scene:Scene {number: 'SCENE V. Another part of the field.'})<-[:IS_IN]-(line:Line)
RETURN play.name AS Play, scene.number AS Scene, COLLECT(line.text_entry) AS SceneText
""").to_table()

# %% [markdown]
# ### CONSULTAS GENÉRICAS

# %%
# Consulta: Listado con las localizaciones que aparecen en cada obra de Shakespeare

graph.run("""
    MATCH (play:Play)-[:REPRESENTED_IN]->(location:Location)
    RETURN play.name AS Play, COLLECT(location.name) AS Locations
    ORDER BY play.name
""").to_table()
# Out:
#  Play                     | Locations
# --------------------------|------------------------------------------------------------------------------------------------------------------------
#  A Comedy of Errors       | ['Alexandria']
#  A Midsummer nights dream | ['The same', 'The wood', 'Athens']
#  A Winters Tale           | ['Bohemia', 'The frontiers of Mantua']
#  Alls well that ends well | ['Marseilles', 'Florence', 'Paris', 'Rousillon']
#  Antony and Cleopatra     | ['Alexandria', 'Before Alexandria', 'Egypt', 'The same', 'Rome', 'Messina', 'Athens', 'Near Actium']
#  As you like it           | ['Rousillon']
#  Coriolanus               | ['Rome', 'Corioli', 'The same', 'Antium']
#  Cymbeline                | ['Britain', 'The same', 'Rome', 'Wales']
#  Hamlet                   | ['Elsinore']
#  Henry IV                 | ['York', 'Bangor', 'Rochester', 'London']
#  Henry V                  | ['France', 'Southampton', 'The same', 'London']
#  Henry VI Part 1          | ['York', 'France', 'London', 'Orleans', 'Auvergne', 'Paris']
#  Henry VI Part 2          | ['London', 'The Abbey at Bury St', 'Bury St', 'Kent', 'Fields near St']
#  Henry VI Part 3          | ['France', 'London']
#  Henry VIII               | ['Before the council-chamber', 'Westminster', 'The same', 'London']
#  Julius Caesar            | ['Camp near Sardis', 'The same', 'Rome']
#  King John                | ['LEWISs camp at St', 'The same', 'France', 'Before the council-chamber']
#  King Lear                | ['A tent in the French camp', 'The heath', 'Another part of the heath', 'Before GLOUCESTERs castle', 'The same']
#  Loves Labours Lost       | ['A tent in the French camp']
#  Measure for measure      | ['The moated grange at ST', 'Dunsinane']
#  Merchant of Venice       | ['The same', 'Belmont', 'Venice']
#  Merry Wives of Windsor   | ['Windsor']
#  Much Ado about nothing   | ['Athens']
#  Othello                  | ['Cyprus', 'A Sea-port in Cyprus', 'Venice']
#  Pericles                 | ['On board PERICLES ship, off Mytilene', 'Mytilene', 'Ephesus', 'The same', 'Pentapolis', 'Tarsus', 'Tyre', 'Antioch']
#  Richard II               | ['LANGLEY', 'Wales', 'The coast of Wales', 'Bristol', 'London']
#  Richard III              | ['Salisbury', 'The same', 'London']
#  Romeo and Juliet         | ['Mantua', 'Verona']
#  Taming of the Shrew      | ['Padua', 'Mantua']
#  The Tempest              | ['The island', 'Padua']
#  Timon of Athens          | ['The woods', 'The same', 'Athens']
#  Titus Andronicus         | ['Court of TITUSs house', 'The same', 'A room in Tituss house', 'A forest near Rome', 'Rome']
#  Troilus and Cressida     | ['Troy', 'The Same', 'The Grecian camp', 'The same']
#  Twelfth Night            | ['Troy']
#  Two Gentlemen of Verona  | ['The frontiers of Mantua', 'Milan', 'The same', 'Verona']
#  macbeth                  | ['A tent in the French camp', 'Forres', 'Inverness', 'The same', 'A cavern', 'Fife', 'England', 'Dunsinane']

# %%
# Consulta: Listado con los ambientes que tiene cada una de las localizaciones de la obra de Shakespeare

graph.run("""
    MATCH (location:Location)-[:HAS_LOCATION]->(ambience:Ambience)
    RETURN location.name AS Location, COLLECT(ambience.name) AS Ambience
    ORDER BY location.name
""").to_table()
# Out:
#  Location                             | Ambience
# --------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  A Sea-port in Cyprus                 | ['An open place near the quay.']
#  A cavern                             | ['In the middle, a boiling cauldron.']
#  A forest near Rome                   | ['Horns and cry of hounds heard.']
#  A room in Tituss house               | ['A banquet set out.']
#  A tent in the French camp            | ['LEAR on a bed asleep,']
#  Alexandria                           | ['A room in the monument.', 'Cleopatras palace.', 'OCTAVIUS CAESARs camp.', 'MARK ANTONYs camp.', 'CLEOPATRAs palace.', 'A room in CLEOPATRAs palace.']
#  Another part of the heath            | ['Storm still.']
#  Antioch                              | ['A room in the palace.']
#  Antium                               | ['A public place.', 'Before Aufidiuss house.']
#  Athens                               | ['A room in Timons house.', 'A hall in Timons house.', 'QUINCES house.', 'The palace of THESEUS.', 'A room in MARK ANTONYs house.']
#  Auvergne                             | ['The COUNTESSs castle.']
#  Bangor                               | ['The Archdeacons house.']
#  Before Alexandria                    | ['OCTAVIUS CAESARs camp.']
#  Before GLOUCESTERs castle            | ['KENT in the stocks.']
#  Before the council-chamber           | ['Pursuivants, Pages,  and c.']
#  Belmont                              | ['Avenue to PORTIAS house.', 'A room in PORTIAS house.']
#  Bohemia                              | ['The palace of POLIXENES.', 'A desert country near the sea.']
#  Bristol                              | ['Before the castle.']
#  Britain                              | ['The Roman camp.', 'A hall in Cymbelines palace.', 'Before Cymbelines palace.', 'A room in Cymbelines palace.', 'The garden of Cymbelines palace.']
#  Bury St                              | ['Edmunds. A room of state.']
#  Camp near Sardis                     | ['Before BRUTUSs tent.']
#  Corioli                              | ['A street.', 'The Senate-house.']
#  Court of TITUSs house                | ['A banquet set out.']
#  Cyprus                               | ['A street.', 'Before the castle.']
#  Dunsinane                            | ['Before the castle.', 'Within the castle.', 'A room in the castle.', 'Ante-room in the castle.']
#  Egypt                                | ['OCTAVIUS CAESARs camp.']
#  Elsinore                             | ['A room in the castle.', 'A platform before the castle.']
#  England                              | ['Before the Kings palace.']
#  Ephesus                              | ['A room in CERIMONs house.']
#  Fields near St                       | ['Albans.']
#  Fife                                 | ['Macduffs castle.']
#  Florence                             | ['The Widows house.', 'Without the walls. A tucket afar off.', 'Before the DUKEs palace.', 'The DUKEs palace.']
#  Forres                               | ['The palace.']
#  France                               | ['Before Angiers.', 'A royal palace.', 'The English camp.', 'Before Harfleur.', 'The KINGS palace.', 'KING LEWIS XIs palace.', 'Plains in Anjou.', 'Before Rouen.', 'Before Orleans.']
#  Inverness                            | ['Macbeths castle.']
#  Kent                                 | ['IDENs garden.']
#  LANGLEY                              | ['The DUKE OF YORKs garden.']
#  LEWISs camp at St                    | ['Edmundsbury.']
#  London                               | ['A street leading to the Tower.', 'KING RICHARD IIs palace.', 'A gallery in the palace.', 'QUEEN KATHARINEs apartments.', 'An ante-chamber in the palace.', 'Before a tavern.', 'A street.', 'An ante-chamber in the KINGS palace.', 'Smithfield.', 'Cannon Street.', 'The Tower.', 'YORKS garden.', 'The Parliament-house.', 'The Temple-garden.', 'Before the Tower.', 'An apartment of the Princes.', 'The palace.']
#  Mantua                               | ['A street.']
#  Marseilles                           | ['A street.']
#  Messina                              | ['POMPEYs house.']
#  Milan                                | ['An abbey.', 'Outside the DUKEs palace, under SILVIAs chamber.', 'The DUKEs palace.']
# ...
#  The coast of Wales                   | ['A castle in view.']
#  The frontiers of Mantua              | ['The forest.', 'A forest.']
#  The heath                            | ['Before a hovel.']
#  The island                           | ['Before PROSPEROS cell.']
#  The moated grange at ST              | ['LUKEs.']
#  The same                             | ['Street before Pandarus house.', 'The DUKEs palace.', 'The DUKES palace.', 'ANTONIOs house.', 'Garden of JULIAs house.', 'Before Calchas tent.', 'Pandarus house.', 'Another room.', 'OCTAVIUS CAESARs house.', 'A street.', 'Before the palace.', 'A room in the palace.', 'A monument.', 'The Capitol.', 'The Forum.', 'A  street near the gate.', 'A hall in Aufidiuss house.', 'A street near the gate.', 'A public place.', 'Another room in the palace.', 'The Presence chamber.', 'Before the gates.', 'The council-chamber.', 'Plains near Angiers.', 'KING PHILIPS tent.', 'The field of battle.', 'A tent.', 'Hall in the palace.', 'A room in SHYLOCKS house.', 'Before SHYLOCKS house.', 'A garden.', 'LYSANDER, DEMETRIUS, HELENA, and HERMIA', 'A public way or platform leading to the', 'A hall of state: a banquet prepared.', 'A room in the brothel.', 'Another street.', 'A hall in Timons house.', 'The senate-house. The Senate sitting.', 'A banqueting-room in Timons house.', 'Pandarus orchard.', 'Court of Pandarus house.']
#  The wood                             | ['TITANIA lying asleep.']
#  The woods                            | ['Timons cave, and a rude tomb seen.', 'Before Timons cave.']
#  Troy                                 | ['A street.', 'Priams palace.', 'A room in Priams palace.', 'Before Priams palace.']
#  Tyre                                 | ['A room in the Governors house.', 'An ante-chamber in the palace.', 'A room in the palace.']
#  Venice                               | ['A court of justice.', 'A public place.', 'A street.']
#  Verona                               | ['JULIAS house.', 'An open place.', 'A public place.']
#  Wales                                | ['Before Flint castle.', 'Before the cave of Belarius.']
#  Westminster                          | ['A street.']
#  Windsor                              | ['Before PAGEs house.']
#  York                                 | ['The ARCHBISHOPS palace.']

# %%
# Consulta: Personajes que actuan en cada obra de Shakespeare
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COLLECT(character.name) AS Character
    ORDER BY play.name
""").to_table()
# Out:
#  Play                     | Character
# --------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  A Comedy of Errors       | ['Courtezan', 'ADRIANA', 'DROMIO OF SYRACUSE', 'OF EPHESUS', 'LUCIANA', 'OF SYRACUSE', 'AEGEON', 'OCTAVIUS CAESAR']
#  A Midsummer nights dream | ['TITANIA', 'HERMIA', 'PUCK', 'BOTTOM', 'HELENA', 'FORD']
#  A Winters Tale           | ['Clown', 'AUTOLYCUS', 'POLIXENES', 'Time', 'DION', 'LEONTES', 'PAULINA', 'ANTIGONUS', 'CAMILLO', 'ARCHIDAMUS', 'VALENTINE']
#  Alls well that ends well | ['Clown', 'DIANA', 'Second Lord', 'First Lord', 'BOTH', 'DUKE', 'PAROLLES', 'KING', 'COUNTESS', 'BERTRAM', 'HELENA', 'KING EDWARD IV']
#  Antony and Cleopatra     | ['ROSALIND', 'Third Soldier', 'SCARUS', 'All', 'THYREUS', 'DEMETRIUS', 'DOMITIUS ENOBARBUS', 'MARK ANTONY', 'OCTAVIUS CAESAR', 'CLEOPATRA', 'POMPEY', 'LEPIDUS', 'MENAS', 'VENTIDIUS', 'CHARMIAN', 'EROS', 'CANIDIUS']
#  As you like it           | ['TOUCHSTONE', 'Forester', 'PHEBE', 'SIR OLIVER MARTEXT', 'ROSALIND', 'DUKE SENIOR', 'AMIENS', 'CORIN', 'ADAM', 'DUKE FREDERICK', 'First Lord', 'CELIA', 'ORLANDO', 'OLIVER', 'KING']
#  Coriolanus               | ['Second Senator', 'DROMIO OF EPHESUS', 'BRUTUS', 'All', 'VALERIA', 'LARTIUS', 'COMINIUS', 'AUFIDIUS', 'First Soldier', 'SICINIUS', 'First Senator', 'CORIOLANUS', 'Citizens', 'MENENIUS', 'Roman']
#  Cymbeline                | ['First Gaoler', 'AUFIDIUS', 'IMOGEN', 'Second Lord', 'PISANIO', 'PHILARIO', 'CLOTEN', 'IACHIMO', 'POSTHUMUS LEONATUS', 'CYMBELINE', 'BELARIUS', 'ARVIRAGUS', 'First Tribune', 'CAIUS LUCIUS', 'Second Captain']
#  Hamlet                   | ['HORATIO', 'KING CLAUDIUS', 'LORD POLONIUS', 'OPHELIA', 'HAMLET', 'MARCELLUS', 'CYMBELINE']
#  Henry IV                 | ['ARCHBISHOP OF YORK', 'SIR WALTER BLUNT', 'EARL OF DOUGLAS', 'FALSTAFF', 'MORTIMER', 'PETO', 'LADY PERCY', 'POINS', 'GADSHILL', 'HOTSPUR', 'PRINCE HENRY', 'WESTMORELAND', '']
#  Henry V                  | ['BOURBON', 'Boy', 'Constable', 'KING OF FRANCE', 'KATHARINE', 'FLUELLEN', 'Hostess', 'KING HENRY V', 'PISTOL', 'ELY', 'Chorus']
#  Henry VI Part 1          | ['KING HENRY IV', 'YORK', 'SUFFOLK', 'OF WINCHESTER', 'CHARLES', 'Mayor', 'TALBOT', 'Soldier', 'Captain', 'OF AUVERGNE', 'PLANTAGENET', 'EXETER', 'VERNON', 'LUCY']
#  Henry VI Part 2          | ['YOUNG CLIFFORD', 'SUFFOLK', 'YORK', 'HUME', 'KING HENRY VI', 'DUCHESS', 'QUEEN MARGARET', 'First Gentleman', 'CADE', 'SAY', 'SCALES', 'BUCKINGHAM', 'IDEN', 'RICHARD']
#  Henry VI Part 3          | ['OXFORD', 'SOMERSET', 'QUEEN ELIZABETH', 'KING EDWARD IV', 'GLOUCESTER', 'KING HENRY VI', 'RICHARD', 'GEORGE', 'EDWARD', 'QUEEN MARGARET', 'CLIFFORD', 'YORK', 'EXETER', 'WARWICK']
#  Henry VIII               | ['Porter', 'KATHARINE', 'Both', 'CARDINAL WOLSEY', 'QUEEN KATHARINE', 'Old Lady', 'First Gentleman', 'SANDS', 'KING HENRY VIII', 'BUCKINGHAM', 'Chorus']
#  Julius Caesar            | ['CLAUDIUS', 'OCTAVIUS', 'Third Citizen', 'ANTONY', 'PORTIA', 'ARTEMIDORUS', 'BRUTUS', 'CASSIUS', 'FLAVIUS', 'BASTARD']
#  King John                | ['SALISBURY', 'HUBERT', 'LEWIS', 'KING JOHN', 'BASTARD', 'KING HENRY VIII']
#  King Lear                | ['REGAN', 'CORDELIA', 'Third Servant', 'CORNWALL', 'EDGAR', 'KENT', 'GLOUCESTER', 'Fool', 'ALBANY', 'EDMUND', 'GONERIL', 'OCTAVIUS']
#  Loves Labours Lost       | ['HOLOFERNES', 'BIRON', 'BOYET', 'ADRIANO DE ARMADO', 'COSTARD', 'ALBANY']
#  Measure for measure      | ['FRIAR PETER', 'LUCIO', 'Provost', 'ANGELO', 'ISABELLA', 'DUKE VINCENTIO', 'CLAUDIO', 'ESCALUS', 'MALCOLM']
#  Merchant of Venice       | ['BASSANIO', 'SHYLOCK', 'NERISSA', 'SALARINO', 'LORENZO', 'JESSICA', 'GRATIANO', 'MOROCCO', 'PORTIA', 'ANTONIO', 'DUKE VINCENTIO']
#  Merry Wives of Windsor   | ['MISTRESS FORD', 'PAGE', 'FENTON', 'FALSTAFF', 'Host', 'MISTRESS PAGE', 'All', 'DOCTOR CAIUS', 'FORD', 'MISTRESS QUICKLY', 'PISTOL', 'SIR HUGH EVANS', 'SLENDER', 'GRATIANO']
#  Much Ado about nothing   | ['CLAUDIO', 'DOGBERRY', 'HERO', 'CONRADE', 'BEATRICE', 'BENEDICK', 'DON JOHN', 'BORACHIO', 'LEONATO', 'DON PEDRO', 'PUCK']
#  Othello                  | ['DESDEMONA', 'LODOVICO', 'BIANCA', 'Gentleman', 'CASSIO', 'Herald', 'IAGO', 'BRABANTIO', 'BENEDICK']
#  Pericles                 | ['First Gentleman', 'Bawd', 'LEONINE', 'CERIMON', 'SIMONIDES', 'GOWER', 'HELICANUS', 'PERICLES', 'ANTIOCHUS', 'LODOVICO']
#  Richard II               | ['EXTON', 'DUCHESS OF YORK', 'Abbot', 'GARDENER', 'EARL OF SALISBURY', 'DUKE OF YORK', 'BAGOT', 'LORD WILLOUGHBY', 'All', 'HENRY BOLINGBROKE', 'DUCHESS', 'KING RICHARD II', 'GOWER']
#  Richard III              | ['RICHMOND', 'DERBY', 'KING RICHARD III', 'QUEEN ELIZABETH', 'Scrivener', 'RIVERS', 'HASTINGS', 'ARCHBISHOP OF YORK', 'Third Citizen', 'BUCKINGHAM', 'First Murderer', 'GLOUCESTER', 'HENRY BOLINGBROKE']
#  Romeo and Juliet         | ['Second Musician', 'CAPULET', 'PRINCE', 'JULIET', 'FRIAR LAURENCE', 'Chorus', 'Nurse', 'ROMEO', 'BENVOLIO', 'RICHMOND']
#  Taming of the Shrew      | ['LUCENTIO', 'PETRUCHIO', 'BAPTISTA', 'TRANIO', 'HORTENSIO', 'SLY', 'Lord', 'PRINCE']
#  The Tempest              | ['ADRIAN', 'TRINCULO', 'STEPHANO', 'ARIEL', 'PROSPERO', 'GONZALO', 'LUCENTIO']
#  Timon of Athens          | ['Soldier', 'Third Senator', 'First Senator', 'Fourth Lord', 'ALCIBIADES', 'TIMON', 'Servant', 'First Stranger', 'FLAMINIUS', 'FLAVIUS', 'Senator', 'APEMANTUS', 'First Lord', 'PROSPERO']
#  Titus Andronicus         | ['AARON', 'MARCUS ANDRONICUS', 'LUCIUS', 'MARCUS', 'TITUS ANDRONICUS', 'DEMETRIUS', 'SATURNINUS', 'ALCIBIADES']
#  Troilus and Cressida     | ['LUCIUS', 'TROILUS', 'CRESSIDA', 'NESTOR', 'AJAX', 'HECTOR', 'AGAMEMNON', 'PARIS', 'PANDARUS', 'THERSITES', 'AENEAS', 'ACHILLES', 'MARGARELON']
#  Twelfth Night            | ['Clown', 'SEBASTIAN', 'SIR ANDREW', 'ANTONIO', 'OLIVIA', 'SIR TOBY BELCH', 'VIOLA', 'DUKE ORSINO', 'PANDARUS']
#  Two Gentlemen of Verona  | ['EGLAMOUR', 'SILVIA', 'Third Outlaw', 'DUKE', 'LAUNCE', 'SPEED', 'JULIA', 'PROTEUS', 'Clown']
#  macbeth                  | ['ADRIANO DE ARMADO', 'MACDUFF', 'SIWARD', 'Doctor', 'LENNOX', 'ALL', 'DUNCAN', 'MACBETH', 'LADY MACBETH', 'MALCOLM', 'Old Man', 'First Murderer', 'First Witch', 'Lord', 'Son', 'Gentlewoman']

# %%
# Consulta: ¿Cuántos personajes hay en cada obra de Shakespeare?
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COUNT(character) AS NumberOfCharacters
    ORDER BY NumberOfCharacters DESC
""").to_table()
# Out:
#  Play                     | NumberOfCharacters
# --------------------------|--------------------
#  Antony and Cleopatra     |                 17
#  macbeth                  |                 16
#  As you like it           |                 15
#  Coriolanus               |                 15
#  Cymbeline                |                 15
#  Henry VI Part 1          |                 14
#  Henry VI Part 2          |                 14
#  Henry VI Part 3          |                 14
#  Merry Wives of Windsor   |                 14
#  Timon of Athens          |                 14
#  Henry IV                 |                 13
#  Richard II               |                 13
#  Richard III              |                 13
#  Troilus and Cressida     |                 13
#  Alls well that ends well |                 12
#  King Lear                |                 12
#  Henry V                  |                 11
#  Henry VIII               |                 11
#  Merchant of Venice       |                 11
#  Much Ado about nothing   |                 11
#  A Winters Tale           |                 11
#  Julius Caesar            |                 10
#  Pericles                 |                 10
#  Romeo and Juliet         |                 10
#  Measure for measure      |                  9
#  Othello                  |                  9
#  Twelfth Night            |                  9
#  Two Gentlemen of Verona  |                  9
#  A Comedy of Errors       |                  8
#  Taming of the Shrew      |                  8
#  Titus Andronicus         |                  8
#  Hamlet                   |                  7
#  The Tempest              |                  7
#  King John                |                  6
#  Loves Labours Lost       |                  6
#  A Midsummer nights dream |                  6

# %%
# Consulta: Número de personajes en toda la obra de Shakespeare.
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN COUNT(DISTINCT character) AS TotalCharacters 
    ORDER BY TotalCharacters DESC
""").to_table()
# Out:
#  TotalCharacters
# -----------------
#              331

# %%
# Consulta: Lista de las escenas en las que está dividida cada obra de Shakespeare.

graph.run("""
MATCH (play:Play)-[:DIVIDED_BY]->(scene:Scene)
RETURN play.name AS Play, COLLECT(scene.number) AS Scenes
ORDER BY Play
""").to_table()
# Out:
#  Play                     | Scenes
# --------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  A Comedy of Errors       | ['SCENE I. A street before a Priory.', 'SCENE IV. A street.', 'SCENE III. A public place.', 'SCENE II. The house of ANTIPHOLUS of Ephesus.', 'SCENE I. A public place.', 'SCENE II. The same.', 'SCENE I. Before the house of ANTIPHOLUS of Ephesus.', 'SCENE II. A public place.', 'SCENE I. The house of ANTIPHOLUS of Ephesus.', 'SCENE II. The Mart.', 'SCENE I. A hall in DUKE SOLINUSS palace.']
#  A Midsummer nights dream | ['SCENE I. The same. LYSANDER, DEMETRIUS, HELENA, and HERMIA', 'SCENE I. The wood. TITANIA lying asleep.', 'SCENE II. Another part of the wood.', 'SCENE I. A wood near Athens.', 'SCENE II. Athens. QUINCES house.', 'SCENE I. Athens. The palace of THESEUS.']
#  A Winters Tale           | ['SCENE III. A chapel in PAULINAS house.', 'SCENE II. Before LEONTES palace.', 'SCENE IV. The Shepherds cottage.', 'SCENE III. A road near the Shepherds cottage.', 'SCENE II. Bohemia. The palace of POLIXENES.', 'SCENE III. Bohemia. A desert country near the sea.', 'SCENE II. A court of Justice.', 'SCENE I. A sea-port in Sicilia.', 'SCENE III. A room in LEONTES palace.', 'SCENE II. A prison.', 'SCENE I. A room in LEONTES palace.', 'SCENE II. A room of state in the same.', 'SCENE I. Antechamber in LEONTES palace.']
#  Alls well that ends well | ['SCENE II. Rousillon. Before the COUNTs palace.', 'SCENE I. Marseilles. A street.', 'SCENE V. Rousillon. The COUNTs palace.', 'SCENE IV. Florence. The Widows house.', 'SCENE III. The Florentine camp.', 'SCENE II. Florence. The Widows house.', 'SCENE I. Without the Florentine camp.', 'SCENE VII. Florence. The Widows house.', 'SCENE VI. Camp before Florence.', 'SCENE V. Florence. Without the walls. A tucket afar off.', 'SCENE IV. Rousillon. The COUNTs palace.', 'SCENE III. Florence. Before the DUKEs palace.', 'SCENE I. Florence. The DUKEs palace.', 'SCENE V. Paris. The KINGs palace.', 'SCENE IV. Paris. The KINGs palace.', 'SCENE III. Paris. The KINGs palace.', 'SCENE II. Rousillon. The COUNTs palace.', 'SCENE I. Paris. The KINGs palace.', 'SCENE III. Rousillon. The COUNTs palace.', 'SCENE II. Paris. The KINGs palace.', 'SCENE I. Rousillon. The COUNTs palace.']
#  Antony and Cleopatra     | ['SCENE XI. Alexandria. CLEOPATRAs palace.', 'SCENE II. Alexandria. A room in the monument.', 'SCENE I. Alexandria. OCTAVIUS CAESARs camp.', 'SCENE XV. The same. A monument.', 'SCENE XIV. The same. Another room.', 'SCENE XIII. Alexandria. Cleopatras palace.', 'SCENE XII. Another part of the same.', 'SCENE XI. Another part of the same.', 'SCENE X. Between the two camps.', 'SCENE IX. OCTAVIUS CAESARs camp.', 'SCENE VIII. Under the walls of Alexandria.', 'SCENE VII. Field of battle between the camps.', 'SCENE VI. Alexandria. OCTAVIUS CAESARs camp.', 'SCENE V. Alexandria. MARK ANTONYs camp.', 'SCENE IV. The same. A room in the palace.', 'SCENE III. The same. Before the palace.', 'SCENE II. Alexandria. CLEOPATRAs palace.', 'SCENE I. Before Alexandria. OCTAVIUS CAESARs camp.', 'SCENE XIII. Alexandria. CLEOPATRAs palace.', 'SCENE XII. Egypt. OCTAVIUS CAESARs camp.', 'SCENE I. Alexandria. A room in CLEOPATRAs palace.', 'SCENE II. The same. Another room.', 'SCENE III. The same. Another room.', 'SCENE IV. Rome. OCTAVIUS CAESARs house.', 'SCENE V. Alexandria. CLEOPATRAs palace.', 'SCENE I. Messina. POMPEYs house.', 'SCENE II. Rome. The house of LEPIDUS.', 'SCENE III. The same. OCTAVIUS CAESARs house.', 'SCENE IV. The same. A street.', 'SCENE VI. Near Misenum.', 'SCENE VII. On board POMPEYs galley, off Misenum.', 'SCENE I. A plain in Syria.', 'SCENE II. Rome. An ante-chamber in OCTAVIUS CAESARs house.', 'SCENE III. Alexandria. CLEOPATRAs palace.', 'SCENE IV. Athens. A room in MARK ANTONYs house.', 'SCENE V. The same. Another room.', 'SCENE VI. Rome. OCTAVIUS CAESARs house.', 'SCENE VII. Near Actium. MARK ANTONYs camp.', 'SCENE VIII. A plain near Actium.', 'SCENE IX. Another part of the plain.', 'SCENE X. Another part of the plain.']
#  As you like it           | ['SCENE I. The forest.', 'SCENE V. Another part of the forest.', 'SCENE IV. The forest.', 'SCENE III. The forest.', 'SCENE II. The forest.', 'SCENE I. A room in the palace.', 'SCENE VII. The forest.', 'SCENE VI. The forest.', 'SCENE V. The Forest.', 'SCENE IV. The Forest of Arden.', 'SCENE III. Before OLIVERS house.', 'SCENE II. A room in the palace.', 'SCENE I. The Forest of Arden.', 'SCENE III. A room in the palace.', 'SCENE II. Lawn before the Dukes palace.', 'SCENE I. Orchard of Olivers house.']
#  Coriolanus               | ['SCENE I. Rome. A street.', 'SCENE VI. Antium. A public place.', 'SCENE V. The same. A street near the gate.', 'SCENE IV. Rome. A public place.', 'SCENE III. The tent of Coriolanus.', 'SCENE II. Corioli. The Senate-house.', 'SCENE III. Rome. A room in Marcius house.', 'SCENE IV. Before Corioli.', 'SCENE V. Corioli. A street.', 'SCENE VI. Near the camp of Cominius.', 'SCENE VII. The gates of Corioli.', 'SCENE VIII. A field of battle.', 'SCENE IX. The Roman camp.', 'SCENE X. The camp of the Volsces.', 'SCENE I. Rome. A public place.', 'SCENE II. The same. The Capitol.', 'SCENE III. The same. The Forum.', 'SCENE II. A room in CORIOLANUSS house.', 'SCENE I. Rome. Before a gate of the city.', 'SCENE II. The same. A  street near the gate.', 'SCENE III. A highway between Rome and Antium.', 'SCENE IV. Antium. Before Aufidiuss house.', 'SCENE V. The same. A hall in Aufidiuss house.', 'SCENE VI. Rome. A public place.', 'SCENE VII. A camp, at a small distance from Rome.', 'SCENE II. Entrance of the Volscian camp before Rome.']
#  Cymbeline                | ['SCENE I. Britain. The garden of Cymbelines palace.', 'SCENE V. Cymbelines tent.', 'SCENE II. The same. A public place.', 'SCENE III. A room in Cymbelines palace.', 'SCENE IV. Rome. Philarios house.', 'SCENE V. Britain. A room in Cymbelines palace.', 'SCENE VI. The same. Another room in the palace.', 'SCENE I. Britain. Before Cymbelines palace.', 'SCENE II. Imogens bedchamber in Cymbelines palace:', 'SCENE V. Another room in Philarios house.', 'SCENE I. Britain. A hall in Cymbelines palace.', 'SCENE II. Another room in the palace.', 'SCENE III. Wales: a mountainous country with a cave.', 'SCENE IV. Country near Milford-Haven.', 'SCENE V. A room in Cymbelines palace.', 'SCENE VI. Wales. Before the cave of Belarius.', 'SCENE VII. Rome. A public place.', 'SCENE I. Wales: near the cave of Belarius.', 'SCENE II. Before the cave of Belarius.', 'SCENE IV. Wales: before the cave of Belarius.', 'SCENE I. Britain. The Roman camp.', 'SCENE II. Field of battle between the British and Roman camps.', 'SCENE III. Another part of the field.', 'SCENE IV. A British prison.']
#  Hamlet                   | ['SCENE I. A churchyard.', 'SCENE VII. Another room in the castle.', 'SCENE VI. Another room in the castle.', 'SCENE V. Elsinore. A room in the castle.', 'SCENE IV. A plain in Denmark.', 'SCENE III. Another room in the castle.', 'SCENE II. Another room in the castle.', 'SCENE IV. The Queens closet.', 'SCENE III. A room in the castle.', 'SCENE II. A hall in the castle.', 'SCENE I. A room in the castle.', 'SCENE II. A room in the castle.', 'SCENE I. A room in POLONIUS house.', 'SCENE V. Another part of the platform.', 'SCENE IV. The platform.', 'SCENE III. A room in Polonius house.', 'SCENE II. A room of state in the castle.', 'SCENE I. Elsinore. A platform before the castle.']
#  Henry IV                 | ['SCENE V. Another part of the field.', 'SCENE IV. Another part of the field.', 'SCENE III. Plain between the camps.', 'SCENE II. The rebel camp.', 'SCENE I. KING HENRY IVs camp near Shrewsbury.', 'SCENE IV. York. The ARCHBISHOPS palace.', 'SCENE III. The rebel camp near Shrewsbury.', 'SCENE II. A public road near Coventry.', 'SCENE I. The rebel camp near Shrewsbury.', 'SCENE II. London. The palace.', 'SCENE I. Bangor. The Archdeacons house.', 'SCENE IV. The Boars-Head Tavern, Eastcheap.', 'SCENE III. Warkworth castle', 'SCENE II. The highway, near Gadshill.', 'SCENE I. Rochester. An inn yard.', 'SCENE III. London. The palace.', 'SCENE II. London. An apartment of the Princes.', 'SCENE I. London. The palace.']
#  Henry V                  | ['SCENE II. France. A royal palace.', 'SCENE I. France. The English camp.', 'SCENE VIII. Before KING HENRYS pavilion.', 'SCENE VII. Another part of the field.', 'SCENE VI. Another part of the field.', 'SCENE V. Another part of the field.', 'SCENE IV. The field of battle.', 'SCENE III. The English camp.', 'SCENE II. The French camp.', 'SCENE I. The English camp at Agincourt.', 'SCENE VII. The French camp, near Agincourt:', 'SCENE VI. The English camp in Picardy.', 'SCENE V. The same.', 'SCENE IV. The FRENCH KINGs palace.', 'SCENE III. The same. Before the gates.', 'SCENE II. The same.', 'SCENE I. France. Before Harfleur.', 'SCENE IV. France. The KINGS palace.', 'SCENE III. London. Before a tavern.', 'SCENE II. Southampton. A council-chamber.', 'SCENE I. London. A street.', 'SCENE II. The same. The Presence chamber.', 'SCENE I. London. An ante-chamber in the KINGS palace.']
#  Henry VI Part 1          | ['SCENE I. London. The palace.', 'SCENE V. London. The palace.', 'SCENE IV. Camp of the YORK in Anjou.', 'SCENE III. Before Angiers.', 'SCENE II. France. Plains in Anjou.', 'SCENE I. Westminster Abbey.', 'SCENE II. France. Before Orleans.', 'SCENE III. London. Before the Tower.', 'SCENE IV. Orleans.', 'SCENE V. The same.', 'SCENE VI. The same.', 'SCENE I. Before Orleans.', 'SCENE II. Orleans. Within the town.', 'SCENE III. Auvergne. The COUNTESSs castle.', 'SCENE IV. London. The Temple-garden.', 'SCENE V. The Tower of London.', 'SCENE I. London. The Parliament-house.', 'SCENE II. France. Before Rouen.', 'SCENE III. The plains near Rouen.', 'SCENE IV. Paris. The palace.', 'SCENE I. Paris. A hall of state.', 'SCENE II. Before Bourdeaux.', 'SCENE III. Plains in Gascony.', 'SCENE IV. Other plains in Gascony.', 'SCENE V. The English camp near Bourdeaux.', 'SCENE VI. A field of battle.', 'SCENE VII. Another part of the field.']
#  Henry VI Part 2          | ['SCENE I. London. The palace.', 'SCENE III. Fields near St. Albans.', 'SCENE II. GLOUCESTERS house.', 'SCENE III. The palace.', 'SCENE IV. GLOUCESTERs garden.', 'SCENE I. Saint Albans.', 'SCENE II. London. YORKS garden.', 'SCENE III. A hall of justice.', 'SCENE IV. A street.', 'SCENE I. The Abbey at Bury St. Edmunds.', 'SCENE II. Bury St. Edmunds. A room of state.', 'SCENE III. A bedchamber.', 'SCENE I. The coast of Kent.', 'SCENE II. Blackheath.', 'SCENE III. Another part of Blackheath.', 'SCENE IV. London. The palace.', 'SCENE V. London. The Tower.', 'SCENE VI. London. Cannon Street.', 'SCENE VII. London. Smithfield.', 'SCENE VIII. Southwark.', 'SCENE IX. Kenilworth Castle.', 'SCENE X. Kent. IDENs garden.', 'SCENE I. Fields between Dartford and Blackheath.', 'SCENE II. Saint Albans.']
#  Henry VI Part 3          | ['SCENE VII. London. The palace.', 'SCENE IV. Plains near Tewksbury.', 'SCENE III. Another part of the field.', 'SCENE II. A field of battle near Barnet.', 'SCENE I. Coventry.', 'SCENE VIII. London. The palace.', 'SCENE VII. Before York.', 'SCENE VI. London. The Tower.', 'SCENE V. A park near Middleham Castle In Yorkshire.', 'SCENE IV. London. The palace.', 'SCENE III. Edwards camp, near Warwick.', 'SCENE II. A plain in Warwickshire.', 'SCENE I. London. The palace.', 'SCENE III. France. KING LEWIS XIs palace.', 'SCENE II. London. The palace.', 'SCENE I. A forest in the north of England.', 'SCENE VI. Another part of the field.', 'SCENE V. Another part of the field.', 'SCENE III. A field of battle between Towton and Saxton, in', 'SCENE II. Before York.', 'SCENE I. A plain near Mortimers Cross in Herefordshire.', 'SCENE IV. Another part of the field.', 'SCENE III. Field of battle betwixt Sandal Castle and Wakefield.', 'SCENE II. Sandal Castle.', 'SCENE I. London. The Parliament-house.']
#  Henry VIII               | ['SCENE V. The palace.', 'SCENE IV. The palace yard.', 'SCENE III. The Council-Chamber.', 'SCENE II. Before the council-chamber. Pursuivants, Pages,  and c.', 'SCENE I. London. A gallery in the palace.', 'SCENE II. Kimbolton.', 'SCENE I. A street in Westminster.', 'SCENE II. Ante-chamber to KING HENRY VIIIs apartment.', 'SCENE I. London. QUEEN KATHARINEs apartments.', 'SCENE IV. A hall in Black-Friars.', 'SCENE III. An ante-chamber of the QUEENS apartments.', 'SCENE II. An ante-chamber in the palace.', 'SCENE I. Westminster. A street.', 'SCENE IV. A Hall in York Place.', 'SCENE III. An ante-chamber in the palace.', 'SCENE II. The same. The council-chamber.', 'SCENE I. London. An ante-chamber in the palace.']
#  Julius Caesar            | ['SCENE V. Another part of the field.', 'SCENE IV. Another part of the field.', 'SCENE III. Another part of the field.', 'SCENE II. The same. The field of battle.', 'SCENE I. The plains of Philippi.', 'SCENE III. Brutuss tent.', 'SCENE II. Camp near Sardis. Before BRUTUSs tent.', 'SCENE I. A house in Rome.', 'SCENE III. A street.', 'SCENE II. The Forum.', 'SCENE I. Rome. Before the Capitol; the Senate sitting above.', 'SCENE IV. Another part of the same street, before the house of BRUTUS.', 'SCENE III. A street near the Capitol.', 'SCENE II. CAESARs house.', 'SCENE I. Rome. BRUTUSs orchard.', 'SCENE III. The same. A street.', 'SCENE II. A public place.', 'SCENE I. Rome. A street.']
#  King John                | ['SCENE VII. The orchard in Swinstead Abbey.', 'SCENE VI. An open place in the neighbourhood of Swinstead Abbey.', 'SCENE V. The French camp.', 'SCENE IV. Another part of the field.', 'SCENE III. The field of battle.', 'SCENE II. LEWISs camp at St. Edmundsbury.', 'SCENE III. Before the castle.', 'SCENE II. KING JOHNS palace.', 'SCENE I. A room in a castle.', 'SCENE IV. The same. KING PHILIPS tent.', 'SCENE III. The same.', 'SCENE II. The same. Plains near Angiers.', 'SCENE I. The French Kings pavilion.', 'SCENE I. France. Before Angiers.', 'SCENE I. KING JOHNS palace.']
#  King Lear                | ['SCENE III. The British camp near Dover.', 'SCENE II. A field between the two camps.', 'SCENE I. The British camp, near Dover.', 'SCENE VII. A tent in the French camp. LEAR on a bed asleep,', 'SCENE VI. Fields near Dover.', 'SCENE IV. The same. A tent.', 'SCENE III. The French camp near Dover.', 'SCENE II. Before ALBANYs palace.', 'SCENE I. The heath.', 'SCENE VII. Gloucesters castle.', 'SCENE VI. A chamber in a farmhouse adjoining the castle.', 'SCENE V. Gloucesters castle.', 'SCENE IV. The heath. Before a hovel.', 'SCENE III. Gloucesters castle.', 'SCENE II. Another part of the heath. Storm still.', 'SCENE I. A heath.', 'SCENE IV. Before GLOUCESTERs castle. KENT in the stocks.', 'SCENE III. A wood.', 'SCENE II. Before Gloucesters castle.', 'SCENE I. GLOUCESTERs castle.', 'SCENE V. Court before the same.', 'SCENE IV. A hall in the same.', 'SCENE III. The Duke of Albanys palace.', 'SCENE II. The Earl of Gloucesters castle.', 'SCENE I. King Lears palace.']
#  Loves Labours Lost       | ['SCENE III. The same.', 'SCENE I. The same.', 'SCENE II. The same.', 'SCENE I. The king of Navarres park.']
#  Measure for measure      | ['SCENE I. The city gate.', 'SCENE VI. Street near the city gate.', 'SCENE V. Fields without the town.', 'SCENE III. Another room in the same.', 'SCENE II. A room in the prison.', 'SCENE I. The moated grange at ST. LUKEs.', 'SCENE II. The street before the prison.', 'SCENE I. A room in the prison.', 'SCENE IV. A room in ANGELOs house.', 'SCENE III. A room in a prison.', 'SCENE II. Another room in the same.', 'SCENE I. A hall In ANGELOs house.', 'SCENE IV. A nunnery.', 'SCENE III. A monastery.', 'SCENE II. A Street.', 'SCENE I. An apartment in the DUKES palace.']
#  Merchant of Venice       | ['SCENE I. Belmont. Avenue to PORTIAS house.', 'SCENE II. The same. A street.', 'SCENE I. Venice. A court of justice.', 'SCENE V. The same. A garden.', 'SCENE IV. Belmont. A room in PORTIAS house.', 'SCENE III. Venice. A street.', 'SCENE II. Belmont. A room in PORTIAS house.', 'SCENE IX. Belmont. A room in PORTIAS house.', 'SCENE VIII. Venice. A street.', 'SCENE VII. Belmont. A room in PORTIAS house.', 'SCENE VI. The same.', 'SCENE V. The same. Before SHYLOCKS house.', 'SCENE IV. The same. A street.', 'SCENE III. The same. A room in SHYLOCKS house.', 'SCENE II. Venice. A street.', 'SCENE I. Belmont. A room in PORTIAS house.', 'SCENE III. Venice. A public place.', 'SCENE II: Belmont. A room in PORTIAS house.', 'SCENE I. Venice. A street.']
#  Merry Wives of Windsor   | ['SCENE V. Another part of the Park.', 'SCENE IV. Windsor Park.', 'SCENE III. A street leading to the Park.', 'SCENE II. Windsor Park.', 'SCENE I. A room in the Garter Inn.', 'SCENE VI. Another room in the Garter Inn.', 'SCENE IV. A room in FORDS house.', 'SCENE II. A room in FORDS house.', 'SCENE I. A street.', 'SCENE V. A room in the Garter Inn.', 'SCENE IV. A room in PAGES house.', 'SCENE III. A room in FORDS house.', 'SCENE II. A street.', 'SCENE I. A field near Frogmore.', 'SCENE III. A field near Windsor.', 'SCENE II. A room in the Garter Inn.', 'SCENE I. Before PAGES house.', 'SCENE IV. A room in DOCTOR CAIUS house.', 'SCENE III. A room in the Garter Inn.', 'SCENE II. The same.', 'SCENE I. Windsor. Before PAGEs house.']
#  Much Ado about nothing   | ['SCENE IV. A room in LEONATOS house.', 'SCENE III. A church.', 'SCENE II. LEONATOS garden.', 'SCENE II. A prison.', 'SCENE I. A church.', 'SCENE V. Another room in LEONATOS house.', 'SCENE IV. HEROs apartment.', 'SCENE III. A street.', 'SCENE II. A room in LEONATOS house', 'SCENE I. LEONATOS garden.', 'SCENE III. LEONATOS orchard.', 'SCENE II. The same.', 'SCENE I. A hall in LEONATOS house.', 'SCENE III. The same.', 'SCENE II. A room in LEONATOs house.', 'SCENE I. Before LEONATOS house.']
#  Othello                  | ['SCENE II. A bedchamber in the castle: DESDEMONA in bed asleep;', 'SCENE I. Cyprus. A street.', 'SCENE III. Another room In the castle.', 'SCENE I. Cyprus. Before the castle.', 'SCENE IV. Before the castle.', 'SCENE III. The garden of the castle.', 'SCENE II. A room in the castle.', 'SCENE I. Before the castle.', 'SCENE III. A hall in the castle.', 'SCENE II. A street.', 'SCENE I. A Sea-port in Cyprus. An open place near the quay.', 'SCENE III. A council-chamber.', 'SCENE II. Another street.', 'SCENE I. Venice. A street.']
# ...
#  Romeo and Juliet         | ['SCENE III. A churchyard; in it a tomb belonging to the Capulets.', 'SCENE II. Friar Laurences cell.', 'SCENE I. Mantua. A street.', 'SCENE V. Juliets chamber.', 'SCENE IV. Hall in Capulets house.', 'SCENE III. Juliets chamber.', 'SCENE II. Hall in Capulets house.', 'SCENE I. Friar Laurences cell.', 'SCENE IV. A room in Capulets house.', 'SCENE I. A public place.', 'SCENE VI. Friar Laurences cell.', 'SCENE V. Capulets orchard.', 'SCENE III. Friar Laurences cell.', 'SCENE II. Capulets orchard.', 'SCENE I. A lane by the wall of Capulets orchard.', 'SCENE V. A hall in Capulets house.', 'SCENE IV. A street.', 'SCENE III. A room in Capulets house.', 'SCENE II. A street.', 'SCENE I. Verona. A public place.']
#  Taming of the Shrew      | ['SCENE II. Padua. LUCENTIOS house.', 'SCENE I. Padua. Before LUCENTIOS house.', 'SCENE V. A public road.', 'SCENE IV. Padua. Before BAPTISTAS house.', 'SCENE III. A room in PETRUCHIOS house.', 'SCENE I. PETRUCHIOS country house.', 'SCENE II. Padua. Before BAPTISTAS house.', 'SCENE I. Padua. BAPTISTAS house.', 'SCENE I. Padua. A room in BAPTISTAS house.', 'SCENE II. Padua. Before HORTENSIOS house.', 'SCENE I. Padua. A public place.', 'SCENE II. A bedchamber in the Lords house.', 'SCENE I. Before an alehouse on a heath.']
#  The Tempest              | ['SCENE I. Before PROSPEROS cell.', 'SCENE III. Another part of the island.', 'SCENE I. Before PROSPEROS Cell.', 'SCENE II. Another part of the island.', 'SCENE I. Another part of the island.', 'SCENE II. The island. Before PROSPEROS cell.', 'SCENE I. On a ship at sea: a tempestuous noise']
#  Timon of Athens          | ['SCENE IV. Before the walls of Athens.', 'SCENE III. The woods. Timons cave, and a rude tomb seen.', 'SCENE II. Before the walls of Athens.', 'SCENE I. The woods. Before Timons cave.', 'SCENE III. Woods and cave, near the seashore.', 'SCENE II. Athens. A room in Timons house.', 'SCENE I. Without the walls of Athens.', 'SCENE VI. The same. A banqueting-room in Timons house.', 'SCENE V. The same. The senate-house. The Senate sitting.', 'SCENE IV. The same. A hall in Timons house.', 'SCENE III. A room in Sempronius house.', 'SCENE II. A public place.', 'SCENE I. A room in Lucullus house.', 'SCENE II. The same. A hall in Timons house.', 'SCENE I. A Senators house.', 'SCENE II. A banqueting-room in Timons house.', 'SCENE I. Athens. A hall in Timons house.']
#  Titus Andronicus         | ['SCENE III. Court of TITUSs house. A banquet set out.', 'SCENE II. Rome. Before TITUSs house.', 'SCENE I. Plains near Rome.', 'SCENE IV. The same. Before the palace.', 'SCENE III. The same. A public place.', 'SCENE II. The same. A room in the palace.', 'SCENE I. Rome. Tituss garden.', 'SCENE II. A room in Tituss house. A banquet set out.', 'SCENE I. Rome. A street.', 'SCENE IV. Another part of the forest.', 'SCENE III. A lonely part of the forest.', 'SCENE II. A forest near Rome. Horns and cry of hounds heard.', 'SCENE I. Rome. Before the Palace.', 'SCENE I. Rome. Before the Capitol.']
#  Troilus and Cressida     | ['SCENE IX. Another part of the plains.', 'SCENE X. Another part of the plains.', 'SCENE I. Troy. Before Priams palace.', 'SCENE II. The Same. A street.', 'SCENE III. The Grecian camp. Before Agamemnons tent.', 'SCENE I. A part of the Grecian camp.', 'SCENE II. Troy. A room in Priams palace.', 'SCENE III. The Grecian camp. Before Achilles tent.', 'SCENE I. Troy. Priams palace.', 'SCENE II. The same. Pandarus orchard.', 'SCENE I. Troy. A street.', 'SCENE II. The same. Court of Pandarus house.', 'SCENE III. The same. Street before Pandarus house.', 'SCENE IV. The same. Pandarus house.', 'SCENE V. The Grecian camp. Lists set out.', 'SCENE I. The Grecian camp. Before Achilles tent.', 'SCENE II. The same. Before Calchas tent.', 'SCENE III. Troy. Before Priams palace.', 'SCENE IV. Plains between Troy and the Grecian camp.', 'SCENE V. Another part of the plains.', 'SCENE VI. Another part of the plains.', 'SCENE VII. Another part of the plains.', 'SCENE VIII. Another part of the plains.']
#  Twelfth Night            | ['SCENE III. OLIVIAs garden.', 'SCENE I. Before OLIVIAs house.', 'SCENE IV. OLIVIAs garden.', 'SCENE III. A street.', 'SCENE II. OLIVIAs house.', 'SCENE I. OLIVIAs garden.', 'SCENE V. OLIVIAs garden.', 'SCENE III. OLIVIAs house.', 'SCENE II. A street.', 'SCENE I. The sea-coast.', 'SCENE V. OLIVIAS house.', 'SCENE IV. DUKE ORSINOs palace.', 'SCENE III. OLIVIAS house.', 'SCENE II. The sea-coast.', 'SCENE I. DUKE ORSINOs palace.']
#  Two Gentlemen of Verona  | ['SCENE IV. Another part of the forest.', 'SCENE III. The frontiers of Mantua. The forest.', 'SCENE I. Milan. An abbey.', 'SCENE IV. The same.', 'SCENE III. The same.', 'SCENE II. Milan. Outside the DUKEs palace, under SILVIAs chamber.', 'SCENE I. The frontiers of Mantua. A forest.', 'SCENE II. The same. The DUKEs palace.', 'SCENE VII. Verona. JULIAS house.', 'SCENE VI. The same. The DUKES palace.', 'SCENE V. The same. A street.', 'SCENE IV. Milan. The DUKEs palace.', 'SCENE III. The same. A street.', 'SCENE II. Verona. JULIAS house.', 'SCENE I. Milan. The DUKEs palace.', 'SCENE III. The same. ANTONIOs house.', 'SCENE II. The same. Garden of JULIAs house.', 'SCENE I. Verona. An open place.']
#  macbeth                  | ['SCENE I. A desert place.', 'SCENE VIII. Another part of the field.', 'SCENE VII. Another part of the field.', 'SCENE VI. Dunsinane. Before the castle.', 'SCENE V. Dunsinane. Within the castle.', 'SCENE IV. Country near Birnam wood.', 'SCENE III. Dunsinane. A room in the castle.', 'SCENE II. A camp near Forres.', 'SCENE III. A heath near Forres.', 'SCENE IV. Forres. The palace.', 'SCENE V. Inverness. Macbeths castle.', 'SCENE VI. Before Macbeths castle.', 'SCENE VII. Macbeths castle.', 'SCENE I. Court of Macbeths castle.', 'SCENE II. The same.', 'SCENE III. The same.', 'SCENE IV. Outside Macbeths castle.', 'SCENE I. Forres. The palace.', 'SCENE II. The palace.', 'SCENE III. A park near the palace.', 'SCENE IV. The same. Hall in the palace.', 'SCENE V. A Heath.', 'SCENE VI. Forres. The palace.', 'SCENE I. A cavern. In the middle, a boiling cauldron.', 'SCENE II. Fife. Macduffs castle.', 'SCENE III. England. Before the Kings palace.', 'SCENE I. Dunsinane. Ante-room in the castle.', 'SCENE II. The country near Dunsinane.']
