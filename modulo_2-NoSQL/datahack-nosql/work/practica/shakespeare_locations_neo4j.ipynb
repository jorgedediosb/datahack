# %% [markdown]
# # PRÁCTICA NOSQL (NEO4J) - SHAKESPEARE

# %% [markdown]
# ## Dataset elegido:
#
# ### Obras completas de Wiliam Sakespeare
#
# Este dataset contiene los diálogos de todas la obras de Wiliam Sakespeare. Cada línea representa una fráse de un diálogo expresada por algún personaje de la obra.
#
# Enlace de descarga: https://github.com/rafaelgarrote/datahack-nosql/raw/nosql-especial/workespecial/practica/data/shakespeare.json
#
# Formato: json
#
# Cada diálogo contiene los siguientes campos:
#
# * **line_id**: Identificador único de la línea de diálogo. Tipo entero.
# * **play_name**: Nombre de la obra.
# * **speach_number**: Número del diálogo.
# * **line_number**: Número de línea del diálogo en la obra.
# * **speaker**: Personaje que dice el texto.
# * **text_entry**: Texto dicho por el personaje en el diálogo.
#
# Este dataset tiene el siguiente formato:
#
# `
# {
#     "type": "String", --> (act, scene or line)
#     "line_id": INT,
#     "play_name": "String",
#     "speech_number": INT,
#     "line_number": "String",
#     "speaker": "String",
#     "text_entry": "String"
# }
# `
#
# Ejemplo:
#
# `
# {
#     "type":"act",
#     "line_id":110469,
#     "play_name":"A Winters Tale",
#     "speech_number":163,
#     "line_number":"4.4.674",
#     "speaker":"CAMILLO",
#     "text_entry":"Do all lie there: it shall be so my care"
# }
#
# {
#   "type": "scene", --> Cuando es una  escena, se especifica un lugar.
#   "line_id": 2,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "SCENE I. London. The palace." --> Lugar donde se representa la escena
# }
# `

# %% [markdown]
# ### Caso de uso: EMPRESA DE VISITAS TEATRALIZADAS
#
# Una empresa afincada en Londres quiere hacer visitas teatralizadas por la ciudad basadas en la obra de Shakespeare.
#
# Para poder hacer el plan de trabajo de cada representación necesitan saber:
#
# 1. Obras de Shakespeare ambientadas en Londres y sus localizaciones.
# 2. Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare.
# 3. De las obras en Londres, saber las escenas de cada obra.
# 4. De las obras en Londres, saber los personajes que aparecen en cada obra.
# 5. Cuantas veces aparece un personaje en un ambiente y en qué ambiente.
#
# Nota:
# * Localización: Lugar donde se representa una secuencia.
# * Ambiente: Espacio dentro de una localización (cuando se especifica).
#
# A parte de estas consultas, facilito otras más genéricas que me han resultado interesantes.

# %% [markdown]
# ### Elección Neo4j
#
# He elegido Neo4j en vez de mongodb por:
#
# * Modelo de Datos Gráfico:
# Neo4j está basado en un modelo de datos gráfico, por lo que es muy sencillo para representar y consultar relaciones complejas entre entidades. Al necesitar bastantes relaciones y conexiones entre datos, consideré que ofrecería un rendimiento más eficiente a mongo para las consultas necesarias.
#
# * Consultas de Relaciones:
# Neo4j proporciona el lenguaje Cypher que facilita la expresión y ejecución de consultas que involucran relaciones entre nodos de forma más sencilla que mongo. Es muy intuitivo de usar no sólo por el Cypher sino también por el apartado visual que ofrece el 'Browser', mostrando los nodos y sus relaciones graficamente.
#
# SOBRE MONGO:
#
# Las pruebas que he realizado para consultas que implican recopilación de "texto completo", por ejemplo, "Mostrar el texto completo de una secuencia concreta de una obra concreta" Neo4j no ofrecía un rendimiento ópticmo. Las consultas y creación de nodos era MUY larga. Para este tipo de consultas he probado mongodb y funciona MUCHO mejor que Neo4j ofreciendo un rendimiento muchísimo mejor.
#
# * Adjunto también el Notebook con las pruebas en mongo.

# %% [markdown]
# El diagrama del modelo de datos (extraído del Browser) es:
#
# <img src="images/shakespeare_schema.jpg" alt="shakespeare" style="width: 800px; PADDING-LEFT: 5px"/>

# %% [markdown]
# #### Conclusiones:
# * ¿Qué te parece la base de datos seleccionada como data store?
#
# Neo4j me ha gustado especialmente porque la considero más creativa e intuitiva. Permite un modelado visualmente muy atractivo y sencillo en el uso de nodos y sus relaciones para (casi) todo tipo de  consultas.
#
# Como he comprobado en las pruebas realizadas previamente, mongo supera a meo4j en las consultas que requieren recopilación de información de multitud de nodos. En el caso del dataset de Shakespeare, para la recolilación de textos completos de las obras, mongo funciona mucho mejor que neo4j.
#
# También me encantan las herramientas que ofrece Neo4j para la visualización y creación de proyectos. A parte del Browser, he 'trasteado' con sus otras herramientas (data importer, arrows, Aura/Workspace y Bloom) y me han parecido muy intuitivas, sencillas de usar y visualmente muy atractivas.
# * ¿Qué te ha parecido el ejercicio?
#
# Muy interesante al poder elegir entre distintos datasets en el que cada uno ofrece posibilidades muy distintas. Poder elegir el dataset que más te motive creo que es esencial para disfrutar haciendo el ejercicio. Yo lo he disfrutado mucho.
# * ¿Qué has aprendido?
#
# No sólo a manejar mongodb y sobretodo Neo4j sino a entender la importancia de estudiar el dataset y el caso de uso concreto antes de 'lanzarte' a modelar y hacer consultas sin un objetivo concreto.
# * ¿Qué has hechado de menos?
#
# En la práctica nada. Tal vez algún otro dataset para trastear o tener más opciones. En clase, ver en casos de uso reales de cada una de las bases de datos más importantes que hemos visto para entender mejor cuando elegir una u otra y qué se puede hacer con ellas.
# * ¿Cómo mejorarías la prática?
#
# Creo que hay personas que les cuesta encontrar un caso de uso, se necesita algo de creatividad que no tenemos porque tenerla, bien por falta de tiempo bien  por ner una  persona más 'técnica'. Sería útil poner varios casos de uso genéricos para aquellas personas que lo puedan necesitar.

# %% [markdown]
# ## Preparación del entorno

# %%
# Instalar librerías pprintpp y py2neo
# pprintpp -  (pretty-print) mejora la legibilidad al mostrar estructuras de datos complejas.
# py2neo - facilita la creación y ejecución de consultas en Neo4j usando Python

# !pip install pprintpp
# !pip install py2neo
# Out:
# Requirement already satisfied: pprintpp in /opt/conda/lib/python3.6/site-packages (0.4.0)
# Requirement already satisfied: py2neo in /opt/conda/lib/python3.6/site-packages (2021.2.3)
# Requirement already satisfied: pansi>=2020.7.3 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: interchange~=2021.0.4 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: monotonic in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.6)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.6/site-packages (from py2neo) (2018.8.24)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.23)
# Requirement already satisfied: six>=1.15.0 in /opt/conda/lib/python3.6/site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: pygments>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from py2neo) (2.2.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from py2neo) (18.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from interchange~=2021.0.4->py2neo) (2018.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->py2neo) (2.2.2)

# %%
# Importación de clases de py2neo:
    # Graph, para representar la conexión con la base de datos.
    # Relationship, para modelar relaciones entre nodos en la base de datos.
    # Node, para representar nodos en la base de datos.

from py2neo import Graph, Relationship, Node

graph = Graph("http://neo4j:1234@neo4j:7474/db/data")

# %%
# Resetear notebook tras ejecuciones anteriores borrando los nodos y realaciones existentes en la base de datos.

graph.run("MATCH (n) DETACH DELETE n").evaluate()

# %% [markdown]
# ## Creación de índices y constraints

# %%
# Comprobar ÍNDICES Y CONSTRAINTS creados:
graph.run("""
CALL db.indexes()
""").to_table()

# Eliminar constraint:
# graph.run("DROP CONSTRAINT const_name")
# Crear constraint:
# graph.run("""CREATE CONSTRAINT new_const_name ON (new_atrib:new_const_name) ASSERT new_atrib.new_prop IS UNIQUE""")
# Out:
#  id | name      | state  | populationPercent | uniqueness | type  | entityType | labelsOrTypes | properties | provider
# ----|-----------|--------|-------------------|------------|-------|------------|---------------|------------|------------------
#   4 | Ambience  | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Ambience']  | ['name']   | native-btree-1.0
#  16 | Character | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Character'] | ['name']   | native-btree-1.0
#   1 | Location  | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Location']  | ['name']   | native-btree-1.0
#  10 | Play      | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Play']      | ['name']   | native-btree-1.0
#   8 | Scene     | ONLINE |             100.0 | UNIQUE     | BTREE | NODE       | ['Scene']     | ['number'] | native-btree-1.0

# %%
import json
import requests
from py2neo import Graph, Node, Relationship

# URL del conjunto de datos
url = "https://raw.githubusercontent.com/rafaelgarrote/datahack-nosql/nosql-especial/workespecial/practica/data/shakespeare.json"

# Ruta del archivo local
local_file = "dataset_shakespeare.json"

# Realizar la solicitud HTTP
response = requests.get(url)

# Verificar si la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Guardar los datos en un archivo local en modo "escritura"
    with open(local_file, "w") as file:
        file.write(response.text)  
    print("Datos descargados exitosamente.")

    # Dividir cada línea del dataset y cargarlas como un objeto JSON
    data_list = [json.loads(line) for line in response.text.split('\n') if line]

    # Verificar si los índices ya existen antes de intentar crearlos
    if not graph.schema.get_indexes("Location"):
        graph.run("CREATE INDEX ON :Location(name)")

    if not graph.schema.get_indexes("Ambience"):
        graph.run("CREATE INDEX ON :Ambience(name)")

    if not graph.schema.get_indexes("Play"):
        graph.run("CREATE INDEX ON :Play(name)")
        
    if not graph.schema.get_indexes("Character"):
        graph.run("CREATE INDEX ON :Character(name)")
    
    if not graph.schema.get_indexes("Scene"):
        graph.run("CREATE INDEX ON :Scene(number)")
        
    # Agregar restricciones de unicidad si no existen (las elimina y luego las vuelve a crear)
    if not graph.schema.get_uniqueness_constraints("Location"):
        graph.run("DROP INDEX ON :Location(name)")
        graph.run("CREATE CONSTRAINT Location ON (location:Location) ASSERT location.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Ambience"):
        graph.run("DROP INDEX ON :Ambience(name)")
        graph.run("CREATE CONSTRAINT Ambience ON (ambience:Ambience) ASSERT ambience.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Play"):
        graph.run("DROP INDEX ON :Play(name)")
        graph.run("CREATE CONSTRAINT Play ON (play:Play) ASSERT play.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Character"):
        graph.run("DROP INDEX ON :Character(name)")
        graph.run("CREATE CONSTRAINT Character ON (character:Character) ASSERT character.name IS UNIQUE")
        
    if not graph.schema.get_uniqueness_constraints("Scene"):
        graph.run("DROP INDEX ON :Scene(number)")
        graph.run("CREATE CONSTRAINT Scene ON (scene:Scene) ASSERT scene.number IS UNIQUE")

    print("\nÍndices y restricciones de unicidad creados exitosamente.")
    
else:
    print(f"Error al obtener datos. Código de estado: {response.status_code}")
    
# Imprimir los primeros documentos JSON
print("\nPrimeros documentos JSON:")
for i, entry in enumerate(data_list[:3], 1):
    print(f"\nDocumento {i}:\n{json.dumps(entry, indent=2)}")
# Out:
# Datos descargados exitosamente.
#
# Índices y restricciones de unicidad creados exitosamente.
#
# Primeros documentos JSON:
#
# Documento 1:
# {
#   "type": "act",
#   "line_id": 1,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "ACT I"
# }
#
# Documento 2:
# {
#   "type": "scene",
#   "line_id": 2,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "SCENE I. London. The palace."
# }
#
# Documento 3:
# {
#   "type": "line",
#   "line_id": 3,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "Enter KING HENRY, LORD JOHN OF LANCASTER, the EARL of WESTMORELAND, SIR WALTER BLUNT, and others"
# }

# %% [markdown]
# ### MODELADO DE DATOS
#
# Tras varias pruebas en donde creaba un nodo por cada documento json y para mejorar los tiempos de carga, he importado sólo los documentos con 'type'='scene' ya  que con ellos se disponía de los datos necesarios para el caso de  uso. De esta forma se ha reducido el tiempo de carga de 30 min a 2 min.
#
# Según indica el dataset, hay secuencias de la obra que tienen una única localización: 'SCENE III. Warkworth castle' y hay otras que se especifica, dentro de esa localización, otro 'ambiente': 'SCENE IV. York. The ARCHBISHOPS palace.' (en 'York', 'The ARCHBISHOPS palace.'
#
# Por ello he creído necesario dividir en dos nodos distintos 'Location' y 'Ambience' para poder hacer las consultas más  precisas. Paro ello he tenido que importar los documentos dividiendo la frase en sus '.' para obtener cada parte y asignarla a su nodo correspondiente.
#
# Para el nodo 'Scene' he dejado el texto completo de la propiedad 'text_entry' ya que veía útil en ciertos casos que se indicase el nº de secuencia con su localización para facilitar las consultas.
#
# Para el resto de nodos se ha usado la propiedad que  indicaba el json del dataset:
# * Play --> 'play_name'
# * Character --> 'speaker'

# %%
# Crear grafo con nodos y relaciones

for entry in data_list:
    if entry["type"] == "scene":
        location_split = entry["text_entry"].split(". ", 1)
        if len(location_split) == 2:
            location_and_ambience = location_split[1].split(". ", 1)
            if len(location_and_ambience) == 2:
                location, ambience = location_and_ambience
            
            # Crear nodos con etiquetas y claves principales
            location_node = Node("Location", name=location)
            ambience_node = Node("Ambience", name=ambience)
            play_node = Node("Play", name=entry["play_name"])
            character_node = Node("Character", name=entry["speaker"])
            scene_node = Node("Scene", number=entry["text_entry"])

            graph.merge(location_node, "Location", "name")
            graph.merge(ambience_node, "Ambience", "name")
            graph.merge(play_node, "Play", "name")
            graph.merge(character_node, "Character", "name")
            graph.merge(scene_node, "Scene", "number")
            
            # Crear relaciones entre los nodos
            play_location_rel = Relationship(play_node, "REPRESENTED_IN", location_node)
            location_ambience_rel = Relationship(location_node, "HAS_A", ambience_node)
            ambience_play_rel = Relationship(ambience_node, "BELONGS_TO", play_node)
            character_play_rel = Relationship(character_node, "APPEARS_IN", play_node)
            character_ambience_rel =Relationship(character_node, "IS_IN", ambience_node)
            play_scene_rel = Relationship(play_node, "DIVIDED_BY", scene_node)
                
            graph.merge(play_location_rel)
            graph.merge(location_ambience_rel)
            graph.merge(ambience_play_rel)
            graph.merge(character_ambience_rel)
            graph.merge(character_play_rel)
            graph.merge(play_scene_rel)

print("Grafo creado exitosamente.")
# Out:
# Grafo creado exitosamente.

# %%
# Nodos y relaciones existentes
graph.run("""
MATCH (n)
RETURN DISTINCT labels(n) AS Labels, keys(n) AS Keys, n
""").to_table()
# Out:
#  Labels        | Keys       | n
# ---------------|------------|--------------------------------------------------------------------------------------------------
#  ['Location']  | ['name']   | (_2460:Location {name: 'London'})
#  ['Ambience']  | ['name']   | (_2461:Ambience {name: 'The palace.'})
#  ['Play']      | ['name']   | (_2462:Play {name: 'Henry IV'})
#  ['Character'] | ['name']   | (_2463:Character {name: ''})
#  ['Scene']     | ['number'] | (_2464:Scene {number: 'SCENE I. London. The palace.'})
#  ['Ambience']  | ['name']   | (_2465:Ambience {name: 'An apartment of the Princes.'})
#  ['Character'] | ['name']   | (_2466:Character {name: 'WESTMORELAND'})
#  ['Scene']     | ['number'] | (_2467:Scene {number: 'SCENE II. London. An apartment of the Princes.'})
#  ['Character'] | ['name']   | (_2468:Character {name: 'PRINCE HENRY'})
#  ['Scene']     | ['number'] | (_2469:Scene {number: 'SCENE III. London. The palace.'})
#  ['Location']  | ['name']   | (_2470:Location {name: 'Rochester'})
#  ['Ambience']  | ['name']   | (_2471:Ambience {name: 'An inn yard.'})
#  ['Character'] | ['name']   | (_2472:Character {name: 'HOTSPUR'})
#  ['Scene']     | ['number'] | (_2473:Scene {number: 'SCENE I. Rochester. An inn yard.'})
#  ['Character'] | ['name']   | (_2474:Character {name: 'GADSHILL'})
#  ['Scene']     | ['number'] | (_2475:Scene {number: 'SCENE II. The highway, near Gadshill.'})
#  ['Character'] | ['name']   | (_2476:Character {name: 'POINS'})
#  ['Scene']     | ['number'] | (_2477:Scene {number: 'SCENE III. Warkworth castle'})
#  ['Character'] | ['name']   | (_2478:Character {name: 'LADY PERCY'})
#  ['Scene']     | ['number'] | (_2479:Scene {number: 'SCENE IV. The Boars-Head Tavern, Eastcheap.'})
#  ['Location']  | ['name']   | (_2480:Location {name: 'Bangor'})
#  ['Ambience']  | ['name']   | (_2481:Ambience {name: 'The Archdeacons house.'})
#  ['Character'] | ['name']   | (_2482:Character {name: 'PETO'})
#  ['Scene']     | ['number'] | (_2483:Scene {number: 'SCENE I. Bangor. The Archdeacons house.'})
#  ['Character'] | ['name']   | (_2484:Character {name: 'MORTIMER'})
#  ['Scene']     | ['number'] | (_2485:Scene {number: 'SCENE II. London. The palace.'})
#  ['Character'] | ['name']   | (_2486:Character {name: 'FALSTAFF'})
#  ['Scene']     | ['number'] | (_2487:Scene {number: 'SCENE I. The rebel camp near Shrewsbury.'})
#  ['Character'] | ['name']   | (_2488:Character {name: 'EARL OF DOUGLAS'})
#  ['Scene']     | ['number'] | (_2489:Scene {number: 'SCENE II. A public road near Coventry.'})
#  ['Scene']     | ['number'] | (_2490:Scene {number: 'SCENE III. The rebel camp near Shrewsbury.'})
#  ['Location']  | ['name']   | (_2491:Location {name: 'York'})
#  ['Ambience']  | ['name']   | (_2492:Ambience {name: 'The ARCHBISHOPS palace.'})
#  ['Character'] | ['name']   | (_2493:Character {name: 'SIR WALTER BLUNT'})
#  ['Scene']     | ['number'] | (_2494:Scene {number: 'SCENE IV. York. The ARCHBISHOPS palace.'})
#  ['Character'] | ['name']   | (_2495:Character {name: 'ARCHBISHOP OF YORK'})
#  ['Scene']     | ['number'] | (_2496:Scene {number: 'SCENE I. KING HENRY IVs camp near Shrewsbury.'})
#  ['Scene']     | ['number'] | (_2497:Scene {number: 'SCENE II. The rebel camp.'})
#  ['Scene']     | ['number'] | (_2498:Scene {number: 'SCENE III. Plain between the camps.'})
#  ['Scene']     | ['number'] | (_2499:Scene {number: 'SCENE IV. Another part of the field.'})
#  ['Scene']     | ['number'] | (_2500:Scene {number: 'SCENE V. Another part of the field.'})
#  ['Play']      | ['name']   | (_2501:Play {name: 'Henry VI Part 1'})
#  ['Character'] | ['name']   | (_2502:Character {name: 'KING HENRY IV'})
#  ['Scene']     | ['number'] | (_2503:Scene {number: 'SCENE I. Westminster Abbey.'})
#  ['Location']  | ['name']   | (_2504:Location {name: 'France'})
#  ['Ambience']  | ['name']   | (_2505:Ambience {name: 'Before Orleans.'})
#  ['Character'] | ['name']   | (_2506:Character {name: 'OF WINCHESTER'})
#  ['Scene']     | ['number'] | (_2507:Scene {number: 'SCENE II. France. Before Orleans.'})
#  ['Ambience']  | ['name']   | (_2508:Ambience {name: 'Before the Tower.'})
#  ['Character'] | ['name']   | (_2509:Character {name: 'CHARLES'})
#  ['Scene']     | ['number'] | (_2510:Scene {number: 'SCENE III. London. Before the Tower.'})
#  ['Character'] | ['name']   | (_2511:Character {name: 'Mayor'})
#  ['Scene']     | ['number'] | (_2512:Scene {number: 'SCENE IV. Orleans.'})
#  ['Character'] | ['name']   | (_2513:Character {name: 'TALBOT'})
#  ['Scene']     | ['number'] | (_2514:Scene {number: 'SCENE V. The same.'})
#  ['Scene']     | ['number'] | (_2515:Scene {number: 'SCENE VI. The same.'})
#  ['Scene']     | ['number'] | (_2516:Scene {number: 'SCENE I. Before Orleans.'})
#  ['Location']  | ['name']   | (_2517:Location {name: 'Orleans'})
#  ['Ambience']  | ['name']   | (_2518:Ambience {name: 'Within the town.'})
#  ['Character'] | ['name']   | (_2519:Character {name: 'Soldier'})
#  ['Scene']     | ['number'] | (_2520:Scene {number: 'SCENE II. Orleans. Within the town.'})
#  ['Location']  | ['name']   | (_2521:Location {name: 'Auvergne'})
#  ['Ambience']  | ['name']   | (_2522:Ambience {name: 'The COUNTESSs castle.'})
#  ['Character'] | ['name']   | (_2523:Character {name: 'Captain'})
#  ['Scene']     | ['number'] | (_2524:Scene {number: 'SCENE III. Auvergne. The COUNTESSs castle.'})
#  ['Ambience']  | ['name']   | (_2525:Ambience {name: 'The Temple-garden.'})
#  ['Character'] | ['name']   | (_2526:Character {name: 'OF AUVERGNE'})
#  ['Scene']     | ['number'] | (_2527:Scene {number: 'SCENE IV. London. The Temple-garden.'})
#  ['Character'] | ['name']   | (_2528:Character {name: 'PLANTAGENET'})
#  ['Scene']     | ['number'] | (_2529:Scene {number: 'SCENE V. The Tower of London.'})
#  ['Ambience']  | ['name']   | (_2530:Ambience {name: 'The Parliament-house.'})
#  ['Scene']     | ['number'] | (_2531:Scene {number: 'SCENE I. London. The Parliament-house.'})
#  ['Ambience']  | ['name']   | (_2532:Ambience {name: 'Before Rouen.'})
#  ['Character'] | ['name']   | (_2533:Character {name: 'EXETER'})
#  ['Scene']     | ['number'] | (_2534:Scene {number: 'SCENE II. France. Before Rouen.'})
#  ['Scene']     | ['number'] | (_2535:Scene {number: 'SCENE III. The plains near Rouen.'})
#  ['Location']  | ['name']   | (_2536:Location {name: 'Paris'})
#  ['Scene']     | ['number'] | (_2537:Scene {number: 'SCENE IV. Paris. The palace.'})
#  ['Ambience']  | ['name']   | (_2538:Ambience {name: 'A hall of state.'})
#  ['Character'] | ['name']   | (_2539:Character {name: 'VERNON'})
#  ['Scene']     | ['number'] | (_2540:Scene {number: 'SCENE I. Paris. A hall of state.'})
#  ['Scene']     | ['number'] | (_2541:Scene {number: 'SCENE II. Before Bourdeaux.'})
#  ['Scene']     | ['number'] | (_2542:Scene {number: 'SCENE III. Plains in Gascony.'})
#  ['Character'] | ['name']   | (_2543:Character {name: 'LUCY'})
#  ['Scene']     | ['number'] | (_2544:Scene {number: 'SCENE IV. Other plains in Gascony.'})
#  ['Scene']     | ['number'] | (_2545:Scene {number: 'SCENE V. The English camp near Bourdeaux.'})
#  ['Scene']     | ['number'] | (_2546:Scene {number: 'SCENE VI. A field of battle.'})
#  ['Scene']     | ['number'] | (_2547:Scene {number: 'SCENE VII. Another part of the field.'})
#  ['Ambience']  | ['name']   | (_2548:Ambience {name: 'Plains in Anjou.'})
#  ['Scene']     | ['number'] | (_2549:Scene {number: 'SCENE II. France. Plains in Anjou.'})
#  ['Scene']     | ['number'] | (_2550:Scene {number: 'SCENE III. Before Angiers.'})
#  ['Character'] | ['name']   | (_2551:Character {name: 'SUFFOLK'})
#  ['Scene']     | ['number'] | (_2552:Scene {number: 'SCENE IV. Camp of the YORK in Anjou.'})
#  ['Character'] | ['name']   | (_2553:Character {name: 'YORK'})
#  ['Scene']     | ['number'] | (_2554:Scene {number: 'SCENE V. London. The palace.'})
#  ['Play']      | ['name']   | (_2555:Play {name: 'Henry VI Part 2'})
#  ['Scene']     | ['number'] | (_2556:Scene {number: 'SCENE II. GLOUCESTERS house.'})
#  ['Character'] | ['name']   | (_2557:Character {name: 'HUME'})
#  ['Scene']     | ['number'] | (_2558:Scene {number: 'SCENE III. The palace.'})
#  ['Character'] | ['name']   | (_2559:Character {name: 'KING HENRY VI'})
#  ['Scene']     | ['number'] | (_2560:Scene {number: 'SCENE IV. GLOUCESTERs garden.'})
#  ['Scene']     | ['number'] | (_2561:Scene {number: 'SCENE I. Saint Albans.'})
#  ['Ambience']  | ['name']   | (_2562:Ambience {name: 'YORKS garden.'})
#  ['Scene']     | ['number'] | (_2563:Scene {number: 'SCENE II. London. YORKS garden.'})
#  ['Scene']     | ['number'] | (_2564:Scene {number: 'SCENE III. A hall of justice.'})
#  ['Scene']     | ['number'] | (_2565:Scene {number: 'SCENE IV. A street.'})
#  ['Location']  | ['name']   | (_2566:Location {name: 'The Abbey at Bury St'})
#  ['Ambience']  | ['name']   | (_2567:Ambience {name: 'Edmunds.'})
#  ['Character'] | ['name']   | (_2568:Character {name: 'DUCHESS'})
#  ['Scene']     | ['number'] | (_2569:Scene {number: 'SCENE I. The Abbey at Bury St. Edmunds.'})
#  ['Location']  | ['name']   | (_2570:Location {name: 'Bury St'})
#  ['Ambience']  | ['name']   | (_2571:Ambience {name: 'Edmunds. A room of state.'})
#  ['Scene']     | ['number'] | (_2572:Scene {number: 'SCENE II. Bury St. Edmunds. A room of state.'})
#  ['Character'] | ['name']   | (_2573:Character {name: 'QUEEN MARGARET'})
#  ['Scene']     | ['number'] | (_2574:Scene {number: 'SCENE III. A bedchamber.'})
#  ['Scene']     | ['number'] | (_2575:Scene {number: 'SCENE I. The coast of Kent.'})
#  ['Character'] | ['name']   | (_2576:Character {name: 'First Gentleman'})
#  ['Scene']     | ['number'] | (_2577:Scene {number: 'SCENE II. Blackheath.'})
#  ['Character'] | ['name']   | (_2578:Character {name: 'CADE'})
#  ['Scene']     | ['number'] | (_2579:Scene {number: 'SCENE III. Another part of Blackheath.'})
#  ['Scene']     | ['number'] | (_2580:Scene {number: 'SCENE IV. London. The palace.'})
#  ['Ambience']  | ['name']   | (_2581:Ambience {name: 'The Tower.'})
#  ['Character'] | ['name']   | (_2582:Character {name: 'SAY'})
#  ['Scene']     | ['number'] | (_2583:Scene {number: 'SCENE V. London. The Tower.'})
#  ['Ambience']  | ['name']   | (_2584:Ambience {name: 'Cannon Street.'})
#  ['Character'] | ['name']   | (_2585:Character {name: 'SCALES'})
#  ['Scene']     | ['number'] | (_2586:Scene {number: 'SCENE VI. London. Cannon Street.'})
#  ['Ambience']  | ['name']   | (_2587:Ambience {name: 'Smithfield.'})
#  ['Scene']     | ['number'] | (_2588:Scene {number: 'SCENE VII. London. Smithfield.'})
#  ['Scene']     | ['number'] | (_2589:Scene {number: 'SCENE VIII. Southwark.'})
#  ['Character'] | ['name']   | (_2590:Character {name: 'BUCKINGHAM'})
#  ['Scene']     | ['number'] | (_2591:Scene {number: 'SCENE IX. Kenilworth Castle.'})
#  ['Location']  | ['name']   | (_2592:Location {name: 'Kent'})
#  ['Ambience']  | ['name']   | (_2593:Ambience {name: 'IDENs garden.'})
#  ['Scene']     | ['number'] | (_2594:Scene {number: 'SCENE X. Kent. IDENs garden.'})
#  ['Character'] | ['name']   | (_2595:Character {name: 'IDEN'})
#  ['Scene']     | ['number'] | (_2596:Scene {number: 'SCENE I. Fields between Dartford and Blackheath.'})
#  ['Character'] | ['name']   | (_2597:Character {name: 'RICHARD'})
#  ['Scene']     | ['number'] | (_2598:Scene {number: 'SCENE II. Saint Albans.'})
#  ['Location']  | ['name']   | (_2599:Location {name: 'Fields near St'})
#  ['Ambience']  | ['name']   | (_2600:Ambience {name: 'Albans.'})
#  ['Character'] | ['name']   | (_2601:Character {name: 'YOUNG CLIFFORD'})
#  ['Scene']     | ['number'] | (_2602:Scene {number: 'SCENE III. Fields near St. Albans.'})
#  ['Play']      | ['name']   | (_2603:Play {name: 'Henry VI Part 3'})
#  ['Character'] | ['name']   | (_2604:Character {name: 'WARWICK'})
#  ['Scene']     | ['number'] | (_2605:Scene {number: 'SCENE II. Sandal Castle.'})
#  ['Scene']     | ['number'] | (_2606:Scene {number: 'SCENE III. Field of battle betwixt Sandal Castle and Wakefield.'})
#  ['Character'] | ['name']   | (_2607:Character {name: 'CLIFFORD'})
#  ['Scene']     | ['number'] | (_2608:Scene {number: 'SCENE I. A plain near Mortimers Cross in Herefordshire.'})
#  ['Scene']     | ['number'] | (_2609:Scene {number: 'SCENE II. Before York.'})
#  ['Character'] | ['name']   | (_2610:Character {name: 'EDWARD'})
#  ['Scene']     | ['number'] | (_2611:Scene {number: 'SCENE III. A field of battle between Towton and Saxton, in'})
#  ['Character'] | ['name']   | (_2612:Character {name: 'GEORGE'})
#  ['Scene']     | ['number'] | (_2613:Scene {number: 'SCENE VI. Another part of the field.'})
#  ['Scene']     | ['number'] | (_2614:Scene {number: 'SCENE I. A forest in the north of England.'})
#  ['Ambience']  | ['name']   | (_2615:Ambience {name: 'KING LEWIS XIs palace.'})
#  ['Character'] | ['name']   | (_2616:Character {name: 'GLOUCESTER'})
#  ['Scene']     | ['number'] | (_2617:Scene {number: 'SCENE III. France. KING LEWIS XIs palace.'})
#  ['Character'] | ['name']   | (_2618:Character {name: 'KING EDWARD IV'})
#  ['Scene']     | ['number'] | (_2619:Scene {number: 'SCENE II. A plain in Warwickshire.'})
#  ['Scene']     | ['number'] | (_2620:Scene {number: 'SCENE III. Edwards camp, near Warwick.'})
#  ['Character'] | ['name']   | (_2621:Character {name: 'QUEEN ELIZABETH'})
#  ['Scene']     | ['number'] | (_2622:Scene {number: 'SCENE V. A park near Middleham Castle In Yorkshire.'})
#  ['Scene']     | ['number'] | (_2623:Scene {number: 'SCENE VI. London. The Tower.'})
#  ['Character'] | ['name']   | (_2624:Character {name: 'SOMERSET'})
#  ['Scene']     | ['number'] | (_2625:Scene {number: 'SCENE VII. Before York.'})
#  ['Scene']     | ['number'] | (_2626:Scene {number: 'SCENE VIII. London. The palace.'})
#  ['Scene']     | ['number'] | (_2627:Scene {number: 'SCENE I. Coventry.'})
#  ['Scene']     | ['number'] | (_2628:Scene {number: 'SCENE II. A field of battle near Barnet.'})
#  ['Character'] | ['name']   | (_2629:Character {name: 'OXFORD'})
#  ['Scene']     | ['number'] | (_2630:Scene {number: 'SCENE III. Another part of the field.'})
#  ['Scene']     | ['number'] | (_2631:Scene {number: 'SCENE IV. Plains near Tewksbury.'})
#  ['Scene']     | ['number'] | (_2632:Scene {number: 'SCENE VII. London. The palace.'})
#  ['Location']  | ['name']   | (_2633:Location {name: 'Rousillon'})
#  ['Ambience']  | ['name']   | (_2634:Ambience {name: 'The COUNTs palace.'})
#  ['Play']      | ['name']   | (_2635:Play {name: 'Alls well that ends well'})
#  ['Scene']     | ['number'] | (_2636:Scene {number: 'SCENE I. Rousillon. The COUNTs palace.'})
#  ['Ambience']  | ['name']   | (_2637:Ambience {name: 'The KINGs palace.'})
#  ['Character'] | ['name']   | (_2638:Character {name: 'HELENA'})
#  ['Scene']     | ['number'] | (_2639:Scene {number: 'SCENE II. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_2640:Character {name: 'BERTRAM'})
#  ['Scene']     | ['number'] | (_2641:Scene {number: 'SCENE III. Rousillon. The COUNTs palace.'})
#  ['Character'] | ['name']   | (_2642:Character {name: 'COUNTESS'})
#  ['Scene']     | ['number'] | (_2643:Scene {number: 'SCENE I. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_2644:Character {name: 'KING'})
#  ['Scene']     | ['number'] | (_2645:Scene {number: 'SCENE II. Rousillon. The COUNTs palace.'})
#  ['Scene']     | ['number'] | (_2646:Scene {number: 'SCENE III. Paris. The KINGs palace.'})
#  ['Character'] | ['name']   | (_2647:Character {name: 'PAROLLES'})
#  ['Scene']     | ['number'] | (_2648:Scene {number: 'SCENE IV. Paris. The KINGs palace.'})
#  ['Scene']     | ['number'] | (_2649:Scene {number: 'SCENE V. Paris. The KINGs palace.'})
#  ['Location']  | ['name']   | (_2650:Location {name: 'Florence'})
#  ['Ambience']  | ['name']   | (_2651:Ambience {name: 'The DUKEs palace.'})
#  ['Scene']     | ['number'] | (_2652:Scene {number: 'SCENE I. Florence. The DUKEs palace.'})
#  ['Character'] | ['name']   | (_2653:Character {name: 'DUKE'})
#  ['Ambience']  | ['name']   | (_2654:Ambience {name: 'Before the DUKEs palace.'})
#  ['Scene']     | ['number'] | (_2655:Scene {number: 'SCENE III. Florence. Before the DUKEs palace.'})
#  ['Scene']     | ['number'] | (_2656:Scene {number: 'SCENE IV. Rousillon. The COUNTs palace.'})
#  ['Ambience']  | ['name']   | (_2657:Ambience {name: 'Without the walls. A tucket afar off.'})
#  ['Scene']     | ['number'] | (_2658:Scene {number: 'SCENE V. Florence. Without the walls. A tucket afar off.'})
#  ['Character'] | ['name']   | (_2659:Character {name: 'BOTH'})
#  ['Scene']     | ['number'] | (_2660:Scene {number: 'SCENE VI. Camp before Florence.'})
#  ['Ambience']  | ['name']   | (_2661:Ambience {name: 'The Widows house.'})
#  ['Character'] | ['name']   | (_2662:Character {name: 'First Lord'})
#  ['Scene']     | ['number'] | (_2663:Scene {number: 'SCENE VII. Florence. The Widows house.'})
#  ['Scene']     | ['number'] | (_2664:Scene {number: 'SCENE I. Without the Florentine camp.'})
#  ['Character'] | ['name']   | (_2665:Character {name: 'Second Lord'})
#  ['Scene']     | ['number'] | (_2666:Scene {number: 'SCENE II. Florence. The Widows house.'})
#  ['Character'] | ['name']   | (_2667:Character {name: 'DIANA'})
#  ['Scene']     | ['number'] | (_2668:Scene {number: 'SCENE III. The Florentine camp.'})
#  ['Scene']     | ['number'] | (_2669:Scene {number: 'SCENE IV. Florence. The Widows house.'})
#  ['Scene']     | ['number'] | (_2670:Scene {number: 'SCENE V. Rousillon. The COUNTs palace.'})
#  ['Location']  | ['name']   | (_2671:Location {name: 'Marseilles'})
#  ['Ambience']  | ['name']   | (_2672:Ambience {name: 'A street.'})
#  ['Character'] | ['name']   | (_2673:Character {name: 'Clown'})
#  ['Scene']     | ['number'] | (_2674:Scene {number: 'SCENE I. Marseilles. A street.'})
#  ['Ambience']  | ['name']   | (_2675:Ambience {name: 'Before the COUNTs palace.'})
#  ['Scene']     | ['number'] | (_2676:Scene {number: 'SCENE II. Rousillon. Before the COUNTs palace.'})
#  ['Play']      | ['name']   | (_2677:Play {name: 'As you like it'})
#  ['Scene']     | ['number'] | (_2678:Scene {number: 'SCENE I. Orchard of Olivers house.'})
#  ['Character'] | ['name']   | (_2679:Character {name: 'OLIVER'})
#  ['Scene']     | ['number'] | (_2680:Scene {number: 'SCENE II. Lawn before the Dukes palace.'})
#  ['Character'] | ['name']   | (_2681:Character {name: 'ORLANDO'})
#  ['Scene']     | ['number'] | (_2682:Scene {number: 'SCENE III. A room in the palace.'})
#  ['Character'] | ['name']   | (_2683:Character {name: 'CELIA'})
#  ['Scene']     | ['number'] | (_2684:Scene {number: 'SCENE I. The Forest of Arden.'})
#  ['Scene']     | ['number'] | (_2685:Scene {number: 'SCENE II. A room in the palace.'})
#  ['Character'] | ['name']   | (_2686:Character {name: 'DUKE FREDERICK'})
#  ['Scene']     | ['number'] | (_2687:Scene {number: 'SCENE III. Before OLIVERS house.'})
#  ['Character'] | ['name']   | (_2688:Character {name: 'ADAM'})
#  ['Scene']     | ['number'] | (_2689:Scene {number: 'SCENE IV. The Forest of Arden.'})
#  ['Character'] | ['name']   | (_2690:Character {name: 'CORIN'})
#  ['Scene']     | ['number'] | (_2691:Scene {number: 'SCENE V. The Forest.'})
#  ['Character'] | ['name']   | (_2692:Character {name: 'AMIENS'})
#  ['Scene']     | ['number'] | (_2693:Scene {number: 'SCENE VI. The forest.'})
#  ['Scene']     | ['number'] | (_2694:Scene {number: 'SCENE VII. The forest.'})
#  ['Character'] | ['name']   | (_2695:Character {name: 'DUKE SENIOR'})
#  ['Scene']     | ['number'] | (_2696:Scene {number: 'SCENE I. A room in the palace.'})
#  ['Scene']     | ['number'] | (_2697:Scene {number: 'SCENE II. The forest.'})
#  ['Character'] | ['name']   | (_2698:Character {name: 'ROSALIND'})
#  ['Scene']     | ['number'] | (_2699:Scene {number: 'SCENE III. The forest.'})
#  ['Character'] | ['name']   | (_2700:Character {name: 'SIR OLIVER MARTEXT'})
#  ['Scene']     | ['number'] | (_2701:Scene {number: 'SCENE IV. The forest.'})
#  ['Scene']     | ['number'] | (_2702:Scene {number: 'SCENE V. Another part of the forest.'})
#  ['Character'] | ['name']   | (_2703:Character {name: 'PHEBE'})
#  ['Scene']     | ['number'] | (_2704:Scene {number: 'SCENE I. The forest.'})
#  ['Character'] | ['name']   | (_2705:Character {name: 'Forester'})
#  ['Character'] | ['name']   | (_2706:Character {name: 'TOUCHSTONE'})
#  ['Location']  | ['name']   | (_2707:Location {name: 'Alexandria'})
#  ['Ambience']  | ['name']   | (_2708:Ambience {name: 'A room in CLEOPATRAs palace.'})
#  ['Play']      | ['name']   | (_2709:Play {name: 'Antony and Cleopatra'})
#  ['Scene']     | ['number'] | (_2710:Scene {number: 'SCENE I. Alexandria. A room in CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_2711:Location {name: 'The same'})
#  ['Ambience']  | ['name']   | (_2712:Ambience {name: 'Another room.'})
#  ['Character'] | ['name']   | (_2713:Character {name: 'DEMETRIUS'})
#  ['Scene']     | ['number'] | (_2714:Scene {number: 'SCENE II. The same. Another room.'})
#  ['Character'] | ['name']   | (_2715:Character {name: 'DOMITIUS ENOBARBUS'})
#  ['Scene']     | ['number'] | (_2716:Scene {number: 'SCENE III. The same. Another room.'})
#  ['Location']  | ['name']   | (_2717:Location {name: 'Rome'})
#  ['Ambience']  | ['name']   | (_2718:Ambience {name: 'OCTAVIUS CAESARs house.'})
#  ['Character'] | ['name']   | (_2719:Character {name: 'MARK ANTONY'})
#  ['Scene']     | ['number'] | (_2720:Scene {number: 'SCENE IV. Rome. OCTAVIUS CAESARs house.'})
#  ['Ambience']  | ['name']   | (_2721:Ambience {name: 'CLEOPATRAs palace.'})
#  ['Character'] | ['name']   | (_2722:Character {name: 'OCTAVIUS CAESAR'})
#  ['Scene']     | ['number'] | (_2723:Scene {number: 'SCENE V. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_2724:Location {name: 'Messina'})
#  ['Ambience']  | ['name']   | (_2725:Ambience {name: 'POMPEYs house.'})
#  ['Character'] | ['name']   | (_2726:Character {name: 'CLEOPATRA'})
#  ['Scene']     | ['number'] | (_2727:Scene {number: 'SCENE I. Messina. POMPEYs house.'})
#  ['Ambience']  | ['name']   | (_2728:Ambience {name: 'The house of LEPIDUS.'})
#  ['Character'] | ['name']   | (_2729:Character {name: 'POMPEY'})
#  ['Scene']     | ['number'] | (_2730:Scene {number: 'SCENE II. Rome. The house of LEPIDUS.'})
#  ['Scene']     | ['number'] | (_2731:Scene {number: 'SCENE III. The same. OCTAVIUS CAESARs house.'})
#  ['Scene']     | ['number'] | (_2732:Scene {number: 'SCENE IV. The same. A street.'})
#  ['Character'] | ['name']   | (_2733:Character {name: 'LEPIDUS'})
#  ['Scene']     | ['number'] | (_2734:Scene {number: 'SCENE VI. Near Misenum.'})
#  ['Character'] | ['name']   | (_2735:Character {name: 'MENAS'})
#  ['Scene']     | ['number'] | (_2736:Scene {number: 'SCENE VII. On board POMPEYs galley, off Misenum.'})
#  ['Scene']     | ['number'] | (_2737:Scene {number: 'SCENE I. A plain in Syria.'})
#  ['Ambience']  | ['name']   | (_2738:Ambience {name: 'An ante-chamber in OCTAVIUS CAESARs house.'})
#  ['Character'] | ['name']   | (_2739:Character {name: 'VENTIDIUS'})
#  ['Scene']     | ['number'] | (_2740:Scene {number: 'SCENE II. Rome. An ante-chamber in OCTAVIUS CAESARs house.'})
#  ['Scene']     | ['number'] | (_2741:Scene {number: 'SCENE III. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_2742:Location {name: 'Athens'})
#  ['Ambience']  | ['name']   | (_2743:Ambience {name: 'A room in MARK ANTONYs house.'})
#  ['Character'] | ['name']   | (_2744:Character {name: 'CHARMIAN'})
#  ['Scene']     | ['number'] | (_2745:Scene {number: 'SCENE IV. Athens. A room in MARK ANTONYs house.'})
#  ['Scene']     | ['number'] | (_2746:Scene {number: 'SCENE V. The same. Another room.'})
#  ['Character'] | ['name']   | (_2747:Character {name: 'EROS'})
#  ['Scene']     | ['number'] | (_2748:Scene {number: 'SCENE VI. Rome. OCTAVIUS CAESARs house.'})
#  ['Location']  | ['name']   | (_2749:Location {name: 'Near Actium'})
#  ['Ambience']  | ['name']   | (_2750:Ambience {name: 'MARK ANTONYs camp.'})
#  ['Scene']     | ['number'] | (_2751:Scene {number: 'SCENE VII. Near Actium. MARK ANTONYs camp.'})
#  ['Character'] | ['name']   | (_2752:Character {name: 'CANIDIUS'})
#  ['Scene']     | ['number'] | (_2753:Scene {number: 'SCENE VIII. A plain near Actium.'})
#  ['Scene']     | ['number'] | (_2754:Scene {number: 'SCENE IX. Another part of the plain.'})
#  ['Scene']     | ['number'] | (_2755:Scene {number: 'SCENE X. Another part of the plain.'})
#  ['Scene']     | ['number'] | (_2756:Scene {number: 'SCENE XI. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_2757:Location {name: 'Egypt'})
#  ['Ambience']  | ['name']   | (_2758:Ambience {name: 'OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_2759:Scene {number: 'SCENE XII. Egypt. OCTAVIUS CAESARs camp.'})
#  ['Character'] | ['name']   | (_2760:Character {name: 'THYREUS'})
#  ['Scene']     | ['number'] | (_2761:Scene {number: 'SCENE XIII. Alexandria. CLEOPATRAs palace.'})
#  ['Location']  | ['name']   | (_2762:Location {name: 'Before Alexandria'})
#  ['Scene']     | ['number'] | (_2763:Scene {number: 'SCENE I. Before Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_2764:Scene {number: 'SCENE II. Alexandria. CLEOPATRAs palace.'})
#  ['Ambience']  | ['name']   | (_2765:Ambience {name: 'Before the palace.'})
#  ['Scene']     | ['number'] | (_2766:Scene {number: 'SCENE III. The same. Before the palace.'})
#  ['Ambience']  | ['name']   | (_2767:Ambience {name: 'A room in the palace.'})
#  ['Character'] | ['name']   | (_2768:Character {name: 'All'})
#  ['Scene']     | ['number'] | (_2769:Scene {number: 'SCENE IV. The same. A room in the palace.'})
#  ['Scene']     | ['number'] | (_2770:Scene {number: 'SCENE V. Alexandria. MARK ANTONYs camp.'})
#  ['Scene']     | ['number'] | (_2771:Scene {number: 'SCENE VI. Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Scene']     | ['number'] | (_2772:Scene {number: 'SCENE VII. Field of battle between the camps.'})
#  ['Character'] | ['name']   | (_2773:Character {name: 'SCARUS'})
#  ['Scene']     | ['number'] | (_2774:Scene {number: 'SCENE VIII. Under the walls of Alexandria.'})
#  ['Scene']     | ['number'] | (_2775:Scene {number: 'SCENE IX. OCTAVIUS CAESARs camp.'})
#  ['Character'] | ['name']   | (_2776:Character {name: 'Third Soldier'})
#  ['Scene']     | ['number'] | (_2777:Scene {number: 'SCENE X. Between the two camps.'})
#  ['Scene']     | ['number'] | (_2778:Scene {number: 'SCENE XI. Another part of the same.'})
#  ['Scene']     | ['number'] | (_2779:Scene {number: 'SCENE XII. Another part of the same.'})
#  ['Ambience']  | ['name']   | (_2780:Ambience {name: 'Cleopatras palace.'})
#  ['Scene']     | ['number'] | (_2781:Scene {number: 'SCENE XIII. Alexandria. Cleopatras palace.'})
#  ['Scene']     | ['number'] | (_2782:Scene {number: 'SCENE XIV. The same. Another room.'})
#  ['Ambience']  | ['name']   | (_2783:Ambience {name: 'A monument.'})
#  ['Scene']     | ['number'] | (_2784:Scene {number: 'SCENE XV. The same. A monument.'})
#  ['Scene']     | ['number'] | (_2785:Scene {number: 'SCENE I. Alexandria. OCTAVIUS CAESARs camp.'})
#  ['Ambience']  | ['name']   | (_2786:Ambience {name: 'A room in the monument.'})
#  ['Scene']     | ['number'] | (_2787:Scene {number: 'SCENE II. Alexandria. A room in the monument.'})
#  ['Play']      | ['name']   | (_2788:Play {name: 'A Comedy of Errors'})
#  ['Scene']     | ['number'] | (_2789:Scene {number: 'SCENE I. A hall in DUKE SOLINUSS palace.'})
#  ['Character'] | ['name']   | (_2790:Character {name: 'AEGEON'})
#  ['Scene']     | ['number'] | (_2791:Scene {number: 'SCENE II. The Mart.'})
#  ['Character'] | ['name']   | (_2792:Character {name: 'OF SYRACUSE'})
#  ['Scene']     | ['number'] | (_2793:Scene {number: 'SCENE I. The house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_2794:Character {name: 'LUCIANA'})
#  ['Scene']     | ['number'] | (_2795:Scene {number: 'SCENE II. A public place.'})
#  ['Scene']     | ['number'] | (_2796:Scene {number: 'SCENE I. Before the house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_2797:Character {name: 'OF EPHESUS'})
#  ['Scene']     | ['number'] | (_2798:Scene {number: 'SCENE II. The same.'})
#  ['Scene']     | ['number'] | (_2799:Scene {number: 'SCENE I. A public place.'})
#  ['Character'] | ['name']   | (_2800:Character {name: 'DROMIO OF SYRACUSE'})
#  ['Scene']     | ['number'] | (_2801:Scene {number: 'SCENE II. The house of ANTIPHOLUS of Ephesus.'})
#  ['Character'] | ['name']   | (_2802:Character {name: 'ADRIANA'})
#  ['Scene']     | ['number'] | (_2803:Scene {number: 'SCENE III. A public place.'})
#  ['Character'] | ['name']   | (_2804:Character {name: 'Courtezan'})
#  ['Scene']     | ['number'] | (_2805:Scene {number: 'SCENE I. A street before a Priory.'})
#  ['Play']      | ['name']   | (_2806:Play {name: 'Coriolanus'})
#  ['Character'] | ['name']   | (_2807:Character {name: 'DROMIO OF EPHESUS'})
#  ['Scene']     | ['number'] | (_2808:Scene {number: 'SCENE I. Rome. A street.'})
#  ['Location']  | ['name']   | (_2809:Location {name: 'Corioli'})
#  ['Ambience']  | ['name']   | (_2810:Ambience {name: 'The Senate-house.'})
#  ['Character'] | ['name']   | (_2811:Character {name: 'BRUTUS'})
#  ['Scene']     | ['number'] | (_2812:Scene {number: 'SCENE II. Corioli. The Senate-house.'})
#  ['Ambience']  | ['name']   | (_2813:Ambience {name: 'A room in Marcius house.'})
#  ['Scene']     | ['number'] | (_2814:Scene {number: 'SCENE III. Rome. A room in Marcius house.'})
#  ['Character'] | ['name']   | (_2815:Character {name: 'VALERIA'})
#  ['Scene']     | ['number'] | (_2816:Scene {number: 'SCENE IV. Before Corioli.'})
#  ['Character'] | ['name']   | (_2817:Character {name: 'LARTIUS'})
#  ['Scene']     | ['number'] | (_2818:Scene {number: 'SCENE V. Corioli. A street.'})
#  ['Scene']     | ['number'] | (_2819:Scene {number: 'SCENE VI. Near the camp of Cominius.'})
#  ['Character'] | ['name']   | (_2820:Character {name: 'COMINIUS'})
#  ['Scene']     | ['number'] | (_2821:Scene {number: 'SCENE VII. The gates of Corioli.'})
#  ['Scene']     | ['number'] | (_2822:Scene {number: 'SCENE VIII. A field of battle.'})
#  ['Character'] | ['name']   | (_2823:Character {name: 'AUFIDIUS'})
#  ['Scene']     | ['number'] | (_2824:Scene {number: 'SCENE IX. The Roman camp.'})
#  ['Scene']     | ['number'] | (_2825:Scene {number: 'SCENE X. The camp of the Volsces.'})
#  ['Ambience']  | ['name']   | (_2826:Ambience {name: 'A public place.'})
#  ['Character'] | ['name']   | (_2827:Character {name: 'First Soldier'})
#  ['Scene']     | ['number'] | (_2828:Scene {number: 'SCENE I. Rome. A public place.'})
#  ['Ambience']  | ['name']   | (_2829:Ambience {name: 'The Capitol.'})
#  ['Character'] | ['name']   | (_2830:Character {name: 'SICINIUS'})
#  ['Scene']     | ['number'] | (_2831:Scene {number: 'SCENE II. The same. The Capitol.'})
#  ['Ambience']  | ['name']   | (_2832:Ambience {name: 'The Forum.'})
# ...
#  ['Scene']     | ['number'] | (_3565:Scene {number: 'SCENE I. Troy. Before Priams palace.'})
#  ['Location']  | ['name']   | (_3566:Location {name: 'The Same'})
#  ['Character'] | ['name']   | (_3567:Character {name: 'TROILUS'})
#  ['Scene']     | ['number'] | (_3568:Scene {number: 'SCENE II. The Same. A street.'})
#  ['Location']  | ['name']   | (_3569:Location {name: 'The Grecian camp'})
#  ['Ambience']  | ['name']   | (_3570:Ambience {name: 'Before Agamemnons tent.'})
#  ['Character'] | ['name']   | (_3571:Character {name: 'CRESSIDA'})
#  ['Scene']     | ['number'] | (_3572:Scene {number: 'SCENE III. The Grecian camp. Before Agamemnons tent.'})
#  ['Character'] | ['name']   | (_3573:Character {name: 'NESTOR'})
#  ['Scene']     | ['number'] | (_3574:Scene {number: 'SCENE I. A part of the Grecian camp.'})
#  ['Ambience']  | ['name']   | (_3575:Ambience {name: 'A room in Priams palace.'})
#  ['Character'] | ['name']   | (_3576:Character {name: 'AJAX'})
#  ['Scene']     | ['number'] | (_3577:Scene {number: 'SCENE II. Troy. A room in Priams palace.'})
#  ['Ambience']  | ['name']   | (_3578:Ambience {name: 'Before Achilles tent.'})
#  ['Character'] | ['name']   | (_3579:Character {name: 'HECTOR'})
#  ['Scene']     | ['number'] | (_3580:Scene {number: 'SCENE III. The Grecian camp. Before Achilles tent.'})
#  ['Ambience']  | ['name']   | (_3581:Ambience {name: 'Priams palace.'})
#  ['Character'] | ['name']   | (_3582:Character {name: 'AGAMEMNON'})
#  ['Scene']     | ['number'] | (_3583:Scene {number: 'SCENE I. Troy. Priams palace.'})
#  ['Ambience']  | ['name']   | (_3584:Ambience {name: 'Pandarus orchard.'})
#  ['Character'] | ['name']   | (_3585:Character {name: 'PARIS'})
#  ['Scene']     | ['number'] | (_3586:Scene {number: 'SCENE II. The same. Pandarus orchard.'})
#  ['Character'] | ['name']   | (_3587:Character {name: 'PANDARUS'})
#  ['Character'] | ['name']   | (_3588:Character {name: 'THERSITES'})
#  ['Scene']     | ['number'] | (_3589:Scene {number: 'SCENE I. Troy. A street.'})
#  ['Ambience']  | ['name']   | (_3590:Ambience {name: 'Court of Pandarus house.'})
#  ['Scene']     | ['number'] | (_3591:Scene {number: 'SCENE II. The same. Court of Pandarus house.'})
#  ['Ambience']  | ['name']   | (_3592:Ambience {name: 'Street before Pandarus house.'})
#  ['Scene']     | ['number'] | (_3593:Scene {number: 'SCENE III. The same. Street before Pandarus house.'})
#  ['Ambience']  | ['name']   | (_3594:Ambience {name: 'Pandarus house.'})
#  ['Scene']     | ['number'] | (_3595:Scene {number: 'SCENE IV. The same. Pandarus house.'})
#  ['Ambience']  | ['name']   | (_3596:Ambience {name: 'Lists set out.'})
#  ['Character'] | ['name']   | (_3597:Character {name: 'AENEAS'})
#  ['Scene']     | ['number'] | (_3598:Scene {number: 'SCENE V. The Grecian camp. Lists set out.'})
#  ['Scene']     | ['number'] | (_3599:Scene {number: 'SCENE I. The Grecian camp. Before Achilles tent.'})
#  ['Ambience']  | ['name']   | (_3600:Ambience {name: 'Before Calchas tent.'})
#  ['Scene']     | ['number'] | (_3601:Scene {number: 'SCENE II. The same. Before Calchas tent.'})
#  ['Scene']     | ['number'] | (_3602:Scene {number: 'SCENE III. Troy. Before Priams palace.'})
#  ['Scene']     | ['number'] | (_3603:Scene {number: 'SCENE IV. Plains between Troy and the Grecian camp.'})
#  ['Scene']     | ['number'] | (_3604:Scene {number: 'SCENE V. Another part of the plains.'})
#  ['Character'] | ['name']   | (_3605:Character {name: 'ACHILLES'})
#  ['Scene']     | ['number'] | (_3606:Scene {number: 'SCENE VI. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_3607:Scene {number: 'SCENE VII. Another part of the plains.'})
#  ['Character'] | ['name']   | (_3608:Character {name: 'MARGARELON'})
#  ['Scene']     | ['number'] | (_3609:Scene {number: 'SCENE VIII. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_3610:Scene {number: 'SCENE IX. Another part of the plains.'})
#  ['Scene']     | ['number'] | (_3611:Scene {number: 'SCENE X. Another part of the plains.'})
#  ['Play']      | ['name']   | (_3612:Play {name: 'Twelfth Night'})
#  ['Scene']     | ['number'] | (_3613:Scene {number: 'SCENE I. DUKE ORSINOs palace.'})
#  ['Character'] | ['name']   | (_3614:Character {name: 'DUKE ORSINO'})
#  ['Scene']     | ['number'] | (_3615:Scene {number: 'SCENE II. The sea-coast.'})
#  ['Character'] | ['name']   | (_3616:Character {name: 'VIOLA'})
#  ['Scene']     | ['number'] | (_3617:Scene {number: 'SCENE III. OLIVIAS house.'})
#  ['Character'] | ['name']   | (_3618:Character {name: 'SIR TOBY BELCH'})
#  ['Scene']     | ['number'] | (_3619:Scene {number: 'SCENE IV. DUKE ORSINOs palace.'})
#  ['Scene']     | ['number'] | (_3620:Scene {number: 'SCENE V. OLIVIAS house.'})
#  ['Character'] | ['name']   | (_3621:Character {name: 'OLIVIA'})
#  ['Scene']     | ['number'] | (_3622:Scene {number: 'SCENE I. The sea-coast.'})
#  ['Scene']     | ['number'] | (_3623:Scene {number: 'SCENE III. OLIVIAs house.'})
#  ['Scene']     | ['number'] | (_3624:Scene {number: 'SCENE V. OLIVIAs garden.'})
#  ['Character'] | ['name']   | (_3625:Character {name: 'SIR ANDREW'})
#  ['Scene']     | ['number'] | (_3626:Scene {number: 'SCENE I. OLIVIAs garden.'})
#  ['Scene']     | ['number'] | (_3627:Scene {number: 'SCENE II. OLIVIAs house.'})
#  ['Character'] | ['name']   | (_3628:Character {name: 'SEBASTIAN'})
#  ['Scene']     | ['number'] | (_3629:Scene {number: 'SCENE IV. OLIVIAs garden.'})
#  ['Scene']     | ['number'] | (_3630:Scene {number: 'SCENE I. Before OLIVIAs house.'})
#  ['Scene']     | ['number'] | (_3631:Scene {number: 'SCENE III. OLIVIAs garden.'})
#  ['Play']      | ['name']   | (_3632:Play {name: 'Two Gentlemen of Verona'})
#  ['Scene']     | ['number'] | (_3633:Scene {number: 'SCENE I. Verona. An open place.'})
#  ['Ambience']  | ['name']   | (_3634:Ambience {name: 'Garden of JULIAs house.'})
#  ['Character'] | ['name']   | (_3635:Character {name: 'PROTEUS'})
#  ['Scene']     | ['number'] | (_3636:Scene {number: 'SCENE II. The same. Garden of JULIAs house.'})
#  ['Ambience']  | ['name']   | (_3637:Ambience {name: 'ANTONIOs house.'})
#  ['Character'] | ['name']   | (_3638:Character {name: 'JULIA'})
#  ['Scene']     | ['number'] | (_3639:Scene {number: 'SCENE III. The same. ANTONIOs house.'})
#  ['Location']  | ['name']   | (_3640:Location {name: 'Milan'})
#  ['Scene']     | ['number'] | (_3641:Scene {number: 'SCENE I. Milan. The DUKEs palace.'})
#  ['Ambience']  | ['name']   | (_3642:Ambience {name: 'JULIAS house.'})
#  ['Character'] | ['name']   | (_3643:Character {name: 'SPEED'})
#  ['Scene']     | ['number'] | (_3644:Scene {number: 'SCENE II. Verona. JULIAS house.'})
#  ['Character'] | ['name']   | (_3645:Character {name: 'LAUNCE'})
#  ['Scene']     | ['number'] | (_3646:Scene {number: 'SCENE IV. Milan. The DUKEs palace.'})
#  ['Scene']     | ['number'] | (_3647:Scene {number: 'SCENE V. The same. A street.'})
#  ['Ambience']  | ['name']   | (_3648:Ambience {name: 'The DUKES palace.'})
#  ['Scene']     | ['number'] | (_3649:Scene {number: 'SCENE VI. The same. The DUKES palace.'})
#  ['Scene']     | ['number'] | (_3650:Scene {number: 'SCENE VII. Verona. JULIAS house.'})
#  ['Scene']     | ['number'] | (_3651:Scene {number: 'SCENE II. The same. The DUKEs palace.'})
#  ['Location']  | ['name']   | (_3652:Location {name: 'The frontiers of Mantua'})
#  ['Ambience']  | ['name']   | (_3653:Ambience {name: 'A forest.'})
#  ['Scene']     | ['number'] | (_3654:Scene {number: 'SCENE I. The frontiers of Mantua. A forest.'})
#  ['Ambience']  | ['name']   | (_3655:Ambience {name: 'Outside the DUKEs palace, under SILVIAs chamber.'})
#  ['Character'] | ['name']   | (_3656:Character {name: 'Third Outlaw'})
#  ['Scene']     | ['number'] | (_3657:Scene {number: 'SCENE II. Milan. Outside the DUKEs palace, under SILVIAs chamber.'})
#  ['Character'] | ['name']   | (_3658:Character {name: 'SILVIA'})
#  ['Ambience']  | ['name']   | (_3659:Ambience {name: 'An abbey.'})
#  ['Scene']     | ['number'] | (_3660:Scene {number: 'SCENE I. Milan. An abbey.'})
#  ['Character'] | ['name']   | (_3661:Character {name: 'EGLAMOUR'})
#  ['Ambience']  | ['name']   | (_3662:Ambience {name: 'The forest.'})
#  ['Scene']     | ['number'] | (_3663:Scene {number: 'SCENE III. The frontiers of Mantua. The forest.'})
#  ['Play']      | ['name']   | (_3664:Play {name: 'A Winters Tale'})
#  ['Character'] | ['name']   | (_3665:Character {name: 'VALENTINE'})
#  ['Scene']     | ['number'] | (_3666:Scene {number: 'SCENE I. Antechamber in LEONTES palace.'})
#  ['Character'] | ['name']   | (_3667:Character {name: 'ARCHIDAMUS'})
#  ['Scene']     | ['number'] | (_3668:Scene {number: 'SCENE II. A room of state in the same.'})
#  ['Character'] | ['name']   | (_3669:Character {name: 'CAMILLO'})
#  ['Scene']     | ['number'] | (_3670:Scene {number: 'SCENE I. A room in LEONTES palace.'})
#  ['Character'] | ['name']   | (_3671:Character {name: 'ANTIGONUS'})
#  ['Character'] | ['name']   | (_3672:Character {name: 'PAULINA'})
#  ['Scene']     | ['number'] | (_3673:Scene {number: 'SCENE III. A room in LEONTES palace.'})
#  ['Character'] | ['name']   | (_3674:Character {name: 'LEONTES'})
#  ['Scene']     | ['number'] | (_3675:Scene {number: 'SCENE I. A sea-port in Sicilia.'})
#  ['Character'] | ['name']   | (_3676:Character {name: 'DION'})
#  ['Scene']     | ['number'] | (_3677:Scene {number: 'SCENE II. A court of Justice.'})
#  ['Location']  | ['name']   | (_3678:Location {name: 'Bohemia'})
#  ['Ambience']  | ['name']   | (_3679:Ambience {name: 'A desert country near the sea.'})
#  ['Scene']     | ['number'] | (_3680:Scene {number: 'SCENE III. Bohemia. A desert country near the sea.'})
#  ['Ambience']  | ['name']   | (_3681:Ambience {name: 'The palace of POLIXENES.'})
#  ['Character'] | ['name']   | (_3682:Character {name: 'Time'})
#  ['Scene']     | ['number'] | (_3683:Scene {number: 'SCENE II. Bohemia. The palace of POLIXENES.'})
#  ['Character'] | ['name']   | (_3684:Character {name: 'POLIXENES'})
#  ['Scene']     | ['number'] | (_3685:Scene {number: 'SCENE III. A road near the Shepherds cottage.'})
#  ['Character'] | ['name']   | (_3686:Character {name: 'AUTOLYCUS'})
#  ['Scene']     | ['number'] | (_3687:Scene {number: 'SCENE IV. The Shepherds cottage.'})
#  ['Scene']     | ['number'] | (_3688:Scene {number: 'SCENE II. Before LEONTES palace.'})
#  ['Scene']     | ['number'] | (_3689:Scene {number: 'SCENE III. A chapel in PAULINAS house.'})

# %%
# Relaciones existentes entre los nodos:

graph.run("""
    MATCH (n)-[r]-(m)
    RETURN DISTINCT TYPE(r) AS RelationshipType
""").to_table()

# Eliminar relaciones:
# graph.run(""" MATCH (:City)-[r:BELONGS_TO]->(:Play) DELETE r """)
# Out:
#  RelationshipType
# ------------------
#  REPRESENTED_IN
#  HAS_A
#  IS_IN
#  BELONGS_TO
#  DIVIDED_BY
#  APPEARS_IN

# %% [markdown]
# #### El resultado del grafo y sus nodos desde la herramienta Bloom de Neo4j se ve así:
#
# <img src="images/grafo2.png" alt="grafo1" style="width: 800px; PADDING-LEFT: 5px"/>
# <img src="images/grafo1.png" alt="grafo1" style="width: 800px; PADDING-LEFT: 5px"/>
# <img src="images/grafo3.png" alt="grafo1" style="width: 800px; PADDING-LEFT: 5px"/>
# <img src="images/grafo4.png" alt="grafo1" style="width: 800px; PADDING-LEFT: 5px"/>

# %% [markdown]
# ### CONSULTAS CASO DE USO

# %%
# Consulta 1: Obras de Shakespeare ambientadas en Londres y sus localizaciones
graph.run("""
    MATCH (ambience:Ambience)<-[:HAS_LOCATION]-(locatioin:Location {name: 'London'})<-[:REPRESENTED_IN]-(play:Play)
    RETURN play.name AS Play, COLLECT(ambience.name) AS Ambience
""").to_table()

# %%
# Consulta 2: Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare

graph.run("""
    MATCH (location:Location {name: 'London'})-[:HAS_LOCATION]->(ambience:Ambience)
    RETURN location.name AS Location, COLLECT(ambience.name) AS Ambience
    ORDER BY location.name
""").to_table()

# %%
# Consulta 3: De las obras en Londres, saber las escenas de cada obra.
graph.run("""
    MATCH (location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)-[:DIVIDED_BY]->(scene:Scene)
    RETURN play.name AS Play, COLLECT(scene.number) AS Scene
    ORDER BY Scene
""").to_table()

# %%
# Consulta 4: De las obras en Londres, saber los personajes que aparecen en cada obra.
graph.run("""
    MATCH (location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COLLECT(character.name) AS Character
""").to_table()

# %%
# Consulta 5: Cuantas veces aparece un personaje en un ambiente y en qué ambiente.

graph.run("""
    MATCH (ambience:Ambience)<-[HAS_LOCATION]-(location:Location {name:'London'})<-[:REPRESENTED_IN]-(play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN character.name AS Character, COUNT(*) AS Appearances, COLLECT(ambience.name) As Ambience
    ORDER BY Appearances DESC
""").to_table()

# %% [markdown]
# ### CONSULTAS GENÉRICAS

# %%
# Consulta: Listado con las localizaciones que aparecen en cada obra de Shakespeare

graph.run("""
    MATCH (play:Play)-[:REPRESENTED_IN]->(location:Location)
    RETURN play.name AS Play, COLLECT(location.name) AS Locations
    ORDER BY play.name
""").to_table()

# %%
# Consulta: Listado con los ambientes que tiene cada una de las localizaciones de la obra de Shakespeare

graph.run("""
    MATCH (location:Location)-[:HAS_LOCATION]->(ambience:Ambience)
    RETURN location.name AS Location, COLLECT(ambience.name) AS Ambience
    ORDER BY location.name
""").to_table()

# %%
# Consulta: Personajes que actuan en cada obra de Shakespeare
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COLLECT(character.name) AS Character
    ORDER BY play.name
""").to_table()

# %%
# Consulta: ¿Cuántos personajes hay en cada obra de Shakespeare?
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN play.name AS Play, COUNT(character) AS NumberOfCharacters
    ORDER BY NumberOfCharacters DESC
""").to_table()

# %%
# Consulta: Número de personajes en toda la obra de Shakespeare.
graph.run("""
    MATCH (play:Play)<-[:APPEARS_IN]-(character:Character)
    RETURN COUNT(DISTINCT character) AS TotalCharacters 
    ORDER BY TotalCharacters DESC
""").to_table()

# %%
# Consulta: Lista de las escenas en las que está dividida cada obra de Shakespeare.

graph.run("""
MATCH (play:Play)-[:DIVIDED_BY]->(scene:Scene)
RETURN play.name AS Play, COLLECT(scene.number) AS Scenes
ORDER BY Play
""").to_table()
