# %% [markdown]
# # PRÁCTICA NOSQL (MONGODB) - SHAKESPEARE

# %% [markdown]
# He  querido probar el dataset de Shakespeare con mongodb para testear la diferencia con Neo4j.
#
# En mis pruebas he comprobado que Mongo es mucho más eficiente que neo4j para ciertas consultas.
#
# En este Notebook he realizado consultas en Mongo para unir textos completos y ha demostrado funcionar mucho mejor que Neo4j. Con Neo4j el tiempo para estas consultas era 'desesperante' y con mongo las consultas se realizan 'instantaneamente'.
#
# La idea era probar si con Mongodb, las consultas de recopilación de texto (en cada documento json hay una línea de texto de las obras de Shakespeare) era más rápida que con Neo4j. Aunque en mi caso de uso con Neo4j no tenía planteado estos casos, pensé que en un caso real, la empresa podría solicitarlo, ¿qué haría entonces?. Tras realizar varias pruebas con Neo4j y no mostrar un rendimiento eficiente, decidí probarlo con mongodb. El resultado fue mucho mejor.
#
# Por otro lado, para las consultas planteadas en el caso de uso de Neo4j, sin recopilar los datos pensando en esas consultas, las consultas son mucho más complejas que en Neo4j. Suponngo que haciendo una recopilación de datos pensando en dichas consultas, estas serán más sencillas, pero me ha resultado que en mongodb la petición de consultas con CRUD es mucho menos intuitivo que con CYPHER.

# %% [markdown]
# ### Dataset: Obras completas de Wiliam Sakespeare
#
# Este dataset contiene los diálogos de todas la obras de Wiliam Sakespeare. Cada línea representa una fráse de un diálogo expresada por algún personaje de la obra.
#
# Enlace de descarga: https://github.com/rafaelgarrote/datahack-nosql/raw/nosql-especial/workespecial/practica/data/shakespeare.json
#
# Formato: json
#
# Cada diálogo contiene los siguientes campos:
#
# * **line_id**: Identificador único de la línea de diálogo. Tipo entero.
# * **play_name**: Nombre de la obra.
# * **speach_number**: Número del diálogo.
# * **line_number**: Número de línea del diálogo en la obra.
# * **speaker**: Personaje que dice el texto.
# * **text_entry**: Texto dicho por el personaje en el diálogo.
#
# Este dataset tiene el siguiente formato:
#
# `
# {
#     "type": "String", --> (act, scene or line)
#     "line_id": INT,
#     "play_name": "String",
#     "speech_number": INT,
#     "line_number": "String",
#     "speaker": "String",
#     "text_entry": "String"
# }
# `
#
# Ejemplo:
#
# `
# {
#     "type":"act",
#     "line_id":110469,
#     "play_name":"A Winters Tale",
#     "speech_number":163,
#     "line_number":"4.4.674",
#     "speaker":"CAMILLO",
#     "text_entry":"Do all lie there: it shall be so my care"
# }
#
# {
#   "type": "scene", --> Cuando es una  escena, se especifica un lugar.
#   "line_id": 2,
#   "play_name": "Henry IV",
#   "speech_number": "",
#   "line_number": "",
#   "speaker": "",
#   "text_entry": "SCENE I. London. The palace." --> Lugar donde se representa la escena
# }
# `

# %% [markdown]
# ## Preparación del entorno

# %%
import pymongo
import requests
from pymongo import MongoClient
from pprint import pprint
import json

# %%
# Descargar el archivo JSON desde el enlace
url = "https://raw.githubusercontent.com/rafaelgarrote/datahack-nosql/nosql-especial/workespecial/practica/data/shakespeare.json"
response = requests.get(url)
data_lines = response.text.splitlines()

# Conectar a MongoDB
client = pymongo.MongoClient("mongodb://nosql:nosql@mongo:27017/")
db = client["shakespeare"]

# Insertar los documentos en la colección
for line in data_lines:
    # Intentar cargar la línea como un objeto JSON
    try:
        data = json.loads(line)
        db.ShakespeareWorks.insert_one(data)
    except json.JSONDecodeError:
        print(f"Error al cargar la línea: {line}")

# %%
# Consultar bases de datos existentes:

# Seleccionar la base de datos admin
admin_db = client.admin

# Obtener la lista de bases de datos
database_list = admin_db.command("listDatabases")["databases"]

# Mostrar la lista de bases de datos
print("Bases de datos disponibles:")
for db in database_list:
    print(db["name"])
# Out:
# Bases de datos disponibles:
# admin
# config
# local
# shakespeare

# %%
# Consultar colecciones dentro de una base de datos concreta:

# Seleccionar la base de datos admin
db = client["shakespeare"]

# Obtener la lista de colecciones
collection_names = db.list_collection_names()

# Mostrar la lista de colecciones
print("Colecciones disponibles:")
for collection_name in collection_names:
    print(collection_name)
# Out:
# Colecciones disponibles:
# ShakespeareWorks

# %% [markdown]
# ### CONSULTAS RECOPILACIÓN DE TEXTO

# %%
# Consulta 1: Mostrar todas las obras de Shakespeare

all_plays = db.ShakespeareWorks.distinct("play_name")
print("Obras de Shakespeare:\n")
pprint(all_plays)
# Out:
# Obras de Shakespeare:
#
# ['A Comedy of Errors',
#  'A Midsummer nights dream',
#  'A Winters Tale',
#  'Alls well that ends well',
#  'Antony and Cleopatra',
#  'As you like it',
#  'Coriolanus',
#  'Cymbeline',
#  'Hamlet',
#  'Henry IV',
#  'Henry V',
#  'Henry VI Part 1',
#  'Henry VI Part 2',
#  'Henry VI Part 3',
#  'Henry VIII',
#  'Julius Caesar',
#  'King John',
#  'King Lear',
#  'Loves Labours Lost',
#  'Measure for measure',
#  'Merchant of Venice',
#  'Merry Wives of Windsor',
#  'Much Ado about nothing',
#  'Othello',
#  'Pericles',
#  'Richard II',
#  'Richard III',
#  'Romeo and Juliet',
#  'Taming of the Shrew',
#  'The Tempest',
#  'Timon of Athens',
#  'Titus Andronicus',
#  'Troilus and Cressida',
#  'Twelfth Night',
#  'Two Gentlemen of Verona',
#  'macbeth']

# %%
# Consulta 2: Mostrar los actos y secuencias de una obra concreta (por ejemplo 'Othello')

selected_play = "Othello"
projection = {"_id": 0, "line_id": 0, "line_number": 0, "play_name": 0, "speaker": 0, "speech_number": 0, "type": 0}

play_info = db.ShakespeareWorks.find(
    {"play_name": selected_play, "type": {"$in": ["act", "scene"]}},
    projection
)
print(f"Secuencias y actos de {selected_play}:\n")
for entry in play_info:
    pprint({"text_entry": entry.get("text_entry")})
# Out:
# Secuencias y actos de Othello:
#
# {'text_entry': 'ACT I'}
# {'text_entry': 'SCENE I. Venice. A street.'}
# {'text_entry': 'SCENE II. Another street.'}
# {'text_entry': 'SCENE III. A council-chamber.'}
# {'text_entry': 'ACT II'}
# {'text_entry': 'SCENE I. A Sea-port in Cyprus. An open place near the quay.'}
# {'text_entry': 'SCENE II. A street.'}
# {'text_entry': 'SCENE III. A hall in the castle.'}
# {'text_entry': 'ACT III'}
# {'text_entry': 'SCENE I. Before the castle.'}
# {'text_entry': 'SCENE II. A room in the castle.'}
# {'text_entry': 'SCENE III. The garden of the castle.'}
# {'text_entry': 'SCENE IV. Before the castle.'}
# {'text_entry': 'ACT IV'}
# {'text_entry': 'SCENE I. Cyprus. Before the castle.'}
# {'text_entry': 'SCENE II. A room in the castle.'}
# {'text_entry': 'SCENE III. Another room In the castle.'}
# {'text_entry': 'ACT V'}
# {'text_entry': 'SCENE I. Cyprus. A street.'}
# {'text_entry': 'SCENE II. A bedchamber in the castle: DESDEMONA in bed asleep;'}

# %%
# Consulta 3: Texto completo de un ACTO concreto de una obra concreta (por ejemplo 'Hamlet') y los personajes que actuan.

selected_play = "Hamlet"
selected_act = 1
projection = {"_id": 0, "line_id": 0, "line_number": 0, "play_name": 0, "speech_number": 0, "type": 0}
act_text = db.ShakespeareWorks.find(
    {"play_name": selected_play, "type": "line", "line_number": {"$regex": f"{selected_act}\..*"}},
    projection
)
print(f"Texto completo del Acto {selected_act} de {selected_play}:\n")
for line in act_text:
    pprint(line)
# Out:
# Texto completo del Acto 1 de Hamlet:
#
# {'speaker': 'BERNARDO', 'text_entry': 'Whos there?'}
# {'speaker': 'FRANCISCO',
#  'text_entry': 'Nay, answer me: stand, and unfold yourself.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Long live the king!'}
# {'speaker': 'FRANCISCO', 'text_entry': 'Bernardo?'}
# {'speaker': 'BERNARDO', 'text_entry': 'He.'}
# {'speaker': 'FRANCISCO',
#  'text_entry': 'You come most carefully upon your hour.'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Tis now struck twelve; get thee to bed, Francisco.'}
# {'speaker': 'FRANCISCO',
#  'text_entry': 'For this relief much thanks: tis bitter cold,'}
# {'speaker': 'FRANCISCO', 'text_entry': 'And I am sick at heart.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Have you had quiet guard?'}
# {'speaker': 'FRANCISCO', 'text_entry': 'Not a mouse stirring.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Well, good night.'}
# {'speaker': 'BERNARDO', 'text_entry': 'If you do meet Horatio and Marcellus,'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'The rivals of my watch, bid them make haste.'}
# {'speaker': 'FRANCISCO',
#  'text_entry': 'I think I hear them. Stand, ho! Whos there?'}
# {'speaker': 'HORATIO', 'text_entry': 'Friends to this ground.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'And liegemen to the Dane.'}
# {'speaker': 'FRANCISCO', 'text_entry': 'Give you good night.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'O, farewell, honest soldier:'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Who hath relieved you?'}
# {'speaker': 'FRANCISCO', 'text_entry': 'Bernardo has my place.'}
# {'speaker': 'FRANCISCO', 'text_entry': 'Give you good night.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Holla! Bernardo!'}
# {'speaker': 'BERNARDO', 'text_entry': 'Say,'}
# {'speaker': 'BERNARDO', 'text_entry': 'What, is Horatio there?'}
# {'speaker': 'HORATIO', 'text_entry': 'A piece of him.'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Welcome, Horatio: welcome, good Marcellus.'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'What, has this thing appeard again to-night?'}
# {'speaker': 'BERNARDO', 'text_entry': 'I have seen nothing.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Horatio says tis but our fantasy,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'And will not let belief take hold of him'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Touching this dreaded sight, twice seen of us:'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Therefore I have entreated him along'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'With us to watch the minutes of this night;'}
# {'speaker': 'MARCELLUS', 'text_entry': 'That if again this apparition come,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'He may approve our eyes and speak to it.'}
# {'speaker': 'HORATIO', 'text_entry': 'Tush, tush, twill not appear.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Sit down awhile;'}
# {'speaker': 'BERNARDO', 'text_entry': 'And let us once again assail your ears,'}
# {'speaker': 'BERNARDO', 'text_entry': 'That are so fortified against our story'}
# {'speaker': 'BERNARDO', 'text_entry': 'What we have two nights seen.'}
# {'speaker': 'HORATIO', 'text_entry': 'Well, sit we down,'}
# {'speaker': 'HORATIO', 'text_entry': 'And let us hear Bernardo speak of this.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Last night of all,'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'When yond same star thats westward from the pole'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Had made his course to illume that part of heaven'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Where now it burns, Marcellus and myself,'}
# {'speaker': 'BERNARDO', 'text_entry': 'The bell then beating one,--'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Peace, break thee off; look, where it comes again!'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'In the same figure, like the king thats dead.'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Thou art a scholar; speak to it, Horatio.'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Looks it not like the king?  mark it, Horatio.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Most like: it harrows me with fear and wonder.'}
# {'speaker': 'BERNARDO', 'text_entry': 'It would be spoke to.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Question it, Horatio.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'What art thou that usurpst this time of night,'}
# {'speaker': 'HORATIO', 'text_entry': 'Together with that fair and warlike form'}
# {'speaker': 'HORATIO', 'text_entry': 'In which the majesty of buried Denmark'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Did sometimes march? by heaven I charge thee, speak!'}
# {'speaker': 'MARCELLUS', 'text_entry': 'It is offended.'}
# {'speaker': 'BERNARDO', 'text_entry': 'See, it stalks away!'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Stay! speak, speak! I charge thee, speak!'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Tis gone, and will not answer.'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'How now, Horatio! you tremble and look pale:'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Is not this something more than fantasy?'}
# {'speaker': 'BERNARDO', 'text_entry': 'What think you ont?'}
# {'speaker': 'HORATIO', 'text_entry': 'Before my God, I might not this believe'}
# {'speaker': 'HORATIO', 'text_entry': 'Without the sensible and true avouch'}
# {'speaker': 'HORATIO', 'text_entry': 'Of mine own eyes.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Is it not like the king?'}
# {'speaker': 'HORATIO', 'text_entry': 'As thou art to thyself:'}
# {'speaker': 'HORATIO', 'text_entry': 'Such was the very armour he had on'}
# {'speaker': 'HORATIO', 'text_entry': 'When he the ambitious Norway combated;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'So frownd he once, when, in an angry parle,'}
# {'speaker': 'HORATIO', 'text_entry': 'He smote the sledded Polacks on the ice.'}
# {'speaker': 'HORATIO', 'text_entry': 'Tis strange.'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Thus twice before, and jump at this dead hour,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'With martial stalk hath he gone by our watch.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'In what particular thought to work I know not;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'But in the gross and scope of my opinion,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'This bodes some strange eruption to our state.'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Good now, sit down, and tell me, he that knows,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Why this same strict and most observant watch'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'So nightly toils the subject of the land,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'And why such daily cast of brazen cannon,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'And foreign mart for implements of war;'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Why such impress of shipwrights, whose sore task'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Does not divide the Sunday from the week;'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'What might be toward, that this sweaty haste'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Doth make the night joint-labourer with the day:'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Who ist that can inform me?'}
# {'speaker': 'HORATIO', 'text_entry': 'That can I;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'At least, the whisper goes so. Our last king,'}
# {'speaker': 'HORATIO', 'text_entry': 'Whose image even but now appeard to us,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Was, as you know, by Fortinbras of Norway,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Thereto prickd on by a most emulate pride,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Dared to the combat; in which our valiant Hamlet--'}
# {'speaker': 'HORATIO',
#  'text_entry': 'For so this side of our known world esteemd him--'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Did slay this Fortinbras; who by a seald compact,'}
# {'speaker': 'HORATIO', 'text_entry': 'Well ratified by law and heraldry,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Did forfeit, with his life, all those his lands'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Which he stood seized of, to the conqueror:'}
# {'speaker': 'HORATIO', 'text_entry': 'Against the which, a moiety competent'}
# {'speaker': 'HORATIO', 'text_entry': 'Was gaged by our king; which had returnd'}
# {'speaker': 'HORATIO', 'text_entry': 'To the inheritance of Fortinbras,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Had he been vanquisher; as, by the same covenant,'}
# {'speaker': 'HORATIO', 'text_entry': 'And carriage of the article designd,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'His fell to Hamlet. Now, sir, young Fortinbras,'}
# {'speaker': 'HORATIO', 'text_entry': 'Of unimproved mettle hot and full,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Hath in the skirts of Norway here and there'}
# {'speaker': 'HORATIO', 'text_entry': 'Sharkd up a list of lawless resolutes,'}
# {'speaker': 'HORATIO', 'text_entry': 'For food and diet, to some enterprise'}
# {'speaker': 'HORATIO',
#  'text_entry': 'That hath a stomach int; which is no other--'}
# {'speaker': 'HORATIO', 'text_entry': 'As it doth well appear unto our state--'}
# {'speaker': 'HORATIO', 'text_entry': 'But to recover of us, by strong hand'}
# {'speaker': 'HORATIO',
#  'text_entry': 'And terms compulsatory, those foresaid lands'}
# {'speaker': 'HORATIO',
#  'text_entry': 'So by his father lost: and this, I take it,'}
# {'speaker': 'HORATIO', 'text_entry': 'Is the main motive of our preparations,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'The source of this our watch and the chief head'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Of this post-haste and romage in the land.'}
# {'speaker': 'BERNARDO', 'text_entry': 'I think it be no other but een so:'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Well may it sort that this portentous figure'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'Comes armed through our watch; so like the king'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'That was and is the question of these wars.'}
# {'speaker': 'HORATIO', 'text_entry': 'A mote it is to trouble the minds eye.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'In the most high and palmy state of Rome,'}
# {'speaker': 'HORATIO', 'text_entry': 'A little ere the mightiest Julius fell,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'The graves stood tenantless and the sheeted dead'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Did squeak and gibber in the Roman streets:'}
# {'speaker': 'HORATIO',
#  'text_entry': 'As stars with trains of fire and dews of blood,'}
# {'speaker': 'HORATIO', 'text_entry': 'Disasters in the sun; and the moist star'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Upon whose influence Neptunes empire stands'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Was sick almost to doomsday with eclipse:'}
# {'speaker': 'HORATIO',
#  'text_entry': 'And even the like precurse of fierce events,'}
# {'speaker': 'HORATIO', 'text_entry': 'As harbingers preceding still the fates'}
# {'speaker': 'HORATIO', 'text_entry': 'And prologue to the omen coming on,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Have heaven and earth together demonstrated'}
# {'speaker': 'HORATIO', 'text_entry': 'Unto our climatures and countrymen.--'}
# {'speaker': 'HORATIO',
#  'text_entry': 'But soft, behold! lo, where it comes again!'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Ill cross it, though it blast me. Stay, illusion!'}
# {'speaker': 'HORATIO', 'text_entry': 'If thou hast any sound, or use of voice,'}
# {'speaker': 'HORATIO', 'text_entry': 'Speak to me:'}
# {'speaker': 'HORATIO', 'text_entry': 'If there be any good thing to be done,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'That may to thee do ease and grace to me,'}
# {'speaker': 'HORATIO', 'text_entry': 'Speak to me:'}
# {'speaker': 'HORATIO', 'text_entry': 'If thou art privy to thy countrys fate,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Which, happily, foreknowing may avoid, O, speak!'}
# {'speaker': 'HORATIO', 'text_entry': 'Or if thou hast uphoarded in thy life'}
# {'speaker': 'HORATIO', 'text_entry': 'Extorted treasure in the womb of earth,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'For which, they say, you spirits oft walk in death,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Speak of it: stay, and speak! Stop it, Marcellus.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Shall I strike at it with my partisan?'}
# {'speaker': 'HORATIO', 'text_entry': 'Do, if it will not stand.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Tis here!'}
# {'speaker': 'HORATIO', 'text_entry': 'Tis here!'}
# {'speaker': 'MARCELLUS', 'text_entry': 'Tis gone!'}
# {'speaker': 'MARCELLUS', 'text_entry': 'We do it wrong, being so majestical,'}
# {'speaker': 'MARCELLUS', 'text_entry': 'To offer it the show of violence;'}
# {'speaker': 'MARCELLUS', 'text_entry': 'For it is, as the air, invulnerable,'}
# {'speaker': 'MARCELLUS', 'text_entry': 'And our vain blows malicious mockery.'}
# {'speaker': 'BERNARDO',
#  'text_entry': 'It was about to speak, when the cock crew.'}
# {'speaker': 'HORATIO', 'text_entry': 'And then it started like a guilty thing'}
# {'speaker': 'HORATIO', 'text_entry': 'Upon a fearful summons. I have heard,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'The cock, that is the trumpet to the morn,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Doth with his lofty and shrill-sounding throat'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Awake the god of day; and, at his warning,'}
# {'speaker': 'HORATIO', 'text_entry': 'Whether in sea or fire, in earth or air,'}
# {'speaker': 'HORATIO', 'text_entry': 'The extravagant and erring spirit hies'}
# {'speaker': 'HORATIO', 'text_entry': 'To his confine: and of the truth herein'}
# {'speaker': 'HORATIO', 'text_entry': 'This present object made probation.'}
# {'speaker': 'MARCELLUS', 'text_entry': 'It faded on the crowing of the cock.'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Some say that ever gainst that season comes'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Wherein our Saviours birth is celebrated,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'The bird of dawning singeth all night long:'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'And then, they say, no spirit dares stir abroad;'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'The nights are wholesome; then no planets strike,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'No fairy takes, nor witch hath power to charm,'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'So hallowd and so gracious is the time.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'So have I heard and do in part believe it.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'But, look, the morn, in russet mantle clad,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Walks oer the dew of yon high eastward hill:'}
# {'speaker': 'HORATIO', 'text_entry': 'Break we our watch up; and by my advice,'}
# {'speaker': 'HORATIO', 'text_entry': 'Let us impart what we have seen to-night'}
# {'speaker': 'HORATIO', 'text_entry': 'Unto young Hamlet; for, upon my life,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'This spirit, dumb to us, will speak to him.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Do you consent we shall acquaint him with it,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'As needful in our loves, fitting our duty?'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Lets dot, I pray; and I this morning know'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'Where we shall find him most conveniently.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Though yet of Hamlet our dear brothers death'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'The memory be green, and that it us befitted'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To bear our hearts in grief and our whole kingdom'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To be contracted in one brow of woe,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Yet so far hath discretion fought with nature'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'That we with wisest sorrow think on him,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Together with remembrance of ourselves.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Therefore our sometime sister, now our queen,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'The imperial jointress to this warlike state,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Have we, as twere with a defeated joy,--'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'With an auspicious and a dropping eye,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'With mirth in funeral and with dirge in marriage,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'In equal scale weighing delight and dole,--'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Taken to wife: nor have we herein barrd'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Your better wisdoms, which have freely gone'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'With this affair along. For all, our thanks.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Now follows, that you know, young Fortinbras,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Holding a weak supposal of our worth,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Or thinking by our late dear brothers death'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Our state to be disjoint and out of frame,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Colleagued with the dream of his advantage,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'He hath not faild to pester us with message,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Importing the surrender of those lands'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Lost by his father, with all bonds of law,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To our most valiant brother. So much for him.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Now for ourself and for this time of meeting:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Thus much the business is: we have here writ'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To Norway, uncle of young Fortinbras,--'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Who, impotent and bed-rid, scarcely hears'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Of this his nephews purpose,--to suppress'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'His further gait herein; in that the levies,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'The lists and full proportions, are all made'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Out of his subject: and we here dispatch'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'You, good Cornelius, and you, Voltimand,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'For bearers of this greeting to old Norway;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Giving to you no further personal power'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To business with the king, more than the scope'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'Of these delated articles allow.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Farewell, and let your haste commend your duty.'}
# {'speaker': 'VOLTIMAND',
#  'text_entry': 'In that and all things will we show our duty.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'We doubt it nothing: heartily farewell.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'And now, Laertes, whats the news with you?'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'You told us of some suit; what ist, Laertes?'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'You cannot speak of reason to the Dane,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'And loose your voice: what wouldst thou beg, Laertes,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'That shall not be my offer, not thy asking?'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'The head is not more native to the heart,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'The hand more instrumental to the mouth,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Than is the throne of Denmark to thy father.'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'What wouldst thou have, Laertes?'}
# {'speaker': 'LAERTES', 'text_entry': 'My dread lord,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Your leave and favour to return to France;'}
# {'speaker': 'LAERTES',
#  'text_entry': 'From whence though willingly I came to Denmark,'}
# {'speaker': 'LAERTES', 'text_entry': 'To show my duty in your coronation,'}
# {'speaker': 'LAERTES', 'text_entry': 'Yet now, I must confess, that duty done,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'My thoughts and wishes bend again toward France'}
# {'speaker': 'LAERTES',
#  'text_entry': 'And bow them to your gracious leave and pardon.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Have you your fathers leave? What says Polonius?'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'He hath, my lord, wrung from me my slow leave'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'By laboursome petition, and at last'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Upon his will I seald my hard consent:'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'I do beseech you, give him leave to go.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Take thy fair hour, Laertes; time be thine,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'And thy best graces spend it at thy will!'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'But now, my cousin Hamlet, and my son,--'}
# {'speaker': 'HAMLET',
#  'text_entry': '[Aside]  A little more than kin, and less than kind.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'How is it that the clouds still hang on you?'}
# {'speaker': 'HAMLET', 'text_entry': 'Not so, my lord; I am too much i the sun.'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Good Hamlet, cast thy nighted colour off,'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'And let thine eye look like a friend on Denmark.'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Do not for ever with thy vailed lids'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Seek for thy noble father in the dust:'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Thou knowst tis common; all that lives must die,'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Passing through nature to eternity.'}
# {'speaker': 'HAMLET', 'text_entry': 'Ay, madam, it is common.'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'If it be,'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Why seems it so particular with thee?'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Seems, madam! nay it is; I know not seems.'}
# {'speaker': 'HAMLET', 'text_entry': 'Tis not alone my inky cloak, good mother,'}
# {'speaker': 'HAMLET', 'text_entry': 'Nor customary suits of solemn black,'}
# {'speaker': 'HAMLET', 'text_entry': 'Nor windy suspiration of forced breath,'}
# {'speaker': 'HAMLET', 'text_entry': 'No, nor the fruitful river in the eye,'}
# {'speaker': 'HAMLET', 'text_entry': 'Nor the dejected havior of the visage,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Together with all forms, moods, shapes of grief,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'That can denote me truly: these indeed seem,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'For they are actions that a man might play:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'But I have that within which passeth show;'}
# {'speaker': 'HAMLET',
#  'text_entry': 'These but the trappings and the suits of woe.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Tis sweet and commendable in your nature, Hamlet,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To give these mourning duties to your father:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'But, you must know, your father lost a father;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'That father lost, lost his, and the survivor bound'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'In filial obligation for some term'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To do obsequious sorrow: but to persever'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'In obstinate condolement is a course'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Of impious stubbornness; tis unmanly grief;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'It shows a will most incorrect to heaven,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'A heart unfortified, a mind impatient,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'An understanding simple and unschoold:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'For what we know must be and is as common'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'As any the most vulgar thing to sense,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Why should we in our peevish opposition'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Take it to heart? Fie! tis a fault to heaven,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'A fault against the dead, a fault to nature,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'To reason most absurd: whose common theme'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Is death of fathers, and who still hath cried,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'From the first corse till he that died to-day,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'This must be so. We pray you, throw to earth'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'This unprevailing woe, and think of us'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'As of a father: for let the world take note,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'You are the most immediate to our throne;'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'And with no less nobility of love'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Than that which dearest father bears his son,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Do I impart toward you. For your intent'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'In going back to school in Wittenberg,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'It is most retrograde to our desire:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'And we beseech you, bend you to remain'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Here, in the cheer and comfort of our eye,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Our chiefest courtier, cousin, and our son.'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Let not thy mother lose her prayers, Hamlet:'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'I pray thee, stay with us; go not to Wittenberg.'}
# {'speaker': 'HAMLET', 'text_entry': 'I shall in all my best obey you, madam.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Why, tis a loving and a fair reply:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Be as ourself in Denmark. Madam, come;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'This gentle and unforced accord of Hamlet'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Sits smiling to my heart: in grace whereof,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'No jocund health that Denmark drinks to-day,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'But the great cannon to the clouds shall tell,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'And the kings rouse the heavens all bruit again,'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Re-speaking earthly thunder. Come away.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'O, that this too too solid flesh would melt'}
# {'speaker': 'HAMLET', 'text_entry': 'Thaw and resolve itself into a dew!'}
# {'speaker': 'HAMLET', 'text_entry': 'Or that the Everlasting had not fixd'}
# {'speaker': 'HAMLET',
#  'text_entry': 'His canon gainst self-slaughter! O God! God!'}
# {'speaker': 'HAMLET', 'text_entry': 'How weary, stale, flat and unprofitable,'}
# {'speaker': 'HAMLET', 'text_entry': 'Seem to me all the uses of this world!'}
# {'speaker': 'HAMLET', 'text_entry': 'Fie ont! ah fie! tis an unweeded garden,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'That grows to seed; things rank and gross in nature'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Possess it merely. That it should come to this!'}
# {'speaker': 'HAMLET',
#  'text_entry': 'But two months dead: nay, not so much, not two:'}
# {'speaker': 'HAMLET', 'text_entry': 'So excellent a king; that was, to this,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Hyperion to a satyr; so loving to my mother'}
# {'speaker': 'HAMLET',
#  'text_entry': 'That he might not beteem the winds of heaven'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Visit her face too roughly. Heaven and earth!'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Must I remember? why, she would hang on him,'}
# {'speaker': 'HAMLET', 'text_entry': 'As if increase of appetite had grown'}
# {'speaker': 'HAMLET',
#  'text_entry': 'By what it fed on: and yet, within a month--'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Let me not think ont--Frailty, thy name is woman!--'}
# {'speaker': 'HAMLET',
#  'text_entry': 'A little month, or ere those shoes were old'}
# {'speaker': 'HAMLET',
#  'text_entry': 'With which she followd my poor fathers body,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Like Niobe, all tears:--why she, even she--'}
# {'speaker': 'HAMLET',
#  'text_entry': 'O, God! a beast, that wants discourse of reason,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Would have mournd longer--married with my uncle,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'My fathers brother, but no more like my father'}
# {'speaker': 'HAMLET', 'text_entry': 'Than I to Hercules: within a month:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Ere yet the salt of most unrighteous tears'}
# {'speaker': 'HAMLET', 'text_entry': 'Had left the flushing in her galled eyes,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'She married. O, most wicked speed, to post'}
# {'speaker': 'HAMLET', 'text_entry': 'With such dexterity to incestuous sheets!'}
# {'speaker': 'HAMLET', 'text_entry': 'It is not nor it cannot come to good:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'But break, my heart; for I must hold my tongue.'}
# {'speaker': 'HORATIO', 'text_entry': 'Hail to your lordship!'}
# {'speaker': 'HAMLET', 'text_entry': 'I am glad to see you well:'}
# {'speaker': 'HAMLET', 'text_entry': 'Horatio,--or I do forget myself.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'The same, my lord, and your poor servant ever.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Sir, my good friend; Ill change that name with you:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'And what make you from Wittenberg, Horatio? Marcellus?'}
# {'speaker': 'MARCELLUS', 'text_entry': 'My good lord--'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I am very glad to see you. Good even, sir.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'But what, in faith, make you from Wittenberg?'}
# {'speaker': 'HORATIO', 'text_entry': 'A truant disposition, good my lord.'}
# {'speaker': 'HAMLET', 'text_entry': 'I would not hear your enemy say so,'}
# {'speaker': 'HAMLET', 'text_entry': 'Nor shall you do mine ear that violence,'}
# {'speaker': 'HAMLET', 'text_entry': 'To make it truster of your own report'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Against yourself: I know you are no truant.'}
# {'speaker': 'HAMLET', 'text_entry': 'But what is your affair in Elsinore?'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Well teach you to drink deep ere you depart.'}
# {'speaker': 'HORATIO',
#  'text_entry': 'My lord, I came to see your fathers funeral.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I pray thee, do not mock me, fellow-student;'}
# {'speaker': 'HAMLET', 'text_entry': 'I think it was to see my mothers wedding.'}
# {'speaker': 'HORATIO', 'text_entry': 'Indeed, my lord, it followd hard upon.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Thrift, thrift, Horatio! the funeral baked meats'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Did coldly furnish forth the marriage tables.'}
# {'speaker': 'HAMLET', 'text_entry': 'Would I had met my dearest foe in heaven'}
# {'speaker': 'HAMLET', 'text_entry': 'Or ever I had seen that day, Horatio!'}
# {'speaker': 'HAMLET', 'text_entry': 'My father!--methinks I see my father.'}
# {'speaker': 'HORATIO', 'text_entry': 'Where, my lord?'}
# {'speaker': 'HAMLET', 'text_entry': 'In my minds eye, Horatio.'}
# {'speaker': 'HORATIO', 'text_entry': 'I saw him once; he was a goodly king.'}
# {'speaker': 'HAMLET', 'text_entry': 'He was a man, take him for all in all,'}
# {'speaker': 'HAMLET', 'text_entry': 'I shall not look upon his like again.'}
# {'speaker': 'HORATIO', 'text_entry': 'My lord, I think I saw him yesternight.'}
# {'speaker': 'HAMLET', 'text_entry': 'Saw? who?'}
# {'speaker': 'HORATIO', 'text_entry': 'My lord, the king your father.'}
# {'speaker': 'HAMLET', 'text_entry': 'The king my father!'}
# {'speaker': 'HORATIO', 'text_entry': 'Season your admiration for awhile'}
# {'speaker': 'HORATIO', 'text_entry': 'With an attent ear, till I may deliver,'}
# {'speaker': 'HORATIO', 'text_entry': 'Upon the witness of these gentlemen,'}
# {'speaker': 'HORATIO', 'text_entry': 'This marvel to you.'}
# {'speaker': 'HAMLET', 'text_entry': 'For Gods love, let me hear.'}
# {'speaker': 'HORATIO', 'text_entry': 'Two nights together had these gentlemen,'}
# {'speaker': 'HORATIO', 'text_entry': 'Marcellus and Bernardo, on their watch,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'In the dead vast and middle of the night,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Been thus encounterd. A figure like your father,'}
# {'speaker': 'HORATIO', 'text_entry': 'Armed at point exactly, cap-a-pe,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Appears before them, and with solemn march'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Goes slow and stately by them: thrice he walkd'}
# {'speaker': 'HORATIO',
#  'text_entry': 'By their oppressd and fear-surprised eyes,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Within his truncheons length; whilst they, distilled'}
# {'speaker': 'HORATIO', 'text_entry': 'Almost to jelly with the act of fear,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Stand dumb and speak not to him. This to me'}
# {'speaker': 'HORATIO', 'text_entry': 'In dreadful secrecy impart they did;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'And I with them the third night kept the watch;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Where, as they had deliverd, both in time,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Form of the thing, each word made true and good,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'The apparition comes: I knew your father;'}
# {'speaker': 'HORATIO', 'text_entry': 'These hands are not more like.'}
# {'speaker': 'HAMLET', 'text_entry': 'But where was this?'}
# {'speaker': 'MARCELLUS',
#  'text_entry': 'My lord, upon the platform where we watchd.'}
# {'speaker': 'HAMLET', 'text_entry': 'Did you not speak to it?'}
# {'speaker': 'HORATIO', 'text_entry': 'My lord, I did;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'But answer made it none: yet once methought'}
# {'speaker': 'HORATIO', 'text_entry': 'It lifted up its head and did address'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Itself to motion, like as it would speak;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'But even then the morning cock crew loud,'}
# {'speaker': 'HORATIO',
#  'text_entry': 'And at the sound it shrunk in haste away,'}
# {'speaker': 'HORATIO', 'text_entry': 'And vanishd from our sight.'}
# {'speaker': 'HAMLET', 'text_entry': 'Tis very strange.'}
# {'speaker': 'HORATIO', 'text_entry': 'As I do live, my honourd lord, tis true;'}
# {'speaker': 'HORATIO',
#  'text_entry': 'And we did think it writ down in our duty'}
# {'speaker': 'HORATIO', 'text_entry': 'To let you know of it.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Indeed, indeed, sirs, but this troubles me.'}
# {'speaker': 'HAMLET', 'text_entry': 'Hold you the watch to-night?'}
# {'speaker': 'BERNARDO', 'text_entry': 'We do, my lord.'}
# {'speaker': 'HAMLET', 'text_entry': 'Armd, say you?'}
# {'speaker': 'BERNARDO', 'text_entry': 'Armd, my lord.'}
# {'speaker': 'HAMLET', 'text_entry': 'From top to toe?'}
# {'speaker': 'BERNARDO', 'text_entry': 'My lord, from head to foot.'}
# {'speaker': 'HAMLET', 'text_entry': 'Then saw you not his face?'}
# {'speaker': 'HORATIO', 'text_entry': 'O, yes, my lord; he wore his beaver up.'}
# {'speaker': 'HAMLET', 'text_entry': 'What, lookd he frowningly?'}
# {'speaker': 'HORATIO',
#  'text_entry': 'A countenance more in sorrow than in anger.'}
# {'speaker': 'HAMLET', 'text_entry': 'Pale or red?'}
# {'speaker': 'HORATIO', 'text_entry': 'Nay, very pale.'}
# {'speaker': 'HAMLET', 'text_entry': 'And fixd his eyes upon you?'}
# {'speaker': 'HORATIO', 'text_entry': 'Most constantly.'}
# {'speaker': 'HAMLET', 'text_entry': 'I would I had been there.'}
# {'speaker': 'HORATIO', 'text_entry': 'It would have much amazed you.'}
# {'speaker': 'HAMLET', 'text_entry': 'Very like, very like. Stayd it long?'}
# {'speaker': 'HORATIO',
#  'text_entry': 'While one with moderate haste might tell a hundred.'}
# {'speaker': 'BERNARDO', 'text_entry': 'Longer, longer.'}
# {'speaker': 'HORATIO', 'text_entry': 'Not when I sawt.'}
# {'speaker': 'HAMLET', 'text_entry': 'His beard was grizzled--no?'}
# {'speaker': 'HORATIO', 'text_entry': 'It was, as I have seen it in his life,'}
# {'speaker': 'HORATIO', 'text_entry': 'A sable silverd.'}
# {'speaker': 'HAMLET', 'text_entry': 'I will watch to-night;'}
# {'speaker': 'HAMLET', 'text_entry': 'Perchance twill walk again.'}
# {'speaker': 'HORATIO', 'text_entry': 'I warrant it will.'}
# {'speaker': 'HAMLET', 'text_entry': 'If it assume my noble fathers person,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Ill speak to it, though hell itself should gape'}
# {'speaker': 'HAMLET', 'text_entry': 'And bid me hold my peace. I pray you all,'}
# {'speaker': 'HAMLET', 'text_entry': 'If you have hitherto conceald this sight,'}
# {'speaker': 'HAMLET', 'text_entry': 'Let it be tenable in your silence still;'}
# {'speaker': 'HAMLET', 'text_entry': 'And whatsoever else shall hap to-night,'}
# {'speaker': 'HAMLET', 'text_entry': 'Give it an understanding, but no tongue:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I will requite your loves. So, fare you well:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Upon the platform, twixt eleven and twelve,'}
# {'speaker': 'HAMLET', 'text_entry': 'Ill visit you.'}
# {'speaker': 'All', 'text_entry': 'Our duty to your honour.'}
# {'speaker': 'HAMLET', 'text_entry': 'Your loves, as mine to you: farewell.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'My fathers spirit in arms! all is not well;'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I doubt some foul play: would the night were come!'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Till then sit still, my soul: foul deeds will rise,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Though all the earth oerwhelm them, to mens eyes.'}
# {'speaker': 'LAERTES', 'text_entry': 'My necessaries are embarkd: farewell:'}
# {'speaker': 'LAERTES', 'text_entry': 'And, sister, as the winds give benefit'}
# {'speaker': 'LAERTES', 'text_entry': 'And convoy is assistant, do not sleep,'}
# {'speaker': 'LAERTES', 'text_entry': 'But let me hear from you.'}
# {'speaker': 'OPHELIA', 'text_entry': 'Do you doubt that?'}
# {'speaker': 'LAERTES',
#  'text_entry': 'For Hamlet and the trifling of his favour,'}
# {'speaker': 'LAERTES', 'text_entry': 'Hold it a fashion and a toy in blood,'}
# {'speaker': 'LAERTES', 'text_entry': 'A violet in the youth of primy nature,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Forward, not permanent, sweet, not lasting,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'The perfume and suppliance of a minute; No more.'}
# {'speaker': 'OPHELIA', 'text_entry': 'No more but so?'}
# {'speaker': 'LAERTES', 'text_entry': 'Think it no more;'}
# {'speaker': 'LAERTES',
#  'text_entry': 'For nature, crescent, does not grow alone'}
# {'speaker': 'LAERTES',
#  'text_entry': 'In thews and bulk, but, as this temple waxes,'}
# {'speaker': 'LAERTES', 'text_entry': 'The inward service of the mind and soul'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Grows wide withal. Perhaps he loves you now,'}
# {'speaker': 'LAERTES', 'text_entry': 'And now no soil nor cautel doth besmirch'}
# {'speaker': 'LAERTES',
#  'text_entry': 'The virtue of his will: but you must fear,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'His greatness weighd, his will is not his own;'}
# {'speaker': 'LAERTES', 'text_entry': 'For he himself is subject to his birth:'}
# {'speaker': 'LAERTES', 'text_entry': 'He may not, as unvalued persons do,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Carve for himself; for on his choice depends'}
# {'speaker': 'LAERTES',
#  'text_entry': 'The safety and health of this whole state;'}
# {'speaker': 'LAERTES',
#  'text_entry': 'And therefore must his choice be circumscribed'}
# {'speaker': 'LAERTES', 'text_entry': 'Unto the voice and yielding of that body'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Whereof he is the head. Then if he says he loves you,'}
# {'speaker': 'LAERTES', 'text_entry': 'It fits your wisdom so far to believe it'}
# {'speaker': 'LAERTES', 'text_entry': 'As he in his particular act and place'}
# {'speaker': 'LAERTES',
#  'text_entry': 'May give his saying deed; which is no further'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Than the main voice of Denmark goes withal.'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Then weigh what loss your honour may sustain,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'If with too credent ear you list his songs,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Or lose your heart, or your chaste treasure open'}
# {'speaker': 'LAERTES', 'text_entry': 'To his unmasterd importunity.'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Fear it, Ophelia, fear it, my dear sister,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'And keep you in the rear of your affection,'}
# {'speaker': 'LAERTES', 'text_entry': 'Out of the shot and danger of desire.'}
# {'speaker': 'LAERTES', 'text_entry': 'The chariest maid is prodigal enough,'}
# {'speaker': 'LAERTES', 'text_entry': 'If she unmask her beauty to the moon:'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Virtue itself scapes not calumnious strokes:'}
# {'speaker': 'LAERTES',
#  'text_entry': 'The canker galls the infants of the spring,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Too oft before their buttons be disclosed,'}
# {'speaker': 'LAERTES', 'text_entry': 'And in the morn and liquid dew of youth'}
# {'speaker': 'LAERTES', 'text_entry': 'Contagious blastments are most imminent.'}
# {'speaker': 'LAERTES', 'text_entry': 'Be wary then; best safety lies in fear:'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Youth to itself rebels, though none else near.'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'I shall the effect of this good lesson keep,'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'As watchman to my heart. But, good my brother,'}
# {'speaker': 'OPHELIA', 'text_entry': 'Do not, as some ungracious pastors do,'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'Show me the steep and thorny way to heaven;'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'Whiles, like a puffd and reckless libertine,'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'Himself the primrose path of dalliance treads,'}
# {'speaker': 'OPHELIA', 'text_entry': 'And recks not his own rede.'}
# {'speaker': 'LAERTES', 'text_entry': 'O, fear me not.'}
# {'speaker': 'LAERTES',
#  'text_entry': 'I stay too long: but here my father comes.'}
# {'speaker': 'LAERTES', 'text_entry': 'A double blessing is a double grace,'}
# {'speaker': 'LAERTES', 'text_entry': 'Occasion smiles upon a second leave.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Yet here, Laertes! aboard, aboard, for shame!'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'The wind sits in the shoulder of your sail,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And you are stayd for. There; my blessing with thee!'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And these few precepts in thy memory'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'See thou character. Give thy thoughts no tongue,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Nor any unproportioned thought his act.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Be thou familiar, but by no means vulgar.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Those friends thou hast, and their adoption tried,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Grapple them to thy soul with hoops of steel;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'But do not dull thy palm with entertainment'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Of each new-hatchd, unfledged comrade. Beware'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Of entrance to a quarrel, but being in,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Beart that the opposed may beware of thee.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Give every man thy ear, but few thy voice;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Take each mans censure, but reserve thy judgment.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Costly thy habit as thy purse can buy,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'But not expressd in fancy; rich, not gaudy;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'For the apparel oft proclaims the man,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And they in France of the best rank and station'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Are of a most select and generous chief in that.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Neither a borrower nor a lender be;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'For loan oft loses both itself and friend,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And borrowing dulls the edge of husbandry.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'This above all: to thine ownself be true,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And it must follow, as the night the day,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Thou canst not then be false to any man.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Farewell: my blessing season this in thee!'}
# {'speaker': 'LAERTES', 'text_entry': 'Most humbly do I take my leave, my lord.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'The time invites you; go; your servants tend.'}
# {'speaker': 'LAERTES', 'text_entry': 'Farewell, Ophelia; and remember well'}
# {'speaker': 'LAERTES', 'text_entry': 'What I have said to you.'}
# {'speaker': 'OPHELIA', 'text_entry': 'Tis in my memory lockd,'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'And you yourself shall keep the key of it.'}
# {'speaker': 'LAERTES', 'text_entry': 'Farewell.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'What ist, Ophelia, be hath said to you?'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'So please you, something touching the Lord Hamlet.'}
# {'speaker': 'LORD POLONIUS', 'text_entry': 'Marry, well bethought:'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Tis told me, he hath very oft of late'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Given private time to you; and you yourself'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Have of your audience been most free and bounteous:'}
# {'speaker': 'LORD POLONIUS', 'text_entry': 'If it be so, as so tis put on me,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'And that in way of caution, I must tell you,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'You do not understand yourself so clearly'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'As it behoves my daughter and your honour.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'What is between you? give me up the truth.'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'He hath, my lord, of late made many tenders'}
# {'speaker': 'OPHELIA', 'text_entry': 'Of his affection to me.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Affection! pooh! you speak like a green girl,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Unsifted in such perilous circumstance.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Do you believe his tenders, as you call them?'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'I do not know, my lord, what I should think.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Marry, Ill teach you: think yourself a baby;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'That you have taen these tenders for true pay,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Which are not sterling. Tender yourself more dearly;'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Or--not to crack the wind of the poor phrase,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Running it thus--youll tender me a fool.'}
# {'speaker': 'OPHELIA', 'text_entry': 'My lord, he hath importuned me with love'}
# {'speaker': 'OPHELIA', 'text_entry': 'In honourable fashion.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Ay, fashion you may call it; go to, go to.'}
# {'speaker': 'OPHELIA',
#  'text_entry': 'And hath given countenance to his speech, my lord,'}
# {'speaker': 'OPHELIA', 'text_entry': 'With almost all the holy vows of heaven.'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Ay, springes to catch woodcocks. I do know,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'When the blood burns, how prodigal the soul'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Lends the tongue vows: these blazes, daughter,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Giving more light than heat, extinct in both,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Even in their promise, as it is a-making,'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'You must not take for fire. From this time'}
# {'speaker': 'LORD POLONIUS',
#  'text_entry': 'Be somewhat scanter of your maiden presence;'}
# {'speaker': 'LORD POLONIUS',
# ...
# {'speaker': 'HAMLET',
#  'text_entry': 'the length and breadth of a pair of indentures? The'}
# {'speaker': 'HAMLET',
#  'text_entry': 'very conveyances of his lands will hardly lie in'}
# {'speaker': 'HAMLET',
#  'text_entry': 'this box; and must the inheritor himself have no more, ha?'}
# {'speaker': 'HORATIO', 'text_entry': 'Not a jot more, my lord.'}
# {'speaker': 'HAMLET', 'text_entry': 'Is not parchment made of sheepskins?'}
# {'speaker': 'HORATIO', 'text_entry': 'Ay, my lord, and of calf-skins too.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'They are sheep and calves which seek out assurance'}
# {'speaker': 'HAMLET',
#  'text_entry': 'in that. I will speak to this fellow. Whose'}
# {'speaker': 'HAMLET', 'text_entry': 'graves this, sirrah?'}
# {'speaker': 'First Clown', 'text_entry': 'Mine, sir.'}
# {'speaker': 'First Clown', 'text_entry': 'O, a pit of clay for to be made'}
# {'speaker': 'First Clown', 'text_entry': 'For such a guest is meet.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I think it be thine, indeed; for thou liest int.'}
# {'speaker': 'First Clown',
#  'text_entry': 'You lie out ont, sir, and therefore it is not'}
# {'speaker': 'First Clown',
#  'text_entry': 'yours: for my part, I do not lie int, and yet it is mine.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Thou dost lie int, to be int and say it is thine:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'tis for the dead, not for the quick; therefore thou liest.'}
# {'speaker': 'First Clown',
#  'text_entry': 'Tis a quick lie, sir; twill away gain, from me to'}
# {'speaker': 'First Clown', 'text_entry': 'you.'}
# {'speaker': 'HAMLET', 'text_entry': 'What man dost thou dig it for?'}
# {'speaker': 'First Clown', 'text_entry': 'For no man, sir.'}
# {'speaker': 'HAMLET', 'text_entry': 'What woman, then?'}
# {'speaker': 'First Clown', 'text_entry': 'For none, neither.'}
# {'speaker': 'HAMLET', 'text_entry': 'Who is to be buried int?'}
# {'speaker': 'First Clown',
#  'text_entry': 'One that was a woman, sir; but, rest her soul, shes dead.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'How absolute the knave is! we must speak by the'}
# {'speaker': 'HAMLET',
#  'text_entry': 'card, or equivocation will undo us. By the Lord,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Horatio, these three years I have taken a note of'}
# {'speaker': 'HAMLET',
#  'text_entry': 'it; the age is grown so picked that the toe of the'}
# {'speaker': 'HAMLET',
#  'text_entry': 'peasant comes so near the heel of the courtier, he'}
# {'speaker': 'HAMLET', 'text_entry': 'gaffs his kibe. How long hast thou been a'}
# {'speaker': 'HAMLET', 'text_entry': 'grave-maker?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Of all the days i the year, I came tot that day'}
# {'speaker': 'First Clown',
#  'text_entry': 'that our last king Hamlet overcame Fortinbras.'}
# {'speaker': 'HAMLET', 'text_entry': 'How long is that since?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Cannot you tell that? every fool can tell that: it'}
# {'speaker': 'First Clown',
#  'text_entry': 'was the very day that young Hamlet was born; he that'}
# {'speaker': 'First Clown', 'text_entry': 'is mad, and sent into England.'}
# {'speaker': 'HAMLET', 'text_entry': 'Ay, marry, why was he sent into England?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Why, because he was mad: he shall recover his wits'}
# {'speaker': 'First Clown',
#  'text_entry': 'there; or, if he do not, its no great matter there.'}
# {'speaker': 'HAMLET', 'text_entry': 'Why?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Twill, a not be seen in him there; there the men'}
# {'speaker': 'First Clown', 'text_entry': 'are as mad as he.'}
# {'speaker': 'HAMLET', 'text_entry': 'How came he mad?'}
# {'speaker': 'First Clown', 'text_entry': 'Very strangely, they say.'}
# {'speaker': 'HAMLET', 'text_entry': 'How strangely?'}
# {'speaker': 'First Clown', 'text_entry': 'Faith, een with losing his wits.'}
# {'speaker': 'HAMLET', 'text_entry': 'Upon what ground?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Why, here in Denmark: I have been sexton here, man'}
# {'speaker': 'First Clown', 'text_entry': 'and boy, thirty years.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'How long will a man lie i the earth ere he rot?'}
# {'speaker': 'First Clown',
#  'text_entry': 'I faith, if he be not rotten before he die--as we'}
# {'speaker': 'First Clown',
#  'text_entry': 'have many pocky corses now-a-days, that will scarce'}
# {'speaker': 'First Clown',
#  'text_entry': 'hold the laying in--he will last you some eight year'}
# {'speaker': 'First Clown',
#  'text_entry': 'or nine year: a tanner will last you nine year.'}
# {'speaker': 'HAMLET', 'text_entry': 'Why he more than another?'}
# {'speaker': 'First Clown',
#  'text_entry': 'Why, sir, his hide is so tanned with his trade, that'}
# {'speaker': 'First Clown',
#  'text_entry': 'he will keep out water a great while; and your water'}
# {'speaker': 'First Clown',
#  'text_entry': 'is a sore decayer of your whoreson dead body.'}
# {'speaker': 'First Clown',
#  'text_entry': 'Heres a skull now; this skull has lain in the earth'}
# {'speaker': 'First Clown', 'text_entry': 'three and twenty years.'}
# {'speaker': 'HAMLET', 'text_entry': 'Whose was it?'}
# {'speaker': 'First Clown',
#  'text_entry': 'A whoreson mad fellows it was: whose do you think it was?'}
# {'speaker': 'HAMLET', 'text_entry': 'Nay, I know not.'}
# {'speaker': 'First Clown',
#  'text_entry': 'A pestilence on him for a mad rogue! a poured a'}
# {'speaker': 'First Clown',
#  'text_entry': 'flagon of Rhenish on my head once. This same skull,'}
# {'speaker': 'First Clown',
#  'text_entry': 'sir, was Yoricks skull, the kings jester.'}
# {'speaker': 'HAMLET', 'text_entry': 'This?'}
# {'speaker': 'First Clown', 'text_entry': 'Een that.'}
# {'speaker': 'HAMLET', 'text_entry': 'Let me see.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Alas, poor Yorick! I knew him, Horatio: a fellow'}
# {'speaker': 'HAMLET',
#  'text_entry': 'of infinite jest, of most excellent fancy: he hath'}
# {'speaker': 'HAMLET',
#  'text_entry': 'borne me on his back a thousand times; and now, how'}
# {'speaker': 'HAMLET',
#  'text_entry': 'abhorred in my imagination it is! my gorge rims at'}
# {'speaker': 'HAMLET',
#  'text_entry': 'it. Here hung those lips that I have kissed I know'}
# {'speaker': 'HAMLET',
#  'text_entry': 'not how oft. Where be your gibes now? your'}
# {'speaker': 'HAMLET',
#  'text_entry': 'gambols? your songs? your flashes of merriment,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'that were wont to set the table on a roar? Not one'}
# {'speaker': 'HAMLET',
#  'text_entry': 'now, to mock your own grinning? quite chap-fallen?'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Now get you to my ladys chamber, and tell her, let'}
# {'speaker': 'HAMLET',
#  'text_entry': 'her paint an inch thick, to this favour she must'}
# {'speaker': 'HAMLET',
#  'text_entry': 'come; make her laugh at that. Prithee, Horatio, tell'}
# {'speaker': 'HAMLET', 'text_entry': 'me one thing.'}
# {'speaker': 'HORATIO', 'text_entry': 'Whats that, my lord?'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Dost thou think Alexander looked o this fashion i'}
# {'speaker': 'HAMLET', 'text_entry': 'the earth?'}
# {'speaker': 'HORATIO', 'text_entry': 'Een so.'}
# {'speaker': 'HAMLET', 'text_entry': 'And smelt so? pah!'}
# {'speaker': 'HORATIO', 'text_entry': 'Een so, my lord.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'To what base uses we may return, Horatio! Why may'}
# {'speaker': 'HAMLET',
#  'text_entry': 'not imagination trace the noble dust of Alexander,'}
# {'speaker': 'HAMLET', 'text_entry': 'till he find it stopping a bung-hole?'}
# {'speaker': 'HORATIO',
#  'text_entry': 'Twere to consider too curiously, to consider so.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'No, faith, not a jot; but to follow him thither with'}
# {'speaker': 'HAMLET',
#  'text_entry': 'modesty enough, and likelihood to lead it: as'}
# {'speaker': 'HAMLET',
#  'text_entry': 'thus: Alexander died, Alexander was buried,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Alexander returneth into dust; the dust is earth; of'}
# {'speaker': 'HAMLET',
#  'text_entry': 'earth we make loam; and why of that loam, whereto he'}
# {'speaker': 'HAMLET',
#  'text_entry': 'was converted, might they not stop a beer-barrel?'}
# {'speaker': 'HAMLET', 'text_entry': 'Imperious Caesar, dead and turnd to clay,'}
# {'speaker': 'HAMLET', 'text_entry': 'Might stop a hole to keep the wind away:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'O, that that earth, which kept the world in awe,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Should patch a wall to expel the winter flaw!'}
# {'speaker': 'HAMLET',
#  'text_entry': 'But soft! but soft! aside: here comes the king.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Enter Priest,  and c. in procession; the Corpse of  OPHELIA, '
#                'LAERTES and Mourners following; KING CLAUDIUS, QUEEN GERTRUDE, '
#                'their trains,  and c'}
# {'speaker': 'HAMLET',
#  'text_entry': 'The queen, the courtiers: who is this they follow?'}
# {'speaker': 'HAMLET',
#  'text_entry': 'And with such maimed rites? This doth betoken'}
# {'speaker': 'HAMLET',
#  'text_entry': 'The corse they follow did with desperate hand'}
# {'speaker': 'HAMLET', 'text_entry': 'Fordo its own life: twas of some estate.'}
# {'speaker': 'HAMLET', 'text_entry': 'Couch we awhile, and mark.'}
# {'speaker': 'LAERTES', 'text_entry': 'What ceremony else?'}
# {'speaker': 'HAMLET', 'text_entry': 'That is Laertes,'}
# {'speaker': 'HAMLET', 'text_entry': 'A very noble youth: mark.'}
# {'speaker': 'LAERTES', 'text_entry': 'What ceremony else?'}
# {'speaker': 'First Priest',
#  'text_entry': 'Her obsequies have been as far enlarged'}
# {'speaker': 'First Priest',
#  'text_entry': 'As we have warrantise: her death was doubtful;'}
# {'speaker': 'First Priest',
#  'text_entry': 'And, but that great command oersways the order,'}
# {'speaker': 'First Priest',
#  'text_entry': 'She should in ground unsanctified have lodged'}
# {'speaker': 'First Priest',
#  'text_entry': 'Till the last trumpet: for charitable prayers,'}
# {'speaker': 'First Priest',
#  'text_entry': 'Shards, flints and pebbles should be thrown on her;'}
# {'speaker': 'First Priest',
#  'text_entry': 'Yet here she is allowd her virgin crants,'}
# {'speaker': 'First Priest',
#  'text_entry': 'Her maiden strewments and the bringing home'}
# {'speaker': 'First Priest', 'text_entry': 'Of bell and burial.'}
# {'speaker': 'LAERTES', 'text_entry': 'Must there no more be done?'}
# {'speaker': 'First Priest', 'text_entry': 'No more be done:'}
# {'speaker': 'First Priest',
#  'text_entry': 'We should profane the service of the dead'}
# {'speaker': 'First Priest',
#  'text_entry': 'To sing a requiem and such rest to her'}
# {'speaker': 'First Priest', 'text_entry': 'As to peace-parted souls.'}
# {'speaker': 'LAERTES', 'text_entry': 'Lay her i the earth:'}
# {'speaker': 'LAERTES', 'text_entry': 'And from her fair and unpolluted flesh'}
# {'speaker': 'LAERTES',
#  'text_entry': 'May violets spring! I tell thee, churlish priest,'}
# {'speaker': 'LAERTES', 'text_entry': 'A ministering angel shall my sister be,'}
# {'speaker': 'LAERTES', 'text_entry': 'When thou liest howling.'}
# {'speaker': 'HAMLET', 'text_entry': 'What, the fair Ophelia!'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'Sweets to the sweet: farewell!'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'I hoped thou shouldst have been my Hamlets wife;'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'I thought thy bride-bed to have deckd, sweet maid,'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'And not have strewd thy grave.'}
# {'speaker': 'LAERTES', 'text_entry': 'O, treble woe'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Fall ten times treble on that cursed head,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Whose wicked deed thy most ingenious sense'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Deprived thee of! Hold off the earth awhile,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Till I have caught her once more in mine arms:'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Now pile your dust upon the quick and dead,'}
# {'speaker': 'LAERTES',
#  'text_entry': 'Till of this flat a mountain you have made,'}
# {'speaker': 'LAERTES', 'text_entry': 'To oertop old Pelion, or the skyish head'}
# {'speaker': 'LAERTES', 'text_entry': 'Of blue Olympus.'}
# {'speaker': 'HAMLET', 'text_entry': '[Advancing]     What is he whose grief'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Bears such an emphasis? whose phrase of sorrow'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Conjures the wandering stars, and makes them stand'}
# {'speaker': 'HAMLET', 'text_entry': 'Like wonder-wounded hearers? This is I,'}
# {'speaker': 'HAMLET', 'text_entry': 'Hamlet the Dane.'}
# {'speaker': 'LAERTES', 'text_entry': 'The devil take thy soul!'}
# {'speaker': 'HAMLET', 'text_entry': 'Thou prayst not well.'}
# {'speaker': 'HAMLET',
#  'text_entry': 'I prithee, take thy fingers from my throat;'}
# {'speaker': 'HAMLET', 'text_entry': 'For, though I am not splenitive and rash,'}
# {'speaker': 'HAMLET', 'text_entry': 'Yet have I something in me dangerous,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Which let thy wiseness fear: hold off thy hand.'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'Pluck them asunder.'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'Hamlet, Hamlet!'}
# {'speaker': 'All', 'text_entry': 'Gentlemen,--'}
# {'speaker': 'HORATIO', 'text_entry': 'Good my lord, be quiet.'}
# {'speaker': 'HAMLET', 'text_entry': 'Why I will fight with him upon this theme'}
# {'speaker': 'HAMLET', 'text_entry': 'Until my eyelids will no longer wag.'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'O my son, what theme?'}
# {'speaker': 'HAMLET', 'text_entry': 'I loved Ophelia: forty thousand brothers'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Could not, with all their quantity of love,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Make up my sum. What wilt thou do for her?'}
# {'speaker': 'KING CLAUDIUS', 'text_entry': 'O, he is mad, Laertes.'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'For love of God, forbear him.'}
# {'speaker': 'HAMLET', 'text_entry': 'Swounds, show me what thoult do:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Woot weep? woot fight? woot fast? woot tear thyself?'}
# {'speaker': 'HAMLET', 'text_entry': 'Woot drink up eisel? eat a crocodile?'}
# {'speaker': 'HAMLET', 'text_entry': 'Ill dot. Dost thou come here to whine?'}
# {'speaker': 'HAMLET', 'text_entry': 'To outface me with leaping in her grave?'}
# {'speaker': 'HAMLET', 'text_entry': 'Be buried quick with her, and so will I:'}
# {'speaker': 'HAMLET',
#  'text_entry': 'And, if thou prate of mountains, let them throw'}
# {'speaker': 'HAMLET', 'text_entry': 'Millions of acres on us, till our ground,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Singeing his pate against the burning zone,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'Make Ossa like a wart! Nay, an thoult mouth,'}
# {'speaker': 'HAMLET', 'text_entry': 'Ill rant as well as thou.'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'This is mere madness:'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'And thus awhile the fit will work on him;'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'Anon, as patient as the female dove,'}
# {'speaker': 'QUEEN GERTRUDE',
#  'text_entry': 'When that her golden couplets are disclosed,'}
# {'speaker': 'QUEEN GERTRUDE', 'text_entry': 'His silence will sit drooping.'}
# {'speaker': 'HAMLET', 'text_entry': 'Hear you, sir;'}
# {'speaker': 'HAMLET', 'text_entry': 'What is the reason that you use me thus?'}
# {'speaker': 'HAMLET', 'text_entry': 'I loved you ever: but it is no matter;'}
# {'speaker': 'HAMLET', 'text_entry': 'Let Hercules himself do what he may,'}
# {'speaker': 'HAMLET',
#  'text_entry': 'The cat will mew and dog will have his day.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'I pray you, good Horatio, wait upon him.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Strengthen your patience in our last nights speech;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Well put the matter to the present push.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Good Gertrude, set some watch over your son.'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'This grave shall have a living monument:'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'An hour of quiet shortly shall we see;'}
# {'speaker': 'KING CLAUDIUS',
#  'text_entry': 'Till then, in patience our proceeding be.'}

# %%
# Consulta 4: Texto completo de una secuencia concreta de una obra concreta (por ejemplo 'Romeo and Juliet') y los personajes que actuan

selected_play = "Romeo and Juliet"
selected_act = 2
selected_scene = 2
projection = {"_id": 0, "line_id": 0, "line_number": 0, "play_name": 0, "speech_number": 0, "type": 0}

sequence_text = db.ShakespeareWorks.find(
    {
        "play_name": selected_play,
        "type": "line",
        "line_number": {"$regex": f"{selected_act}\.{selected_scene}\..*"}
    },
    projection
)

print(f"Texto completo de la Secuencia {selected_scene} del Acto {selected_act} de {selected_play}:\n")
for line in sequence_text:
    pprint({"speaker": line.get("speaker"), "text_entry": line.get("text_entry")})
# Out:
# Texto completo de la Secuencia 2 del Acto 2 de Romeo and Juliet:
#
# {'speaker': 'ROMEO', 'text_entry': 'He jests at scars that never felt a wound.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'But, soft! what light through yonder window breaks?'}
# {'speaker': 'ROMEO', 'text_entry': 'It is the east, and Juliet is the sun.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Arise, fair sun, and kill the envious moon,'}
# {'speaker': 'ROMEO', 'text_entry': 'Who is already sick and pale with grief,'}
# {'speaker': 'ROMEO',
#  'text_entry': 'That thou her maid art far more fair than she:'}
# {'speaker': 'ROMEO', 'text_entry': 'Be not her maid, since she is envious;'}
# {'speaker': 'ROMEO', 'text_entry': 'Her vestal livery is but sick and green'}
# {'speaker': 'ROMEO',
#  'text_entry': 'And none but fools do wear it; cast it off.'}
# {'speaker': 'ROMEO', 'text_entry': 'It is my lady, O, it is my love!'}
# {'speaker': 'ROMEO', 'text_entry': 'O, that she knew she were!'}
# {'speaker': 'ROMEO',
#  'text_entry': 'She speaks yet she says nothing: what of that?'}
# {'speaker': 'ROMEO', 'text_entry': 'Her eye discourses; I will answer it.'}
# {'speaker': 'ROMEO', 'text_entry': 'I am too bold, tis not to me she speaks:'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Two of the fairest stars in all the heaven,'}
# {'speaker': 'ROMEO', 'text_entry': 'Having some business, do entreat her eyes'}
# {'speaker': 'ROMEO',
#  'text_entry': 'To twinkle in their spheres till they return.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'What if her eyes were there, they in her head?'}
# {'speaker': 'ROMEO',
#  'text_entry': 'The brightness of her cheek would shame those stars,'}
# {'speaker': 'ROMEO',
#  'text_entry': 'As daylight doth a lamp; her eyes in heaven'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Would through the airy region stream so bright'}
# {'speaker': 'ROMEO',
#  'text_entry': 'That birds would sing and think it were not night.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'See, how she leans her cheek upon her hand!'}
# {'speaker': 'ROMEO', 'text_entry': 'O, that I were a glove upon that hand,'}
# {'speaker': 'ROMEO', 'text_entry': 'That I might touch that cheek!'}
# {'speaker': 'JULIET', 'text_entry': 'Ay me!'}
# {'speaker': 'ROMEO', 'text_entry': 'She speaks:'}
# {'speaker': 'ROMEO', 'text_entry': 'O, speak again, bright angel! for thou art'}
# {'speaker': 'ROMEO',
#  'text_entry': 'As glorious to this night, being oer my head'}
# {'speaker': 'ROMEO', 'text_entry': 'As is a winged messenger of heaven'}
# {'speaker': 'ROMEO', 'text_entry': 'Unto the white-upturned wondering eyes'}
# {'speaker': 'ROMEO', 'text_entry': 'Of mortals that fall back to gaze on him'}
# {'speaker': 'ROMEO', 'text_entry': 'When he bestrides the lazy-pacing clouds'}
# {'speaker': 'ROMEO', 'text_entry': 'And sails upon the bosom of the air.'}
# {'speaker': 'JULIET', 'text_entry': 'O Romeo, Romeo! wherefore art thou Romeo?'}
# {'speaker': 'JULIET', 'text_entry': 'Deny thy father and refuse thy name;'}
# {'speaker': 'JULIET',
#  'text_entry': 'Or, if thou wilt not, be but sworn my love,'}
# {'speaker': 'JULIET', 'text_entry': 'And Ill no longer be a Capulet.'}
# {'speaker': 'ROMEO',
#  'text_entry': '[Aside]  Shall I hear more, or shall I speak at this?'}
# {'speaker': 'JULIET', 'text_entry': 'Tis but thy name that is my enemy;'}
# {'speaker': 'JULIET', 'text_entry': 'Thou art thyself, though not a Montague.'}
# {'speaker': 'JULIET', 'text_entry': 'Whats Montague? it is nor hand, nor foot,'}
# {'speaker': 'JULIET', 'text_entry': 'Nor arm, nor face, nor any other part'}
# {'speaker': 'JULIET',
#  'text_entry': 'Belonging to a man. O, be some other name!'}
# {'speaker': 'JULIET',
#  'text_entry': 'Whats in a name? that which we call a rose'}
# {'speaker': 'JULIET', 'text_entry': 'By any other name would smell as sweet;'}
# {'speaker': 'JULIET', 'text_entry': 'So Romeo would, were he not Romeo calld,'}
# {'speaker': 'JULIET', 'text_entry': 'Retain that dear perfection which he owes'}
# {'speaker': 'JULIET', 'text_entry': 'Without that title. Romeo, doff thy name,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And for that name which is no part of thee'}
# {'speaker': 'JULIET', 'text_entry': 'Take all myself.'}
# {'speaker': 'ROMEO', 'text_entry': 'I take thee at thy word:'}
# {'speaker': 'ROMEO', 'text_entry': 'Call me but love, and Ill be new baptized;'}
# {'speaker': 'ROMEO', 'text_entry': 'Henceforth I never will be Romeo.'}
# {'speaker': 'JULIET',
#  'text_entry': 'What man art thou that thus bescreend in night'}
# {'speaker': 'JULIET', 'text_entry': 'So stumblest on my counsel?'}
# {'speaker': 'ROMEO', 'text_entry': 'By a name'}
# {'speaker': 'ROMEO', 'text_entry': 'I know not how to tell thee who I am:'}
# {'speaker': 'ROMEO', 'text_entry': 'My name, dear saint, is hateful to myself,'}
# {'speaker': 'ROMEO', 'text_entry': 'Because it is an enemy to thee;'}
# {'speaker': 'ROMEO', 'text_entry': 'Had I it written, I would tear the word.'}
# {'speaker': 'JULIET',
#  'text_entry': 'My ears have not yet drunk a hundred words'}
# {'speaker': 'JULIET',
#  'text_entry': 'Of that tongues utterance, yet I know the sound:'}
# {'speaker': 'JULIET', 'text_entry': 'Art thou not Romeo and a Montague?'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Neither, fair saint, if either thee dislike.'}
# {'speaker': 'JULIET',
#  'text_entry': 'How camest thou hither, tell me, and wherefore?'}
# {'speaker': 'JULIET',
#  'text_entry': 'The orchard walls are high and hard to climb,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And the place death, considering who thou art,'}
# {'speaker': 'JULIET', 'text_entry': 'If any of my kinsmen find thee here.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'With loves light wings did I oer-perch these walls;'}
# {'speaker': 'ROMEO', 'text_entry': 'For stony limits cannot hold love out,'}
# {'speaker': 'ROMEO',
#  'text_entry': 'And what love can do that dares love attempt;'}
# {'speaker': 'ROMEO', 'text_entry': 'Therefore thy kinsmen are no let to me.'}
# {'speaker': 'JULIET',
#  'text_entry': 'If they do see thee, they will murder thee.'}
# {'speaker': 'ROMEO', 'text_entry': 'Alack, there lies more peril in thine eye'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Than twenty of their swords: look thou but sweet,'}
# {'speaker': 'ROMEO', 'text_entry': 'And I am proof against their enmity.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I would not for the world they saw thee here.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'I have nights cloak to hide me from their sight;'}
# {'speaker': 'ROMEO',
#  'text_entry': 'And but thou love me, let them find me here:'}
# {'speaker': 'ROMEO', 'text_entry': 'My life were better ended by their hate,'}
# {'speaker': 'ROMEO', 'text_entry': 'Than death prorogued, wanting of thy love.'}
# {'speaker': 'JULIET',
#  'text_entry': 'By whose direction foundst thou out this place?'}
# {'speaker': 'ROMEO',
#  'text_entry': 'By love, who first did prompt me to inquire;'}
# {'speaker': 'ROMEO', 'text_entry': 'He lent me counsel and I lent him eyes.'}
# {'speaker': 'ROMEO', 'text_entry': 'I am no pilot; yet, wert thou as far'}
# {'speaker': 'ROMEO',
#  'text_entry': 'As that vast shore washd with the farthest sea,'}
# {'speaker': 'ROMEO', 'text_entry': 'I would adventure for such merchandise.'}
# {'speaker': 'JULIET',
#  'text_entry': 'Thou knowst the mask of night is on my face,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Else would a maiden blush bepaint my cheek'}
# {'speaker': 'JULIET',
#  'text_entry': 'For that which thou hast heard me speak to-night'}
# {'speaker': 'JULIET',
#  'text_entry': 'Fain would I dwell on form, fain, fain deny'}
# {'speaker': 'JULIET',
#  'text_entry': 'What I have spoke: but farewell compliment!'}
# {'speaker': 'JULIET',
#  'text_entry': 'Dost thou love me? I know thou wilt say Ay,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And I will take thy word: yet if thou swearst,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Thou mayst prove false; at lovers perjuries'}
# {'speaker': 'JULIET', 'text_entry': 'Then say, Jove laughs. O gentle Romeo,'}
# {'speaker': 'JULIET',
#  'text_entry': 'If thou dost love, pronounce it faithfully:'}
# {'speaker': 'JULIET', 'text_entry': 'Or if thou thinkst I am too quickly won,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Ill frown and be perverse an say thee nay,'}
# {'speaker': 'JULIET',
#  'text_entry': 'So thou wilt woo; but else, not for the world.'}
# {'speaker': 'JULIET', 'text_entry': 'In truth, fair Montague, I am too fond,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And therefore thou mayst think my havior light:'}
# {'speaker': 'JULIET',
#  'text_entry': 'But trust me, gentleman, Ill prove more true'}
# {'speaker': 'JULIET',
#  'text_entry': 'Than those that have more cunning to be strange.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I should have been more strange, I must confess,'}
# {'speaker': 'JULIET',
#  'text_entry': 'But that thou overheardst, ere I was ware,'}
# {'speaker': 'JULIET',
#  'text_entry': 'My true loves passion: therefore pardon me,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And not impute this yielding to light love,'}
# {'speaker': 'JULIET', 'text_entry': 'Which the dark night hath so discovered.'}
# {'speaker': 'ROMEO', 'text_entry': 'Lady, by yonder blessed moon I swear'}
# {'speaker': 'ROMEO',
#  'text_entry': 'That tips with silver all these fruit-tree tops--'}
# {'speaker': 'JULIET',
#  'text_entry': 'O, swear not by the moon, the inconstant moon,'}
# {'speaker': 'JULIET', 'text_entry': 'That monthly changes in her circled orb,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Lest that thy love prove likewise variable.'}
# {'speaker': 'ROMEO', 'text_entry': 'What shall I swear by?'}
# {'speaker': 'JULIET', 'text_entry': 'Do not swear at all;'}
# {'speaker': 'JULIET',
#  'text_entry': 'Or, if thou wilt, swear by thy gracious self,'}
# {'speaker': 'JULIET', 'text_entry': 'Which is the god of my idolatry,'}
# {'speaker': 'JULIET', 'text_entry': 'And Ill believe thee.'}
# {'speaker': 'ROMEO', 'text_entry': 'If my hearts dear love--'}
# {'speaker': 'JULIET',
#  'text_entry': 'Well, do not swear: although I joy in thee,'}
# {'speaker': 'JULIET', 'text_entry': 'I have no joy of this contract to-night:'}
# {'speaker': 'JULIET',
#  'text_entry': 'It is too rash, too unadvised, too sudden;'}
# {'speaker': 'JULIET',
#  'text_entry': 'Too like the lightning, which doth cease to be'}
# {'speaker': 'JULIET',
#  'text_entry': 'Ere one can say It lightens. Sweet, good night!'}
# {'speaker': 'JULIET',
#  'text_entry': 'This bud of love, by summers ripening breath,'}
# {'speaker': 'JULIET',
#  'text_entry': 'May prove a beauteous flower when next we meet.'}
# {'speaker': 'JULIET',
#  'text_entry': 'Good night, good night! as sweet repose and rest'}
# {'speaker': 'JULIET',
#  'text_entry': 'Come to thy heart as that within my breast!'}
# {'speaker': 'ROMEO', 'text_entry': 'O, wilt thou leave me so unsatisfied?'}
# {'speaker': 'JULIET',
#  'text_entry': 'What satisfaction canst thou have to-night?'}
# {'speaker': 'ROMEO',
#  'text_entry': 'The exchange of thy loves faithful vow for mine.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I gave thee mine before thou didst request it:'}
# {'speaker': 'JULIET', 'text_entry': 'And yet I would it were to give again.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Wouldst thou withdraw it? for what purpose, love?'}
# {'speaker': 'JULIET', 'text_entry': 'But to be frank, and give it thee again.'}
# {'speaker': 'JULIET', 'text_entry': 'And yet I wish but for the thing I have:'}
# {'speaker': 'JULIET', 'text_entry': 'My bounty is as boundless as the sea,'}
# {'speaker': 'JULIET', 'text_entry': 'My love as deep; the more I give to thee,'}
# {'speaker': 'JULIET', 'text_entry': 'The more I have, for both are infinite.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I hear some noise within; dear love, adieu!'}
# {'speaker': 'JULIET',
#  'text_entry': 'Anon, good nurse! Sweet Montague, be true.'}
# {'speaker': 'JULIET', 'text_entry': 'Stay but a little, I will come again.'}
# {'speaker': 'ROMEO', 'text_entry': 'O blessed, blessed night! I am afeard.'}
# {'speaker': 'ROMEO', 'text_entry': 'Being in night, all this is but a dream,'}
# {'speaker': 'ROMEO', 'text_entry': 'Too flattering-sweet to be substantial.'}
# {'speaker': 'JULIET',
#  'text_entry': 'Three words, dear Romeo, and good night indeed.'}
# {'speaker': 'JULIET', 'text_entry': 'If that thy bent of love be honourable,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Thy purpose marriage, send me word to-morrow,'}
# {'speaker': 'JULIET', 'text_entry': 'By one that Ill procure to come to thee,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Where and what time thou wilt perform the rite;'}
# {'speaker': 'JULIET', 'text_entry': 'And all my fortunes at thy foot Ill lay'}
# {'speaker': 'JULIET',
#  'text_entry': 'And follow thee my lord throughout the world.'}
# {'speaker': 'Nurse', 'text_entry': '[Within]  Madam!'}
# {'speaker': 'JULIET',
#  'text_entry': 'I come, anon.--But if thou meanst not well,'}
# {'speaker': 'JULIET', 'text_entry': 'I do beseech thee--'}
# {'speaker': 'Nurse', 'text_entry': '[Within]  Madam!'}
# {'speaker': 'JULIET', 'text_entry': 'By and by, I come:--'}
# {'speaker': 'JULIET',
#  'text_entry': 'To cease thy suit, and leave me to my grief:'}
# {'speaker': 'JULIET', 'text_entry': 'To-morrow will I send.'}
# {'speaker': 'ROMEO', 'text_entry': 'So thrive my soul--'}
# {'speaker': 'JULIET', 'text_entry': 'A thousand times good night!'}
# {'speaker': 'ROMEO',
#  'text_entry': 'A thousand times the worse, to want thy light.'}
# {'speaker': 'ROMEO', 'text_entry': 'Love goes toward love, as schoolboys from'}
# {'speaker': 'ROMEO', 'text_entry': 'their books,'}
# {'speaker': 'ROMEO',
#  'text_entry': 'But love from love, toward school with heavy looks.'}
# {'speaker': 'JULIET',
#  'text_entry': 'Hist! Romeo, hist! O, for a falconers voice,'}
# {'speaker': 'JULIET', 'text_entry': 'To lure this tassel-gentle back again!'}
# {'speaker': 'JULIET',
#  'text_entry': 'Bondage is hoarse, and may not speak aloud;'}
# {'speaker': 'JULIET',
#  'text_entry': 'Else would I tear the cave where Echo lies,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And make her airy tongue more hoarse than mine,'}
# {'speaker': 'JULIET', 'text_entry': 'With repetition of my Romeos name.'}
# {'speaker': 'ROMEO', 'text_entry': 'It is my soul that calls upon my name:'}
# {'speaker': 'ROMEO',
#  'text_entry': 'How silver-sweet sound lovers tongues by night,'}
# {'speaker': 'ROMEO', 'text_entry': 'Like softest music to attending ears!'}
# {'speaker': 'JULIET', 'text_entry': 'Romeo!'}
# {'speaker': 'ROMEO', 'text_entry': 'My dear?'}
# {'speaker': 'JULIET', 'text_entry': 'At what oclock to-morrow'}
# {'speaker': 'JULIET', 'text_entry': 'Shall I send to thee?'}
# {'speaker': 'ROMEO', 'text_entry': 'At the hour of nine.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I will not fail: tis twenty years till then.'}
# {'speaker': 'JULIET', 'text_entry': 'I have forgot why I did call thee back.'}
# {'speaker': 'ROMEO', 'text_entry': 'Let me stand here till thou remember it.'}
# {'speaker': 'JULIET',
#  'text_entry': 'I shall forget, to have thee still stand there,'}
# {'speaker': 'JULIET', 'text_entry': 'Remembering how I love thy company.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'And Ill still stay, to have thee still forget,'}
# {'speaker': 'ROMEO', 'text_entry': 'Forgetting any other home but this.'}
# {'speaker': 'JULIET',
#  'text_entry': 'Tis almost morning; I would have thee gone:'}
# {'speaker': 'JULIET', 'text_entry': 'And yet no further than a wantons bird;'}
# {'speaker': 'JULIET', 'text_entry': 'Who lets it hop a little from her hand,'}
# {'speaker': 'JULIET',
#  'text_entry': 'Like a poor prisoner in his twisted gyves,'}
# {'speaker': 'JULIET',
#  'text_entry': 'And with a silk thread plucks it back again,'}
# {'speaker': 'JULIET', 'text_entry': 'So loving-jealous of his liberty.'}
# {'speaker': 'ROMEO', 'text_entry': 'I would I were thy bird.'}
# {'speaker': 'JULIET', 'text_entry': 'Sweet, so would I:'}
# {'speaker': 'JULIET',
#  'text_entry': 'Yet I should kill thee with much cherishing.'}
# {'speaker': 'JULIET', 'text_entry': 'Good night, good night! parting is such'}
# {'speaker': 'JULIET', 'text_entry': 'sweet sorrow,'}
# {'speaker': 'JULIET',
#  'text_entry': 'That I shall say good night till it be morrow.'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Sleep dwell upon thine eyes, peace in thy breast!'}
# {'speaker': 'ROMEO',
#  'text_entry': 'Would I were sleep and peace, so sweet to rest!'}
# {'speaker': 'ROMEO', 'text_entry': 'Hence will I to my ghostly fathers cell,'}
# {'speaker': 'ROMEO',
#  'text_entry': 'His help to crave, and my dear hap to tell.'}

# %% [markdown]
# ### CONSULTAS CASO DE USO NEO4J

# %%
# Consulta 1: Obras de Shakespeare ambientadas en Londres
result_1 = db.ShakespeareWorks.find({"text_entry": {"$regex": "London"}}, {"play_name": 1, "_id": 0})
print("Obras de Shakespeare ambientadas en Londres:")
# Almacenar los nombres únicos de las obras
plays = set()
for doc in result_1:
    plays.add(doc["play_name"])

# Imprimir los nombres únicos de las obras
for play_name in plays:
    pprint(play_name)
# Out:
# Obras de Shakespeare ambientadas en Londres:
# 'Henry VI Part 1'
# 'Henry VI Part 3'
# 'Henry VIII'
# 'Henry IV'
# 'Richard II'
# 'King John'
# 'Richard III'
# 'Henry VI Part 2'
# 'Henry V'

# %%
import re

# Consulta 2: Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare
london_locations = db.ShakespeareWorks.find({
    "text_entry": {"$regex": ".*London.*"}
})

# Crear un diccionario para almacenar los ambientes únicos por localización
environments_by_location = {}

# Procesar cada documento para extraer la localización y el ambiente
for work in london_locations:
    # Obtener la localización y el ambiente usando expresiones regulares
    match = re.match(r"SCENE [IVXLCDM]+\. ([^\d]+)\. (.+)", work["text_entry"])
    if match:
        location = match.group(1).strip()
        environment = match.group(2).strip()
        # Agregar el ambiente al conjunto de ambientes de la localización
        environments_by_location.setdefault(location, set()).add(environment)

# Mostrar los resultados
print("Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare:")
for location, environments in environments_by_location.items():
    print(f"Localización: {location}")
    print("Ambientes:")
    for environment in environments:
        print(f"- {environment}")
    print()
# Out:
# Listado con los ambientes que tiene cada una de las localizaciones de Londres de la obra de Shakespeare:
# Localización: London
# Ambientes:
# - An ante-chamber in the KINGS palace.
# - A street.
# - YORKS garden.
# - Smithfield.
# - An apartment of the Princes.
# - The Temple-garden.
# - Cannon Street.
# - Before the Tower.
# - KING RICHARD IIs palace.
# - The Parliament-house.
# - QUEEN KATHARINEs apartments.
# - An ante-chamber in the palace.
# - The palace.
# - The Tower.
# - Before a tavern.
# - A gallery in the palace.
# - A street leading to the Tower.

# %%
import re

# Consulta 3: De las obras en Londres, saber las localizaciones y ambientes de cada obra
london_works = db.ShakespeareWorks.find({
    "text_entry": {"$regex": ".*London.*"}
})

# Crear un diccionario para almacenar las localizaciones y ambientes por obra
locations_and_environments_by_work = {}

# Procesar cada documento para extraer la obra, la localización y el ambiente
for work in london_works:
    # Obtener la obra, la localización y el ambiente usando expresiones regulares
    match = re.match(r"SCENE ([IVXLCDM]+)\. (.+)", work["text_entry"])
    if match:
        work_name = work["play_name"]
        scene = match.group(1).strip()
        location_and_environment = match.group(2).strip()
        # Agregar la localización y el ambiente a la lista de escenas de la obra
        if work_name not in locations_and_environments_by_work:
            locations_and_environments_by_work[work_name] = []
        locations_and_environments_by_work[work_name].append((scene, location_and_environment))

# Mostrar los resultados
print("De las obras en Londres, saber las localizaciones y ambientes de cada obra:")
for work_name, locations_environments in locations_and_environments_by_work.items():
    print(f"Obra: {work_name}")
    print("Escenas:")
    for scene, location_and_environment in locations_environments:
        print(f"- Escena {scene}: {location_and_environment}")
    print()
# Out:
# De las obras en Londres, saber las localizaciones y ambientes de cada obra:
# Obra: Henry IV
# Escenas:
# - Escena I: London. The palace.
# - Escena II: London. An apartment of the Princes.
# - Escena III: London. The palace.
# - Escena II: London. The palace.
#
# Obra: Henry VI Part 1
# Escenas:
# - Escena III: London. Before the Tower.
# - Escena IV: London. The Temple-garden.
# - Escena V: The Tower of London.
# - Escena I: London. The Parliament-house.
# - Escena I: London. The palace.
# - Escena V: London. The palace.
#
# Obra: Henry VI Part 2
# Escenas:
# - Escena I: London. The palace.
# - Escena II: London. YORKS garden.
# - Escena IV: London. The palace.
# - Escena V: London. The Tower.
# - Escena VI: London. Cannon Street.
# - Escena VII: London. Smithfield.
#
# Obra: Henry VI Part 3
# Escenas:
# - Escena I: London. The Parliament-house.
# - Escena II: London. The palace.
# - Escena I: London. The palace.
# - Escena IV: London. The palace.
# - Escena VI: London. The Tower.
# - Escena VIII: London. The palace.
# - Escena VI: London. The Tower.
# - Escena VII: London. The palace.
#
# Obra: Henry V
# Escenas:
# - Escena I: London. An ante-chamber in the KINGS palace.
# - Escena I: London. A street.
# - Escena III: London. Before a tavern.
#
# Obra: Henry VIII
# Escenas:
# - Escena I: London. An ante-chamber in the palace.
# - Escena I: London. QUEEN KATHARINEs apartments.
# - Escena I: London. A gallery in the palace.
#
# Obra: Richard II
# Escenas:
# - Escena I: London. KING RICHARD IIs palace.
# - Escena I: London. A street leading to the Tower.
#
# Obra: Richard III
# Escenas:
# - Escena I: London. A street.
# - Escena IV: London. The Tower.
# - Escena I: London. The palace.
# - Escena III: London. A street.
# - Escena IV: London. The palace.
# - Escena I: London. A street.
# - Escena IV: The Tower of London.
# - Escena II: London. The palace.

# %%
# Consulta 4: De las obras en Londres, saber los personajes que aparecen en cada obra
london_works = db.ShakespeareWorks.find({
    "text_entry": {"$regex": ".*London.*"}
})

# Crear un diccionario para almacenar los personajes por obra
characters_by_work = {}

# Procesar cada documento para extraer la obra y los personajes
for work in london_works:
    work_name = work["play_name"]
    speaker = work["speaker"]
    # Agregar el personaje a la lista de personajes de la obra
    if work_name not in characters_by_work:
        characters_by_work[work_name] = set()
    if speaker:
        characters_by_work[work_name].add(speaker.strip())

# Mostrar los resultados
print("De las obras en Londres, saber los personajes que aparecen en cada obra:")
for work_name, characters in characters_by_work.items():
    print(f"Obra: {work_name}")
    print("Personajes:")
    for character in sorted(characters):
        print(f"- {character}")
    print()
# Out:
# De las obras en Londres, saber los personajes que aparecen en cada obra:
# Obra: Henry IV
# Personajes:
# - FALSTAFF
# - GADSHILL
# - MORTIMER
# - POINS
# - PRINCE HENRY
# - Second Carrier
# - WESTMORELAND
#
# Obra: Henry VI Part 1
# Personajes:
# - CHARLES
# - GLOUCESTER
# - Mayor
# - OF AUVERGNE
# - PLANTAGENET
# - YORK
#
# Obra: Henry VI Part 2
# Personajes:
# - CADE
# - CARDINAL
# - CLIFFORD
# - KING HENRY VI
# - Messenger
# - QUEEN MARGARET
# - SAY
# - SCALES
# - SUFFOLK
# - WARWICK
# - YORK
#
# Obra: Henry VI Part 3
# Personajes:
# - CLARENCE
# - GLOUCESTER
# - KING EDWARD IV
# - KING HENRY VI
# - OXFORD
# - QUEEN ELIZABETH
# - Son
# - WARWICK
# - YORK
#
# Obra: Henry V
# Personajes:
# - Boy
# - Chorus
# - GOWER
# - KING HENRY V
#
# Obra: Henry VIII
# Personajes:
# - Chamberlain
# - Chorus
# - KATHARINE
# - KING HENRY VIII
# - Second Gentleman
# - Surveyor
# - Third Gentleman
#
# Obra: King John
# Personajes:
# - BASTARD
#
# Obra: Richard II
# Personajes:
# - Abbot
# - DUCHESS OF YORK
# - GOWER
# - Gardener
# - Groom
# - HENRY BOLINGBROKE
# - KING RICHARD II
# - LORD FITZWATER
# - NORTHUMBERLAND
# - QUEEN
#
# Obra: Richard III
# Personajes:
# - ARCHBISHOP OF YORK
# - BUCKINGHAM
# - CHRISTOPHER
# - First Murderer
# - GLOUCESTER
# - HENRY BOLINGBROKE
# - QUEEN ELIZABETH
# - RIVERS
# - STANLEY
# - Third Citizen

# %%
# Consulta 5: Actos y Secuencias en donde aparece un personaje en Londres
character_name = "KING HENRY VI"
result = db.ShakespeareWorks.find({"$and": [{"text_entry": {"$regex": "London"}},
                                            {"speaker": character_name},
                                            {"type": "scene"}]},
                                  {"play_name": 1, "text_entry": 1, "_id": 0})
print("Consulta:")
for doc in result:
    pprint(doc)
# Out:
# Consulta:
# {'play_name': 'Henry VI Part 2',
#  'text_entry': 'SCENE II. London. YORKS garden.'}
# {'play_name': 'Henry VI Part 3', 'text_entry': 'SCENE II. London. The palace.'}
